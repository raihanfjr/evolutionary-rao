# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
import random
import operator
import pickle
from copy import deepcopy

# %%
df = pd.read_csv('flightlist-november.csv') 

print(df)
# Out:
#         callsign number  icao24 registration typecode origin destination  \
# 0        TUP6928    NaN  424450          NaN      NaN    NaN        UUWW
# 1         CSN399  CZ399  781795          NaN      NaN   YMML        KJFK
# 2         ETH714    NaN  040101       ET-ASG     B788   KEWR        ESSA
# 3          ZSALT    NaN  008142       ZS-ALT     B190    NaN        YPPH
# 4         IRM112  W5112  7335a1       EP-MMA     A343   WMKK        LTBW
# ...          ...    ...     ...          ...      ...    ...         ...
# 1825010   NKS236  NK236  ac97e1       N910NK      NaN    NaN        KFLL
# 1825011    AM333    NaN  7c6a57       VH-VAH     BE20   YMAV        YMEN
# 1825012   N404AM    NaN  a4bb89       N404AM     B407    NaN        1IL4
# 1825013   N383AK    NaN  a46679       N383AK      NaN   PAMR        PAMR
# 1825014   EJA426  1I426  a51358       N426QS     GLF4   KALN        KSUS
#
#                          firstseen                   lastseen  \
# 0        2020-10-31 01:29:44+00:00  2020-11-01 08:20:32+00:00
# 1        2020-10-31 01:36:33+00:00  2020-11-01 08:09:29+00:00
# 2        2020-10-31 02:07:17+00:00  2020-11-01 04:37:41+00:00
# 3        2020-10-31 03:33:19+00:00  2020-11-01 10:21:26+00:00
# 4        2020-10-31 03:58:50+00:00  2020-11-01 06:27:20+00:00
# ...                            ...                        ...
# 1825010  2020-11-30 23:36:31+00:00  2020-11-30 23:48:56+00:00
# 1825011  2020-11-30 23:36:47+00:00  2020-11-30 23:48:04+00:00
# 1825012  2020-11-30 23:37:40+00:00  2020-11-30 23:48:30+00:00
# 1825013  2020-11-30 23:37:41+00:00  2020-11-30 23:49:10+00:00
# 1825014  2020-11-30 23:38:09+00:00  2020-11-30 23:49:10+00:00
#
#                                day  latitude_1  longitude_1  altitude_1  \
# 0        2020-11-01 00:00:00+00:00   55.096390    83.177975      3962.4
# 1        2020-11-01 00:00:00+00:00  -37.679306   144.839776         0.0
# 2        2020-11-01 00:00:00+00:00   40.699677   -74.159973         0.0
# 3        2020-11-01 00:00:00+00:00    3.441971    99.149051      3962.4
# 4        2020-11-01 00:00:00+00:00    2.687073   101.735540       304.8
# ...                            ...         ...          ...         ...
# 1825010  2020-11-30 00:00:00+00:00   25.533949   -79.421669      3352.8
# 1825011  2020-11-30 00:00:00+00:00  -38.082275   144.500603       609.6
# 1825012  2020-11-30 00:00:00+00:00   38.586452   -90.448425         0.0
# 1825013  2020-11-30 00:00:00+00:00   61.202957  -149.835761       304.8
# 1825014  2020-11-30 00:00:00+00:00   38.893603   -90.052002       304.8
#
#          latitude_2  longitude_2  altitude_2
# 0         55.478723    37.030020      944.88
# 1         40.654999   -73.747314      -22.86
# 2         59.676710    17.968992      190.50
# 3        -31.957169   115.960199       91.44
# 4         41.183395    28.729309      533.40
# ...             ...          ...         ...
# 1825010   26.065292   -80.063125      396.24
# 1825011  -37.743298   144.901786      236.22
# 1825012   38.379501   -90.119973      518.16
# 1825013   61.213074  -149.846257      281.94
# 1825014   38.662844   -90.628601      137.16
#
# [1825015 rows x 16 columns]

# %%
dfs = df

# %%
dfs = dfs.drop(['number', 'icao24', 'altitude_1', 'altitude_2'], axis=1)

# %%
dfs = dfs.dropna(subset=['registration', 'typecode', 'origin', 'destination', 'latitude_2', 'longitude_2'])

# %%
dfs = dfs[dfs["callsign"].str[:3]=="SIA"]

# %%
dfs.head()
# Out:
#     callsign registration typecode origin destination  \
# 34    SIA377       9V-SMG     A359   LIMC        WSSS
# 161    SIA26       9V-SMI     A359   WSSS        EDDF
# 167   SIA324       9V-SMT     A359   WSSS        EHAM
# 171   SIA283       9V-SMD     A359   WSSS        NZAA
# 267   SIA346       9V-SMH     A359   WSSS        LSZH
#
#                      firstseen                   lastseen  \
# 34   2020-10-31 12:31:55+00:00  2020-11-01 00:48:28+00:00
# 161  2020-10-31 16:12:38+00:00  2020-11-01 04:36:47+00:00
# 167  2020-10-31 16:16:27+00:00  2020-11-01 04:55:17+00:00
# 171  2020-10-31 16:18:49+00:00  2020-11-01 01:19:01+00:00
# 267  2020-10-31 17:42:04+00:00  2020-11-01 06:16:57+00:00
#
#                            day  latitude_1  longitude_1  latitude_2  \
# 34   2020-11-01 00:00:00+00:00   45.623749     8.735337    1.308929
# 161  2020-11-01 00:00:00+00:00    1.395721   103.997048   50.040572
# 167  2020-11-01 00:00:00+00:00    1.389542   103.994720   52.357628
# 171  2020-11-01 00:00:00+00:00    1.394240   103.996298  -36.991241
# 267  2020-11-01 00:00:00+00:00    1.392471   103.996251   47.478653
#
#      longitude_2
# 34    103.960644
# 161     8.549163
# 167     4.711487
# 171   174.861496
# 267     8.540771

# %%
dfs.registration.unique()
# dfs.origin.unique()
# Out:
# array(['9V-SMG', '9V-SMI', '9V-SMT', '9V-SMD', '9V-SMH', '9V-SFN',
#        '9V-SMC', '9V-SFM', '9V-SMS', '9V-SFK', '9V-SML', '9V-SWQ',
#        '9V-MGL', '9V-SMF', '9V-SFQ', '9V-SWE', '9V-SFI', '9V-SMO',
#        '9V-SFP', '9V-SFO', '9V-SMQ', '9V-SMN', '9V-SMJ', '9V-SMM',
#        '9V-SMB', '9V-SMP', '9V-SMA', '9V-SWY', '9V-SWR', '9V-SCB',
#        '9V-SWP', '9V-SMK', '9V-MGI', '9V-SMR', '9V-SWM', '9V-SWH',
#        '9V-SWO', '9V-MGF', '9V-SWS', '9V-SKU', '9V-SME', '9V-SWK',
#        '9V-SWN'], dtype=object)

# %%
data = {'airport': [],
        'latitude': [],
        'longitude': []}

airports = pd.DataFrame(data)
print(airports)
# Out:
# Empty DataFrame
# Columns: [airport, latitude, longitude]
# Index: []

# %%
airports_data = dfs.origin.unique()
airports_another_data = dfs.destination.unique()

for i in airports_another_data:
    found = False
    for j in airports_data:
        if i == j:
            found = True
    if found == False:
        airports_data = np.append(airports_data, i)

# %%
print(airports_data)
# Out:
# ['LIMC' 'WSSS' 'OMSJ' 'EGLL' 'YSSY' 'YMML' 'NZAA' 'KORD' 'WBSB' 'VOMM'
#  'KDFW' 'EHAM' 'VHHH' 'EDDF' 'FAOR' 'YBBN' 'PANC' 'EBMB' 'WMKK' 'KLAX'
#  'LSZH' 'NZCH' 'VOBL' 'ZUCK' 'VABB' 'LFPG' 'EKCH' 'VIDP' 'FARA' 'EBBR'
#  'YPPH' 'LEBL' 'WSAC' 'VGZR' 'YSCB' 'RJAK' 'FAGM' 'LTBW' 'YTWB' 'YRED'
#  'TS53' 'YPWH' 'RJAA' 'LTBA' 'FABB' 'VGTJ' '6AK5' 'WIDD']

# %%
for i in airports_data:
    if (np.isnan(dfs[dfs["origin"]==i]["latitude_1"].median())):
        latitude = dfs[dfs["destination"]==i]["latitude_2"].median()
        longitude = dfs[dfs["destination"]==i]["longitude_2"].median()
        
    elif (np.isnan(dfs[dfs["destination"]==i]["latitude_2"].median())):
        latitude = dfs[dfs["origin"]==i]["latitude_1"].median()
        longitude = dfs[dfs["origin"]==i]["longitude_1"].median()
        
    else:
        latitude = (dfs[dfs["origin"]==i]["latitude_1"].median() + dfs[dfs["destination"]==i]["latitude_2"].median())/2
        longitude = (dfs[dfs["origin"]==i]["longitude_1"].median() + dfs[dfs["destination"]==i]["longitude_2"].median())/2
        
    airport = {'airport': i, 'latitude': latitude, 'longitude': longitude}
    airports = airports.append(airport, ignore_index=True)

print(airports)
# Out:
#    airport   latitude   longitude
# 0     LIMC  45.622997    8.729880
# 1     WSSS   1.349354  103.991831
# 2     OMSJ  25.333187   55.513881
# 3     EGLL  51.464928   -0.451351
# 4     YSSY -33.937398  151.173686
# 5     YMML -37.659397  144.836085
# 6     NZAA -37.007307  174.802684
# 7     KORD  41.967407  -87.905482
# 8     WBSB   4.943314  114.927863
# 9     VOMM  12.988395   80.164536
# 10    KDFW  32.904827  -97.050797
# 11    EHAM  52.329506    4.733640
# 12    VHHH  22.306459  113.907723
# 13    EDDF  50.045047    8.569396
# 14    FAOR -26.110302   28.248013
# 15    YBBN -27.383320  153.122108
# 16    PANC  61.179126 -150.017751
# 17    EBMB  50.909637    4.492666
# 18    WMKK   2.714566  101.717297
# 19    KLAX  33.936884 -118.397799
# 20    LSZH  47.467043    8.551562
# 21    NZCH -43.486825  172.534596
# 22    VOBL  13.189594   77.703107
# 23    ZUCK  29.778076  106.693145
# 24    VABB  19.088734   72.868544
# 25    LFPG  48.996591    2.563600
# 26    EKCH  55.612789   12.641687
# 27    VIDP  28.559853   77.113512
# 28    FARA -26.040070   28.290002
# 29    EBBR  50.899951    4.490988
# 30    YPPH -31.945056  115.963682
# 31    LEBL  41.243946    2.255799
# 32    WSAC   1.355883  104.011877
# 33    VGZR  23.810166   90.425202
# 34    YSCB -35.311934  149.194422
# 35    RJAK  35.937350  140.290852
# 36    FAGM -26.213150   28.215637
# 37    LTBW  41.195649   28.718870
# 38    YTWB -27.684998  151.934181
# 39    YRED -27.252937  153.181211
# 40    TS53  32.915543  -97.089313
# 41    YPWH -27.861511  151.637239
# 42    RJAA  35.736291  140.589996
# 43    LTBA  40.966736   28.866821
# 44    FABB -26.219757   28.231166
# 45    VGTJ  23.776183   90.456244
# 46    6AK5  61.167709 -150.083738
# 47    WIDD   1.111854  104.047252

# %%
e_asia = ["VOMM", "VHHH", "VOBL", "ZUCK", "VABB", "VIDP", "VGZR", "RJAK", "RJAA", "VGTJ"]
americas = ["KORD", "KDFW", "PANC", "KLAX", "TS53", "6AK5"]
europe = ["LIMC", "EGLL", "EHAM", "EDDF", "EBMB", "LSZH", "LFPG", "EKCH", "FARA", "EBBR", "LEBL"]
sw_pasific = ["WSSS", "YSSY", "YMML", "NZAA", "WBSB", "YBBN", "WMKK", "NZCH", "YPPH", "WSAC", "YSCB", "YTWB", "YRED", "YPWH", "WIDD"]
w_asia_africa = ["OMSJ", "FAOR", "FAGM", "LTBW", "LTBA", "FABB"]

# %%
region = []
load_rate = []
for i in range(len(airports)):
    for j in range(len(e_asia)):
        if(airports["airport"].iloc[i]==e_asia[j]):
            region.append("East Asia")
            load_rate.append(0.128)
            break
    for k in range(len(americas)):
        if(airports["airport"].iloc[i]==americas[k]):
            region.append("Americas")
            load_rate.append(0.113)
            break
    for l in range(len(europe)):
        if(airports["airport"].iloc[i]==europe[l]):
            region.append("Europe")
            load_rate.append(0.133)
            break
    for m in range(len(sw_pasific)):
        if(airports["airport"].iloc[i]==sw_pasific[m]):
            region.append("South West Pacific")
            load_rate.append(0.171)
            break
    for n in range(len(w_asia_africa)):
        if(airports["airport"].iloc[i]==w_asia_africa[n]):
            region.append("West Asia and Africa")
            load_rate.append(0.140)
            break
            
print(region)
# Out:
# ['Europe', 'South West Pacific', 'West Asia and Africa', 'Europe', 'South West Pacific', 'South West Pacific', 'South West Pacific', 'Americas', 'South West Pacific', 'East Asia', 'Americas', 'Europe', 'East Asia', 'Europe', 'West Asia and Africa', 'South West Pacific', 'Americas', 'Europe', 'South West Pacific', 'Americas', 'Europe', 'South West Pacific', 'East Asia', 'East Asia', 'East Asia', 'Europe', 'Europe', 'East Asia', 'Europe', 'Europe', 'South West Pacific', 'Europe', 'South West Pacific', 'East Asia', 'South West Pacific', 'East Asia', 'West Asia and Africa', 'West Asia and Africa', 'South West Pacific', 'South West Pacific', 'Americas', 'South West Pacific', 'East Asia', 'West Asia and Africa', 'West Asia and Africa', 'East Asia', 'Americas', 'South West Pacific']

# %%
airports['region'] = region
airports['load_rate'] = load_rate
print(airports)
# Out:
#    airport   latitude   longitude                region  load_rate
# 0     LIMC  45.622997    8.729880                Europe      0.133
# 1     WSSS   1.349354  103.991831    South West Pacific      0.171
# 2     OMSJ  25.333187   55.513881  West Asia and Africa      0.140
# 3     EGLL  51.464928   -0.451351                Europe      0.133
# 4     YSSY -33.937398  151.173686    South West Pacific      0.171
# 5     YMML -37.659397  144.836085    South West Pacific      0.171
# 6     NZAA -37.007307  174.802684    South West Pacific      0.171
# 7     KORD  41.967407  -87.905482              Americas      0.113
# 8     WBSB   4.943314  114.927863    South West Pacific      0.171
# 9     VOMM  12.988395   80.164536             East Asia      0.128
# 10    KDFW  32.904827  -97.050797              Americas      0.113
# 11    EHAM  52.329506    4.733640                Europe      0.133
# 12    VHHH  22.306459  113.907723             East Asia      0.128
# 13    EDDF  50.045047    8.569396                Europe      0.133
# 14    FAOR -26.110302   28.248013  West Asia and Africa      0.140
# 15    YBBN -27.383320  153.122108    South West Pacific      0.171
# 16    PANC  61.179126 -150.017751              Americas      0.113
# 17    EBMB  50.909637    4.492666                Europe      0.133
# 18    WMKK   2.714566  101.717297    South West Pacific      0.171
# 19    KLAX  33.936884 -118.397799              Americas      0.113
# 20    LSZH  47.467043    8.551562                Europe      0.133
# 21    NZCH -43.486825  172.534596    South West Pacific      0.171
# 22    VOBL  13.189594   77.703107             East Asia      0.128
# 23    ZUCK  29.778076  106.693145             East Asia      0.128
# 24    VABB  19.088734   72.868544             East Asia      0.128
# 25    LFPG  48.996591    2.563600                Europe      0.133
# 26    EKCH  55.612789   12.641687                Europe      0.133
# 27    VIDP  28.559853   77.113512             East Asia      0.128
# 28    FARA -26.040070   28.290002                Europe      0.133
# 29    EBBR  50.899951    4.490988                Europe      0.133
# 30    YPPH -31.945056  115.963682    South West Pacific      0.171
# 31    LEBL  41.243946    2.255799                Europe      0.133
# 32    WSAC   1.355883  104.011877    South West Pacific      0.171
# 33    VGZR  23.810166   90.425202             East Asia      0.128
# 34    YSCB -35.311934  149.194422    South West Pacific      0.171
# 35    RJAK  35.937350  140.290852             East Asia      0.128
# 36    FAGM -26.213150   28.215637  West Asia and Africa      0.140
# 37    LTBW  41.195649   28.718870  West Asia and Africa      0.140
# 38    YTWB -27.684998  151.934181    South West Pacific      0.171
# 39    YRED -27.252937  153.181211    South West Pacific      0.171
# 40    TS53  32.915543  -97.089313              Americas      0.113
# 41    YPWH -27.861511  151.637239    South West Pacific      0.171
# 42    RJAA  35.736291  140.589996             East Asia      0.128
# 43    LTBA  40.966736   28.866821  West Asia and Africa      0.140
# 44    FABB -26.219757   28.231166  West Asia and Africa      0.140
# 45    VGTJ  23.776183   90.456244             East Asia      0.128
# 46    6AK5  61.167709 -150.083738              Americas      0.113
# 47    WIDD   1.111854  104.047252    South West Pacific      0.171

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(lat1, lon1, lat2, lon2):

      R = 6378.1 #earth radius in km

      dLat = radians(lat2 - lat1)
      dLon = radians(lon2 - lon1)
      lat1 = radians(lat1)
      lat2 = radians(lat2)

      a = sin(dLat/2)**2 + cos(lat1)*cos(lat2)*sin(dLon/2)**2
      c = 2*asin(sqrt(a))

      return R * c

# %%
airport_dist = []

# print(len(airports))
# print(airports["latitude"].iloc[1])
for i in range(len(airports)):
    row = []
    for j in range(len(airports)):
        dist = haversine(airports["latitude"].iloc[i], airports["longitude"].iloc[i], airports["latitude"].iloc[j], airports["longitude"].iloc[j])
        row.append(dist)
    airport_dist.append(row)
    
print(airport_dist)
# Out:
# [[0.0, 10320.430258215578, 4717.841781312695, 937.1660268519785, 16609.560128529316, 16328.954466590929, 18532.59680591183, 7269.067818856925, 10868.089507810684, 7548.95074633125, 8547.656137571441, 801.3169185796232, 9367.722728633229, 492.40317589072635, 8226.20896899483, 16305.37145127493, 7994.969157835845, 666.7552359065804, 10035.00646673157, 9707.300556374426, 205.7303869886589, 18733.26757149964, 7342.358008596109, 8269.138067898637, 6515.603799301376, 597.7053144643955, 1145.392331724757, 6165.855188281992, 8219.648382286154, 665.8771017492281, 13763.71195323607, 714.7633108335267, 10321.464585191243, 7525.8491042544, 16538.803322184736, 9739.086961262197, 8236.528918768698, 1684.8073009086406, 16240.840339895418, 16299.853550010886, 8549.282279244859, 16231.958278267468, 9772.276447147076, 1706.5289191728648, 8237.618885773374, 7530.724450895547, 7997.137643355394, 10343.682712043537], [10320.430258215578, 0.0, 5841.7632385838115, 10894.76051264912, 6299.836779033911, 6038.438896550015, 8418.73633260409, 15068.744588255582, 1279.5010057485506, 2928.8002861878294, 15629.793631547207, 10527.265421668828, 2568.044722254665, 10290.596335412143, 8664.6708760633, 6150.109163748203, 10735.388681880311, 10566.321673598291, 295.1642203208813, 14118.598208005285, 10316.7968215347, 8412.83732523417, 3182.78032127795, 3177.546517831396, 3925.97264061222, 10735.785552170339, 9979.602726518628, 4162.711379891772, 8659.473513963996, 10566.592870740193, 3915.4931135500406, 10897.657772001752, 2.346255818210745, 2896.810574720782, 6218.429548740631, 5368.625060503927, 8669.39451207522, 8690.481931602231, 6056.067552693563, 6149.820325551374, 15626.779809616955, 6037.478416658099, 5376.563159517929, 8674.304631877993, 8667.954912411142, 2891.9234600277327, 10732.28529348282, 27.14817244047462], [4717.841781312695, 5841.7632385838115, 0.0, 5506.8618381394035, 12048.0465062446, 11649.800806282066, 14208.311769009377, 11653.51701532367, 6715.45708634375, 2925.7975035142226, 12931.98577783635, 5180.021024368576, 5909.281941024525, 4852.729801807736, 6432.468071091534, 11982.514029612448, 10135.328939956715, 5156.62005286444, 5546.606912613255, 13408.178593563865, 4777.860433835961, 14062.502015456803, 2688.7369433071267, 5034.7179282817, 1916.72379593414, 5247.629826986142, 4825.292960299169, 2170.1861289891613, 6423.595415009144, 5156.478901784671, 9046.378059979404, 5173.872130678893, 5843.287759886152, 3528.5121745318047, 11926.469286105654, 7956.359633934239, 6444.0353642012615, 3035.1468561185375, 11883.945104798386, 11983.058602550253, 12932.598121808254, 11863.338303540371, 7989.047891226768, 3012.486651697701, 6443.917975772616, 3532.2906358651935, 10135.1174669785, 5860.8374465065635], [937.1660268519785, 10894.76051264912, 5506.8618381394035, 0.0, 17038.360971755203, 16925.68607274427, 18384.972264798915, 6352.641899767896, 11294.007238315664, 8243.215397150638, 7636.805148062444, 368.84994843109445, 9641.050469242773, 654.1805012689989, 9081.354186250748, 16561.734354164048, 7209.1891097368825, 350.37749834459356, 10619.936469989312, 8770.375175195673, 787.9736159669434, 19005.39943512223, 8055.302858017427, 8544.453182630268, 7220.381364726168, 348.63996871279, 979.3847603022281, 6739.414795785145, 9075.17333846972, 350.48964845255233, 14523.847910406084, 1156.4275864777765, 10895.54267726216, 8027.9995280294925, 17029.349580281367, 9581.330257766034, 9091.289961308832, 2493.8459120463403, 16526.18991716695, 16552.579821679705, 7638.30620788436, 16526.313289986098, 9612.535110199567, 2519.1781225173677, 9092.459574789265, 8032.929097669114, 7211.614576108594, 10919.484974283207], [16609.560128529316, 6299.836779033911, 12048.0465062446, 17038.360971755203, 0.0, 706.1771528962224, 2163.4923737566182, 14878.267636807592, 5765.535532732732, 9138.29299935174, 13822.743285185885, 16677.203955988603, 7401.315329951462, 16513.708884399803, 11038.639144083883, 753.0182097296351, 11842.042921354594, 16754.7976630837, 6588.55598012932, ...

# %%
dfs['day'].value_counts()
# Out:
# 2020-11-28 00:00:00+00:00    40
# 2020-11-25 00:00:00+00:00    38
# 2020-11-15 00:00:00+00:00    38
# 2020-11-18 00:00:00+00:00    37
# 2020-11-29 00:00:00+00:00    37
# 2020-11-16 00:00:00+00:00    37
# 2020-11-21 00:00:00+00:00    37
# 2020-11-22 00:00:00+00:00    37
# 2020-11-20 00:00:00+00:00    36
# 2020-11-23 00:00:00+00:00    36
# 2020-11-09 00:00:00+00:00    35
# 2020-11-14 00:00:00+00:00    35
# 2020-11-04 00:00:00+00:00    35
# 2020-11-11 00:00:00+00:00    34
# 2020-11-30 00:00:00+00:00    34
# 2020-11-19 00:00:00+00:00    34
# 2020-11-01 00:00:00+00:00    34
# 2020-11-13 00:00:00+00:00    34
# 2020-11-26 00:00:00+00:00    33
# 2020-11-07 00:00:00+00:00    33
# 2020-11-27 00:00:00+00:00    33
# 2020-11-08 00:00:00+00:00    33
# 2020-11-02 00:00:00+00:00    33
# 2020-11-12 00:00:00+00:00    32
# 2020-11-05 00:00:00+00:00    32
# 2020-11-06 00:00:00+00:00    32
# 2020-11-17 00:00:00+00:00    30
# 2020-11-10 00:00:00+00:00    28
# 2020-11-03 00:00:00+00:00    27
# 2020-11-24 00:00:00+00:00    26
# Name: day, dtype: int64

# %%
# dfs[dfs["day"].isin({day, day_after})]

# %%
day = "2020-11-21 00:00:00+00:00"
# day_after = "2020-11-30 00:00:00+00:00"
day_after = "2020-11-30 00:00:00+00:00"
day_before = "2020-11-20 00:00:00+00:00"
# dfx = dfs[dfs["day"]==day]
# dfx = dfs[dfs["day"].isin({day, day_after})]
# dfx = dfs[dfs["day"].isin({day, day_after})]
dfx = dfs[(dfs["day"] >= day) & (dfs["day"] <= day_after)]
dfy = dfs[dfs["day"]<day]

# %%
print(dfx)
# Out:
#         callsign registration typecode origin destination  \
# 1208410   SIA322       9V-SMQ     A359   WSSS        EGLL
# 1208521   SIA324       9V-SMM     A359   WSSS        EHAM
# 1208877    SIA26       9V-SMB     A359   WSSS        EDDF
# 1211170   SIA352       9V-SMN     A359   WSSS        EKCH
# 1215881   SIA478       9V-SMA     A359   WSSS        FABB
# ...          ...          ...      ...    ...         ...
# 1796785  SIA7343       9V-SFI     B744   EHAM        OMSJ
# 1797786   SIA282       9V-SMO     A359   NZAA        WSSS
# 1799511   SIA288       9V-SMF     A359   YBBN        WIDD
# 1803996  SIA7970       9V-SFM     B744   PANC        KORD
# 1807100  SIA7872       9V-SFP     B744   WSSS        VHHH
#
#                          firstseen                   lastseen  \
# 1208410  2020-11-20 16:06:59+00:00  2020-11-21 05:40:59+00:00
# 1208521  2020-11-20 16:08:35+00:00  2020-11-21 05:29:37+00:00
# 1208877  2020-11-20 16:13:20+00:00  2020-11-21 05:09:18+00:00
# 1211170  2020-11-20 16:44:59+00:00  2020-11-21 05:14:59+00:00
# 1215881  2020-11-20 17:48:48+00:00  2020-11-21 03:40:12+00:00
# ...                            ...                        ...
# 1796785  2020-11-30 12:08:02+00:00  2020-11-30 18:42:41+00:00
# 1797786  2020-11-30 12:32:08+00:00  2020-11-30 22:38:39+00:00
# 1799511  2020-11-30 13:16:04+00:00  2020-11-30 20:29:56+00:00
# 1803996  2020-11-30 14:53:03+00:00  2020-11-30 20:05:29+00:00
# 1807100  2020-11-30 15:55:15+00:00  2020-11-30 19:05:20+00:00
#
#                                day  latitude_1  longitude_1  latitude_2  \
# 1208410  2020-11-21 00:00:00+00:00    1.376782   104.004680   51.477676
# 1208521  2020-11-21 00:00:00+00:00    1.373151   104.003543   52.366985
# 1208877  2020-11-21 00:00:00+00:00    1.369567   104.002407   50.030225
# 1211170  2020-11-21 00:00:00+00:00    1.371429   104.002691   55.628155
# 1215881  2020-11-21 00:00:00+00:00    1.369939   104.001980  -26.219757
# ...                            ...         ...          ...         ...
# 1796785  2020-11-30 00:00:00+00:00   52.301193     4.768753   25.313690
# 1797786  2020-11-30 00:00:00+00:00  -37.021645   174.752595    1.319663
# 1799511  2020-11-30 00:00:00+00:00  -27.382864   153.129607    1.111854
# 1803996  2020-11-30 00:00:00+00:00   61.192886  -150.010757   41.965772
# 1807100  2020-11-30 00:00:00+00:00    1.379017   104.005106   22.297265
#
#          longitude_2
# 1208410    -0.446357
# 1208521     4.712350
# 1208877     8.541035
# 1211170    12.671700
# 1215881    28.231166
# ...              ...
# 1796785    55.547740
# 1797786   103.981144
# 1799511   104.047252
# 1803996   -87.911256
# 1807100   113.901316
#
# [351 rows x 12 columns]

# %%
data = {'airplane': [],
        'type': [],
        'curr_loc': [],
        'last_seen': [],
        'capacity': [],
        'fixed_cost': [],
        'min_cost': [],
        'idle_cost': []}

airplanes = pd.DataFrame(data)
print(airplanes)
# Out:
# Empty DataFrame
# Columns: [airplane, type, curr_loc, last_seen, capacity, fixed_cost, min_cost, idle_cost]
# Index: []

# %%
airplanes_data = dfs.registration.unique()
print(airplanes_data)
# Out:
# ['9V-SMG' '9V-SMI' '9V-SMT' '9V-SMD' '9V-SMH' '9V-SFN' '9V-SMC' '9V-SFM'
#  '9V-SMS' '9V-SFK' '9V-SML' '9V-SWQ' '9V-MGL' '9V-SMF' '9V-SFQ' '9V-SWE'
#  '9V-SFI' '9V-SMO' '9V-SFP' '9V-SFO' '9V-SMQ' '9V-SMN' '9V-SMJ' '9V-SMM'
#  '9V-SMB' '9V-SMP' '9V-SMA' '9V-SWY' '9V-SWR' '9V-SCB' '9V-SWP' '9V-SMK'
#  '9V-MGI' '9V-SMR' '9V-SWM' '9V-SWH' '9V-SWO' '9V-MGF' '9V-SWS' '9V-SKU'
#  '9V-SME' '9V-SWK' '9V-SWN']

# %%
airplanes_capacity = []
airplanes_fixedcost = []
airplanes_idlecost = []
airplanes_minutecost = []

for i in range(len(airplanes_data)):
    for j in range(len(dfs)):
        if(dfs["registration"].iloc[j]==airplanes_data[i]):
            if(dfs["typecode"].iloc[j]=="A359"):
                capacity = 350
                min_cost = 244
                fixed_cost = 946069
                idle_min_cost = 195
            elif(dfs["typecode"].iloc[j]=="B744"):
                capacity = 416
                min_cost = 321
                fixed_cost = 851244
                idle_min_cost = 257
            elif(dfs["typecode"].iloc[j]=="B77W"):
                capacity = 264
                min_cost = 194
                fixed_cost = 969244
                idle_min_cost = 155
            elif(dfs["typecode"].iloc[j]=="B738"):
                capacity = 215
                min_cost = 116
                fixed_cost = 732745
                idle_min_cost = 92
            elif(dfs["typecode"].iloc[j]=="B78X"):
                capacity = 337
                min_cost = 187
                fixed_cost = 1001250
                idle_min_cost = 150
            elif(dfs["typecode"].iloc[j]=="A388"):
                capacity = 471
                min_cost = 433
                fixed_cost = 638418
                idle_min_cost = 347
            airplanes_capacity.append(int(capacity))
            airplanes_fixedcost.append(int(fixed_cost))
            airplanes_idlecost.append(int(idle_min_cost))
            airplanes_minutecost.append(int(min_cost))
            break

print(airplanes_capacity)
# Out:
# [350, 350, 350, 350, 350, 416, 350, 416, 350, 416, 350, 264, 215, 350, 416, 264, 416, 350, 416, 416, 350, 350, 350, 350, 350, 350, 350, 264, 264, 337, 264, 350, 215, 350, 264, 264, 264, 215, 264, 471, 350, 264, 264]

# %%
no_airplane = 0
for i in airplanes_data:
    for j in range(len(dfx)):
        if(dfx["registration"].iloc[j]==i):
            airplane = {'airplane': i,
                        'type': dfx["typecode"].iloc[j],
                        'curr_loc': dfx["origin"].iloc[j],
                        'last_seen': dfx["firstseen"].iloc[j],
                        'capacity': airplanes_capacity[no_airplane],
                        'fixed_cost': airplanes_fixedcost[no_airplane],
                        'min_cost': airplanes_minutecost[no_airplane],
                        'idle_cost': airplanes_idlecost[no_airplane]}
            
            airplanes = airplanes.append(airplane, ignore_index=True)
            break
        elif((j==(len(dfx)-1)) and (dfx["registration"].iloc[j]!=i)):
            for k in range(len(dfy)):
                if((k!=0) and (dfy["registration"].iloc[-k]==i)):
                    airplane = {'airplane': i,
                                'type': dfy["typecode"].iloc[-k],
                                'curr_loc': dfy["destination"].iloc[-k],
                                'last_seen': dfy["firstseen"].iloc[-k],
                                'capacity': airplanes_capacity[no_airplane],
                                'fixed_cost': airplanes_fixedcost[no_airplane],
                                'min_cost': airplanes_minutecost[no_airplane],
                                'idle_cost': airplanes_idlecost[no_airplane]}
                    
                    airplanes = airplanes.append(airplane, ignore_index=True)
                    break
                elif((k==(len(dfy)-1)) and (dfy["registration"].iloc[-k]!=i)):
                    for l in range(len(dfs)):
                        if((l!=0) and (dfs["registration"].iloc[-l]==i)):
                            airplane = {'airplane': i,
                                        'type': dfs["typecode"].iloc[-l],
                                        'curr_loc': "WSSS",
                                        'last_seen': day_before,
                                        'capacity': airplanes_capacity[no_airplane],
                                        'fixed_cost': airplanes_fixedcost[no_airplane],
                                        'min_cost': airplanes_minutecost[no_airplane],
                                        'idle_cost': airplanes_idlecost[no_airplane]}
                            airplanes = airplanes.append(airplane, ignore_index=True)
                            break
                            
    no_airplane = no_airplane + 1
    
print(airplanes)
# Out:
#    airplane  type curr_loc                  last_seen  capacity  fixed_cost  \
# 0    9V-SMG  A359     LSZH  2020-11-21 13:12:36+00:00     350.0    946069.0
# 1    9V-SMI  A359     WSSS  2020-11-20 17:54:12+00:00     350.0    946069.0
# 2    9V-SMT  A359     WSSS  2020-11-22 02:15:05+00:00     350.0    946069.0
# 3    9V-SMD  A359     NZCH  2020-11-20 22:51:25+00:00     350.0    946069.0
# 4    9V-SMH  A359     LFPG  2020-11-21 10:03:18+00:00     350.0    946069.0
# 5    9V-SFN  B744     WSSS  2020-11-21 03:07:03+00:00     416.0    851244.0
# 6    9V-SMC  A359     WSSS  2020-11-23 00:43:50+00:00     350.0    946069.0
# 7    9V-SFM  B744     WSSS  2020-11-20 22:21:21+00:00     416.0    851244.0
# 8    9V-SMS  A359     WSSS  2020-11-21 16:05:15+00:00     350.0    946069.0
# 9    9V-SFK  B744     WSSS  2020-11-22 06:01:20+00:00     416.0    851244.0
# 10   9V-SML  A359     WSSS  2020-11-21 01:12:22+00:00     350.0    946069.0
# 11   9V-SWQ  B77W     WSSS  2020-11-29 12:43:28+00:00     264.0    969244.0
# 12   9V-MGL  B738     WSSS  2020-11-29 00:52:06+00:00     215.0    732745.0
# 13   9V-SMF  A359     LEBL  2020-11-21 09:57:44+00:00     350.0    946069.0
# 14   9V-SFQ  B744     KLAX  2020-11-20 20:56:06+00:00     416.0    851244.0
# 15   9V-SWE  B77W     WSSS  2020-11-28 23:31:42+00:00     264.0    969244.0
# 16   9V-SFI  B744     EBMB  2020-11-20 19:32:05+00:00     416.0    851244.0
# 17   9V-SMO  A359     WSSS  2020-11-21 16:11:06+00:00     350.0    946069.0
# 18   9V-SFP  B744     WSSS  2020-11-20 18:54:04+00:00     416.0    851244.0
# 19   9V-SFO  B744     WSSS  2020-11-21 02:30:04+00:00     416.0    851244.0
# 20   9V-SMQ  A359     WSSS  2020-11-20 16:06:59+00:00     350.0    946069.0
# 21   9V-SMN  A359     WSSS  2020-11-20 16:44:59+00:00     350.0    946069.0
# 22   9V-SMJ  A359     WSSS  2020-11-21 16:26:10+00:00     350.0    946069.0
# 23   9V-SMM  A359     WSSS  2020-11-20 16:08:35+00:00     350.0    946069.0
# 24   9V-SMB  A359     WSSS  2020-11-20 16:13:20+00:00     350.0    946069.0
# 25   9V-SMP  A359     EGLL  2020-11-20 20:31:38+00:00     350.0    946069.0
# 26   9V-SMA  A359     WSSS  2020-11-20 17:48:48+00:00     350.0    946069.0
# 27   9V-SWY  B77W     WSSS  2020-11-22 18:13:24+00:00     264.0    969244.0
# 28   9V-SWR  B77W     WSSS  2020-11-21 17:54:28+00:00     264.0    969244.0
# 29   9V-SCB  B78X     WSSS  2020-11-21 12:28:41+00:00     337.0   1001250.0
# 30   9V-SWP  B77W     WSSS  2020-11-28 12:48:35+00:00     264.0    969244.0
# 31   9V-SMK  A359     NZAA  2020-11-21 07:25:25+00:00     350.0    946069.0
# 32   9V-MGI  B738     WSSS  2020-11-15 04:06:48+00:00     215.0    732745.0
# 33   9V-SMR  A359     EKCH  2020-11-21 11:32:34+00:00     350.0    946069.0
# 34   9V-SWM  B77W     RJAA  2020-11-19 01:29:20+00:00     264.0    969244.0
# 35   9V-SWH  B77W     WSSS  2020-11-20 17:57:55+00:00     264.0    969244.0
# 36   9V-SWO  B77W     WSSS  2020-11-21 12:55:20+00:00     264.0    969244.0
# 37   9V-MGF  B738     WSSS  2020-11-22 00:59:12+00:00     215.0    732745.0
# 38   9V-SWS  B77W     WSSS  2020-11-23 06:12:24+00:00     264.0    969244.0
# 39   9V-SKU  A388     WSAC  2020-11-27 02:41:51+00:00     471.0    638418.0
# 40   9V-SME  A359     WSSS  2020-11-28 01:34:55+00:00     350.0    946069.0
# 41   9V-SWK  B77W     WSAC  2020-11-30 08:43:15+00:00     264.0    969244.0
# 42   9V-SWN  B77W     RJAK  2020-11-30 11:06:03+00:00     264.0    969244.0
#
#     min_cost  idle_cost
# 0      244.0      195.0
# 1      244.0      195.0
# 2      244.0      195.0
# 3      244.0      195.0
# 4      244.0      195.0
# 5      321.0      257.0
# 6      244.0      195.0
# 7      321.0      257.0
# 8      244.0      195.0
# 9      321.0      257.0
# 10     244.0      195.0
# 11     194.0      155.0
# 12     116.0       92.0
# 13     244.0      195.0
# 14     321.0      257.0
# 15     194.0      155.0
# 16     321.0      257.0
# 17     244.0      195.0
# 18     321.0      257.0
# 19     321.0      257.0
# 20     244.0      195.0
# 21     244.0      195.0
# 22     244.0      195.0
# 23     244.0      195.0
# 24     244.0      195.0
# 25     244.0      195.0
# 26     244.0      195.0
# 27     194.0      155.0
# 28     194.0      155.0
# 29     187.0      150.0
# 30     194.0      155.0
# 31     244.0      195.0
# 32     116.0       92.0
# 33     244.0      195.0
# 34     194.0      155.0
# 35     194.0      155.0
# 36     194.0      155.0
# 37     116.0       92.0
# 38     194.0      155.0
# 39     433.0      347.0
# 40     244.0      195.0
# 41     194.0      155.0
# 42     194.0      155.0

# %%
max_delay = 180 #minute
min_safe = 30 #minute
max_arrival = max_delay - min_safe

def createSchedule():
    created = False
    while(created==False):
        airplanes_temp = airplanes.copy()
        schedule = []
        wakeup = time.time() + 10
        for i in range(len(dfx)):
            flight = [i]

            found = False
            while (found == False):
                id_airplane = random.randint(0, len(airplanes)-1)
                if (pd.to_datetime(airplanes_temp["last_seen"].iloc[id_airplane]) < (pd.to_datetime(dfx["firstseen"].iloc[i])+ datetime.timedelta(minutes=max_arrival)) and airplanes_temp["curr_loc"].iloc[id_airplane]==dfx["origin"].iloc[i]):
                    found = True
                else:
                    if (time.time() > wakeup):
                        break       

            airplanes_temp["curr_loc"].iloc[id_airplane]=dfx["destination"].iloc[i]

            if (pd.to_datetime(airplanes_temp["last_seen"].iloc[id_airplane]) < (pd.to_datetime(dfx["firstseen"].iloc[i]) - datetime.timedelta(minutes=min_safe))):
                departure = pd.to_datetime(dfx["firstseen"].iloc[i])
                arrival = departure + (pd.to_datetime(dfx["lastseen"].iloc[i])-pd.to_datetime(dfx["firstseen"].iloc[i]))
                airplanes_temp["last_seen"].iloc[id_airplane]=arrival
            else:
                departure = pd.to_datetime(airplanes_temp["last_seen"].iloc[id_airplane]) + datetime.timedelta(minutes=min_safe)
                arrival = departure + (pd.to_datetime(dfx["lastseen"].iloc[i])-pd.to_datetime(dfx["firstseen"].iloc[i]))
                airplanes_temp["last_seen"].iloc[id_airplane]=arrival

            for j in range(len(airports)):
                if(airports["airport"].iloc[j]==dfx["destination"].iloc[i]):
                    load_rate = airports["load_rate"].iloc[j]
                    break     

            passenger = round(airplanes_temp["capacity"].iloc[id_airplane] * load_rate)

            flight.extend([id_airplane, departure, arrival, passenger, load_rate])
            schedule.append(flight)
        if(len(dfx)==len(schedule)):
            created = True
    
    return schedule

# %%
def createOriginalSchedule():
    schedule = []
    for i in range(len(dfx)):
        flight=[i]
        for j in range(len(airplanes)):
            if(airplanes["airplane"].iloc[j]==dfx["registration"].iloc[i]):
                break
        flight.append(j)
        flight.append(pd.to_datetime(dfx["firstseen"].iloc[i]))
        flight.append(pd.to_datetime(dfx["lastseen"].iloc[i]))
        for k in range(len(airports)):
            if(airports["airport"].iloc[k]==dfx["destination"].iloc[i]):
                break
        flight.append(round(airplanes["capacity"].iloc[j] * airports["load_rate"].iloc[k]))
        flight.append(airports["load_rate"].iloc[k])
        
        schedule.append(flight)
        
    return schedule

# %%
# normalisasi passengger & cost
# cost = fixed cost & minute cost
def countOriginalFitness(schedule):
    fitness = []
    cost = 0
    passenger = 0
    plane_count = 0
    for i in range(len(schedule)):
        if(airplanes["type"].iloc[schedule[i][1]]=="A359"):
            min_cost = 244
        elif(airplanes["type"].iloc[schedule[i][1]]=="B744"):
            min_cost = 321
        elif(airplanes["type"].iloc[schedule[i][1]]=="B77W"):
            min_cost = 194
        elif(airplanes["type"].iloc[schedule[i][1]]=="B738"):
            min_cost = 116
        elif(airplanes["type"].iloc[schedule[i][1]]=="B78X"):
            min_cost = 187
        elif(airplanes["type"].iloc[schedule[i][1]]=="A388"):
            min_cost = 433
        cost = cost + round((schedule[i][3]-schedule[i][2]).seconds/60)*min_cost
        passenger = passenger + schedule[i][4]
        
        for k in range(len(airports)):
            if(airports["airport"].iloc[k]==dfx["origin"].iloc[i]):
                origin_id = k
            if(airports["airport"].iloc[k]==dfx["destination"].iloc[i]):
                destination_id = k
        
        cost = cost + airport_dist[origin_id][destination_id]
        
    for j in range(len(airplanes)):
        plane_used = False
        idle_sec = 0
        fixed_cost = 0
        first_flight = pd.to_datetime(airplanes["last_seen"].iloc[j])
        last_flight = pd.to_datetime(dfx["lastseen"].iloc[len(dfx)-1])
        
        for k in range(len(schedule)):
            if(schedule[k][1]==j):
                if(plane_used==False):
                    plane_used = True
                    plane_count = plane_count + 1
                    lastflight_pos = k
                    idle_sec = idle_sec + (schedule[k][2] - first_flight).seconds
                else:
                    idle_sec = idle_sec + (schedule[k][2] - schedule[lastflight_pos][2]).seconds
                    lastflight_pos = k
                    
        if(plane_used==False):
            idle_sec = idle_sec + (last_flight - first_flight).seconds
            fixed_cost = 0
        else:
            idle_sec = idle_sec + (last_flight - schedule[lastflight_pos][3]).seconds
            if(airplanes["type"].iloc[j]=="A359"):
                fixed_cost = 946069
            elif(airplanes["type"].iloc[j]=="B744"):
                fixed_cost = 851244
            elif(airplanes["type"].iloc[j]=="B77W"):
                fixed_cost = 969244
            elif(airplanes["type"].iloc[j]=="B738"):
                fixed_cost = 732745
            elif(airplanes["type"].iloc[j]=="B78X"):
                fixed_cost = 1001250
            elif(airplanes["type"].iloc[j]=="A388"):
                fixed_cost = 638418
        
        if(airplanes["type"].iloc[j]=="A359"):
            idle_min_cost = 195
        elif(airplanes["type"].iloc[j]=="B744"):
            idle_min_cost = 257
        elif(airplanes["type"].iloc[j]=="B77W"):
            idle_min_cost = 155
        elif(airplanes["type"].iloc[j]=="B738"):
            idle_min_cost = 92
        elif(airplanes["type"].iloc[j]=="B78X"):
            idle_min_cost = 150
        elif(airplanes["type"].iloc[j]=="A388"):
            idle_min_cost = 347
        
        cost = cost + round(idle_sec/60)*idle_min_cost
        cost = cost + fixed_cost
#     
#     fitness_val = (((passenger-0)/(4270-0)*1000)-((cost-0)/(50898241-0)*1000))
    fitness_val = cost-passenger
    fitness.append(fitness_val)
    fitness.append(passenger)
    fitness.append(cost)
    fitness.append(plane_count)
    
    return fitness

# %%
# normalisasi passengger & cost
# cost = fixed cost & minute cost
def countAirplaneFitness(schedule, airplane_id):
    fitness = []
    cost = 0
    passenger = 0
    plane_used = False
    idle_sec = 0
    idle_min_cost = 0
    fixed_cost = 0
    id = airplane_id
    for i in range(len(schedule)):
        if(schedule[i][1]==id):
            if(airplanes["type"].iloc[id]=="A359"):
                min_cost = 244
            elif(airplanes["type"].iloc[id]=="B744"):
                min_cost = 321
            elif(airplanes["type"].iloc[id]=="B77W"):
                min_cost = 194
            elif(airplanes["type"].iloc[id]=="B738"):
                min_cost = 116
            elif(airplanes["type"].iloc[id]=="B78X"):
                min_cost = 187
            elif(airplanes["type"].iloc[id]=="A388"):
                min_cost = 433
            cost = cost + round((schedule[i][3]-schedule[i][2]).seconds/60)*min_cost
            passenger = passenger + schedule[i][4]
            
            for k in range(len(airports)):
                if(airports["airport"].iloc[k]==dfx["origin"].iloc[i]):
                    origin_id = k
                if(airports["airport"].iloc[k]==dfx["destination"].iloc[i]):
                    destination_id = k

            cost = cost + airport_dist[origin_id][destination_id]
        
    first_flight = pd.to_datetime(airplanes["last_seen"].iloc[id])
    last_flight = pd.to_datetime(dfx["lastseen"].iloc[len(dfx)-1])

    for k in range(len(schedule)):
        if(schedule[k][1]==id):
            if(plane_used==False):
                plane_used = True
                lastflight_pos = k
                idle_sec = idle_sec + (schedule[k][2] - first_flight).seconds
            else:
                idle_sec = idle_sec + (schedule[k][2] - schedule[lastflight_pos][2]).seconds
                lastflight_pos = k

    if(plane_used==False):
        idle_sec = idle_sec + (last_flight - first_flight).seconds
        fixed_cost = 0
    else:
        idle_sec = idle_sec + (last_flight - schedule[lastflight_pos][3]).seconds
        if(airplanes["type"].iloc[id]=="A359"):
            fixed_cost = 946069
        elif(airplanes["type"].iloc[id]=="B744"):
            fixed_cost = 851244
        elif(airplanes["type"].iloc[id]=="B77W"):
            fixed_cost = 969244
        elif(airplanes["type"].iloc[id]=="B738"):
            fixed_cost = 732745
        elif(airplanes["type"].iloc[id]=="B78X"):
            fixed_cost = 1001250
        elif(airplanes["type"].iloc[id]=="A388"):
            fixed_cost = 638418

    if(airplanes["type"].iloc[id]=="A359"):
        idle_min_cost = 195
    elif(airplanes["type"].iloc[id]=="B744"):
        idle_min_cost = 257
    elif(airplanes["type"].iloc[id]=="B77W"):
        idle_min_cost = 155
    elif(airplanes["type"].iloc[id]=="B738"):
        idle_min_cost = 92
    elif(airplanes["type"].iloc[id]=="B78X"):
        idle_min_cost = 150
    elif(airplanes["type"].iloc[id]=="A388"):
        idle_min_cost = 347

    cost = cost + round(idle_sec/60)*idle_min_cost
    cost = cost + fixed_cost
    
    originalFitness = countOriginalFitness(createOriginalSchedule())
    
    fitness_val = (((passenger-0)/(originalFitness[1]-0)*5000)-((cost-0)/(originalFitness[2]-0)*1000))
#     fitness_val = cost-passenger
    fitness.append(fitness_val)
    fitness.append(passenger)
    fitness.append(cost)
    
    return fitness

# %%
# normalisasi passengger & cost
# cost = fixed cost & minute cost
def countFitness(schedule):
    fitness = []
    cost = 0
    passenger = 0
    plane_count = 0
    for i in range(len(schedule)):
        if(airplanes["type"].iloc[schedule[i][1]]=="A359"):
            min_cost = 244
        elif(airplanes["type"].iloc[schedule[i][1]]=="B744"):
            min_cost = 321
        elif(airplanes["type"].iloc[schedule[i][1]]=="B77W"):
            min_cost = 194
        elif(airplanes["type"].iloc[schedule[i][1]]=="B738"):
            min_cost = 116
        elif(airplanes["type"].iloc[schedule[i][1]]=="B78X"):
            min_cost = 187
        elif(airplanes["type"].iloc[schedule[i][1]]=="A388"):
            min_cost = 433
        cost = cost + round((schedule[i][3]-schedule[i][2]).seconds/60)*min_cost
        passenger = passenger + schedule[i][4]
        
        for k in range(len(airports)):
            if(airports["airport"].iloc[k]==dfx["origin"].iloc[i]):
                origin_id = k
            if(airports["airport"].iloc[k]==dfx["destination"].iloc[i]):
                destination_id = k
        
        cost = cost + airport_dist[origin_id][destination_id]
        
    for j in range(len(airplanes)):
        plane_used = False
        idle_sec = 0
        fixed_cost = 0
        first_flight = pd.to_datetime(airplanes["last_seen"].iloc[j])
        last_flight = pd.to_datetime(dfx["lastseen"].iloc[len(dfx)-1])
        
        for k in range(len(schedule)):
            if(schedule[k][1]==j):
                if(plane_used==False):
                    plane_used = True
                    plane_count = plane_count + 1
                    lastflight_pos = k
                    idle_sec = idle_sec + (schedule[k][2] - first_flight).seconds
                else:
                    idle_sec = idle_sec + (schedule[k][2] - schedule[lastflight_pos][2]).seconds
                    lastflight_pos = k
                    
        if(plane_used==False):
            idle_sec = idle_sec + (last_flight - first_flight).seconds
            fixed_cost = 0
        else:
            idle_sec = idle_sec + (last_flight - schedule[lastflight_pos][3]).seconds
            if(airplanes["type"].iloc[j]=="A359"):
                fixed_cost = 946069
            elif(airplanes["type"].iloc[j]=="B744"):
                fixed_cost = 851244
            elif(airplanes["type"].iloc[j]=="B77W"):
                fixed_cost = 969244
            elif(airplanes["type"].iloc[j]=="B738"):
                fixed_cost = 732745
            elif(airplanes["type"].iloc[j]=="B78X"):
                fixed_cost = 1001250
            elif(airplanes["type"].iloc[j]=="A388"):
                fixed_cost = 638418
        
        if(airplanes["type"].iloc[j]=="A359"):
            idle_min_cost = 195
        elif(airplanes["type"].iloc[j]=="B744"):
            idle_min_cost = 257
        elif(airplanes["type"].iloc[j]=="B77W"):
            idle_min_cost = 155
        elif(airplanes["type"].iloc[j]=="B738"):
            idle_min_cost = 92
        elif(airplanes["type"].iloc[j]=="B78X"):
            idle_min_cost = 150
        elif(airplanes["type"].iloc[j]=="A388"):
            idle_min_cost = 347
        
        cost = cost + round(idle_sec/60)*idle_min_cost
        cost = cost + fixed_cost
        
    originalFitness = countOriginalFitness(createOriginalSchedule())
    
    fitness_val = (((passenger-0)/(originalFitness[1]-0)*5000)-((cost-0)/(originalFitness[2]-0)*1000))
#     fitness_val = cost-passenger
    fitness.append(fitness_val)
    fitness.append(passenger)
    fitness.append(cost)
    fitness.append(plane_count)
    
    return fitness

# %%
def elite(population):
    curr_elite = 0
    for i in range(len(population)):
        if(population[i][0] > population[curr_elite][0]):
            curr_elite = i
    return curr_elite

# %%
def roulleteWheel(population):
    sump = 0
    sumpart = 0
    worst = 0
    
    for k in range(len(population)):
#         print("worst", population[worst][0])
        if(population[k][0] < population[worst][0]):
            worst = k 
    
    for i in range(len(population)):
        if(population[worst][0] < 0):
            sump = sump + population[i][0] - population[worst][0]
        else:
            sump = sump + population[i][0]
#         print("sump", sump)
    
    rand = random.uniform(0, sump)
#     print("Random", rand)
    
    for j in range(len(population)):
        if(population[worst][0] < 0):
            sumpart = sumpart + population[j][0] - population[worst][0]
        else:
            sumpart = sumpart + population[j][0]
#         print("sumpart", sumpart)
        if(sumpart > rand):
            break
    
    return j

# %%
def swapPlane(flight1, flight2):
    newflight1 = []
    newflight2 = []
    result = []

#     print(flight1[1])
#     print(flight2[1])
    
    newflight1.append(flight1[0])
    newflight2.append(flight2[0])
    
    newflight1.append(flight2[1])
    newflight2.append(flight1[1])
    
#     print(newflight1[1])
#     print(newflight2[1])
    
    newflight1.append(flight2[2])
    newflight2.append(flight1[2])

    newflight1.append(flight1[2] + (flight2[3] - flight2[2]))
    newflight2.append(flight2[2] + (flight1[3] - flight1[2]))
    
    newflight1.append(round(airplanes["capacity"].iloc[flight1[1]] * flight2[5]))
    newflight2.append(round(airplanes["capacity"].iloc[flight2[1]] * flight1[5]))
    
    newflight1.append(flight1[5])
    newflight2.append(flight2[5])
    
    result = [newflight1, newflight2]
    return result

# %%
def rao3(solution, rand_solution, best_solution, worst_solution):  
    rao3_done = False
    while (rao3_done == False):
#         print(1)
        rand_flight = random.randint(0, len(solution)-1)        
        airplanelist = []
        for i in range(len(airplanes)):
            airplane = [i, airplanes["curr_loc"].iloc[i], airplanes["last_seen"].iloc[i], airplanes["capacity"].iloc[i], airplanes["fixed_cost"].iloc[i], airplanes["min_cost"].iloc[i], airplanes["idle_cost"].iloc[i], 0]
            airplanelist.append(airplane)
        for j in range(rand_flight):
            airplanelist[solution[j][1]][1] = dfx["destination"].iloc[j]
            airplanelist[solution[j][1]][2] = solution[j][3]

        available_airplanes = []
        for airplane in airplanelist:
            if (airplane[0] != solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
                available_airplanes.append(airplane)
        
#         print(2)        
        if(len(available_airplanes) >= 3):
            rao3_solution = []
            variables = ["capacity", "fixed_cost", "min_cost", "idle_cost"]
            for variable in variables:
                xsolution = airplanes[variable].iloc[solution[rand_flight][1]]
                xrandsolution = airplanes[variable].iloc[rand_solution[rand_flight][1]]
                xbests = airplanes[variable].iloc[best_solution[rand_flight][1]]
                xworst = airplanes[variable].iloc[worst_solution[rand_flight][1]]
                

                if(countFitness(solution)[0] > countFitness(rand_solution)[0]):
                    or1 = xsolution
                    or2 = xrandsolution
                else:
                    or1 = xrandsolution
                    or2 = xsolution
                    
                xsolution = xsolution + (random.random()*(xbests- abs(xworst))) + (random.random()*(abs(or1) - abs(or2)))
                rao3_solution.append(xsolution)
                
#             print(3)
            for k in range(len(rao3_solution)):
                max_val = rao3_solution[k]*2
                for airplane in available_airplanes:
                    val_diff = abs(rao3_solution[k] - airplane[k+3])                    
                    rate = ((max_val - val_diff) / (max_val - 0))*0.25
                    
                    airplane[-1] = airplane[-1] +  rate
            
#             print(4)
            new_solution = []
            available_airplanes = sorted(available_airplanes,key=lambda l:l[7], reverse=True)
            airplane1 = solution[rand_flight][1]
            airplane2 = available_airplanes[0][0]
            last_pos1 = -1
            last_pos2 = -1
            for l in range(len(solution)):
                if(l < rand_flight):
                    new_solution.append(solution[l])
                    if(solution[l][1]==airplane1):
                        last_pos1 = l
                    elif(solution[l][1]==airplane2):
                        last_pos2 = l   
                else:                                        
                    newflight = solution[l]
                    newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
                    if(solution[l][1]==airplane1):
                        newflight[1] = airplane2                        
                        if(last_pos2 > -1):
                            if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
                                newflight[2] = new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)
                                newflight[3] = new_solution[last_pos2][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
                        last_pos2 = l        
                    elif(solution[l][1]==airplane2):
                        newflight[1] = airplane1                        
                        if(last_pos1 > -1):
                            if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
                                newflight[2] = new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)
                                newflight[3] = new_solution[last_pos1][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
                        last_pos1 = l 
                    new_solution.append(newflight)                    
#             print(5)
            rao3_done = True

    return new_solution

# %%
# def crossover(besthq, xbest):
#     crossover_done = False
#     while (crossover_done == False):
#         solution = deepcopy(besthq)
#         best_solution = deepcopy(xbest)
#         rand_flight = random.randint(0, len(solution)-1)        
#         airplanelist1 = []
#         airplanelist2 = []
#         for i in range(len(airplanes)):
#             airplane = [i, airplanes["curr_loc"].iloc[i], airplanes["last_seen"].iloc[i], airplanes["capacity"].iloc[i], airplanes["fixed_cost"].iloc[i], airplanes["min_cost"].iloc[i], airplanes["idle_cost"].iloc[i], 0]
#             airplanelist1.append(airplane)
#             airplanelist2.append(airplane)
#         for j in range(rand_flight):
#             airplanelist1[solution[j][1]][1] = dfx["destination"].iloc[j]
#             airplanelist1[solution[j][1]][2] = solution[j][3]
#             airplanelist2[best_solution[j][1]][1] = dfx["destination"].iloc[j]
#             airplanelist2[best_solution[j][1]][2] = best_solution[j][3]

#         available_airplanes1 = []
#         available_airplanes2 = []
#         for airplane in airplanelist1:
#             if (airplane[0] != solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
#                 available_airplanes1.append(airplane)
#         for airplane in airplanelist2:        
#             if (airplane[0] != best_solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
#                 available_airplanes2.append(airplane)    
                
#         if(len(available_airplanes1) >= 3 and len(available_airplanes2) >= 3):
#             crossover_solution1 = []
#             crossover_solution2 = []
#             variables = ["capacity", "fixed_cost", "min_cost", "idle_cost"]
#             for variable in variables:
#                 xsolution = airplanes[variable].iloc[solution[rand_flight][1]]
#                 xbests = airplanes[variable].iloc[best_solution[rand_flight][1]]
                
#                 r = random.random()
#                 while (r==0.5):
#                     r = random.random()
#                 xsolution1 = r*xsolution + (1-r)*xbests
#                 xsolution2 = r*xbests + (1-r)*xsolution
#                 crossover_solution1.append(xsolution1)
#                 crossover_solution2.append(xsolution2)
            
#             for k in range(len(crossover_solution1)):
#                 max_val = crossover_solution1[k]*2
#                 for airplane in available_airplanes1:
#                     val_diff = abs(crossover_solution1[k] - airplane[k+3])                    
#                     rate = ((max_val - val_diff) / (max_val - 0))*0.25
                    
#                     airplane[-1] = airplane[-1] +  rate
                    
#             for m in range(len(crossover_solution2)):
#                 max_val = crossover_solution2[m]*2
#                 for airplane in available_airplanes2:
#                     val_diff = abs(crossover_solution2[m] - airplane[m+3])                    
#                     rate = ((max_val - val_diff) / (max_val - 0))*0.25
                    
#                     airplane[-1] = airplane[-1] +  rate
                    
#             new_solution1 = []
#             available_airplanes1 = sorted(available_airplanes1,key=lambda l:l[7], reverse=True)
#             airplane1 = solution[rand_flight][1]
#             airplane2 = available_airplanes1[0][0]
#             last_pos1 = -1
#             last_pos2 = -1
#             for l in range(len(solution)):
#                 if(l < rand_flight):
#                     new_solution1.append(solution[l])
#                     if(solution[l][1]==airplane1):
#                         last_pos1 = l
#                     elif(solution[l][1]==airplane2):
#                         last_pos2 = l   
#                 else:                                        
#                     newflight = solution[l]
#                     newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
#                     if(solution[l][1]==airplane1):
#                         newflight[1] = airplane2                        
#                         if(last_pos2 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution1[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution1[last_pos2][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution1[last_pos2][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos2 = l        
#                     elif(solution[l][1]==airplane2):
#                         newflight[1] = airplane1                        
#                         if(last_pos1 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution1[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution1[last_pos1][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution1[last_pos1][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos1 = l 
#                     new_solution1.append(newflight)
                    
#             new_solution2 = []
#             available_airplanes2 = sorted(available_airplanes2,key=lambda l:l[7], reverse=True)
#             airplane1 = best_solution[rand_flight][1]
#             airplane2 = available_airplanes2[0][0]
#             last_pos1 = -1
#             last_pos2 = -1
#             for l in range(len(best_solution)):
#                 if(l < rand_flight):
#                     new_solution2.append(best_solution[l])
#                     if(best_solution[l][1]==airplane1):
#                         last_pos1 = l
#                     elif(best_solution[l][1]==airplane2):
#                         last_pos2 = l   
#                 else:                                        
#                     newflight = best_solution[l]
#                     newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
#                     if(best_solution[l][1]==airplane1):
#                         newflight[1] = airplane2                        
#                         if(last_pos2 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution2[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution2[last_pos2][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution2[last_pos2][3] + (best_solution[l][3]-best_solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos2 = l        
#                     elif(best_solution[l][1]==airplane2):
#                         newflight[1] = airplane1                        
#                         if(last_pos1 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution2[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution2[last_pos1][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution2[last_pos1][3] + (best_solution[l][3]-best_solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos1 = l 
#                     new_solution2.append(newflight)
            
#             crossover_done = True

#     return new_solution1, new_solution2

# %%
# biar crossover ama randomwalk lebih sering, 
# data last seen pesawat dicek dipenerbangan terakhirnya kalo ada kalo g ada pake last seen di data pesawat
def crossOver(solution, crossover_range):
    doneCrossover = False
    cross_range = round(crossover_range * len(solution))
#     print(cross_range)
    try_time = 0
    while(doneCrossover==False):
        solutionCopy = solution[:]
#         solutionCopy2 = solution[:]
        while True:
            if(try_time > 3 and cross_range >= 3):
                cross_range = cross_range - 1
                try_time = 1
            condition = []
            range1 = random.randint(0, len(solutionCopy)-1-cross_range)
#             range1 = random.randint(0, len(solutionCopy)-1)
            if(cross_range >= 3):
                range2 = range1 + cross_range
            else:
                range2 = range1 + 2
#             range2 = random.randint(0, len(solutionCopy)-1)
            if(range1 < range2 and range1+1!=range2):
                for o in range(range1, range2+1):
                    if(dfx["origin"].iloc[o]!="WSSS"):
                        condition.append(False)

                    else:
                        condition.append(True)
            else:
                condition.append(False)
                print(condition)
            if False not in condition:
                break
                try_time = try_time + 1
            else:
                try_time = try_time + 1
            
        while True:
            cut1 = random.randint(range1, range2)
            cut2 = random.randint(range1, range2)
            if(cut1 < cut2 and cut1+1!=cut2):
                break

        crossover_pos = 0
        exc = []
        constructed_position = [solutionCopy[cut1], solutionCopy[cut2]]
        for i in range(range1, range2+1):
            if(i!=cut1 and i!=cut2):
                constructed_position.append(solution[i])
                    
        index = 0
        for j in range(range1, range2+1):
            condition = []
            last_pos = constructed_position[index][0]

            for p in range(len(constructed_position)):
                if(constructed_position[p][0]==j):
                    index_j = p
            for k in range(len(solution)):
                if(solution[k][1]==constructed_position[index][1] and solution[k][0] < range1):
                    last_pos = solution[k][0]
                elif(solutionCopy[k][0]==constructed_position[index][0]):
                    break
            if(last_pos==constructed_position[index][0]):
                plane_lastseen_time = pd.to_datetime(airplanes["last_seen"].iloc[constructed_position[index][1]])
                plane_lastseen_place = dfx["origin"].iloc[last_pos]
            else:
                plane_lastseen_time = solution[last_pos][3]
                plane_lastseen_place = dfx["destination"].iloc[last_pos]

            if(plane_lastseen_time < (pd.to_datetime(dfx["firstseen"].iloc[j]) + datetime.timedelta(minutes=max_arrival)) and plane_lastseen_place==dfx["origin"].iloc[j]):
                condition.append(True)

                newflight = []
                newflight.append(j)
                newflight.append(constructed_position[index][1])

                if(plane_lastseen_time > (pd.to_datetime(dfx["firstseen"].iloc[j]) - datetime.timedelta(minutes=min_safe))):
                    departure = plane_lastseen_time + datetime.timedelta(minutes=min_safe)
                else:
                    departure = pd.to_datetime(dfx["firstseen"].iloc[j])

                newflight.append(departure)
                arrival = departure + (constructed_position[index_j][3] - constructed_position[index_j][2])
                newflight.append(arrival)
                newflight.append(round(airplanes["capacity"].iloc[constructed_position[index][1]] * constructed_position[index_j][5]))
                newflight.append(constructed_position[index_j][5])


                ext = []
                if(constructed_position[index][0]!=constructed_position[index_j][0]):
                    for l in range(range2, len(solutionCopy)-1):
                        if(solutionCopy[l][0]!=constructed_position[index][0] and solutionCopy[l][0] not in exc):
                            if(constructed_position[index_j][1]==solutionCopy[l][1]):
                                ext.append(solutionCopy[l][0])
                                exc.append(solutionCopy[l][0])

                solutionCopy[j] = newflight

                for m in (ext):
                    new_flight = []
                    new_flight.append(solutionCopy[m][0])
                    new_flight.append(newflight[1])
                    if(pd.to_datetime(dfx["firstseen"].iloc[m]) > newflight[3] + datetime.timedelta(minutes=min_safe)):
                        new_flight.append(pd.to_datetime(dfx["firstseen"].iloc[m]))
                        new_flight.append(pd.to_datetime(dfx["lastseen"].iloc[m]))
                    else:
                        new_flight.append(newflight[3] + datetime.timedelta(minutes=min_safe))
                        new_flight.append(newflight[3] + (solutionCopy[m][3]-solutionCopy[m][2]) + datetime.timedelta(minutes=min_safe))
                    new_flight.append(round(airplanes["capacity"].iloc[newflight[1]] * solutionCopy[m][5]))
                    new_flight.append(solutionCopy[m][5])


                    solutionCopy[m] = new_flight
                    newflight = solutionCopy[m]

                index = index+1

            else:
                condition.append(False)
                index = index+1
                
        solutionCopy1 = solutionCopy[:]
        solutionCopy = solution[:]
        exc = []
        constructed_position = []
        for i in range(range1, range2+1):
            if(i!=cut1 and i!=cut2):
                constructed_position.append(solution[i])
        constructed_position.append(solutionCopy[cut1])
        constructed_position.append(solutionCopy[cut2])
                    
        index = 0
        for j in range(range1, range2+1):
            condition = []
            last_pos = constructed_position[index][0]

            for p in range(len(constructed_position)):
                if(constructed_position[p][0]==j):
                    index_j = p
            for k in range(len(solution)):
                if(solution[k][1]==constructed_position[index][1] and solution[k][0] < range1):
                    last_pos = solution[k][0]
                elif(solutionCopy[k][0]==constructed_position[index][0]):
                    break
            if(last_pos==constructed_position[index][0]):
                plane_lastseen_time = pd.to_datetime(airplanes["last_seen"].iloc[constructed_position[index][1]])
                plane_lastseen_place = dfx["origin"].iloc[last_pos]
            else:
                plane_lastseen_time = solution[last_pos][3]
                plane_lastseen_place = dfx["destination"].iloc[last_pos]

            if(plane_lastseen_time < (pd.to_datetime(dfx["firstseen"].iloc[j]) + datetime.timedelta(minutes=max_arrival)) and plane_lastseen_place==dfx["origin"].iloc[j]):
                condition.append(True)

                newflight = []
                newflight.append(j)
                newflight.append(constructed_position[index][1])

                if(plane_lastseen_time > (pd.to_datetime(dfx["firstseen"].iloc[j]) - datetime.timedelta(minutes=min_safe))):
                    departure = plane_lastseen_time + datetime.timedelta(minutes=min_safe)
                else:
                    departure = pd.to_datetime(dfx["firstseen"].iloc[j])

                newflight.append(departure)
                arrival = departure + (constructed_position[index_j][3] - constructed_position[index_j][2])
                newflight.append(arrival)
                newflight.append(round(airplanes["capacity"].iloc[constructed_position[index][1]] * constructed_position[index_j][5]))
                newflight.append(constructed_position[index_j][5])


                ext = []
                if(constructed_position[index][0]!=constructed_position[index_j][0]):
                    for l in range(range2, len(solutionCopy)-1):
                        if(solutionCopy[l][0]!=constructed_position[index][0] and solutionCopy[l][0] not in exc):
                            if(constructed_position[index_j][1]==solutionCopy[l][1]):
                                ext.append(solutionCopy[l][0])
                                exc.append(solutionCopy[l][0])

                solutionCopy[j] = newflight

                for m in (ext):
                    new_flight = []
                    new_flight.append(solutionCopy[m][0])
                    new_flight.append(newflight[1])
                    if(pd.to_datetime(dfx["firstseen"].iloc[m]) > newflight[3] + datetime.timedelta(minutes=min_safe)):
                        new_flight.append(pd.to_datetime(dfx["firstseen"].iloc[m]))
                        new_flight.append(pd.to_datetime(dfx["lastseen"].iloc[m]))
                    else:
                        new_flight.append(newflight[3] + datetime.timedelta(minutes=min_safe))
                        new_flight.append(newflight[3] + (solutionCopy[m][3]-solutionCopy[m][2]) + datetime.timedelta(minutes=min_safe))
                    new_flight.append(round(airplanes["capacity"].iloc[newflight[1]] * solutionCopy[m][5]))
                    new_flight.append(solutionCopy[m][5])


                    solutionCopy[m] = new_flight
                    newflight = solutionCopy[m]

                index = index+1

            else:
                condition.append(False)
                index = index+1
                
        solutionCopy2 = solutionCopy[:]
        if False not in condition:
            doneCrossover = True
            
    return solutionCopy1, solutionCopy2

# %%
# def mutation(xbest, var_a, var_b):  
#     mutation_done = False
#     solution = deepcopy(xbest)
#     if(random.random() >= var_b):
#         mutation_done = True
#         new_solution = solution
#     while (mutation_done == False):
#         solution = deepcopy(xbest)
#         rand_flight = random.randint(0, len(solution)-1)        
#         airplanelist = []
#         for i in range(len(airplanes)):
#             airplane = [i, airplanes["curr_loc"].iloc[i], airplanes["last_seen"].iloc[i], airplanes["capacity"].iloc[i], airplanes["fixed_cost"].iloc[i], airplanes["min_cost"].iloc[i], airplanes["idle_cost"].iloc[i], 0]
#             airplanelist.append(airplane)
#         for j in range(rand_flight):
#             airplanelist[solution[j][1]][1] = dfx["destination"].iloc[j]
#             airplanelist[solution[j][1]][2] = solution[j][3]

#         available_airplanes = []
#         for airplane in airplanelist:
#             if (airplane[0] != solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
#                 available_airplanes.append(airplane)
                
#         if(len(available_airplanes) >= 3):
#             mutation_solution = []
#             variables = ["capacity", "fixed_cost", "min_cost", "idle_cost"]
#             index = 3
#             for variable in variables:
#                 airplanelist = sorted(airplanelist,key=lambda l:l[index], reverse=True)
#                 xsolution = airplanes[variable].iloc[solution[rand_flight][1]]               
#                 uppervar =  airplanelist[0][index]
#                 lowervar =  airplanelist[-1][index]
#                 xsolution = xsolution + (2*random.random()-1) * var_a*abs(uppervar - lowervar)
#                 mutation_solution.append(xsolution)
#                 index = index + 1
            
#             for k in range(len(mutation_solution)):
#                 max_val = mutation_solution[k]*2
#                 for airplane in available_airplanes:
#                     val_diff = abs(mutation_solution[k] - airplane[k+3])                    
#                     rate = ((max_val - val_diff) / (max_val - 0))*0.25
                    
#                     airplane[-1] = airplane[-1] +  rate
            
#             new_solution = []
#             available_airplanes = sorted(available_airplanes,key=lambda l:l[7], reverse=True)
#             airplane1 = solution[rand_flight][1]
#             airplane2 = available_airplanes[0][0]
#             last_pos1 = -1
#             last_pos2 = -1
#             for l in range(len(solution)):
#                 if(l < rand_flight):
#                     new_solution.append(solution[l])
#                     if(solution[l][1]==airplane1):
#                         last_pos1 = l
#                     elif(solution[l][1]==airplane2):
#                         last_pos2 = l   
#                 else:                                        
#                     newflight = solution[l]
#                     newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
#                     if(solution[l][1]==airplane1):
#                         newflight[1] = airplane2                        
#                         if(last_pos2 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution[last_pos2][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos2 = l        
#                     elif(solution[l][1]==airplane2):
#                         newflight[1] = airplane1                        
#                         if(last_pos1 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution[last_pos1][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos1 = l 
#                     new_solution.append(newflight)                    
#             mutation_done = True

#     return new_solution

# %%
def mutation(solution, solutions, mutation_range):
    doneMutation = False
    mut_range = round(mutation_range * len(solution))
    try_time = 0
    while(doneMutation==False):        
        mut_range = round(mutation_range * len(solution))
        solutionCopy = solution[:]
        while True:
            if(try_time > 3 and mut_range >= 3):
                mut_range = mut_range - 1
                try_time = 1
            condition = []
            range1 = random.randint(0, len(solutionCopy)-1-mut_range)
#             range1 = random.randint(0, len(solutionCopy)-1)
            if(mut_range >= 3):
                range2 = range1 + mut_range
            else:
                range2 = range1 + 2
#             range2 = random.randint(0, len(solutionCopy)-1)
            if(range1 < range2 and range1+1!=range2):
                for o in range(range1, range2+1):
                    if(dfx["origin"].iloc[o]!="WSSS"):
                        condition.append(False)
#                         print("False")
                    else:
                        condition.append(True)
#                         print("True")
            else:
                condition.append(False)
            if False not in condition:
                break
                try_time = try_time + 1
            else:
                try_time = try_time + 1
                
        while True:
            empty_position = []
            constructed_position = []
            changeable_pos = 0
            for a in range(range1, range2+1):
                if(random.randint(0, 1) == 1):
                    constructed_position.append(solutionCopy[a])
                    empty_position.append(solutionCopy[a][0])
                    changeable_pos = changeable_pos + 1
            if(changeable_pos > 1):
                break
            
        
        condition = []
        real_exc = []
        for b in range(len(constructed_position)):
            index = constructed_position[b][0]
#             print("B", index)
            last_pos = constructed_position[b][0]
            found_position = False
            for k in range(len(solutionCopy)):
                if(solution[k][1]==constructed_position[b][1] and solution[k][0] < constructed_position[b][0]):
                    last_pos = solution[k][0]
                elif(solutionCopy[k][0]==constructed_position[b][0]):
                    break
            if(last_pos==constructed_position[b][0]):
                plane_lastseen_time = pd.to_datetime(airplanes["last_seen"].iloc[constructed_position[b][1]])
                plane_lastseen_place = dfx["origin"].iloc[last_pos]
            else:
                plane_lastseen_time = solutionCopy[last_pos][3]
                plane_lastseen_place = dfx["destination"].iloc[last_pos]
            
            for c in range(len(empty_position)):
                exc = real_exc[:]
                best_exc = []
                index_c = empty_position[c]
                solutionCopyCopy = solutionCopy[:]
                if(plane_lastseen_time < (pd.to_datetime(dfx["firstseen"].iloc[index_c]) + datetime.timedelta(minutes=max_arrival)) and plane_lastseen_place==dfx["origin"].iloc[index_c]):
                    
                    newflight = []
                    newflight.append(index_c)
                    newflight.append(constructed_position[b][1])

                    if(plane_lastseen_time > (pd.to_datetime(dfx["firstseen"].iloc[index_c]) - datetime.timedelta(minutes=min_safe))):
                        departure = plane_lastseen_time + datetime.timedelta(minutes=min_safe)
                    else:
                        departure = pd.to_datetime(dfx["firstseen"].iloc[index_c])

                    newflight.append(departure)
                    arrival = departure + (constructed_position[c][3] - constructed_position[c][2])
                    newflight.append(arrival)
                    newflight.append(round(airplanes["capacity"].iloc[constructed_position[b][1]] * constructed_position[c][5]))
                    newflight.append(constructed_position[c][5])


                    ext = []
                    if(constructed_position[b][0]!=index_c):
                        for l in range(range2, len(solutionCopy)-1):
                            if(solutionCopy[l][0]!=constructed_position[b][0] and solutionCopy[l][0] not in exc):
                                if(solutionCopy[index_c][1]==solutionCopy[l][1]):
#                                     print("index_c", index_c)
#                                     print("solutionCopy[index_c][1]", solutionCopy[index_c][1])
                                    ext.append(solutionCopy[l][0])
                                    exc.append(solutionCopy[l][0])

                    solutionCopyCopy[index_c] = newflight
#                     print(ext)

                    for m in (ext):
                        new_flight = []
                        new_flight.append(solutionCopyCopy[m][0])
                        new_flight.append(newflight[1])
                        if(pd.to_datetime(dfx["firstseen"].iloc[m]) > newflight[3] + datetime.timedelta(minutes=min_safe)):
                            new_flight.append(pd.to_datetime(dfx["firstseen"].iloc[m]))
                            new_flight.append(pd.to_datetime(dfx["lastseen"].iloc[m]))
                        else:
                            new_flight.append(newflight[3] + datetime.timedelta(minutes=min_safe))
                            new_flight.append(newflight[3] + (solutionCopyCopy[m][3]-solutionCopyCopy[m][2]) + datetime.timedelta(minutes=min_safe))
                        new_flight.append(round(airplanes["capacity"].iloc[newflight[1]] * solutionCopyCopy[m][5]))
                        new_flight.append(solutionCopyCopy[m][5])


                        solutionCopyCopy[m] = new_flight
                        newflight = solutionCopyCopy[m]
#                         print(new_flight)
                        
                    if(found_position == False):
                        best_position = solutionCopyCopy[:]
                        best_c = c
#                         print("Best position", index_c)
                        temp_exc = exc
                    elif(found_position == True and countFitness(solutionCopyCopy)[0] > countFitness(best_position)[0]):
                        best_position = solutionCopyCopy[:]
                        best_c = c
#                         print("Best position", index_c)
                        temp_exc = exc
                        
                    found_position = True
                    
            if(found_position == True):
                condition.append(True)
                solutionCopy = best_position[:]
                empty_position.pop(best_c)
#                 print("Fitness", countFitness(solutionCopy)[0])
                real_exc.extend(temp_exc)
            else:
                condition.append(False)
                
        if False not in condition:
            done_swap = True
            while (done_swap==False):
                while True:
                    selected_solution = random.randint(0, len(solutions)-1)
                    if(solution != solutions[selected_solution][0]):
                        break
                for o in range(range1, range2+1):
                    if(random.randint(0, 1)==0):
                        found = False
                        for p in range(len(solutionCopy)):
                            if (solutionCopy[p][1]==solutions[selected_solution][0][o][1] and solutionCopy[p][0] < solutionCopy[o][0]):
                                ant_fpos = solutionCopy[p][0]
                                found = True
                            elif (solutionCopy[p][0]==solutionCopy[o][0] and found==True):
                                break
                            elif (solutionCopy[p][1]==solutions[selected_solution][0][o][1] and solutionCopy[p][0] > solutionCopy[o][0]):
                                ant_fpos = solutionCopy[p][0]
                                found = True
                                break

                        if(found==True):
                            last_pos1 = solutionCopy[o][0]
                            last_pos2 = solutionCopy[ant_fpos][0]

                            for a in range(len(solutionCopy)):
                                if(solutionCopy[a][1]==solutionCopy[o][1] and solutionCopy[a][0] < solutionCopy[o][0]):
                                    last_pos1 = solutionCopy[a][0]
                                elif(solutionCopy[a][0]==solutionCopy[o][0]):
                                    break

                            if(last_pos1==solutionCopy[o][0]):
                                plane_lastseen_time1 = pd.to_datetime(airplanes["last_seen"].iloc[solutionCopy[o][1]])
                                plane_lastseen_place1 = dfx["origin"].iloc[last_pos1]
                            else:
                                plane_lastseen_time1 = solutionCopy[last_pos1][3]
                                plane_lastseen_place1 = dfx["destination"].iloc[last_pos1]

                            for b in range(len(solutionCopy)):
                                if(solutionCopy[b][1]==solutionCopy[ant_fpos][1] and solutionCopy[b][0] < solutionCopy[ant_fpos][0]):
                                    last_pos2 = solutionCopy[b][0]
                                elif(solutionCopy[b][0]==solutionCopy[ant_fpos][0]):
                                    break

                            if(last_pos2==solutionCopy[ant_fpos][0]):
                                plane_lastseen_time2 = pd.to_datetime(airplanes["last_seen"].iloc[solutionCopy[ant_fpos][1]])
                                plane_lastseen_place2 = dfx["origin"].iloc[last_pos2]
                            else:
                                plane_lastseen_time2 = solutionCopy[last_pos2][3]
                                plane_lastseen_place2 = dfx["destination"].iloc[last_pos2]

                            if(plane_lastseen_time1 < pd.to_datetime(dfx["firstseen"].iloc[ant_fpos]) + datetime.timedelta(minutes=max_arrival) and plane_lastseen_place1==plane_lastseen_place2):
                                if(plane_lastseen_time2 < pd.to_datetime(dfx["firstseen"].iloc[o]) + datetime.timedelta(minutes=max_arrival) and plane_lastseen_place2==plane_lastseen_place1):
                                    done_swap = True
                                    flight1 = solutionCopy[o]
                                    flight2 = solutionCopy[ant_fpos]

                                    result = swapPlane(flight1, flight2)

                                    solutionCopy[o] = result[0]
                                    solutionCopy[ant_fpos] = result[1]

                                    newflight1 = result[0]
                                    newflight2 = result[1]

                                    ext1 = []
                                    ext2 = []
                                    for k in range(range2, len(solutionCopy)-1):
                                        if(solutionCopy[k][0]!=flight1[0] and solutionCopy[k][0]!=flight2[0]):
                                            if(flight1[1]==solutionCopy[k][1]):
                                                ext1.append(solutionCopy[k][0])
                                            elif(flight2[1]==solutionCopy[k][1]):
                                                ext2.append(solutionCopy[k][0])

                                    for l in (ext1):
                                        newflight = []
                                        newflight.append(solutionCopy[l][0])
                                        newflight.append(newflight1[1])
                                        if(pd.to_datetime(dfx["firstseen"].iloc[l]) > newflight1[3] + datetime.timedelta(minutes=min_safe)):
                                            newflight.append(pd.to_datetime(dfx["firstseen"].iloc[l]))
                                            newflight.append(pd.to_datetime(dfx["lastseen"].iloc[l]))
                                        else:
                                            newflight.append(newflight1[3] + datetime.timedelta(minutes=min_safe))
                                            newflight.append(newflight1[3] + (solutionCopy[l][3]-solutionCopy[l][2]) + datetime.timedelta(minutes=min_safe))
                                        newflight.append(round(airplanes["capacity"].iloc[newflight1[1]] * solutionCopy[l][5]))
                                        newflight.append(solutionCopy[l][5])

                                        newflight1 = newflight
                                        solutionCopy[l] = newflight

                                    for m in (ext2):
                                        newflight = []
                                        newflight.append(solutionCopy[m][0])
                                        newflight.append(newflight2[1])
                                        if(pd.to_datetime(dfx["firstseen"].iloc[m]) > newflight2[3] + datetime.timedelta(minutes=min_safe)):
                                            newflight.append(pd.to_datetime(dfx["firstseen"].iloc[m]))
                                            newflight.append(pd.to_datetime(dfx["lastseen"].iloc[m]))
                                        else:
                                            newflight.append(newflight2[3] + datetime.timedelta(minutes=min_safe))
                                            newflight.append(newflight2[3] + (solutionCopy[m][3]-solutionCopy[m][2]) + (solutionCopy[m][3]-solutionCopy[m][2]) + datetime.timedelta(minutes=min_safe))
                                        newflight.append(round(airplanes["capacity"].iloc[newflight2[1]] * solutionCopy[m][5]))
                                        newflight.append(solutionCopy[m][5])

                                        newflight2 = newflight
                                        solutionCopy[m] = newflight    
            
            doneMutation = True
#             print("Range 1", range1)
#             print("Range 2", range2)
            
    return solutionCopy

# %%
def randomwalk(solution, rand_solution):  
    randomwalk_done = False
    while (randomwalk_done == False):
        rand_flight = random.randint(0, len(solution)-1)        
        airplanelist = []
        for i in range(len(airplanes)):
            airplane = [i, airplanes["curr_loc"].iloc[i], airplanes["last_seen"].iloc[i], airplanes["capacity"].iloc[i], airplanes["fixed_cost"].iloc[i], airplanes["min_cost"].iloc[i], airplanes["idle_cost"].iloc[i], 0]
            airplanelist.append(airplane)
        for j in range(rand_flight):
            airplanelist[solution[j][1]][1] = dfx["destination"].iloc[j]
            airplanelist[solution[j][1]][2] = solution[j][3]

        available_airplanes = []
        for airplane in airplanelist:
            if (airplane[0] != solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
                available_airplanes.append(airplane)
                
        if(len(available_airplanes) >= 3):
            randomwalk_solution = []
            variables = ["capacity", "fixed_cost", "min_cost", "idle_cost"]
            selected_var = random.randint(0,3)
            variable = variables[selected_var]
            xsolution = airplanes[variable].iloc[solution[rand_flight][1]]
            xrandsolution = airplanes[variable].iloc[rand_solution[rand_flight][1]]
                
            xsolution = xsolution + (random.random()*(xrandsolution - xsolution))
            randomwalk_solution.append(xsolution)          

            max_val = randomwalk_solution[0]*2
            for airplane in available_airplanes:
                val_diff = abs(randomwalk_solution[0] - airplane[selected_var+3])                    
                rate = ((max_val - val_diff) / (max_val - 0))
                    
                airplane[-1] = airplane[-1] +  rate
            
            new_solution = []
            available_airplanes = sorted(available_airplanes,key=lambda l:l[7], reverse=True)
            airplane1 = solution[rand_flight][1]
            airplane2 = available_airplanes[0][0]
            last_pos1 = -1
            last_pos2 = -1
            for l in range(len(solution)):
                if(l < rand_flight):
                    new_solution.append(solution[l])
                    if(solution[l][1]==airplane1):
                        last_pos1 = l
                    elif(solution[l][1]==airplane2):
                        last_pos2 = l   
                else:                                        
                    newflight = solution[l]
                    newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
                    if(solution[l][1]==airplane1):
                        newflight[1] = airplane2                        
                        if(last_pos2 > -1):
                            if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
                                newflight[2] = new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)
                                newflight[3] = new_solution[last_pos2][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
                        last_pos2 = l        
                    elif(solution[l][1]==airplane2):
                        newflight[1] = airplane1                        
                        if(last_pos1 > -1):
                            if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
                                newflight[2] = new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)
                                newflight[3] = new_solution[last_pos1][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
                        last_pos1 = l 
                    new_solution.append(newflight)                    
            randomwalk_done = True

    return new_solution

# %%
print(dfx)
# Out:
#         callsign registration typecode origin destination  \
# 1208410   SIA322       9V-SMQ     A359   WSSS        EGLL
# 1208521   SIA324       9V-SMM     A359   WSSS        EHAM
# 1208877    SIA26       9V-SMB     A359   WSSS        EDDF
# 1211170   SIA352       9V-SMN     A359   WSSS        EKCH
# 1215881   SIA478       9V-SMA     A359   WSSS        FABB
# ...          ...          ...      ...    ...         ...
# 1796785  SIA7343       9V-SFI     B744   EHAM        OMSJ
# 1797786   SIA282       9V-SMO     A359   NZAA        WSSS
# 1799511   SIA288       9V-SMF     A359   YBBN        WIDD
# 1803996  SIA7970       9V-SFM     B744   PANC        KORD
# 1807100  SIA7872       9V-SFP     B744   WSSS        VHHH
#
#                          firstseen                   lastseen  \
# 1208410  2020-11-20 16:06:59+00:00  2020-11-21 05:40:59+00:00
# 1208521  2020-11-20 16:08:35+00:00  2020-11-21 05:29:37+00:00
# 1208877  2020-11-20 16:13:20+00:00  2020-11-21 05:09:18+00:00
# 1211170  2020-11-20 16:44:59+00:00  2020-11-21 05:14:59+00:00
# 1215881  2020-11-20 17:48:48+00:00  2020-11-21 03:40:12+00:00
# ...                            ...                        ...
# 1796785  2020-11-30 12:08:02+00:00  2020-11-30 18:42:41+00:00
# 1797786  2020-11-30 12:32:08+00:00  2020-11-30 22:38:39+00:00
# 1799511  2020-11-30 13:16:04+00:00  2020-11-30 20:29:56+00:00
# 1803996  2020-11-30 14:53:03+00:00  2020-11-30 20:05:29+00:00
# 1807100  2020-11-30 15:55:15+00:00  2020-11-30 19:05:20+00:00
#
#                                day  latitude_1  longitude_1  latitude_2  \
# 1208410  2020-11-21 00:00:00+00:00    1.376782   104.004680   51.477676
# 1208521  2020-11-21 00:00:00+00:00    1.373151   104.003543   52.366985
# 1208877  2020-11-21 00:00:00+00:00    1.369567   104.002407   50.030225
# 1211170  2020-11-21 00:00:00+00:00    1.371429   104.002691   55.628155
# 1215881  2020-11-21 00:00:00+00:00    1.369939   104.001980  -26.219757
# ...                            ...         ...          ...         ...
# 1796785  2020-11-30 00:00:00+00:00   52.301193     4.768753   25.313690
# 1797786  2020-11-30 00:00:00+00:00  -37.021645   174.752595    1.319663
# 1799511  2020-11-30 00:00:00+00:00  -27.382864   153.129607    1.111854
# 1803996  2020-11-30 00:00:00+00:00   61.192886  -150.010757   41.965772
# 1807100  2020-11-30 00:00:00+00:00    1.379017   104.005106   22.297265
#
#          longitude_2
# 1208410    -0.446357
# 1208521     4.712350
# 1208877     8.541035
# 1211170    12.671700
# 1215881    28.231166
# ...              ...
# 1796785    55.547740
# 1797786   103.981144
# 1799511   104.047252
# 1803996   -87.911256
# 1807100   113.901316
#
# [351 rows x 12 columns]

# %%
test = createSchedule()
# Out:
# c:\users\user\opencv\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
print(test)
# Out:
# [[0, 20, Timestamp('2020-11-20 16:36:59+0000', tz='UTC'), Timestamp('2020-11-21 06:10:59+0000', tz='UTC'), 47, 0.133], [1, 24, Timestamp('2020-11-20 16:43:20+0000', tz='UTC'), Timestamp('2020-11-21 06:04:22+0000', tz='UTC'), 47, 0.133], [2, 23, Timestamp('2020-11-20 16:38:35+0000', tz='UTC'), Timestamp('2020-11-21 05:34:33+0000', tz='UTC'), 47, 0.133], [3, 1, Timestamp('2020-11-20 18:24:12+0000', tz='UTC'), Timestamp('2020-11-21 06:54:12+0000', tz='UTC'), 47, 0.133], [4, 18, Timestamp('2020-11-20 19:24:04+0000', tz='UTC'), Timestamp('2020-11-21 05:15:28+0000', tz='UTC'), 58, 0.14], [5, 26, Timestamp('2020-11-20 18:18:48+0000', tz='UTC'), Timestamp('2020-11-21 01:22:15+0000', tz='UTC'), 60, 0.171], [6, 32, Timestamp('2020-11-20 18:54:04+0000', tz='UTC'), Timestamp('2020-11-21 01:49:29+0000', tz='UTC'), 37, 0.171], [7, 16, Timestamp('2020-11-20 20:02:05+0000', tz='UTC'), Timestamp('2020-11-21 04:34:48+0000', tz='UTC'), 53, 0.128], [8, 25, Timestamp('2020-11-20 21:01:38+0000', tz='UTC'), Timestamp('2020-11-21 09:16:45+0000', tz='UTC'), 60, 0.171], [9, 14, Timestamp('2020-11-20 21:26:06+0000', tz='UTC'), Timestamp('2020-11-21 06:41:53+0000', tz='UTC'), 55, 0.133], [10, 35, Timestamp('2020-11-20 22:21:21+0000', tz='UTC'), Timestamp('2020-11-21 05:10:47+0000', tz='UTC'), 37, 0.14], [11, 3, Timestamp('2020-11-20 23:21:25+0000', tz='UTC'), Timestamp('2020-11-21 09:35:51+0000', tz='UTC'), 60, 0.171], [12, 19, Timestamp('2020-11-21 03:00:04+0000', tz='UTC'), Timestamp('2020-11-21 16:49:03+0000', tz='UTC'), 55, 0.133], [13, 7, Timestamp('2020-11-21 02:30:04+0000', tz='UTC'), Timestamp('2020-11-21 08:59:52+0000', tz='UTC'), 71, 0.171], [14, 21, Timestamp('2020-11-21 03:07:03+0000', tz='UTC'), Timestamp('2020-11-21 06:16:27+0000', tz='UTC'), 45, 0.128], [15, 32, Timestamp('2020-11-21 04:01:25+0000', tz='UTC'), Timestamp('2020-11-21 11:46:29+0000', tz='UTC'), 37, 0.171], [16, 26, Timestamp('2020-11-21 05:09:13+0000', tz='UTC'), Timestamp('2020-11-21 12:51:55+0000', tz='UTC'), 60, 0.171], [17, 16, Timestamp('2020-11-21 06:32:16+0000', tz='UTC'), Timestamp('2020-11-21 11:06:39+0000', tz='UTC'), 71, 0.171], [18, 35, Timestamp('2020-11-21 06:32:24+0000', tz='UTC'), Timestamp('2020-11-21 14:17:22+0000', tz='UTC'), 35, 0.133], [19, 31, Timestamp('2020-11-21 07:55:25+0000', tz='UTC'), Timestamp('2020-11-21 18:15:52+0000', tz='UTC'), 60, 0.171], [20, 14, Timestamp('2020-11-21 09:24:06+0000', tz='UTC'), Timestamp('2020-11-21 16:09:35+0000', tz='UTC'), 58, 0.14], [21, 24, Timestamp('2020-11-21 09:31:00+0000', tz='UTC'), Timestamp('2020-11-21 21:03:58+0000', tz='UTC'), 60, 0.171], [22, 13, Timestamp('2020-11-21 10:27:44+0000', tz='UTC'), Timestamp('2020-11-21 11:38:48+0000', tz='UTC'), 47, 0.133], [23, 4, Timestamp('2020-11-21 10:33:18+0000', tz='UTC'), Timestamp('2020-11-21 22:31:29+0000', tz='UTC'), 60, 0.171], [24, 23, Timestamp('2020-11-21 10:38:05+0000', tz='UTC'), Timestamp('2020-11-21 10:50:28+0000', tz='UTC'), 47, 0.133], [25, 23, Timestamp('2020-11-21 11:20:28+0000', tz='UTC'), Timestamp('2020-11-21 22:57:06+0000', tz='UTC'), 60, 0.171], [26, 20, Timestamp('2020-11-21 11:06:23+0000', tz='UTC'), Timestamp('2020-11-21 22:54:41+0000', tz='UTC'), 60, 0.171], [27, 1, Timestamp('2020-11-21 11:32:34+0000', tz='UTC'), Timestamp('2020-11-21 22:18:44+0000', tz='UTC'), 60, 0.171], [28, 7, Timestamp('2020-11-21 11:43:39+0000', tz='UTC'), Timestamp('2020-11-21 14:38:28+0000', tz='UTC'), 71, 0.171], [29, 10, Timestamp('2020-11-21 12:28:41+0000', tz='UTC'), Timestamp('2020-11-21 15:55:19+0000', tz='UTC'), 45, 0.128], [30, 13, Timestamp('2020-11-21 12:50:57+0000', tz='UTC'), Timestamp('2020-11-22 00:58:16+0000', tz='UTC'), 60, 0.171], [31, 16, Timestamp('2020-11-21 12:55:20+0000', tz='UTC'), Timestamp('2020-11-21 21:22:54+0000', tz='UTC'), 71, 0.171], [32, 21, Timestamp('2020-11-21 13:10:08+0000', tz='UTC'), Timestamp('2020-11-21 22:01:52+0000', tz='UTC'), 40, 0.113], [33, 0, Timestamp('2020-11-21 13:42:36+0000', tz='UTC'), Timestamp('2020-11-22 01:30:22+000 ...

# %%
def era():
    print("Starting...")
    p = 40
    s = 0.5
    a = 0.075
    b = 0.075
    iteration = 100
    y_plot_list = []
    x_plot_list = []
    xbest = []
    xworst = []
    besthq = []
    f1 = 0
    f2 = 0
    f3 = 0
    
    print("Creating Solution...")
       
    with open('solution/solution_351-1', 'rb') as fp:
        initial_solutions1 = pickle.load(fp)
    with open('solution/solution_351-2', 'rb') as fp:
        initial_solutions2 = pickle.load(fp)
    initial_solutions =  initial_solutions1 + initial_solutions2
    
#     solutions = deepcopy(initial_solutions)
    solutions = []
    
    for i in range(len(initial_solutions)):
        fitness = countFitness(initial_solutions[i])[0]
        sol_fit = [initial_solutions[i], fitness]
        solutions.append(sol_fit)
        
    
    for i in range(iteration):
        print("Iterasi ke-", i)
        for solution in solutions:
            solution[1] = countFitness(solution[0])[0]
            
        solutions = sorted(solutions,key=lambda l:l[1], reverse=True)              
        
        if(i==0):
            f2 = countFitness(solutions[0][0])[0]
            f3 = countFitness(solutions[0][0])[0]
            xbest = deepcopy(solutions[0])
            xworst = deepcopy(solutions[-1])
        else:
            f3 = f2
            f2 = f1
            if(solutions[0][1] > xbest[1]):
                xbest = deepcopy(solutions[0])
            if(solutions[-1][1] > xworst[1]):
                xworst = deepcopy(solutions[-1])
        
        if ((round(s*p)) < 2):
            hq = solutions[:2]
            lq = solutions[2:]
        else:
            hq = solutions[:(round(s*p))]
            lq = solutions[(round(s*p)):]       
        
        print("Rao3 High-Quality solution...")
        for hq_indv in hq:
            
            random_hq = random.randint(0, len(hq)-1)
            while hq_indv==hq[random_hq]:
                random_hq = random.randint(0, len(hq)-1)
            
            randomwalk_indv = rao3(hq_indv[0], hq[random_hq][0], xbest[0], xworst[0])
            randomwalk_indvfit = countFitness(randomwalk_indv)[0]
            if(countFitness(randomwalk_indv)[0] > hq_indv[1]):
                hq_indv[0] = randomwalk_indv
                hq_indv[1] = randomwalk_indvfit
        
        hq = sorted(hq,key=lambda l:l[1], reverse=True)
        
#         print(hq)
        
        besthq = hq[0]
        
        if(random.random() > 0.5):
            print("Solution Crossover...")
#             o1, o2 = crossover(besthq[0], xbest[0])
            o1, o2 = crossOver(besthq[0], a)
            o1fit = countFitness(o1)[0]
            o2fit = countFitness(o2)[0]
            if(o1fit > countFitness(besthq[0])[0]):
#                 print("o1",countFitness(o1)[0])
                offsol1 = [o1, o1fit]
                hq[0] =  offsol1
                
            if(o2fit > countFitness(besthq[0])[0]):
#                 print("o2",countFitness(o2)[0])
                offsol2 = [o2, o2fit]
                hq[0] =  offsol2
#                 xbest = deepcopy(offsol2)
        else:
            print("Solution Mutation...")
#             o = mutation(xbest[0], a, b)
            o = mutation(xbest[0], hq, b)
            ofit = countFitness(o)[0]
            if(ofit > xbest[1]):
#                 print("o",countFitness(o)[0])
                offsol = [o, ofit]
                xbest = deepcopy(offsol)
        
        print("Random Walk Low-Quality Solution...")
        for lq_indv in lq:
            
            random_hq = random.randint(0, len(hq)-1)               
            lq_indv[0] = randomwalk(lq_indv[0], hq[random_hq][0])
            lq_indv[1] = countFitness(lq_indv[0])[0]
        
        solutions = hq+lq
        solutions = sorted(solutions,key=lambda l:l[1], reverse=True)
        
        if(solutions[0][1] > xbest[1]):
            xbest = deepcopy(solutions[0])
       
        f1 = countFitness(xbest[0])[0]
        diff1 = abs(f1-f2)/f1
        diff2 = abs(f2-f3)/f2       
        
        if(diff1 > 0 and diff2 > 0):
            s = s * (1-((diff1 + diff2)/2))
            a = a * 0.97
            b = b * 0.97
        elif(diff1 == 0 and diff2 == 0):
            s = s * 0.97
            a = a * 1.03
            b = b * 1.03
        
        print("s:", s)
        print("a:", a)
        print("b:", b)
        print("Elite Solution:", countFitness(xbest[0]))
        print("High-Quality Solution")
        for j in range(len(hq)):
            print("Solution: ", hq[j][1])
        
#         if(i==0):
#             values = [countFitness(xbest[0])[0]]
#             y_plot_list.append(values)
#         else:
#             y_plot_list[0].append(countFitness(xbest[0])[0])
        
        for j in range(10):
            fit = countFitness(solutions[j][0])[0]
            if(i==0):
                values = [fit]
                y_plot_list.append(values)
            else:
                if(fit > y_plot_list[j][i-1]):
                    y_plot_list[j].append(fit)
                else:
                    y_plot_list[j].append(y_plot_list[j][i-1])    
        x_plot_list.append(i)
        
    print("Final Elite Solutions")
    for k in range(10):
        print("Solution: ", countFitness(solutions[k][0]))
    
    print("Final Elite Solution")
    print("Solution: ", countFitness(xbest[0]))       
            
            
    return xbest[0], x_plot_list, y_plot_list

# %%
start_time = time.time()
result, x_plot_list, y_plot_list = era()
end_time = time.time()
# Out:
# Starting...
# Creating Solution...
# Iterasi ke- 0
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.5
# a: 0.075
# b: 0.075
# Elite Solution: [3718.5721369126513, 18434, 132200162.50216758, 43]
# High-Quality Solution
# Solution:  3718.5721369126513
# Solution:  3697.8306591973997
# Solution:  3688.514195085352
# Solution:  3684.483629844939
# Solution:  3682.5473981843725
# Solution:  3680.445551871124
# Solution:  3672.5572878281
# Solution:  3663.1157532421835
# Solution:  3654.9392873119737
# Solution:  3653.384074253204
# Solution:  3649.1406965962187
# Solution:  3645.5861513411105
# Solution:  3644.9561290669117
# Solution:  3639.7248564432884
# Solution:  3639.723472986289
# Solution:  3637.166650766186
# Solution:  3635.871501737385
# Solution:  3633.5885747359753
# Solution:  3632.7741322667835
# Solution:  3632.6072278800248
# Iterasi ke- 1
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4992376219700001
# a: 0.07275
# b: 0.07275
# Elite Solution: [3729.176599450621, 18482, 132419556.50216758, 43]
# High-Quality Solution
# Solution:  3729.176599450621
# Solution:  3699.9242111916737
# Solution:  3688.514195085352
# Solution:  3686.1319940246954
# Solution:  3683.309604694788
# Solution:  3682.5488379296003
# Solution:  3672.505198584083
# Solution:  3663.1157532421835
# Solution:  3654.8746833594364
# Solution:  3653.7902405836103
# Solution:  3649.1406965962187
# Solution:  3645.5861513411105
# Solution:  3644.252824598008
# Solution:  3641.891163563083
# Solution:  3639.723472986289
# Solution:  3637.2746242749754
# Solution:  3635.097841718341
# Solution:  3633.5885747359753
# Solution:  3632.7741322667835
# Solution:  3632.6072278800248
# Iterasi ke- 2
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4992376219700001
# a: 0.07275
# b: 0.07275
# Elite Solution: [3729.176599450621, 18482, 132419556.50216758, 43]
# High-Quality Solution
# Solution:  3722.5558024237585
# Solution:  3706.6634006212953
# Solution:  3695.554904430645
# Solution:  3688.514195085352
# Solution:  3686.4290748386657
# Solution:  3682.5488379296003
# Solution:  3676.374430539536
# Solution:  3663.443727638385
# Solution:  3663.1157532421835
# Solution:  3655.1383737152355
# Solution:  3653.8505372039594
# Solution:  3649.1406965962187
# Solution:  3645.5861513411105
# Solution:  3644.2006836708288
# Solution:  3641.891163563083
# Solution:  3641.1561501364595
# Solution:  3637.2746242749754
# Solution:  3632.803969866089
# Solution:  3630.4755585554612
# Solution:  3629.8713482530297
# Iterasi ke- 3
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4842604933109001
# a: 0.0749325
# b: 0.0749325
# Elite Solution: [3729.176599450621, 18482, 132419556.50216758, 43]
# High-Quality Solution
# Solution:  3722.5558024237585
# Solution:  3706.6634006212953
# Solution:  3698.28731937408
# Solution:  3688.514195085352
# Solution:  3686.4290748386657
# Solution:  3682.5473981843725
# Solution:  3680.1964268631364
# Solution:  3666.8441253011306
# Solution:  3663.1157532421835
# Solution:  3655.6036815645493
# Solution:  3655.1383737152355
# Solution:  3650.1104878770234
# Solution:  3648.962186862856
# Solution:  3647.132750669186
# Solution:  3645.5842538307334
# Solution:  3641.1561501364595
# Solution:  3635.1698070844554
# Solution:  3628.211359354985
# Solution:  3627.5633814095195
# Solution:  3626.5909920794
# Iterasi ke- 4
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4697326785115731
# a: 0.077180475
# b: 0.077180475
# Elite Solution: [3729.176599450621, 18482, 132419556.50216758, 43]
# High-Quality Solution
# Solution:  3723.5987391002873
# Solution:  3704.128245540711
# Solution:  3698.28731937408
# Solution:  3695.364793701105
# Solution:  3694.86130015115
# Solution:  3682.5473981843725
# Solution:  3682.2696599914243
# Solution:  3667.0466490299314
# Solution:  3666.8441253011306
# Solution:  3655.6036815645493
# Solution:  3655.1739760305654
# Solution:  3650.1104878770234
# Solution:  3649.2601694768055
# Solution:  3648.9636266080843
# Solution:  3647.132750669186
# Solution:  3642.44015765844
# Solution:  3636.3159185611503
# Solution:  3635.1698070844554
# Solution:  3629.1580143026886
# Iterasi ke- 5
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4556406981562259
# a: 0.07949588925000001
# b: 0.07949588925000001
# Elite Solution: [3729.176599450621, 18482, 132419556.50216758, 43]
# High-Quality Solution
# Solution:  3723.5987391002873
# Solution:  3697.979410721031
# Solution:  3695.364793701105
# Solution:  3694.7218938150722
# Solution:  3691.1399095757542
# Solution:  3682.2696599914243
# Solution:  3679.8168807513143
# Solution:  3667.0466490299314
# Solution:  3662.1317787188023
# Solution:  3654.6779946109823
# Solution:  3654.002873438062
# Solution:  3650.381454182191
# Solution:  3649.2601694768055
# Solution:  3648.9636266080843
# Solution:  3642.44015765844
# Solution:  3641.1780397355296
# Solution:  3637.2315192091673
# Solution:  3635.1938364584066
# Solution:  3631.991176313495
# Iterasi ke- 6
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.44197147721153907
# a: 0.08188076592750002
# b: 0.08188076592750002
# Elite Solution: [3729.176599450621, 18482, 132419556.50216758, 43]
# High-Quality Solution
# Solution:  3724.6122664943064
# Solution:  3716.475998075781
# Solution:  3703.6180694083264
# Solution:  3691.1399095757542
# Solution:  3688.4886158373033
# Solution:  3680.556363170131
# Solution:  3679.8168807513143
# Solution:  3669.088041422119
# Solution:  3663.105201542401
# Solution:  3659.8603582850037
# Solution:  3654.6779946109823
# Solution:  3653.692206486984
# Solution:  3649.060207322912
# Solution:  3648.9636266080843
# Solution:  3642.972984303976
# Solution:  3641.9369058548414
# Solution:  3641.1780397355296
# Solution:  3635.1938364584066
# Iterasi ke- 7
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.44197147721153907
# a: 0.08188076592750002
# b: 0.08188076592750002
# Elite Solution: [3747.416976862627, 18550, 132294599.50216758, 43]
# High-Quality Solution
# Solution:  3747.416976862627
# Solution:  3716.475998075781
# Solution:  3704.2876247724244
# Solution:  3691.06581807133
# Solution:  3680.48886496052
# Solution:  3679.008703763343
# Solution:  3674.63810605331
# Solution:  3669.088041422119
# Solution:  3663.105201542401
# Solution:  3659.9150958007963
# Solution:  3659.8603582850037
# Solution:  3656.313401780465
# Solution:  3653.692206486984
# Solution:  3653.6559103952623
# Solution:  3642.8535141167513
# Solution:  3641.9066984870637
# Solution:  3640.41030607478
# Solution:  3633.68948466941
# Iterasi ke- 8
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.44076835757110805
# a: 0.07942434294967501
# b: 0.07942434294967501
# Elite Solution: [3749.5800279432137, 18550, 132001634.50216758, 43]
# High-Quality Solution
# Solution:  3749.5800279432137
# Solution:  3711.319669154864
# Solution:  3704.2876247724244
# Solution:  3691.06581807133
# Solution:  3680.48886496052
# Solution:  3675.562808936466
# Solution:  3674.6633274363803
# Solution:  3659.9150958007963
# Solution:  3659.8603582850037
# Solution:  3659.8053625497632
# Solution:  3656.313401780465
# Solution:  3656.257958254131
# Solution:  3654.744980160771
# Solution:  3653.692206486984
# Solution:  3641.9066984870637
# Solution:  3640.85656533562
# Solution:  3640.41030607478
# Solution:  3633.941677828626
# Iterasi ke- 9
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.44038261495731584
# a: 0.07704161266118476
# b: 0.07704161266118476
# Elite Solution: [3753.9851070991845, 18566, 131956897.50216758, 43]
# High-Quality Solution
# Solution:  3751.887489161821
# Solution:  3707.5730141114714
# Solution:  3704.193475944455
# Solution:  3679.506019038229
# Solution:  3674.6633274363803
# Solution:  3672.069806602469
# Solution:  3669.900982292502
# Solution:  3667.711442074933
# Solution:  3662.344694050695
# Solution:  3657.9762831936396
# Solution:  3657.7036536473943
# Solution:  3657.6700559472933
# Solution:  3656.257958254131
# Solution:  3654.744980160771
# Solution:  3641.690941430063
# Solution:  3640.163743253595
# Solution:  3639.5073681409813
# Solution:  3635.3821663409435
# Iterasi ke- 10
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.44038261495731584
# a: 0.07704161266118476
# b: 0.07704161266118476
# Elite Solution: [3753.9851070991845, 18566, 131956897.50216758, 43]
# High-Quality Solution
# Solution:  3740.870821613334
# Solution:  3716.9710775078884
# Solution:  3704.3156058648133
# Solution:  3680.554084251294
# Solution:  3677.757799166022
# Solution:  3675.246415213339
# Solution:  3672.841569111136
# Solution:  3667.711442074933
# Solution:  3664.5977878032254
# Solution:  3662.344694050695
# Solution:  3657.7036536473943
# Solution:  3657.6700559472933
# Solution:  3654.565012007274
# Solution:  3653.2018792035533
# Solution:  3641.690941430063
# Solution:  3640.163743253595
# Solution:  3639.8803891497128
# Solution:  3634.488010721281
# Iterasi ke- 11
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.42717113650859634
# a: 0.0793528610410203
# b: 0.0793528610410203
# Elite Solution: [3753.9851070991845, 18566, 131956897.50216758, 43]
# High-Quality Solution
# Solution:  3745.9628469524023
# Solution:  3716.9710775078884
# Solution:  3710.180488005576
# Solution:  3680.554084251294
# Solution:  3679.3547452012094
# Solution:  3676.0471719759043
# Solution:  3672.841569111136
# Solution:  3669.608029538711
# Solution:  3667.3221400796365
# Solution:  3665.1944647856462
# Solution:  3664.599685313603
# Solution:  3663.045152827923
# Solution:  3652.0579425154483
# Solution:  3647.5990676108268
# Solution:  3641.146909699918
# Solution:  3639.8577288145316
# Solution:  3634.488010721281
# Solution:  3632.6905468634623
# Iterasi ke- 12
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4143560024133384
# a: 0.08173344687225091
# b: 0.08173344687225091
# Elite Solution: [3753.9851070991845, 18566, 131956897.50216758, 43]
# High-Quality Solution
# Solution:  3745.9628469524023
# Solution:  3721.207552119478
# Solution:  3702.2000287634282
# Solution:  3679.4520276787675
# Solution:  3678.78645366009
# Solution:  3676.0471719759043
# Solution:  3671.008051001698
# Solution:  3669.7205806989946
# Solution:  3667.3321002570383
# Solution:  3667.3221400796365
# Solution:  3666.307734862389
# Solution:  3663.045152827923
# Solution:  3647.406542539289
# Solution:  3646.187063037557
# Solution:  3644.8872462791214
# Solution:  3641.2485377348835
# Solution:  3635.998651517245
# Iterasi ke- 13
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4143560024133384
# a: 0.08173344687225091
# b: 0.08173344687225091
# Elite Solution: [3763.966721169794, 18633, 132916019.50216758, 43]
# High-Quality Solution
# Solution:  3763.966721169794
# Solution:  3721.9773666495325
# Solution:  3712.5210817758248
# Solution:  3680.7317766037177
# Solution:  3676.985722565213
# Solution:  3674.066174013904
# Solution:  3671.056332370047
# Solution:  3667.3321002570383
# Solution:  3667.3221400796365
# Solution:  3666.307734862389
# Solution:  3663.035997524935
# Solution:  3656.974587683826
# Solution:  3649.4439285730077
# Solution:  3646.187063037557
# Solution:  3644.8872462791214
# Solution:  3641.2485377348835
# Solution:  3635.998651517245
# Iterasi ke- 14
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4143560024133384
# a: 0.08173344687225091
# b: 0.08173344687225091
# Elite Solution: [3763.966721169794, 18633, 132916019.50216758, 43]
# High-Quality Solution
# Solution:  3763.966721169794
# Solution:  3721.9773666495325
# Solution:  3712.5210817758248
# Solution:  3680.7317766037177
# Solution:  3680.1090176963503
# Solution:  3671.573686802854
# Solution:  3671.18018311952
# Solution:  3671.056332370047
# Solution:  3663.9197564005544
# Solution:  3663.035997524935
# Solution:  3660.77391412259
# Solution:  3656.3453032312314
# Solution:  3649.4439285730077
# Solution:  3641.921027135723
# Solution:  3639.3242916144536
# Solution:  3635.9169228083356
# Solution:  3633.9567373488485
# Iterasi ke- 15
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.40192532234093825
# a: 0.08418545027841844
# b: 0.08418545027841844
# Elite Solution: [3763.966721169794, 18633, 132916019.50216758, 43]
# High-Quality Solution
# Solution:  3763.633401691245
# Solution:  3721.861574216659
# Solution:  3710.800187529713
# Solution:  3683.9235608711697
# Solution:  3681.0918636186407
# Solution:  3671.573686802854
# Solution:  3668.649610992273
# Solution:  3667.870870559955
# Solution:  3663.9197564005544
# Solution:  3662.2661325266454
# Solution:  3660.7720166122126
# Solution:  3656.343405720854
# Solution:  3646.7115136295724
# Solution:  3640.829811002549
# Solution:  3639.3242916144536
# Solution:  3637.2611631093664
# Solution:  3636.846554708927
# Iterasi ke- 16
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.40192532234093825
# a: 0.08418545027841844
# b: 0.08418545027841844
# Elite Solution: [3764.9035953996013, 18622, 132409704.50216758, 43]
# High-Quality Solution
# Solution:  3764.9035953996013
# Solution:  3721.2675182240037
# Solution:  3707.4681705137414
# Solution:  3683.9235608711697
# Solution:  3682.3420128583657
# Solution:  3672.9646135166267
# Solution:  3672.354434798405
# Solution:  3663.8649057990233
# Solution:  3661.312474820869
# Solution:  3661.2459997645583
# Solution:  3659.8575678363904
# Solution:  3652.0777669543822
# Solution:  3649.682667771294
# Solution:  3646.0490536252905
# Solution:  3639.6726146733863
# Solution:  3637.8220306105395
# Iterasi ke- 17
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.40192532234093825
# a: 0.08418545027841844
# b: 0.08418545027841844
# Elite Solution: [3764.9035953996013, 18622, 132409704.50216758, 43]
# High-Quality Solution
# Solution:  3764.9035953996013
# Solution:  3703.3575513517353
# Solution:  3693.8117029483697
# Solution:  3686.1902409483027
# Solution:  3682.3420128583657
# Solution:  3674.4120373858195
# Solution:  3672.354434798405
# Solution:  3670.7697114446423
# Solution:  3664.0054259784397
# Solution:  3659.8575678363904
# Solution:  3659.569996036324
# Solution:  3649.9941353489753
# Solution:  3649.682667771294
# Solution:  3647.6875029815324
# Solution:  3646.917320143705
# Solution:  3645.4747666587464
# Iterasi ke- 18
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.40192532234093825
# a: 0.08418545027841844
# b: 0.08418545027841844
# Elite Solution: [3775.193713911185, 18661, 132361235.50216758, 43]
# High-Quality Solution
# Solution:  3775.193713911185
# Solution:  3702.139718854897
# Solution:  3694.1862912151655
# Solution:  3686.1902409483027
# Solution:  3680.304626824647
# Solution:  3676.0909944375985
# Solution:  3674.1468249294808
# Solution:  3669.460005912039
# Solution:  3664.457177375907
# Solution:  3664.0054259784397
# Solution:  3652.2365049682717
# Solution:  3648.904895249214
# Solution:  3645.6854820369736
# Solution:  3645.445056223888
# Solution:  3644.4345713650173
# Solution:  3640.321781331578
# Iterasi ke- 19
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4013770581317826
# a: 0.08165988677006589
# b: 0.08165988677006589
# Elite Solution: [3775.203039030277, 18661, 132359972.50216758, 43]
# High-Quality Solution
# Solution:  3775.203039030277
# Solution:  3698.3549491745766
# Solution:  3694.1862912151655
# Solution:  3682.049134804201
# Solution:  3681.5338405603416
# Solution:  3676.0909944375985
# Solution:  3674.1468249294808
# Solution:  3666.975701242899
# Solution:  3664.457177375907
# Solution:  3659.89819254369
# Solution:  3651.366089728349
# Solution:  3648.5032358638437
# Solution:  3645.6854820369736
# Solution:  3644.663506922691
# Solution:  3641.6173680659326
# Solution:  3641.220960473256
# Iterasi ke- 20
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4013770581317826
# a: 0.08165988677006589
# b: 0.08165988677006589
# Elite Solution: [3775.203039030277, 18661, 132359972.50216758, 43]
# High-Quality Solution
# Solution:  3775.203039030277
# Solution:  3696.8769906332946
# Solution:  3694.4130695468443
# Solution:  3683.7709928736344
# Solution:  3682.049134804201
# Solution:  3677.4602129057766
# Solution:  3676.326185824223
# Solution:  3664.1971102193065
# Solution:  3659.89819254369
# Solution:  3657.5605116116735
# Solution:  3651.4487532543617
# Solution:  3650.542061642791
# Solution:  3646.7902223953974
# Solution:  3644.663506922691
# Solution:  3643.7638248494723
# Solution:  3639.798765276695
# Iterasi ke- 21
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4013770581317826
# a: 0.08165988677006589
# b: 0.08165988677006589
# Elite Solution: [3780.6861081198886, 18683, 132376190.50216758, 43]
# High-Quality Solution
# Solution:  3752.5786924723807
# Solution:  3703.302042938938
# Solution:  3694.4130695468443
# Solution:  3684.791583400871
# Solution:  3679.2491687530664
# Solution:  3678.9835125165378
# Solution:  3678.0331576734234
# Solution:  3673.2802435296953
# Solution:  3659.2037456066987
# Solution:  3654.813195069491
# Solution:  3651.4487532543617
# Solution:  3646.7902223953974
# Solution:  3645.5496626803288
# Solution:  3644.663506922691
# Solution:  3639.405796045855
# Solution:  3636.945876279538
# Iterasi ke- 22
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4013770581317826
# a: 0.08165988677006589
# b: 0.08165988677006589
# Elite Solution: [3780.6861081198886, 18683, 132376190.50216758, 43]
# High-Quality Solution
# Solution:  3748.8121206518185
# Solution:  3703.302042938938
# Solution:  3692.141808606704
# Solution:  3685.2452286639345
# Solution:  3679.6811122112927
# Solution:  3679.0773960724055
# Solution:  3678.9835125165378
# Solution:  3673.2802435296953
# Solution:  3659.2037456066987
# Solution:  3654.813195069491
# Solution:  3651.444434367067
# Solution:  3651.2313668399443
# Solution:  3644.6322902928246
# Solution:  3639.907073906374
# Solution:  3636.945876279538
# Solution:  3636.566732341415
# Iterasi ke- 23
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3893357463878291
# a: 0.08410968337316786
# b: 0.08410968337316786
# Elite Solution: [3780.6861081198886, 18683, 132376190.50216758, 43]
# High-Quality Solution
# Solution:  3748.8121206518185
# Solution:  3702.1761621706596
# Solution:  3692.141808606704
# Solution:  3685.2452286639345
# Solution:  3682.2278447534413
# Solution:  3679.6490575289968
# Solution:  3673.2802435296953
# Solution:  3656.1979441200915
# Solution:  3651.444434367067
# Solution:  3651.401182943757
# Solution:  3651.255413673875
# Solution:  3651.166554064426
# Solution:  3649.2740531392155
# Solution:  3643.1300072238646
# Solution:  3639.907073906374
# Solution:  3633.616680384329
# Iterasi ke- 24
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3776556739961942
# a: 0.0866329738743629
# b: 0.0866329738743629
# Elite Solution: [3780.6861081198886, 18683, 132376190.50216758, 43]
# High-Quality Solution
# Solution:  3756.649144437596
# Solution:  3701.4777454522223
# Solution:  3690.569717567386
# Solution:  3685.9466150358494
# Solution:  3682.2278447534413
# Solution:  3679.6490575289968
# Solution:  3674.27621384851
# Solution:  3660.2479507339167
# Solution:  3656.1979441200915
# Solution:  3651.444434367067
# Solution:  3651.401182943757
# Solution:  3651.255413673875
# Solution:  3649.2740531392155
# Solution:  3645.203240352152
# Solution:  3636.2783534917226
# Solution:  3634.427589196579
# Iterasi ke- 25
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.36632600377630836
# a: 0.0892319630905938
# b: 0.0892319630905938
# Elite Solution: [3780.6861081198886, 18683, 132376190.50216758, 43]
# High-Quality Solution
# Solution:  3757.1587330319026
# Solution:  3705.7833866377164
# Solution:  3690.569717567386
# Solution:  3685.9466150358494
# Solution:  3684.9602596968766
# Solution:  3674.27621384851
# Solution:  3670.7247226925233
# Solution:  3670.226147123048
# Solution:  3662.980365677352
# Solution:  3656.4946480280532
# Solution:  3651.444434367067
# Solution:  3649.8661924284365
# Solution:  3648.973111372861
# Solution:  3648.8097370831433
# Solution:  3645.203240352152
# Iterasi ke- 26
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3553362236630191
# a: 0.0919089219833116
# b: 0.0919089219833116
# Elite Solution: [3780.6861081198886, 18683, 132376190.50216758, 43]
# High-Quality Solution
# Solution:  3763.147329980828
# Solution:  3714.4781243755897
# Solution:  3690.8899453092763
# Solution:  3684.9602596968766
# Solution:  3684.774942552743
# Solution:  3670.7247226925233
# Solution:  3670.0664854138927
# Solution:  3668.0883474769166
# Solution:  3666.311114497276
# Solution:  3657.267756643906
# Solution:  3656.4946480280532
# Solution:  3649.6133328508527
# Solution:  3644.977813165995
# Solution:  3641.9979292509697
# Solution:  3633.52668801086
# Iterasi ke- 27
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.3446761369531285
# a: 0.09466618964281096
# b: 0.09466618964281096
# Elite Solution: [3780.6861081198886, 18683, 132376190.50216758, 43]
# High-Quality Solution
# Solution:  3763.1591801915506
# Solution:  3714.4781243755897
# Solution:  3690.8899453092763
# Solution:  3689.1043878743963
# Solution:  3678.8044333169746
# Solution:  3678.281416132045
# Solution:  3673.655896310508
# Solution:  3668.0883474769166
# Solution:  3667.8405937677935
# Solution:  3657.937865756169
# Solution:  3651.4510767365596
# Solution:  3649.6133328508527
# Solution:  3641.9979292509697
# Solution:  3637.5338636255788
# Iterasi ke- 28
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3343358528445346
# a: 0.09750617533209528
# b: 0.09750617533209528
# Elite Solution: [3780.6861081198886, 18683, 132376190.50216758, 43]
# High-Quality Solution
# Solution:  3763.1591801915506
# Solution:  3714.2303331468916
# Solution:  3690.4164458954156
# Solution:  3689.7597082190096
# Solution:  3681.2840818964655
# Solution:  3678.281416132045
# Solution:  3673.655896310508
# Solution:  3668.6784687689783
# Solution:  3665.5270982195007
# Solution:  3657.937865756169
# Solution:  3651.4510767365596
# Solution:  3649.1054260876513
# Solution:  3646.147819281391
# Solution:  3638.687176946177
# Iterasi ke- 29
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.3343358528445346
# a: 0.09750617533209528
# b: 0.09750617533209528
# Elite Solution: [3805.1088573370075, 18773, 132172737.50216758, 43]
# High-Quality Solution
# Solution:  3761.637650051315
# Solution:  3718.61485795265
# Solution:  3690.4164458954156
# Solution:  3689.7597082190096
# Solution:  3681.866819361516
# Solution:  3681.2840818964655
# Solution:  3676.3186663954234
# Solution:  3669.545277148502
# Solution:  3667.1614352424667
# Solution:  3651.467667031571
# Solution:  3650.1189351640187
# Solution:  3646.5407082383854
# Solution:  3641.486051049258
# Iterasi ke- 30
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3343358528445346
# a: 0.09750617533209528
# b: 0.09750617533209528
# Elite Solution: [3805.1088573370075, 18773, 132172737.50216758, 43]
# High-Quality Solution
# Solution:  3766.2934628163193
# Solution:  3725.2763166882364
# Solution:  3690.4150061501873
# Solution:  3689.531177349769
# Solution:  3683.483574381111
# Solution:  3676.3186663954234
# Solution:  3675.4317204628437
# Solution:  3673.643105114301
# Solution:  3667.670781750897
# Solution:  3654.6557574782464
# Solution:  3651.467667031571
# Solution:  3646.5407082383854
# Solution:  3641.928901914766
# Iterasi ke- 31
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.3343358528445346
# a: 0.09750617533209528
# b: 0.09750617533209528
# Elite Solution: [3805.110297082236, 18773, 132172542.50216758, 43]
# High-Quality Solution
# Solution:  3769.6042151211122
# Solution:  3726.694310688308
# Solution:  3687.8818297963776
# Solution:  3685.7769737864764
# Solution:  3683.483574381111
# Solution:  3675.4508123908854
# Solution:  3675.4317204628437
# Solution:  3674.670711857554
# Solution:  3668.035480292107
# Solution:  3664.2031685346087
# Solution:  3663.5631990494044
# Solution:  3643.026637509665
# Solution:  3641.3846560686643
# Iterasi ke- 32
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3343358528445346
# a: 0.09750617533209528
# b: 0.09750617533209528
# Elite Solution: [3805.110297082236, 18773, 132172542.50216758, 43]
# High-Quality Solution
# Solution:  3772.3366300645475
# Solution:  3726.694310688308
# Solution:  3689.0608086286256
# Solution:  3685.7769737864764
# Solution:  3683.1786609304727
# Solution:  3676.752984424848
# Solution:  3671.818205747292
# Solution:  3671.7127431842796
# Solution:  3668.035480292107
# Solution:  3664.2031685346087
# Solution:  3662.8844706588297
# Solution:  3652.74003655595
# Solution:  3645.31725705237
# Iterasi ke- 33
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.3343358528445346
# a: 0.09750617533209528
# b: 0.09750617533209528
# Elite Solution: [3805.159733025009, 18779, 132372805.50216758, 43]
# High-Quality Solution
# Solution:  3772.3366300645475
# Solution:  3726.166414963045
# Solution:  3717.8388863549026
# Solution:  3686.779933584048
# Solution:  3686.3341218330597
# Solution:  3676.752984424848
# Solution:  3673.019699602384
# Solution:  3667.6397046222414
# Solution:  3662.8844706588297
# Solution:  3656.5475218905276
# Solution:  3650.007621612515
# Solution:  3645.975641470161
# Solution:  3641.2745957768293
# Iterasi ke- 34
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.3343358528445346
# a: 0.09750617533209528
# b: 0.09750617533209528
# Elite Solution: [3805.159733025009, 18779, 132372805.50216758, 43]
# High-Quality Solution
# Solution:  3769.9793979609058
# Solution:  3725.8657297096634
# Solution:  3717.8388863549026
# Solution:  3686.78608388033
# Solution:  3686.3341218330597
# Solution:  3673.187142707182
# Solution:  3673.019699602384
# Solution:  3670.827620214477
# Solution:  3667.6397046222414
# Solution:  3657.0580128118304
# Solution:  3650.0090613577427
# Solution:  3648.0235452439874
# Solution:  3645.975641470161
# Iterasi ke- 35
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.32430577725919857
# a: 0.10043136059205815
# b: 0.10043136059205815
# Elite Solution: [3805.159733025009, 18779, 132372805.50216758, 43]
# High-Quality Solution
# Solution:  3774.1258642174803
# Solution:  3723.698133900957
# Solution:  3717.8388863549026
# Solution:  3690.1116810623735
# Solution:  3686.7879813907075
# Solution:  3681.269223637286
# Solution:  3673.187142707182
# Solution:  3667.6397046222414
# Solution:  3666.1435217385824
# Solution:  3657.0580128118304
# Solution:  3654.701970908217
# Solution:  3652.0840960133924
# Solution:  3645.9503121157
# Iterasi ke- 36
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3145766039414226
# a: 0.1034443014098199
# b: 0.1034443014098199
# Elite Solution: [3805.159733025009, 18779, 132372805.50216758, 43]
# High-Quality Solution
# Solution:  3777.310555470089
# Solution:  3723.698133900957
# Solution:  3717.8388863549026
# Solution:  3690.1116810623735
# Solution:  3688.970103558083
# Solution:  3681.269223637286
# Solution:  3670.90779686521
# Solution:  3668.109219751547
# Solution:  3663.174275175043
# Solution:  3654.701970908217
# Solution:  3653.4925872528233
# Solution:  3652.1586012377543
# Solution:  3652.0840960133924
# Iterasi ke- 37
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.30513930582317994
# a: 0.1065476304521145
# b: 0.1065476304521145
# Elite Solution: [3805.159733025009, 18779, 132372805.50216758, 43]
# High-Quality Solution
# Solution:  3783.4173593725136
# Solution:  3719.954259935151
# Solution:  3716.8442069850917
# Solution:  3688.970103558083
# Solution:  3683.745142430875
# Solution:  3679.295489372769
# Solution:  3670.90779686521
# Solution:  3669.769762831025
# Solution:  3665.6754698891204
# Solution:  3663.174275175043
# Solution:  3654.701970908217
# Solution:  3652.0826562681646
# Solution:  3651.702175254359
# Iterasi ke- 38
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.30513930582317994
# a: 0.1065476304521145
# b: 0.1065476304521145
# Elite Solution: [3806.1347016535224, 18773, 132033796.50216758, 43]
# High-Quality Solution
# Solution:  3783.4173593725136
# Solution:  3719.954259935151
# Solution:  3703.056004162922
# Solution:  3684.848707458502
# Solution:  3684.0656534318655
# Solution:  3670.7614754104807
# Solution:  3669.769762831025
# Solution:  3665.6754698891204
# Solution:  3663.351583850047
# Solution:  3658.823991029152
# Solution:  3651.396274343171
# Solution:  3650.6124988425972
# Iterasi ke- 39
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.30513930582317994
# a: 0.1065476304521145
# b: 0.1065476304521145
# Elite Solution: [3806.1347016535224, 18773, 132033796.50216758, 43]
# High-Quality Solution
# Solution:  3768.006776231055
# Solution:  3715.2419767608517
# Solution:  3701.542594099118
# Solution:  3685.2894136894206
# Solution:  3684.0656534318655
# Solution:  3670.7614754104807
# Solution:  3668.4988571135063
# Solution:  3667.3330110036422
# Solution:  3665.1038910336133
# Solution:  3662.8742493811233
# Solution:  3658.823991029152
# Solution:  3652.70076664782
# Iterasi ke- 40
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.29598512664848453
# a: 0.10974405936567794
# b: 0.10974405936567794
# Elite Solution: [3806.1347016535224, 18773, 132033796.50216758, 43]
# High-Quality Solution
# Solution:  3767.7535427220673
# Solution:  3715.2419767608517
# Solution:  3701.542594099118
# Solution:  3685.4897254584453
# Solution:  3685.2894136894206
# Solution:  3670.7603309976075
# Solution:  3669.359581619926
# Solution:  3668.4988571135063
# Solution:  3665.1038910336133
# Solution:  3662.8533695534234
# Solution:  3660.513199240261
# Solution:  3651.111643963154
# Iterasi ke- 41
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.29598512664848453
# a: 0.10974405936567794
# b: 0.10974405936567794
# Elite Solution: [3809.472145053118, 18796, 132375112.50216758, 43]
# High-Quality Solution
# Solution:  3767.754982467295
# Solution:  3714.2638360028905
# Solution:  3685.4897254584453
# Solution:  3684.4088138248276
# Solution:  3675.9297420966595
# Solution:  3670.672581492968
# Solution:  3668.0279160541722
# Solution:  3666.2151996826683
# Solution:  3665.01837755038
# Solution:  3662.8533695534234
# Solution:  3660.513199240261
# Solution:  3654.8858728020223
# Iterasi ke- 42
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.29577502925797006
# a: 0.10645173758470759
# b: 0.10645173758470759
# Elite Solution: [3811.543938436177, 18796, 132094507.50216758, 43]
# High-Quality Solution
# Solution:  3767.754982467295
# Solution:  3706.298534524074
# Solution:  3684.4088138248276
# Solution:  3684.3710435011876
# Solution:  3682.4694935024363
# Solution:  3672.7443748760275
# Solution:  3667.3040980598885
# Solution:  3667.0868168386187
# Solution:  3664.409030725074
# Solution:  3661.165463931305
# Solution:  3660.5117594950334
# Solution:  3659.477457899733
# Iterasi ke- 43
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.29577502925797006
# a: 0.10645173758470759
# b: 0.10645173758470759
# Elite Solution: [3811.543938436177, 18796, 132094507.50216758, 43]
# High-Quality Solution
# Solution:  3767.6254928664375
# Solution:  3706.298534524074
# Solution:  3684.3710435011876
# Solution:  3682.532288544303
# Solution:  3676.7134861611603
# Solution:  3672.7443748760275
# Solution:  3668.9719601736615
# Solution:  3667.3040980598885
# Solution:  3664.959269566746
# Solution:  3664.902929796917
# Solution:  3660.6905247722166
# Solution:  3660.298411563068
# Iterasi ke- 44
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.28690177838023095
# a: 0.10964528971224882
# b: 0.10964528971224882
# Elite Solution: [3811.543938436177, 18796, 132094507.50216758, 43]
# High-Quality Solution
# Solution:  3771.494881434692
# Solution:  3704.2267411410144
# Solution:  3682.532288544303
# Solution:  3681.722051001261
# Solution:  3679.459571950856
# Solution:  3676.120157801957
# Solution:  3669.5538218031998
# Solution:  3668.985709458077
# Solution:  3664.959269566746
# Solution:  3664.902929796917
# Solution:  3664.1793412971056
# Solution:  3660.29697181784
# Iterasi ke- 45
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.278294725028824
# a: 0.11293464840361629
# b: 0.11293464840361629
# Elite Solution: [3811.543938436177, 18796, 132094507.50216758, 43]
# High-Quality Solution
# Solution:  3776.567658487559
# Solution:  3701.461721505647
# Solution:  3683.521903133995
# Solution:  3681.8333417060617
# Solution:  3679.459571950856
# Solution:  3676.120157801957
# Solution:  3669.5538218031998
# Solution:  3669.359153311999
# Solution:  3664.180781042334
# Solution:  3660.2955320726123
# Solution:  3659.642474504397
# Iterasi ke- 46
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.26994588327795926
# a: 0.11632268785572478
# b: 0.11632268785572478
# Elite Solution: [3811.543938436177, 18796, 132094507.50216758, 43]
# High-Quality Solution
# Solution:  3777.4306934603705
# Solution:  3701.222725361119
# Solution:  3686.470702706816
# Solution:  3685.3853269407123
# Solution:  3681.8333417060617
# Solution:  3674.636819012595
# Solution:  3673.9304894596553
# Solution:  3669.359153311999
# Solution:  3664.180781042334
# Solution:  3662.3850326357724
# Solution:  3659.7874865898575
# Iterasi ke- 47
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.2618475067796205
# a: 0.11981236849139652
# b: 0.11981236849139652
# Elite Solution: [3811.543938436177, 18796, 132094507.50216758, 43]
# High-Quality Solution
# Solution:  3789.1831334467256
# Solution:  3701.222725361119
# Solution:  3697.3530723784334
# Solution:  3686.470702706816
# Solution:  3680.4830032163136
# Solution:  3676.2025872461654
# Solution:  3671.751681973557
# Solution:  3663.7375086314432
# Solution:  3662.6386219371398
# Solution:  3662.3850326357724
# Solution:  3661.4642824313387
# Iterasi ke- 48
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.2539920815762319
# a: 0.12340673954613843
# b: 0.12340673954613843
# Elite Solution: [3811.543938436177, 18796, 132094507.50216758, 43]
# High-Quality Solution
# Solution:  3790.0703635226764
# Solution:  3697.3530723784334
# Solution:  3688.9984091588067
# Solution:  3682.556236344601
# Solution:  3676.2025872461654
# Solution:  3668.0143133907673
# Solution:  3667.4222366519048
# Solution:  3665.936606504327
# Solution:  3661.4642824313387
# Solution:  3661.40889336641
# Iterasi ke- 49
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.24637231912894492
# a: 0.12710894173252257
# b: 0.12710894173252257
# Elite Solution: [3811.543938436177, 18796, 132094507.50216758, 43]
# High-Quality Solution
# Solution:  3790.0703635226764
# Solution:  3699.4263055067204
# Solution:  3690.119137592427
# Solution:  3682.5576760898293
# Solution:  3673.9854078956546
# Solution:  3668.8170628739344
# Solution:  3668.0143133907673
# Solution:  3665.936606504327
# Solution:  3665.2222321104664
# Solution:  3658.661040442295
# Iterasi ke- 50
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.23898114955507657
# a: 0.13092220998449824
# b: 0.13092220998449824
# Elite Solution: [3811.543938436177, 18796, 132094507.50216758, 43]
# High-Quality Solution
# Solution:  3779.082126751641
# Solution:  3699.431488589541
# Solution:  3694.7900678989595
# Solution:  3682.5576760898293
# Solution:  3674.9704370261425
# Solution:  3673.9854078956546
# Solution:  3668.409187693922
# Solution:  3668.0143133907673
# Solution:  3668.0063460277147
# Solution:  3662.5184260953138
# Iterasi ke- 51
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.23181171506842427
# a: 0.1348498762840332
# b: 0.1348498762840332
# Elite Solution: [3811.543938436177, 18796, 132094507.50216758, 43]
# High-Quality Solution
# Solution:  3775.1088868210345
# Solution:  3699.431488589541
# Solution:  3695.965167367423
# Solution:  3684.13273174429
# Solution:  3681.3386925873333
# Solution:  3680.8254652278174
# Solution:  3678.5021696748254
# Solution:  3668.409187693922
# Solution:  3668.0081852444123
# Solution:  3663.501272017604
# Iterasi ke- 52
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.23181171506842427
# a: 0.1348498762840332
# b: 0.1348498762840332
# Elite Solution: [3813.316874933091, 18802, 132061338.50216758, 43]
# High-Quality Solution
# Solution:  3774.8542135668195
# Solution:  3695.965167367423
# Solution:  3693.6770599676875
# Solution:  3684.13273174429
# Solution:  3682.862851261536
# Solution:  3682.2396835876852
# Solution:  3678.5021696748254
# Solution:  3670.160907509171
# Solution:  3665.106155985225
# Iterasi ke- 53
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.23181171506842427
# a: 0.1348498762840332
# b: 0.1348498762840332
# Elite Solution: [3813.316874933091, 18802, 132061338.50216758, 43]
# High-Quality Solution
# Solution:  3774.8542135668195
# Solution:  3692.149020442398
# Solution:  3687.747301218976
# Solution:  3682.862851261536
# Solution:  3682.2396835876852
# Solution:  3675.5071483373054
# Solution:  3672.3146203522438
# Solution:  3665.696957323358
# Solution:  3661.881466221883
# Iterasi ke- 54
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.23181171506842427
# a: 0.1348498762840332
# b: 0.1348498762840332
# Elite Solution: [3814.0614170936906, 18795, 131719045.50216758, 43]
# High-Quality Solution
# Solution:  3773.3663477550926
# Solution:  3692.149020442398
# Solution:  3687.747301218976
# Solution:  3682.4839456707605
# Solution:  3682.325902554443
# Solution:  3675.5071483373054
# Solution:  3672.818670692114
# Solution:  3665.696957323358
# Solution:  3660.457440219365
# Iterasi ke- 55
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.23181171506842427
# a: 0.1348498762840332
# b: 0.1348498762840332
# Elite Solution: [3814.0614170936906, 18795, 131719045.50216758, 43]
# High-Quality Solution
# Solution:  3768.7807894339962
# Solution:  3714.393959777786
# Solution:  3703.2557668825957
# Solution:  3684.7129969309185
# Solution:  3680.3528671046543
# Solution:  3675.5071483373054
# Solution:  3675.3116788039665
# Solution:  3663.29133110515
# Solution:  3663.102404661898
# Iterasi ke- 56
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.22485736361637154
# a: 0.1388953725725542
# b: 0.1388953725725542
# Elite Solution: [3814.0614170936906, 18795, 131719045.50216758, 43]
# High-Quality Solution
# Solution:  3773.923998996724
# Solution:  3714.393959777786
# Solution:  3703.2557668825957
# Solution:  3684.7129969309185
# Solution:  3678.7011101627213
# Solution:  3677.384911932254
# Solution:  3675.5071483373054
# Solution:  3666.3341651964083
# Solution:  3661.0650186281796
# Iterasi ke- 57
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.2181116427078804
# a: 0.14306223374973082
# b: 0.14306223374973082
# Elite Solution: [3814.0614170936906, 18795, 131719045.50216758, 43]
# High-Quality Solution
# Solution:  3776.530787806421
# Solution:  3713.884613269356
# Solution:  3683.661281500153
# Solution:  3680.568131994695
# Solution:  3678.384444650721
# Solution:  3677.894258440684
# Solution:  3676.3376967511267
# Solution:  3661.4370144781587
# Solution:  3661.0059744681075
# Iterasi ke- 58
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.21156829342664396
# a: 0.14735410076222275
# b: 0.14735410076222275
# Elite Solution: [3814.0614170936906, 18795, 131719045.50216758, 43]
# High-Quality Solution
# Solution:  3777.5161747170064
# Solution:  3714.0294438227124
# Solution:  3685.3080916251492
# Solution:  3677.894258440684
# Solution:  3676.3376967511267
# Solution:  3672.953683517283
# Solution:  3666.8451736461093
# Solution:  3665.3128349447306
# Solution:  3664.5688395911234
# Iterasi ke- 59
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.20522124462384464
# a: 0.15177472378508944
# b: 0.15177472378508944
# Elite Solution: [3814.0614170936906, 18795, 131719045.50216758, 43]
# High-Quality Solution
# Solution:  3777.5161747170064
# Solution:  3714.0294438227124
# Solution:  3695.364929888189
# Solution:  3685.3080916251492
# Solution:  3680.183340334575
# Solution:  3677.8923609303065
# Solution:  3674.398718151275
# Solution:  3669.9450635183944
# Iterasi ke- 60
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.19906460728512929
# a: 0.1563279654986421
# b: 0.1563279654986421
# Elite Solution: [3814.0614170936906, 18795, 131719045.50216758, 43]
# High-Quality Solution
# Solution:  3775.3207081322757
# Solution:  3711.297028879277
# Solution:  3697.189354811726
# Solution:  3696.2697027059944
# Solution:  3683.463129735365
# Solution:  3680.3756296761135
# Solution:  3680.183340334575
# Solution:  3678.983115908191
# Iterasi ke- 61
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.19906460728512929
# a: 0.1563279654986421
# b: 0.1563279654986421
# Elite Solution: [3818.4664962496613, 18811, 131674308.50216758, 43]
# High-Quality Solution
# Solution:  3761.5448514174477
# Solution:  3718.9864436425923
# Solution:  3697.189354811726
# Solution:  3696.2697027059944
# Solution:  3686.070188949247
# Solution:  3680.3756296761135
# Solution:  3677.381934538211
# Solution:  3666.00746776425
# Iterasi ke- 62
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.19906460728512929
# a: 0.1563279654986421
# b: 0.1563279654986421
# Elite Solution: [3818.4664962496613, 18811, 131674308.50216758, 43]
# High-Quality Solution
# Solution:  3761.5448514174477
# Solution:  3720.5057440235514
# Solution:  3696.828399608109
# Solution:  3693.955737837446
# Solution:  3692.9236899870384
# Solution:  3690.5339550704866
# Solution:  3686.070188949247
# Solution:  3667.802816078578
# Iterasi ke- 63
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.1930926690665754
# a: 0.1610178044636014
# b: 0.1610178044636014
# Elite Solution: [3818.4664962496613, 18811, 131674308.50216758, 43]
# High-Quality Solution
# Solution:  3761.5218154938
# Solution:  3720.5057440235514
# Solution:  3699.372946257565
# Solution:  3693.955737837446
# Solution:  3692.9236899870384
# Solution:  3689.891214320858
# Solution:  3686.068749204019
# Solution:  3667.9055847878894
# Iterasi ke- 64
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.1930926690665754
# a: 0.1610178044636014
# b: 0.1610178044636014
# Elite Solution: [3819.8076564959697, 18826, 132010057.50216758, 43]
# High-Quality Solution
# Solution:  3760.266534421148
# Solution:  3713.823590570005
# Solution:  3703.323235465224
# Solution:  3699.372946257565
# Solution:  3694.358718835103
# Solution:  3685.434094740909
# Solution:  3682.1165020259573
# Solution:  3672.702579706506
# Iterasi ke- 65
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.1930926690665754
# a: 0.1610178044636014
# b: 0.1610178044636014
# Elite Solution: [3819.8076564959697, 18826, 132010057.50216758, 43]
# High-Quality Solution
# Solution:  3759.400348338768
# Solution:  3713.823590570005
# Solution:  3703.323235465224
# Solution:  3694.358718835103
# Solution:  3693.068688444795
# Solution:  3685.434094740909
# Solution:  3676.053622727757
# Solution:  3660.9473979129507
# Iterasi ke- 66
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.1930926690665754
# a: 0.1610178044636014
# b: 0.1610178044636014
# Elite Solution: [3820.3251805839873, 18824, 131870977.50216758, 43]
# High-Quality Solution
# Solution:  3759.619477562466
# Solution:  3712.203087174482
# Solution:  3693.068688444795
# Solution:  3691.509889000756
# Solution:  3677.4316246401177
# Solution:  3676.053622727757
# Solution:  3673.8062079635356
# Solution:  3671.405329891967
# Iterasi ke- 67
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.1930926690665754
# a: 0.1610178044636014
# b: 0.1610178044636014
# Elite Solution: [3820.3251805839873, 18824, 131870977.50216758, 43]
# High-Quality Solution
# Solution:  3759.619477562466
# Solution:  3711.587675959239
# Solution:  3705.8369350835264
# Solution:  3686.9565303436393
# Solution:  3675.9245288687066
# Solution:  3674.9910704086724
# Solution:  3673.8062079635356
# Solution:  3669.9414646266005
# Iterasi ke- 68
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.18729988899457814
# a: 0.16584833859750944
# b: 0.16584833859750944
# Elite Solution: [3820.3251805839873, 18824, 131870977.50216758, 43]
# High-Quality Solution
# Solution:  3755.278121485185
# Solution:  3711.587675959239
# Solution:  3705.8369350835264
# Solution:  3686.9546328332617
# Solution:  3682.7418225753772
# Solution:  3677.255220891724
# Solution:  3675.0177011549313
# Solution:  3672.746154601852
# Iterasi ke- 69
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.1816808923247408
# a: 0.17082378875543472
# b: 0.17082378875543472
# Elite Solution: [3820.3251805839873, 18824, 131870977.50216758, 43]
# High-Quality Solution
# Solution:  3750.482930523784
# Solution:  3711.586236214011
# Solution:  3705.8369350835264
# Solution:  3685.199708916608
# Solution:  3682.7418225753772
# Solution:  3677.255220891724
# Solution:  3675.022751338193
# Iterasi ke- 70
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.17623046555499858
# a: 0.17594850241809776
# b: 0.17594850241809776
# Elite Solution: [3820.3251805839873, 18824, 131870977.50216758, 43]
# High-Quality Solution
# Solution:  3750.482930523784
# Solution:  3716.151528049059
# Solution:  3707.283592651914
# Solution:  3680.3620654076885
# Solution:  3677.079165891924
# Solution:  3675.1896129706806
# Solution:  3675.022751338193
# Iterasi ke- 71
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.17094355158834862
# a: 0.1812269574906407
# b: 0.1812269574906407
# Elite Solution: [3820.3251805839873, 18824, 131870977.50216758, 43]
# High-Quality Solution
# Solution:  3732.442761259838
# Solution:  3716.151528049059
# Solution:  3707.283592651914
# Solution:  3687.33663559035
# Solution:  3677.079165891924
# Solution:  3675.1896129706806
# Solution:  3672.2149391747116
# Iterasi ke- 72
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.17094355158834862
# a: 0.1812269574906407
# b: 0.1812269574906407
# Elite Solution: [3822.8415894433724, 18824, 131530153.50216758, 43]
# High-Quality Solution
# Solution:  3734.66932356325
# Solution:  3713.4239184247654
# Solution:  3696.8434289743336
# Solution:  3687.33663559035
# Solution:  3679.3372423999153
# Solution:  3676.650882294799
# Solution:  3672.2149391747116
# Iterasi ke- 73
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.17094355158834862
# a: 0.1812269574906407
# b: 0.1812269574906407
# Elite Solution: [3822.8415894433724, 18824, 131530153.50216758, 43]
# High-Quality Solution
# Solution:  3734.66932356325
# Solution:  3709.5319532613275
# Solution:  3696.8434289743336
# Solution:  3683.386475186467
# Solution:  3681.9025730815515
# Solution:  3679.3372423999153
# Solution:  3674.695641043768
# Iterasi ke- 74
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.16581524504069817
# a: 0.1866637662153599
# b: 0.1866637662153599
# Elite Solution: [3822.8415894433724, 18824, 131530153.50216758, 43]
# High-Quality Solution
# Solution:  3726.4074882472178
# Solution:  3715.645551107712
# Solution:  3698.258691150126
# Solution:  3683.637699653786
# Solution:  3681.9025730815515
# Solution:  3676.568946835507
# Solution:  3674.695641043768
# Iterasi ke- 75
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.1608407876894772
# a: 0.19226367920182072
# b: 0.19226367920182072
# Elite Solution: [3822.8415894433724, 18824, 131530153.50216758, 43]
# High-Quality Solution
# Solution:  3721.758746347128
# Solution:  3715.645551107712
# Solution:  3698.258691150126
# Solution:  3683.637699653786
# Solution:  3678.360043596592
# Solution:  3676.568946835507
# Solution:  3666.7506034513854
# Iterasi ke- 76
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.15601556405879288
# a: 0.19803158957787534
# b: 0.19803158957787534
# Elite Solution: [3822.8415894433724, 18824, 131530153.50216758, 43]
# High-Quality Solution
# Solution:  3723.6193390501608
# Solution:  3716.692807886464
# Solution:  3691.1278400321103
# Solution:  3678.360043596592
# Solution:  3674.833118518277
# Solution:  3672.0290339566172
# Iterasi ke- 77
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.15133509713702908
# a: 0.2039725372652116
# b: 0.2039725372652116
# Elite Solution: [3822.8415894433724, 18824, 131530153.50216758, 43]
# High-Quality Solution
# Solution:  3723.6193390501608
# Solution:  3716.692807886464
# Solution:  3691.1278400321103
# Solution:  3679.952987878378
# Solution:  3674.833118518277
# Solution:  3666.817900306205
# Iterasi ke- 78
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.15133509713702908
# a: 0.2039725372652116
# b: 0.2039725372652116
# Elite Solution: [3822.86799953917, 18824, 131526576.50216758, 43]
# High-Quality Solution
# Solution:  3721.5461059218733
# Solution:  3716.2110675698664
# Solution:  3692.1379625906975
# Solution:  3682.027660751893
# Solution:  3671.086662042564
# Solution:  3669.571847671642
# Iterasi ke- 79
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.15133509713702908
# a: 0.2039725372652116
# b: 0.2039725372652116
# Elite Solution: [3822.86799953917, 18824, 131526576.50216758, 43]
# High-Quality Solution
# Solution:  3721.5461059218733
# Solution:  3716.4706332644937
# Solution:  3692.1379625906975
# Solution:  3688.1171223829806
# Solution:  3685.281884532338
# Solution:  3669.571847671642
# Iterasi ke- 80
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.1467950442229182
# a: 0.21009171338316796
# b: 0.21009171338316796
# Elite Solution: [3822.86799953917, 18824, 131526576.50216758, 43]
# High-Quality Solution
# Solution:  3728.969151751588
# Solution:  3716.4706332644937
# Solution:  3695.626502279511
# Solution:  3688.1171223829806
# Solution:  3685.281884532338
# Solution:  3677.998101544321
# Iterasi ke- 81
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.14239119289623065
# a: 0.216394464784663
# b: 0.216394464784663
# Elite Solution: [3822.86799953917, 18824, 131526576.50216758, 43]
# High-Quality Solution
# Solution:  3728.969151751588
# Solution:  3717.207740169562
# Solution:  3701.545583472669
# Solution:  3695.626502279511
# Solution:  3690.412309933779
# Solution:  3677.998101544321
# Iterasi ke- 82
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.13811945710934373
# a: 0.2228862987282029
# b: 0.2228862987282029
# Elite Solution: [3822.86799953917, 18824, 131526576.50216758, 43]
# High-Quality Solution
# Solution:  3749.5247754226243
# Solution:  3727.1320896538964
# Solution:  3707.0290969455004
# Solution:  3703.4310959731547
# Solution:  3693.5532691512235
# Solution:  3677.998101544321
# Iterasi ke- 83
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.13397587339606343
# a: 0.229572887690049
# b: 0.229572887690049
# Elite Solution: [3822.86799953917, 18824, 131526576.50216758, 43]
# High-Quality Solution
# Solution:  3750.8146876888572
# Solution:  3732.7506478478404
# Solution:  3707.349576934819
# Solution:  3707.0290969455004
# Solution:  3703.4310959731547
# Solution:  3679.1354264413344
# Iterasi ke- 84
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.1299565971941815
# a: 0.23646007432075047
# b: 0.23646007432075047
# Elite Solution: [3822.86799953917, 18824, 131526576.50216758, 43]
# High-Quality Solution
# Solution:  3762.2043378510966
# Solution:  3732.7506478478404
# Solution:  3707.349576934819
# Solution:  3705.465210325642
# Solution:  3704.044491281571
# Iterasi ke- 85
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.12605789927835606
# a: 0.243553876550373
# b: 0.243553876550373
# Elite Solution: [3822.86799953917, 18824, 131526576.50216758, 43]
# High-Quality Solution
# Solution:  3755.533545143542
# Solution:  3707.1301833904377
# Solution:  3706.673464410795
# Solution:  3704.044491281571
# Solution:  3702.1912970872877
# Iterasi ke- 86
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.12227616230000538
# a: 0.2508604928468842
# b: 0.2508604928468842
# Elite Solution: [3822.86799953917, 18824, 131526576.50216758, 43]
# High-Quality Solution
# Solution:  3756.588350357312
# Solution:  3709.830510210053
# Solution:  3707.1301833904377
# Solution:  3703.0257982647117
# Solution:  3702.1912970872877
# Iterasi ke- 87
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.12227616230000538
# a: 0.2508604928468842
# b: 0.2508604928468842
# Elite Solution: [3824.9397929222296, 18824, 131245971.50216758, 43]
# High-Quality Solution
# Solution:  3756.588350357312
# Solution:  3714.4611318220004
# Solution:  3711.1304894012837
# Solution:  3702.436423026367
# Solution:  3699.4776544232673
# Iterasi ke- 88
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.1222198877940784
# a: 0.24333467806147768
# b: 0.24333467806147768
# Elite Solution: [3826.3892118481303, 18826, 131118647.50216758, 43]
# High-Quality Solution
# Solution:  3732.6117776213196
# Solution:  3725.6667550074526
# Solution:  3711.1304894012837
# Solution:  3704.2191358058712
# Solution:  3699.4776544232673
# Iterasi ke- 89
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.1222198877940784
# a: 0.24333467806147768
# b: 0.24333467806147768
# Elite Solution: [3826.3892118481303, 18826, 131118647.50216758, 43]
# High-Quality Solution
# Solution:  3733.534565712747
# Solution:  3725.6667550074526
# Solution:  3709.1896531644693
# Solution:  3697.117774320225
# Solution:  3695.186710015576
# Iterasi ke- 90
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.11855329116025605
# a: 0.250634718403322
# b: 0.250634718403322
# Elite Solution: [3826.3892118481303, 18826, 131118647.50216758, 43]
# High-Quality Solution
# Solution:  3778.789606995724
# Solution:  3726.41678843814
# Solution:  3709.1896531644693
# Solution:  3697.406040848102
# Solution:  3695.696056524006
# Iterasi ke- 91
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.11499669242544837
# a: 0.25815375995542167
# b: 0.25815375995542167
# Elite Solution: [3826.3892118481303, 18826, 131118647.50216758, 43]
# High-Quality Solution
# Solution:  3774.7031818068103
# Solution:  3726.41678843814
# Solution:  3697.406040848102
# Solution:  3695.696056524006
# Solution:  3686.558849422832
# Iterasi ke- 92
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.11154679165268491
# a: 0.26589837275408434
# b: 0.26589837275408434
# Elite Solution: [3826.3892118481303, 18826, 131118647.50216758, 43]
# High-Quality Solution
# Solution:  3788.888153052373
# Solution:  3716.7872841036237
# Solution:  3696.864655120771
# Solution:  3695.8617970413275
# Solution:  3682.4212628569635
# Iterasi ke- 93
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.10820038790310436
# a: 0.2738753239367069
# b: 0.2738753239367069
# Elite Solution: [3826.3892118481303, 18826, 131118647.50216758, 43]
# High-Quality Solution
# Solution:  3788.888153052373
# Solution:  3716.7872841036237
# Solution:  3696.864655120771
# Solution:  3695.8617970413275
# Iterasi ke- 94
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.10820038790310436
# a: 0.2738753239367069
# b: 0.2738753239367069
# Elite Solution: [3826.423706667131, 18826, 131113975.50216758, 43]
# High-Quality Solution
# Solution:  3732.678739976015
# Solution:  3718.3741048441207
# Solution:  3697.0152249349676
# Solution:  3695.9552778115994
# Iterasi ke- 95
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.10820038790310436
# a: 0.2738753239367069
# b: 0.2738753239367069
# Elite Solution: [3826.423706667131, 18826, 131113975.50216758, 43]
# High-Quality Solution
# Solution:  3766.045788938906
# Solution:  3719.666265111267
# Solution:  3697.695594153185
# Solution:  3690.798669106604
# Iterasi ke- 96
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.10495437626601123
# a: 0.2820915836548081
# b: 0.2820915836548081
# Elite Solution: [3826.423706667131, 18826, 131113975.50216758, 43]
# High-Quality Solution
# Solution:  3766.045788938906
# Solution:  3721.7448896183396
# Solution:  3697.695594153185
# Solution:  3688.9267788109673
# Iterasi ke- 97
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.1018057449780309
# a: 0.29055433116445234
# b: 0.29055433116445234
# Elite Solution: [3826.423706667131, 18826, 131113975.50216758, 43]
# High-Quality Solution
# Solution:  3766.0289814013054
# Solution:  3721.7448896183396
# Solution:  3696.9725097998416
# Solution:  3693.7850256598986
# Iterasi ke- 98
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.09875157262868997
# a: 0.2992709610993859
# b: 0.2992709610993859
# Elite Solution: [3826.423706667131, 18826, 131113975.50216758, 43]
# High-Quality Solution
# Solution:  3766.0289814013054
# Solution:  3715.3717625606023
# Solution:  3696.915274041159
# Solution:  3694.1749308175617
# Iterasi ke- 99
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.09578902544982927
# a: 0.3082490899323675
# b: 0.3082490899323675
# Elite Solution: [3826.423706667131, 18826, 131113975.50216758, 43]
# High-Quality Solution
# Solution:  3765.546125423413
# Solution:  3711.807481414468
# Solution:  3696.915274041159
# Solution:  3694.7969186492965
# Final Elite Solutions
# Solution:  [3765.546125423413, 18600, 131563831.50216758, 42]
# Solution:  [3706.2046698217414, 18344, 130770840.50216758, 43]
# Solution:  [3683.765870845002, 18334, 133465034.50216758, 43]
# Solution:  [3694.7969186492965, 18344, 132315913.50216758, 43]
# Solution:  [3683.5857952471315, 18291, 132006220.50216758, 43]
# Solution:  [3676.3487662428147, 18246, 131434218.50216758, 43]
# Solution:  [3675.58656989395, 18271, 132399778.50216758, 43]
# Solution:  [3666.6245795703862, 18218, 131785461.50216758, 43]
# Solution:  [3658.6332549695844, 18161, 130901704.50216758, 43]
# Solution:  [3651.501233201852, 18175, 132350573.50216758, 43]
# Final Elite Solution
# Solution:  [3826.423706667131, 18826, 131113975.50216758, 43]

# %%
print(result)
# Out:
# [[0, 21, Timestamp('2020-11-20 17:14:59+0000', tz='UTC'), Timestamp('2020-11-21 06:48:59+0000', tz='UTC'), 47, 0.133], [1, 35, Timestamp('2020-11-20 18:27:55+0000', tz='UTC'), Timestamp('2020-11-21 07:48:57+0000', tz='UTC'), 35, 0.133], [2, 24, Timestamp('2020-11-20 16:43:20+0000', tz='UTC'), Timestamp('2020-11-21 05:39:18+0000', tz='UTC'), 47, 0.133], [3, 32, Timestamp('2020-11-21 05:44:59+0000', tz='UTC'), Timestamp('2020-11-21 18:14:59+0000', tz='UTC'), 29, 0.133], [4, 26, Timestamp('2020-11-20 18:18:48+0000', tz='UTC'), Timestamp('2020-11-21 04:10:12+0000', tz='UTC'), 49, 0.14], [5, 20, Timestamp('2020-11-21 01:27:39+0000', tz='UTC'), Timestamp('2020-11-21 08:31:06+0000', tz='UTC'), 60, 0.171], [6, 23, Timestamp('2020-11-21 02:19:29+0000', tz='UTC'), Timestamp('2020-11-21 09:14:54+0000', tz='UTC'), 60, 0.171], [7, 16, Timestamp('2020-11-20 20:02:05+0000', tz='UTC'), Timestamp('2020-11-21 04:34:48+0000', tz='UTC'), 53, 0.128], [8, 25, Timestamp('2020-11-20 21:01:38+0000', tz='UTC'), Timestamp('2020-11-21 09:16:45+0000', tz='UTC'), 60, 0.171], [9, 14, Timestamp('2020-11-20 21:26:06+0000', tz='UTC'), Timestamp('2020-11-21 06:41:53+0000', tz='UTC'), 55, 0.133], [10, 1, Timestamp('2020-11-20 22:21:21+0000', tz='UTC'), Timestamp('2020-11-21 05:10:47+0000', tz='UTC'), 49, 0.14], [11, 3, Timestamp('2020-11-20 23:21:25+0000', tz='UTC'), Timestamp('2020-11-21 09:35:51+0000', tz='UTC'), 60, 0.171], [12, 5, Timestamp('2020-11-21 03:37:03+0000', tz='UTC'), Timestamp('2020-11-21 17:26:02+0000', tz='UTC'), 55, 0.133], [13, 7, Timestamp('2020-11-21 02:30:04+0000', tz='UTC'), Timestamp('2020-11-21 08:59:52+0000', tz='UTC'), 71, 0.171], [14, 19, Timestamp('2020-11-21 03:07:03+0000', tz='UTC'), Timestamp('2020-11-21 06:16:27+0000', tz='UTC'), 53, 0.128], [15, 23, Timestamp('2020-11-21 09:44:54+0000', tz='UTC'), Timestamp('2020-11-21 17:29:58+0000', tz='UTC'), 60, 0.171], [16, 20, Timestamp('2020-11-21 09:01:06+0000', tz='UTC'), Timestamp('2020-11-21 16:43:48+0000', tz='UTC'), 60, 0.171], [17, 16, Timestamp('2020-11-21 06:32:16+0000', tz='UTC'), Timestamp('2020-11-21 11:06:39+0000', tz='UTC'), 71, 0.171], [18, 1, Timestamp('2020-11-21 06:32:24+0000', tz='UTC'), Timestamp('2020-11-21 14:17:22+0000', tz='UTC'), 47, 0.133], [19, 31, Timestamp('2020-11-21 07:55:25+0000', tz='UTC'), Timestamp('2020-11-21 18:15:52+0000', tz='UTC'), 60, 0.171], [20, 14, Timestamp('2020-11-21 09:24:06+0000', tz='UTC'), Timestamp('2020-11-21 16:09:35+0000', tz='UTC'), 58, 0.14], [21, 35, Timestamp('2020-11-21 09:31:00+0000', tz='UTC'), Timestamp('2020-11-21 21:03:58+0000', tz='UTC'), 45, 0.171], [22, 13, Timestamp('2020-11-21 10:27:44+0000', tz='UTC'), Timestamp('2020-11-21 11:38:48+0000', tz='UTC'), 47, 0.133], [23, 4, Timestamp('2020-11-21 10:33:18+0000', tz='UTC'), Timestamp('2020-11-21 22:31:29+0000', tz='UTC'), 60, 0.171], [24, 24, Timestamp('2020-11-21 10:38:05+0000', tz='UTC'), Timestamp('2020-11-21 10:50:28+0000', tz='UTC'), 47, 0.133], [25, 24, Timestamp('2020-11-21 11:20:28+0000', tz='UTC'), Timestamp('2020-11-21 22:57:06+0000', tz='UTC'), 60, 0.171], [26, 21, Timestamp('2020-11-21 11:06:23+0000', tz='UTC'), Timestamp('2020-11-21 22:54:41+0000', tz='UTC'), 60, 0.171], [27, 33, Timestamp('2020-11-21 12:02:34+0000', tz='UTC'), Timestamp('2020-11-21 22:48:44+0000', tz='UTC'), 60, 0.171], [28, 7, Timestamp('2020-11-21 11:43:39+0000', tz='UTC'), Timestamp('2020-11-21 14:38:28+0000', tz='UTC'), 71, 0.171], [29, 29, Timestamp('2020-11-21 13:25:20+0000', tz='UTC'), Timestamp('2020-11-21 16:51:58+0000', tz='UTC'), 34, 0.128], [30, 13, Timestamp('2020-11-21 12:50:57+0000', tz='UTC'), Timestamp('2020-11-22 00:58:16+0000', tz='UTC'), 60, 0.171], [31, 10, Timestamp('2020-11-21 12:55:20+0000', tz='UTC'), Timestamp('2020-11-21 21:22:54+0000', tz='UTC'), 60, 0.171], [32, 19, Timestamp('2020-11-21 13:10:08+0000', tz='UTC'), Timestamp('2020-11-21 22:01:52+0000', tz='UTC'), 47, 0.113], [33, 0, Timestamp('2020-11-21 13:42:36+0000', tz='UTC'), Timestamp('2020-11-22 01:30:22+0000 ...

# %%
def printResult(result):
    fitness = countFitness(result)
    originalschedule = createOriginalSchedule()
    original_fitness = countFitness(originalschedule)
    print("------------------------------------------------------------------------------------------------------------------")
    print("Airplane \tPassenger \tCost \t\tRouting")
    print("------------------------------------------------------------------------------------------------------------------")
    for i in range(len(airplanes)):
        flight_list = []
        airplanefitness = countAirplaneFitness(result, i)
        print(airplanes["airplane"].iloc[i], end="\t\t")
        print(airplanefitness[1], end="\t\t")
        print(airplanefitness[2], end="\t\t")
        
        for j in range(len(result)):
            if(result[j][1]==i):
                flight_list.append(result[j])
                
        for k in range(len(flight_list)):
            print("Flight-", flight_list[k][0], end=", ")     
            
        print("\n")
    
    print("------------------------------------------------------------------------------------------------------------------")
    print('Result\t\t%d\t\t%d\t\t%d' % (fitness[1], fitness[2], fitness[3]))
    print("------------------------------------------------------------------------------------------------------------------")
    print('Original\t%d\t\t%d\t\t%d' % (original_fitness[1], original_fitness[2], original_fitness[3]))
    print("------------------------------------------------------------------------------------------------------------------")
    print('Difference\t%d\t\t%d\t\t\t%d' % (fitness[1] - original_fitness[1], original_fitness[2] - fitness[2], original_fitness[3] - fitness[3]))
    print("------------------------------------------------------------------------------------------------------------------")

# %%
printResult(result)
# Out:
# ------------------------------------------------------------------------------------------------------------------
# Airplane 	Passenger 	Cost 		Routing
# ------------------------------------------------------------------------------------------------------------------
# 9V-SMG		348		2676788.3279908183		Flight- 33, Flight- 58, Flight- 65, Flight- 85, Flight- 229, Flight- 295, Flight- 335,
#
# 9V-SMI		511		2855077.2438521045		Flight- 10, Flight- 18, Flight- 43, Flight- 48, Flight- 63, Flight- 166, Flight- 204, Flight- 205, Flight- 214, Flight- 269,
#
# 9V-SMT		543		3400294.9520853274		Flight- 53, Flight- 68, Flight- 96, Flight- 107, Flight- 131, Flight- 174, Flight- 187, Flight- 276, Flight- 286, Flight- 346,
#
# 9V-SMD		426		3143703.216763235		Flight- 11, Flight- 40, Flight- 122, Flight- 139, Flight- 218, Flight- 240, Flight- 302, Flight- 308,
#
# 9V-SMH		541		3925034.029140172		Flight- 23, Flight- 51, Flight- 57, Flight- 106, Flight- 119, Flight- 215, Flight- 231, Flight- 261, Flight- 316, Flight- 341,
#
# 9V-SFN		749		4815227.883294009		Flight- 12, Flight- 46, Flight- 72, Flight- 98, Flight- 101, Flight- 123, Flight- 194, Flight- 222, Flight- 270, Flight- 314, Flight- 330,
#
# 9V-SMC		325		2749968.4416958666		Flight- 134, Flight- 164, Flight- 223, Flight- 226, Flight- 272, Flight- 289,
#
# 9V-SFM		484		2672154.4344293717		Flight- 13, Flight- 28, Flight- 44, Flight- 50, Flight- 74, Flight- 149, Flight- 296,
#
# 9V-SMS		633		3944959.0139648486		Flight- 37, Flight- 117, Flight- 144, Flight- 154, Flight- 253, Flight- 273, Flight- 274, Flight- 291, Flight- 322, Flight- 325, Flight- 337, Flight- 349,
#
# 9V-SFK		444		3528852.1201019594		Flight- 87, Flight- 94, Flight- 138, Flight- 140, Flight- 146, Flight- 219, Flight- 267,
#
# 9V-SML		1580		8030943.365988564		Flight- 31, Flight- 100, Flight- 142, Flight- 150, Flight- 152, Flight- 158, Flight- 169, Flight- 242, Flight- 243, Flight- 244, Flight- 245, Flight- 246, Flight- 254, Flight- 262, Flight- 278, Flight- 300, Flight- 305, Flight- 307, Flight- 311, Flight- 317, Flight- 318, Flight- 323, Flight- 324, Flight- 331, Flight- 338, Flight- 342,
#
# 9V-SWQ		90		1306968.8450084424		Flight- 143, Flight- 179,
#
# 9V-MGL		94		1122936.4842278073		Flight- 79, Flight- 110, Flight- 350,
#
# 9V-SMF		609		4361812.420677925		Flight- 22, Flight- 30, Flight- 75, Flight- 168, Flight- 183, Flight- 206, Flight- 209, Flight- 232, Flight- 235, Flight- 279, Flight- 293, Flight- 321,
#
# 9V-SFQ		728		3853411.9349465715		Flight- 9, Flight- 20, Flight- 42, Flight- 120, Flight- 126, Flight- 130, Flight- 132, Flight- 189, Flight- 210, Flight- 237, Flight- 285, Flight- 303,
#
# 9V-SWE		194		1671309.618951125		Flight- 78, Flight- 86, Flight- 93, Flight- 211, Flight- 332,
#
# 9V-SFI		697		5016984.548423299		Flight- 7, Flight- 17, Flight- 71, Flight- 82, Flight- 89, Flight- 129, Flight- 157, Flight- 173, Flight- 186, Flight- 216, Flight- 234,
#
# 9V-SMO		666		3327408.4267552933		Flight- 36, Flight- 64, Flight- 111, Flight- 112, Flight- 148, Flight- 161, Flight- 176, Flight- 191, Flight- 192, Flight- 201, Flight- 228, Flight- 233,
#
# 9V-SFP		789		5442108.941260841		Flight- 38, Flight- 136, Flight- 147, Flight- 175, Flight- 190, Flight- 193, Flight- 230, Flight- 251, Flight- 265, Flight- 266, Flight- 333, Flight- 348,
#
# 9V-SFO		707		3970050.5248753456		Flight- 14, Flight- 32, Flight- 49, Flight- 61, Flight- 127, Flight- 137, Flight- 160, Flight- 241, Flight- 298, Flight- 299, Flight- 328, Flight- 336,
#
# 9V-SMQ		532		4034800.858793987		Flight- 5, Flight- 16, Flight- 35, Flight- 66, Flight- 81, Flight- 83, Flight- 92, Flight- 135, Flight- 315, Flight- 345,
#
# 9V-SMN		717		4536208.255935828		Flight- 0, Flight- 26, Flight- 55, Flight- 62, Flight- 99, Flight- 103, Flight- 145, Flight- 188, Flight- 217, Flight- 277, Flight- 284, Flight- 287, Flight- 312,
#
# 9V-SMJ		321		3038364.137461204		Flight- 109, Flight- 153, Flight- 202, Flight- 208, Flight- 252, Flight- 275,
#
# 9V-SMM		421		2527582.2595283287		Flight- 6, Flight- 15, Flight- 47, Flight- 56, Flight- 60, Flight- 172, Flight- 207, Flight- 221,
#
# 9V-SMB		518		3252446.858184262		Flight- 2, Flight- 24, Flight- 25, Flight- 76, Flight- 116, Flight- 163, Flight- 165, Flight- 184, Flight- 203, Flight- 319,
#
# 9V-SMP		240		2331226.522779571		Flight- 8, Flight- 67, Flight- 97, Flight- 102,
#
# 9V-SMA		423		2883374.8051255327		Flight- 4, Flight- 91, Flight- 105, Flight- 167, Flight- 170, Flight- 212, Flight- 259, Flight- 344,
#
# 9V-SWY		335		2445735.807298554		Flight- 90, Flight- 128, Flight- 182, Flight- 185, Flight- 196, Flight- 260, Flight- 263, Flight- 309,
#
# 9V-SWR		37		1239401.4819316021		Flight- 41,
#
# 9V-SCB		429		2932149.870480275		Flight- 29, Flight- 39, Flight- 77, Flight- 171, Flight- 198, Flight- 227, Flight- 256, Flight- 264, Flight- 347,
#
# 9V-SWP		141		1820715.5178723526		Flight- 133, Flight- 195, Flight- 283, Flight- 301,
#
# 9V-SMK		480		2612252.9231001306		Flight- 19, Flight- 54, Flight- 69, Flight- 84, Flight- 197, Flight- 247, Flight- 258, Flight- 343,
#
# 9V-MGI		214		1544575.623573118		Flight- 3, Flight- 70, Flight- 121, Flight- 213, Flight- 281, Flight- 297,
#
# 9V-SMR		245		2216141.9558272604		Flight- 27, Flight- 52, Flight- 180, Flight- 250, Flight- 334,
#
# 9V-SWM		304		2423925.338499931		Flight- 73, Flight- 141, Flight- 156, Flight- 236, Flight- 238, Flight- 304, Flight- 327,
#
# 9V-SWH		323		3093648.095527076		Flight- 1, Flight- 21, Flight- 59, Flight- 104, Flight- 224, Flight- 292, Flight- 313, Flight- 340,
#
# 9V-SWO		292		2350757.5315578626		Flight- 34, Flight- 45, Flight- 113, Flight- 200, Flight- 248, Flight- 280, Flight- 294,
#
# 9V-MGF		131		1339352.7444668757		Flight- 162, Flight- 249, Flight- 255, Flight- 320,
#
# 9V-SWS		150		2109786.8481266988		Flight- 118, Flight- 288, Flight- 310, Flight- 326,
#
# 9V-SKU		603		3147728.1192415594		Flight- 88, Flight- 95, Flight- 114, Flight- 115, Flight- 124, Flight- 159, Flight- 181, Flight- 220,
#
# 9V-SME		287		2400854.9600545126		Flight- 178, Flight- 199, Flight- 239, Flight- 257, Flight- 329,
#
# 9V-SWK		326		2675538.942199736		Flight- 125, Flight- 151, Flight- 155, Flight- 225, Flight- 271, Flight- 282, Flight- 290, Flight- 339,
#
# 9V-SWN		199		2341411.2701683757		Flight- 80, Flight- 108, Flight- 177, Flight- 268, Flight- 306,
#
# ------------------------------------------------------------------------------------------------------------------
# Result		18826		131113975		43
# ------------------------------------------------------------------------------------------------------------------
# Original	19633		135440629		40
# ------------------------------------------------------------------------------------------------------------------
# Difference	-807		4326654			-3
# ------------------------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np
    
for i in range(len(y_plot_list)):
    plt.plot(x_plot_list, y_plot_list[i])

plt.show()

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 51867.55712175369 seconds ---

# %%
import pickle

with open('dera_output-10-40', 'wb') as fp:
    pickle.dump(result, fp)
with open('dera_xplot-10-40', 'wb') as fp:
    pickle.dump(x_plot_list, fp)
with open('dera_yplot-10-40', 'wb') as fp:
    pickle.dump(y_plot_list, fp)

# %%
with open('dera_output-10-40', 'rb') as fp:
    read_result = pickle.load(fp)
    
print(read_result)
# Out:
# [[0, 21, Timestamp('2020-11-20 17:14:59+0000', tz='UTC'), Timestamp('2020-11-21 06:48:59+0000', tz='UTC'), 47, 0.133], [1, 35, Timestamp('2020-11-20 18:27:55+0000', tz='UTC'), Timestamp('2020-11-21 07:48:57+0000', tz='UTC'), 35, 0.133], [2, 24, Timestamp('2020-11-20 16:43:20+0000', tz='UTC'), Timestamp('2020-11-21 05:39:18+0000', tz='UTC'), 47, 0.133], [3, 32, Timestamp('2020-11-21 05:44:59+0000', tz='UTC'), Timestamp('2020-11-21 18:14:59+0000', tz='UTC'), 29, 0.133], [4, 26, Timestamp('2020-11-20 18:18:48+0000', tz='UTC'), Timestamp('2020-11-21 04:10:12+0000', tz='UTC'), 49, 0.14], [5, 20, Timestamp('2020-11-21 01:27:39+0000', tz='UTC'), Timestamp('2020-11-21 08:31:06+0000', tz='UTC'), 60, 0.171], [6, 23, Timestamp('2020-11-21 02:19:29+0000', tz='UTC'), Timestamp('2020-11-21 09:14:54+0000', tz='UTC'), 60, 0.171], [7, 16, Timestamp('2020-11-20 20:02:05+0000', tz='UTC'), Timestamp('2020-11-21 04:34:48+0000', tz='UTC'), 53, 0.128], [8, 25, Timestamp('2020-11-20 21:01:38+0000', tz='UTC'), Timestamp('2020-11-21 09:16:45+0000', tz='UTC'), 60, 0.171], [9, 14, Timestamp('2020-11-20 21:26:06+0000', tz='UTC'), Timestamp('2020-11-21 06:41:53+0000', tz='UTC'), 55, 0.133], [10, 1, Timestamp('2020-11-20 22:21:21+0000', tz='UTC'), Timestamp('2020-11-21 05:10:47+0000', tz='UTC'), 49, 0.14], [11, 3, Timestamp('2020-11-20 23:21:25+0000', tz='UTC'), Timestamp('2020-11-21 09:35:51+0000', tz='UTC'), 60, 0.171], [12, 5, Timestamp('2020-11-21 03:37:03+0000', tz='UTC'), Timestamp('2020-11-21 17:26:02+0000', tz='UTC'), 55, 0.133], [13, 7, Timestamp('2020-11-21 02:30:04+0000', tz='UTC'), Timestamp('2020-11-21 08:59:52+0000', tz='UTC'), 71, 0.171], [14, 19, Timestamp('2020-11-21 03:07:03+0000', tz='UTC'), Timestamp('2020-11-21 06:16:27+0000', tz='UTC'), 53, 0.128], [15, 23, Timestamp('2020-11-21 09:44:54+0000', tz='UTC'), Timestamp('2020-11-21 17:29:58+0000', tz='UTC'), 60, 0.171], [16, 20, Timestamp('2020-11-21 09:01:06+0000', tz='UTC'), Timestamp('2020-11-21 16:43:48+0000', tz='UTC'), 60, 0.171], [17, 16, Timestamp('2020-11-21 06:32:16+0000', tz='UTC'), Timestamp('2020-11-21 11:06:39+0000', tz='UTC'), 71, 0.171], [18, 1, Timestamp('2020-11-21 06:32:24+0000', tz='UTC'), Timestamp('2020-11-21 14:17:22+0000', tz='UTC'), 47, 0.133], [19, 31, Timestamp('2020-11-21 07:55:25+0000', tz='UTC'), Timestamp('2020-11-21 18:15:52+0000', tz='UTC'), 60, 0.171], [20, 14, Timestamp('2020-11-21 09:24:06+0000', tz='UTC'), Timestamp('2020-11-21 16:09:35+0000', tz='UTC'), 58, 0.14], [21, 35, Timestamp('2020-11-21 09:31:00+0000', tz='UTC'), Timestamp('2020-11-21 21:03:58+0000', tz='UTC'), 45, 0.171], [22, 13, Timestamp('2020-11-21 10:27:44+0000', tz='UTC'), Timestamp('2020-11-21 11:38:48+0000', tz='UTC'), 47, 0.133], [23, 4, Timestamp('2020-11-21 10:33:18+0000', tz='UTC'), Timestamp('2020-11-21 22:31:29+0000', tz='UTC'), 60, 0.171], [24, 24, Timestamp('2020-11-21 10:38:05+0000', tz='UTC'), Timestamp('2020-11-21 10:50:28+0000', tz='UTC'), 47, 0.133], [25, 24, Timestamp('2020-11-21 11:20:28+0000', tz='UTC'), Timestamp('2020-11-21 22:57:06+0000', tz='UTC'), 60, 0.171], [26, 21, Timestamp('2020-11-21 11:06:23+0000', tz='UTC'), Timestamp('2020-11-21 22:54:41+0000', tz='UTC'), 60, 0.171], [27, 33, Timestamp('2020-11-21 12:02:34+0000', tz='UTC'), Timestamp('2020-11-21 22:48:44+0000', tz='UTC'), 60, 0.171], [28, 7, Timestamp('2020-11-21 11:43:39+0000', tz='UTC'), Timestamp('2020-11-21 14:38:28+0000', tz='UTC'), 71, 0.171], [29, 29, Timestamp('2020-11-21 13:25:20+0000', tz='UTC'), Timestamp('2020-11-21 16:51:58+0000', tz='UTC'), 34, 0.128], [30, 13, Timestamp('2020-11-21 12:50:57+0000', tz='UTC'), Timestamp('2020-11-22 00:58:16+0000', tz='UTC'), 60, 0.171], [31, 10, Timestamp('2020-11-21 12:55:20+0000', tz='UTC'), Timestamp('2020-11-21 21:22:54+0000', tz='UTC'), 60, 0.171], [32, 19, Timestamp('2020-11-21 13:10:08+0000', tz='UTC'), Timestamp('2020-11-21 22:01:52+0000', tz='UTC'), 47, 0.113], [33, 0, Timestamp('2020-11-21 13:42:36+0000', tz='UTC'), Timestamp('2020-11-22 01:30:22+0000 ...

# %%
with open('dera_yplot-10-40', 'rb') as fp:
    read_yplot = pickle.load(fp)
    
print(read_yplot)
# Out:
# [[3718.5721369126513, 3729.176599450621, 3729.176599450621, 3729.176599450621, 3729.176599450621, 3729.176599450621, 3729.176599450621, 3747.416976862627, 3749.5800279432137, 3751.887489161821, 3751.887489161821, 3751.887489161821, 3751.887489161821, 3763.966721169794, 3763.966721169794, 3763.966721169794, 3764.9035953996013, 3764.9035953996013, 3775.193713911185, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3775.203039030277, 3777.310555470089, 3783.4173593725136, 3783.4173593725136, 3783.4173593725136, 3783.4173593725136, 3783.4173593725136, 3783.4173593725136, 3783.4173593725136, 3783.4173593725136, 3783.4173593725136, 3783.4173593725136, 3789.1831334467256, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764, 3790.0703635226764], [3697.829219452172, 3699.9242111916737, 3706.6634006212953, 3706.6634006212953, 3706.6634006212953, 3706.6634006212953, 3716.475998075781, 3716.475998075781, 3716.475998075781, 3716.475998075781, 3716.9710775078884, 3716.9710775078884, 3721.207552119478, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3721.9773666495325, 3725.2763166882364, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3726.694310688308, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404, 3732.7506478478404], [3688.514195085352, 3688.514195085352, 3695.554904430645, 3698.28731937408, 3698.28731 ...

# %%
with open('dera_output-10-40', 'rb') as fp:
    read_result = pickle.load(fp)
    print(countFitness(read_result))
    
# print(read_result)
# Out:
# [3826.423706667131, 18826, 131113975.50216758, 43]
