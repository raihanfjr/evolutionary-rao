# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
import random
import operator
import pickle
from copy import deepcopy

# %%
df = pd.read_csv('flightlist-november.csv') 

print(df)
# Out:
#         callsign number  icao24 registration typecode origin destination  \
# 0        TUP6928    NaN  424450          NaN      NaN    NaN        UUWW
# 1         CSN399  CZ399  781795          NaN      NaN   YMML        KJFK
# 2         ETH714    NaN  040101       ET-ASG     B788   KEWR        ESSA
# 3          ZSALT    NaN  008142       ZS-ALT     B190    NaN        YPPH
# 4         IRM112  W5112  7335a1       EP-MMA     A343   WMKK        LTBW
# ...          ...    ...     ...          ...      ...    ...         ...
# 1825010   NKS236  NK236  ac97e1       N910NK      NaN    NaN        KFLL
# 1825011    AM333    NaN  7c6a57       VH-VAH     BE20   YMAV        YMEN
# 1825012   N404AM    NaN  a4bb89       N404AM     B407    NaN        1IL4
# 1825013   N383AK    NaN  a46679       N383AK      NaN   PAMR        PAMR
# 1825014   EJA426  1I426  a51358       N426QS     GLF4   KALN        KSUS
#
#                          firstseen                   lastseen  \
# 0        2020-10-31 01:29:44+00:00  2020-11-01 08:20:32+00:00
# 1        2020-10-31 01:36:33+00:00  2020-11-01 08:09:29+00:00
# 2        2020-10-31 02:07:17+00:00  2020-11-01 04:37:41+00:00
# 3        2020-10-31 03:33:19+00:00  2020-11-01 10:21:26+00:00
# 4        2020-10-31 03:58:50+00:00  2020-11-01 06:27:20+00:00
# ...                            ...                        ...
# 1825010  2020-11-30 23:36:31+00:00  2020-11-30 23:48:56+00:00
# 1825011  2020-11-30 23:36:47+00:00  2020-11-30 23:48:04+00:00
# 1825012  2020-11-30 23:37:40+00:00  2020-11-30 23:48:30+00:00
# 1825013  2020-11-30 23:37:41+00:00  2020-11-30 23:49:10+00:00
# 1825014  2020-11-30 23:38:09+00:00  2020-11-30 23:49:10+00:00
#
#                                day  latitude_1  longitude_1  altitude_1  \
# 0        2020-11-01 00:00:00+00:00   55.096390    83.177975      3962.4
# 1        2020-11-01 00:00:00+00:00  -37.679306   144.839776         0.0
# 2        2020-11-01 00:00:00+00:00   40.699677   -74.159973         0.0
# 3        2020-11-01 00:00:00+00:00    3.441971    99.149051      3962.4
# 4        2020-11-01 00:00:00+00:00    2.687073   101.735540       304.8
# ...                            ...         ...          ...         ...
# 1825010  2020-11-30 00:00:00+00:00   25.533949   -79.421669      3352.8
# 1825011  2020-11-30 00:00:00+00:00  -38.082275   144.500603       609.6
# 1825012  2020-11-30 00:00:00+00:00   38.586452   -90.448425         0.0
# 1825013  2020-11-30 00:00:00+00:00   61.202957  -149.835761       304.8
# 1825014  2020-11-30 00:00:00+00:00   38.893603   -90.052002       304.8
#
#          latitude_2  longitude_2  altitude_2
# 0         55.478723    37.030020      944.88
# 1         40.654999   -73.747314      -22.86
# 2         59.676710    17.968992      190.50
# 3        -31.957169   115.960199       91.44
# 4         41.183395    28.729309      533.40
# ...             ...          ...         ...
# 1825010   26.065292   -80.063125      396.24
# 1825011  -37.743298   144.901786      236.22
# 1825012   38.379501   -90.119973      518.16
# 1825013   61.213074  -149.846257      281.94
# 1825014   38.662844   -90.628601      137.16
#
# [1825015 rows x 16 columns]

# %%
dfs = df

# %%
dfs = dfs.drop(['number', 'icao24', 'altitude_1', 'altitude_2'], axis=1)

# %%
dfs = dfs.dropna(subset=['registration', 'typecode', 'origin', 'destination', 'latitude_2', 'longitude_2'])

# %%
dfs = dfs[dfs["callsign"].str[:3]=="SIA"]

# %%
dfs.head()
# Out:
#     callsign registration typecode origin destination  \
# 34    SIA377       9V-SMG     A359   LIMC        WSSS
# 161    SIA26       9V-SMI     A359   WSSS        EDDF
# 167   SIA324       9V-SMT     A359   WSSS        EHAM
# 171   SIA283       9V-SMD     A359   WSSS        NZAA
# 267   SIA346       9V-SMH     A359   WSSS        LSZH
#
#                      firstseen                   lastseen  \
# 34   2020-10-31 12:31:55+00:00  2020-11-01 00:48:28+00:00
# 161  2020-10-31 16:12:38+00:00  2020-11-01 04:36:47+00:00
# 167  2020-10-31 16:16:27+00:00  2020-11-01 04:55:17+00:00
# 171  2020-10-31 16:18:49+00:00  2020-11-01 01:19:01+00:00
# 267  2020-10-31 17:42:04+00:00  2020-11-01 06:16:57+00:00
#
#                            day  latitude_1  longitude_1  latitude_2  \
# 34   2020-11-01 00:00:00+00:00   45.623749     8.735337    1.308929
# 161  2020-11-01 00:00:00+00:00    1.395721   103.997048   50.040572
# 167  2020-11-01 00:00:00+00:00    1.389542   103.994720   52.357628
# 171  2020-11-01 00:00:00+00:00    1.394240   103.996298  -36.991241
# 267  2020-11-01 00:00:00+00:00    1.392471   103.996251   47.478653
#
#      longitude_2
# 34    103.960644
# 161     8.549163
# 167     4.711487
# 171   174.861496
# 267     8.540771

# %%
dfs.registration.unique()
# dfs.origin.unique()
# Out:
# array(['9V-SMG', '9V-SMI', '9V-SMT', '9V-SMD', '9V-SMH', '9V-SFN',
#        '9V-SMC', '9V-SFM', '9V-SMS', '9V-SFK', '9V-SML', '9V-SWQ',
#        '9V-MGL', '9V-SMF', '9V-SFQ', '9V-SWE', '9V-SFI', '9V-SMO',
#        '9V-SFP', '9V-SFO', '9V-SMQ', '9V-SMN', '9V-SMJ', '9V-SMM',
#        '9V-SMB', '9V-SMP', '9V-SMA', '9V-SWY', '9V-SWR', '9V-SCB',
#        '9V-SWP', '9V-SMK', '9V-MGI', '9V-SMR', '9V-SWM', '9V-SWH',
#        '9V-SWO', '9V-MGF', '9V-SWS', '9V-SKU', '9V-SME', '9V-SWK',
#        '9V-SWN'], dtype=object)

# %%
data = {'airport': [],
        'latitude': [],
        'longitude': []}

airports = pd.DataFrame(data)
print(airports)
# Out:
# Empty DataFrame
# Columns: [airport, latitude, longitude]
# Index: []

# %%
airports_data = dfs.origin.unique()
airports_another_data = dfs.destination.unique()

for i in airports_another_data:
    found = False
    for j in airports_data:
        if i == j:
            found = True
    if found == False:
        airports_data = np.append(airports_data, i)

# %%
print(airports_data)
# Out:
# ['LIMC' 'WSSS' 'OMSJ' 'EGLL' 'YSSY' 'YMML' 'NZAA' 'KORD' 'WBSB' 'VOMM'
#  'KDFW' 'EHAM' 'VHHH' 'EDDF' 'FAOR' 'YBBN' 'PANC' 'EBMB' 'WMKK' 'KLAX'
#  'LSZH' 'NZCH' 'VOBL' 'ZUCK' 'VABB' 'LFPG' 'EKCH' 'VIDP' 'FARA' 'EBBR'
#  'YPPH' 'LEBL' 'WSAC' 'VGZR' 'YSCB' 'RJAK' 'FAGM' 'LTBW' 'YTWB' 'YRED'
#  'TS53' 'YPWH' 'RJAA' 'LTBA' 'FABB' 'VGTJ' '6AK5' 'WIDD']

# %%
for i in airports_data:
    if (np.isnan(dfs[dfs["origin"]==i]["latitude_1"].median())):
        latitude = dfs[dfs["destination"]==i]["latitude_2"].median()
        longitude = dfs[dfs["destination"]==i]["longitude_2"].median()
        
    elif (np.isnan(dfs[dfs["destination"]==i]["latitude_2"].median())):
        latitude = dfs[dfs["origin"]==i]["latitude_1"].median()
        longitude = dfs[dfs["origin"]==i]["longitude_1"].median()
        
    else:
        latitude = (dfs[dfs["origin"]==i]["latitude_1"].median() + dfs[dfs["destination"]==i]["latitude_2"].median())/2
        longitude = (dfs[dfs["origin"]==i]["longitude_1"].median() + dfs[dfs["destination"]==i]["longitude_2"].median())/2
        
    airport = {'airport': i, 'latitude': latitude, 'longitude': longitude}
    airports = airports.append(airport, ignore_index=True)

print(airports)
# Out:
#    airport   latitude   longitude
# 0     LIMC  45.622997    8.729880
# 1     WSSS   1.349354  103.991831
# 2     OMSJ  25.333187   55.513881
# 3     EGLL  51.464928   -0.451351
# 4     YSSY -33.937398  151.173686
# 5     YMML -37.659397  144.836085
# 6     NZAA -37.007307  174.802684
# 7     KORD  41.967407  -87.905482
# 8     WBSB   4.943314  114.927863
# 9     VOMM  12.988395   80.164536
# 10    KDFW  32.904827  -97.050797
# 11    EHAM  52.329506    4.733640
# 12    VHHH  22.306459  113.907723
# 13    EDDF  50.045047    8.569396
# 14    FAOR -26.110302   28.248013
# 15    YBBN -27.383320  153.122108
# 16    PANC  61.179126 -150.017751
# 17    EBMB  50.909637    4.492666
# 18    WMKK   2.714566  101.717297
# 19    KLAX  33.936884 -118.397799
# 20    LSZH  47.467043    8.551562
# 21    NZCH -43.486825  172.534596
# 22    VOBL  13.189594   77.703107
# 23    ZUCK  29.778076  106.693145
# 24    VABB  19.088734   72.868544
# 25    LFPG  48.996591    2.563600
# 26    EKCH  55.612789   12.641687
# 27    VIDP  28.559853   77.113512
# 28    FARA -26.040070   28.290002
# 29    EBBR  50.899951    4.490988
# 30    YPPH -31.945056  115.963682
# 31    LEBL  41.243946    2.255799
# 32    WSAC   1.355883  104.011877
# 33    VGZR  23.810166   90.425202
# 34    YSCB -35.311934  149.194422
# 35    RJAK  35.937350  140.290852
# 36    FAGM -26.213150   28.215637
# 37    LTBW  41.195649   28.718870
# 38    YTWB -27.684998  151.934181
# 39    YRED -27.252937  153.181211
# 40    TS53  32.915543  -97.089313
# 41    YPWH -27.861511  151.637239
# 42    RJAA  35.736291  140.589996
# 43    LTBA  40.966736   28.866821
# 44    FABB -26.219757   28.231166
# 45    VGTJ  23.776183   90.456244
# 46    6AK5  61.167709 -150.083738
# 47    WIDD   1.111854  104.047252

# %%
e_asia = ["VOMM", "VHHH", "VOBL", "ZUCK", "VABB", "VIDP", "VGZR", "RJAK", "RJAA", "VGTJ"]
americas = ["KORD", "KDFW", "PANC", "KLAX", "TS53", "6AK5"]
europe = ["LIMC", "EGLL", "EHAM", "EDDF", "EBMB", "LSZH", "LFPG", "EKCH", "FARA", "EBBR", "LEBL"]
sw_pasific = ["WSSS", "YSSY", "YMML", "NZAA", "WBSB", "YBBN", "WMKK", "NZCH", "YPPH", "WSAC", "YSCB", "YTWB", "YRED", "YPWH", "WIDD"]
w_asia_africa = ["OMSJ", "FAOR", "FAGM", "LTBW", "LTBA", "FABB"]

# %%
region = []
load_rate = []
for i in range(len(airports)):
    for j in range(len(e_asia)):
        if(airports["airport"].iloc[i]==e_asia[j]):
            region.append("East Asia")
            load_rate.append(0.128)
            break
    for k in range(len(americas)):
        if(airports["airport"].iloc[i]==americas[k]):
            region.append("Americas")
            load_rate.append(0.113)
            break
    for l in range(len(europe)):
        if(airports["airport"].iloc[i]==europe[l]):
            region.append("Europe")
            load_rate.append(0.133)
            break
    for m in range(len(sw_pasific)):
        if(airports["airport"].iloc[i]==sw_pasific[m]):
            region.append("South West Pacific")
            load_rate.append(0.171)
            break
    for n in range(len(w_asia_africa)):
        if(airports["airport"].iloc[i]==w_asia_africa[n]):
            region.append("West Asia and Africa")
            load_rate.append(0.140)
            break
            
print(region)
# Out:
# ['Europe', 'South West Pacific', 'West Asia and Africa', 'Europe', 'South West Pacific', 'South West Pacific', 'South West Pacific', 'Americas', 'South West Pacific', 'East Asia', 'Americas', 'Europe', 'East Asia', 'Europe', 'West Asia and Africa', 'South West Pacific', 'Americas', 'Europe', 'South West Pacific', 'Americas', 'Europe', 'South West Pacific', 'East Asia', 'East Asia', 'East Asia', 'Europe', 'Europe', 'East Asia', 'Europe', 'Europe', 'South West Pacific', 'Europe', 'South West Pacific', 'East Asia', 'South West Pacific', 'East Asia', 'West Asia and Africa', 'West Asia and Africa', 'South West Pacific', 'South West Pacific', 'Americas', 'South West Pacific', 'East Asia', 'West Asia and Africa', 'West Asia and Africa', 'East Asia', 'Americas', 'South West Pacific']

# %%
airports['region'] = region
airports['load_rate'] = load_rate
print(airports)
# Out:
#    airport   latitude   longitude                region  load_rate
# 0     LIMC  45.622997    8.729880                Europe      0.133
# 1     WSSS   1.349354  103.991831    South West Pacific      0.171
# 2     OMSJ  25.333187   55.513881  West Asia and Africa      0.140
# 3     EGLL  51.464928   -0.451351                Europe      0.133
# 4     YSSY -33.937398  151.173686    South West Pacific      0.171
# 5     YMML -37.659397  144.836085    South West Pacific      0.171
# 6     NZAA -37.007307  174.802684    South West Pacific      0.171
# 7     KORD  41.967407  -87.905482              Americas      0.113
# 8     WBSB   4.943314  114.927863    South West Pacific      0.171
# 9     VOMM  12.988395   80.164536             East Asia      0.128
# 10    KDFW  32.904827  -97.050797              Americas      0.113
# 11    EHAM  52.329506    4.733640                Europe      0.133
# 12    VHHH  22.306459  113.907723             East Asia      0.128
# 13    EDDF  50.045047    8.569396                Europe      0.133
# 14    FAOR -26.110302   28.248013  West Asia and Africa      0.140
# 15    YBBN -27.383320  153.122108    South West Pacific      0.171
# 16    PANC  61.179126 -150.017751              Americas      0.113
# 17    EBMB  50.909637    4.492666                Europe      0.133
# 18    WMKK   2.714566  101.717297    South West Pacific      0.171
# 19    KLAX  33.936884 -118.397799              Americas      0.113
# 20    LSZH  47.467043    8.551562                Europe      0.133
# 21    NZCH -43.486825  172.534596    South West Pacific      0.171
# 22    VOBL  13.189594   77.703107             East Asia      0.128
# 23    ZUCK  29.778076  106.693145             East Asia      0.128
# 24    VABB  19.088734   72.868544             East Asia      0.128
# 25    LFPG  48.996591    2.563600                Europe      0.133
# 26    EKCH  55.612789   12.641687                Europe      0.133
# 27    VIDP  28.559853   77.113512             East Asia      0.128
# 28    FARA -26.040070   28.290002                Europe      0.133
# 29    EBBR  50.899951    4.490988                Europe      0.133
# 30    YPPH -31.945056  115.963682    South West Pacific      0.171
# 31    LEBL  41.243946    2.255799                Europe      0.133
# 32    WSAC   1.355883  104.011877    South West Pacific      0.171
# 33    VGZR  23.810166   90.425202             East Asia      0.128
# 34    YSCB -35.311934  149.194422    South West Pacific      0.171
# 35    RJAK  35.937350  140.290852             East Asia      0.128
# 36    FAGM -26.213150   28.215637  West Asia and Africa      0.140
# 37    LTBW  41.195649   28.718870  West Asia and Africa      0.140
# 38    YTWB -27.684998  151.934181    South West Pacific      0.171
# 39    YRED -27.252937  153.181211    South West Pacific      0.171
# 40    TS53  32.915543  -97.089313              Americas      0.113
# 41    YPWH -27.861511  151.637239    South West Pacific      0.171
# 42    RJAA  35.736291  140.589996             East Asia      0.128
# 43    LTBA  40.966736   28.866821  West Asia and Africa      0.140
# 44    FABB -26.219757   28.231166  West Asia and Africa      0.140
# 45    VGTJ  23.776183   90.456244             East Asia      0.128
# 46    6AK5  61.167709 -150.083738              Americas      0.113
# 47    WIDD   1.111854  104.047252    South West Pacific      0.171

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(lat1, lon1, lat2, lon2):

      R = 6378.1 #earth radius in km

      dLat = radians(lat2 - lat1)
      dLon = radians(lon2 - lon1)
      lat1 = radians(lat1)
      lat2 = radians(lat2)

      a = sin(dLat/2)**2 + cos(lat1)*cos(lat2)*sin(dLon/2)**2
      c = 2*asin(sqrt(a))

      return R * c

# %%
airport_dist = []

# print(len(airports))
# print(airports["latitude"].iloc[1])
for i in range(len(airports)):
    row = []
    for j in range(len(airports)):
        dist = haversine(airports["latitude"].iloc[i], airports["longitude"].iloc[i], airports["latitude"].iloc[j], airports["longitude"].iloc[j])
        row.append(dist)
    airport_dist.append(row)
    
print(airport_dist)
# Out:
# [[0.0, 10320.430258215578, 4717.841781312695, 937.1660268519785, 16609.560128529316, 16328.954466590929, 18532.59680591183, 7269.067818856925, 10868.089507810684, 7548.95074633125, 8547.656137571441, 801.3169185796232, 9367.722728633229, 492.40317589072635, 8226.20896899483, 16305.37145127493, 7994.969157835845, 666.7552359065804, 10035.00646673157, 9707.300556374426, 205.7303869886589, 18733.26757149964, 7342.358008596109, 8269.138067898637, 6515.603799301376, 597.7053144643955, 1145.392331724757, 6165.855188281992, 8219.648382286154, 665.8771017492281, 13763.71195323607, 714.7633108335267, 10321.464585191243, 7525.8491042544, 16538.803322184736, 9739.086961262197, 8236.528918768698, 1684.8073009086406, 16240.840339895418, 16299.853550010886, 8549.282279244859, 16231.958278267468, 9772.276447147076, 1706.5289191728648, 8237.618885773374, 7530.724450895547, 7997.137643355394, 10343.682712043537], [10320.430258215578, 0.0, 5841.7632385838115, 10894.76051264912, 6299.836779033911, 6038.438896550015, 8418.73633260409, 15068.744588255582, 1279.5010057485506, 2928.8002861878294, 15629.793631547207, 10527.265421668828, 2568.044722254665, 10290.596335412143, 8664.6708760633, 6150.109163748203, 10735.388681880311, 10566.321673598291, 295.1642203208813, 14118.598208005285, 10316.7968215347, 8412.83732523417, 3182.78032127795, 3177.546517831396, 3925.97264061222, 10735.785552170339, 9979.602726518628, 4162.711379891772, 8659.473513963996, 10566.592870740193, 3915.4931135500406, 10897.657772001752, 2.346255818210745, 2896.810574720782, 6218.429548740631, 5368.625060503927, 8669.39451207522, 8690.481931602231, 6056.067552693563, 6149.820325551374, 15626.779809616955, 6037.478416658099, 5376.563159517929, 8674.304631877993, 8667.954912411142, 2891.9234600277327, 10732.28529348282, 27.14817244047462], [4717.841781312695, 5841.7632385838115, 0.0, 5506.8618381394035, 12048.0465062446, 11649.800806282066, 14208.311769009377, 11653.51701532367, 6715.45708634375, 2925.7975035142226, 12931.98577783635, 5180.021024368576, 5909.281941024525, 4852.729801807736, 6432.468071091534, 11982.514029612448, 10135.328939956715, 5156.62005286444, 5546.606912613255, 13408.178593563865, 4777.860433835961, 14062.502015456803, 2688.7369433071267, 5034.7179282817, 1916.72379593414, 5247.629826986142, 4825.292960299169, 2170.1861289891613, 6423.595415009144, 5156.478901784671, 9046.378059979404, 5173.872130678893, 5843.287759886152, 3528.5121745318047, 11926.469286105654, 7956.359633934239, 6444.0353642012615, 3035.1468561185375, 11883.945104798386, 11983.058602550253, 12932.598121808254, 11863.338303540371, 7989.047891226768, 3012.486651697701, 6443.917975772616, 3532.2906358651935, 10135.1174669785, 5860.8374465065635], [937.1660268519785, 10894.76051264912, 5506.8618381394035, 0.0, 17038.360971755203, 16925.68607274427, 18384.972264798915, 6352.641899767896, 11294.007238315664, 8243.215397150638, 7636.805148062444, 368.84994843109445, 9641.050469242773, 654.1805012689989, 9081.354186250748, 16561.734354164048, 7209.1891097368825, 350.37749834459356, 10619.936469989312, 8770.375175195673, 787.9736159669434, 19005.39943512223, 8055.302858017427, 8544.453182630268, 7220.381364726168, 348.63996871279, 979.3847603022281, 6739.414795785145, 9075.17333846972, 350.48964845255233, 14523.847910406084, 1156.4275864777765, 10895.54267726216, 8027.9995280294925, 17029.349580281367, 9581.330257766034, 9091.289961308832, 2493.8459120463403, 16526.18991716695, 16552.579821679705, 7638.30620788436, 16526.313289986098, 9612.535110199567, 2519.1781225173677, 9092.459574789265, 8032.929097669114, 7211.614576108594, 10919.484974283207], [16609.560128529316, 6299.836779033911, 12048.0465062446, 17038.360971755203, 0.0, 706.1771528962224, 2163.4923737566182, 14878.267636807592, 5765.535532732732, 9138.29299935174, 13822.743285185885, 16677.203955988603, 7401.315329951462, 16513.708884399803, 11038.639144083883, 753.0182097296351, 11842.042921354594, 16754.7976630837, 6588.55598012932, ...

# %%
dfs['day'].value_counts()
# Out:
# 2020-11-28 00:00:00+00:00    40
# 2020-11-15 00:00:00+00:00    38
# 2020-11-25 00:00:00+00:00    38
# 2020-11-22 00:00:00+00:00    37
# 2020-11-16 00:00:00+00:00    37
# 2020-11-18 00:00:00+00:00    37
# 2020-11-29 00:00:00+00:00    37
# 2020-11-21 00:00:00+00:00    37
# 2020-11-23 00:00:00+00:00    36
# 2020-11-20 00:00:00+00:00    36
# 2020-11-04 00:00:00+00:00    35
# 2020-11-09 00:00:00+00:00    35
# 2020-11-14 00:00:00+00:00    35
# 2020-11-19 00:00:00+00:00    34
# 2020-11-13 00:00:00+00:00    34
# 2020-11-01 00:00:00+00:00    34
# 2020-11-30 00:00:00+00:00    34
# 2020-11-11 00:00:00+00:00    34
# 2020-11-07 00:00:00+00:00    33
# 2020-11-08 00:00:00+00:00    33
# 2020-11-26 00:00:00+00:00    33
# 2020-11-02 00:00:00+00:00    33
# 2020-11-27 00:00:00+00:00    33
# 2020-11-05 00:00:00+00:00    32
# 2020-11-12 00:00:00+00:00    32
# 2020-11-06 00:00:00+00:00    32
# 2020-11-17 00:00:00+00:00    30
# 2020-11-10 00:00:00+00:00    28
# 2020-11-03 00:00:00+00:00    27
# 2020-11-24 00:00:00+00:00    26
# Name: day, dtype: int64

# %%
# dfs[dfs["day"].isin({day, day_after})]

# %%
day = "2020-11-21 00:00:00+00:00"
# day_after = "2020-11-30 00:00:00+00:00"
day_after = "2020-11-22 00:00:00+00:00"
day_before = "2020-11-20 00:00:00+00:00"
dfx = dfs[dfs["day"]==day]
# dfx = dfs[dfs["day"].isin({day, day_after})]
# dfx = dfs[dfs["day"].isin({day, day_after})]
# dfx = dfs[(dfs["day"] >= day) & (dfs["day"] <= day_after)]
dfy = dfs[dfs["day"]<day]

# %%
print(dfx)
# Out:
#         callsign registration typecode origin destination  \
# 1208410   SIA322       9V-SMQ     A359   WSSS        EGLL
# 1208521   SIA324       9V-SMM     A359   WSSS        EHAM
# 1208877    SIA26       9V-SMB     A359   WSSS        EDDF
# 1211170   SIA352       9V-SMN     A359   WSSS        EKCH
# 1215881   SIA478       9V-SMA     A359   WSSS        FABB
# 1216201   SIA231       9V-SMI     A359   WSSS        YSSY
# 1220352  SIA7296       9V-SFP     B744   WSSS        YSSY
# 1223142  SIA7951       9V-SFI     B744   EBMB        VABB
# 1227439   SIA319       9V-SMP     A359   EGLL        WSSS
# 1229204  SIA7321       9V-SFQ     B744   KLAX        EHAM
# 1235197  SIA7394       9V-SFM     B744   WSSS        OMSJ
# 1237066   SIA298       9V-SMD     A359   NZCH        WSSS
# 1244788   SIA308       9V-SML     A359   WSSS        EGLL
# 1248094  SIA7294       9V-SFO     B744   WSSS        YMML
# 1249343  SIA7980       9V-SFN     B744   WSSS        VHHH
# 1250949  SIA7295       9V-SFP     B744   YSSY        WSSS
# 1252570   SIA222       9V-SMI     A359   YSSY        WSSS
# 1254447  SIA7951       9V-SFI     B744   VABB        WSSS
# 1254450  SIA7394       9V-SFM     B744   OMSJ        EHAM
# 1255556   SIA286       9V-SMK     A359   NZAA        WSSS
# 1258178  SIA7321       9V-SFQ     B744   EHAM        OMSJ
# 1258339   SIA323       9V-SMM     A359   EHAM        WSSS
# 1258967   SIA377       9V-SMF     A359   LEBL        LIMC
# 1259110   SIA335       9V-SMH     A359   LFPG        WSSS
# 1259997    SIA25       9V-SMB     A359   EDDF        EDDF
# 1260594    SIA25       9V-SMB     A359   EDDF        WSSS
# 1260751   SIA317       9V-SMQ     A359   EGLL        WSSS
# 1261597   SIA351       9V-SMR     A359   EKCH        WSSS
# 1261968  SIA7294       9V-SFO     B744   YMML        NZAA
# 1263660  SIA8028       9V-SCB     B78X   WSSS        VOMM
# 1264751   SIA447       9V-SWO     B77W   WSSS        WSSS
# 1265422  SIA7980       9V-SFN     B744   VHHH        PANC
# 1271487  SIA7870       9V-SFI     B744   WSSS        VHHH
# 1282361  SIA8029       9V-SCB     B78X   VOMM        WSSS
# 1285468  SIA7394       9V-SFM     B744   EHAM        EGLL
# 1287600  SIA7293       9V-SFO     B744   NZAA        YMML
# 1295141  SIA7869       9V-SFI     B744   VHHH        WSSS
#
#                          firstseen                   lastseen  \
# 1208410  2020-11-20 16:06:59+00:00  2020-11-21 05:40:59+00:00
# 1208521  2020-11-20 16:08:35+00:00  2020-11-21 05:29:37+00:00
# 1208877  2020-11-20 16:13:20+00:00  2020-11-21 05:09:18+00:00
# 1211170  2020-11-20 16:44:59+00:00  2020-11-21 05:14:59+00:00
# 1215881  2020-11-20 17:48:48+00:00  2020-11-21 03:40:12+00:00
# 1216201  2020-11-20 17:54:12+00:00  2020-11-21 00:57:39+00:00
# 1220352  2020-11-20 18:54:04+00:00  2020-11-21 01:49:29+00:00
# 1223142  2020-11-20 19:32:05+00:00  2020-11-21 04:04:48+00:00
# 1227439  2020-11-20 20:31:38+00:00  2020-11-21 08:46:45+00:00
# 1229204  2020-11-20 20:56:06+00:00  2020-11-21 06:11:53+00:00
# 1235197  2020-11-20 22:21:21+00:00  2020-11-21 05:10:47+00:00
# 1237066  2020-11-20 22:51:25+00:00  2020-11-21 09:05:51+00:00
# 1244788  2020-11-21 01:12:22+00:00  2020-11-21 15:01:21+00:00
# 1248094  2020-11-21 02:30:04+00:00  2020-11-21 08:59:52+00:00
# 1249343  2020-11-21 03:07:03+00:00  2020-11-21 06:16:27+00:00
# 1250949  2020-11-21 04:01:25+00:00  2020-11-21 11:46:29+00:00
# 1252570  2020-11-21 05:09:13+00:00  2020-11-21 12:51:55+00:00
# 1254447  2020-11-21 06:32:16+00:00  2020-11-21 11:06:39+00:00
# 1254450  2020-11-21 06:32:24+00:00  2020-11-21 14:17:22+00:00
# 1255556  2020-11-21 07:25:25+00:00  2020-11-21 17:45:52+00:00
# 1258178  2020-11-21 09:24:06+00:00  2020-11-21 16:09:35+00:00
# 1258339  2020-11-21 09:31:00+00:00  2020-11-21 21:03:58+00:00
# 1258967  2020-11-21 09:57:44+00:00  2020-11-21 11:08:48+00:00
# 1259110  2020-11-21 10:03:18+00:00  2020-11-21 22:01:29+00:00
# 1259997  2020-11-21 10:38:05+00:00  2020-11-21 10:50:28+00:00
# 1260594  2020-11-21 11:01:31+00:00  2020-11-21 22:38:09+00:00
# 1260751  2020-11-21 11:06:23+00:00  2020-11-21 22:54:41+00:00
# 1261597  2020-11-21 11:32:34+00:00  2020-11-21 22:18:44+00:00
# 1261968  2020-11-21 11:43:39+00:00  2020-11-21 14:38:28+00:00
# 1263660  2020-11-21 12:28:41+00:00  2020-11-21 15:55:19+00:00
# 1264751  2020-11-21 12:55:20+00:00  2020-11-21 21:22:54+00:00
# 1265422  2020-11-21 13:10:08+00:00  2020-11-21 22:01:52+00:00
# 1271487  2020-11-21 14:53:31+00:00  2020-11-21 17:54:56+00:00
# 1282361  2020-11-21 17:28:30+00:00  2020-11-21 20:59:48+00:00
# 1285468  2020-11-21 18:14:33+00:00  2020-11-21 18:55:57+00:00
# 1287600  2020-11-21 18:46:11+00:00  2020-11-21 22:14:24+00:00
# 1295141  2020-11-21 20:38:56+00:00  2020-11-21 23:54:22+00:00
#
#                                day  latitude_1  longitude_1  latitude_2  \
# 1208410  2020-11-21 00:00:00+00:00    1.376782   104.004680   51.477676
# 1208521  2020-11-21 00:00:00+00:00    1.373151   104.003543   52.366985
# 1208877  2020-11-21 00:00:00+00:00    1.369567   104.002407   50.030225
# 1211170  2020-11-21 00:00:00+00:00    1.371429   104.002691   55.628155
# 1215881  2020-11-21 00:00:00+00:00    1.369939   104.001980  -26.219757
# 1216201  2020-11-21 00:00:00+00:00    1.373151   104.003496  -33.919962
# 1220352  2020-11-21 00:00:00+00:00    1.398988   104.013488  -33.919310
# 1223142  2020-11-21 00:00:00+00:00   50.909295     4.491577   19.088652
# 1227439  2020-11-21 00:00:00+00:00   51.477651    -0.449219    1.315706
# 1229204  2020-11-21 00:00:00+00:00   33.933975  -118.416474   52.359629
# 1235197  2020-11-21 00:00:00+00:00    1.397172   104.013488   25.331726
# 1237066  2020-11-21 00:00:00+00:00  -43.491119   172.529616    1.325715
# 1244788  2020-11-21 00:00:00+00:00    1.370265   104.002501   51.477604
# 1248094  2020-11-21 00:00:00+00:00    1.397265   104.012919  -37.643463
# 1249343  2020-11-21 00:00:00+00:00    1.380600   104.005958   22.310765
# 1250949  2020-11-21 00:00:00+00:00  -33.950363   151.177032    1.321153
# 1252570  2020-11-21 00:00:00+00:00  -33.952595   151.177597    1.325272
# 1254447  2020-11-21 00:00:00+00:00   19.088792    72.872864    1.325109
# 1254450  2020-11-21 00:00:00+00:00   25.329849    55.519714   52.360933
# 1255556  2020-11-21 00:00:00+00:00  -37.021040   174.752058    1.317078
# 1258178  2020-11-21 00:00:00+00:00   52.298401     4.778061   25.319297
# 1258339  2020-11-21 00:00:00+00:00   52.297948     4.760141    1.310632
# 1258967  2020-11-21 00:00:00+00:00   41.282822     2.230347   45.623062
# 1259110  2020-11-21 00:00:00+00:00   49.022881     2.555152    1.312454
# 1259997  2020-11-21 00:00:00+00:00   50.046030     8.570728   50.046449
# 1260594  2020-11-21 00:00:00+00:00   50.044842     8.585671    1.314030
# 1260751  2020-11-21 00:00:00+00:00   51.477676    -0.444946    1.313690
# 1261597  2020-11-21 00:00:00+00:00   55.597092    12.610474    1.309708
# 1261968  2020-11-21 00:00:00+00:00  -37.690063   144.841588  -36.995063
# 1263660  2020-11-21 00:00:00+00:00    1.385239   104.007987   12.978104
# 1264751  2020-11-21 00:00:00+00:00    1.382182   104.006905    1.316683
# 1265422  2020-11-21 00:00:00+00:00   22.301082   113.913015   61.167664
# 1271487  2020-11-21 00:00:00+00:00    1.387583   104.008752   22.284760
# 1282361  2020-11-21 00:00:00+00:00   13.002133    80.202364    1.312363
# 1285468  2020-11-21 00:00:00+00:00   52.293339     4.748056   51.477596
# 1287600  2020-11-21 00:00:00+00:00  -37.021729   174.750873  -37.641441
# 1295141  2020-11-21 00:00:00+00:00   22.300690   113.911893    1.316218
#
#          longitude_2
# 1208410    -0.446357
# 1208521     4.712350
# 1208877     8.541035
# 1211170    12.671700
# 1215881    28.231166
# 1216201   151.169186
# 1220352   151.169014
# 1223142    72.863475
# 1227439   103.979440
# 1229204     4.711722
# 1235197    55.516403
# 1237066   103.983702
# 1244788    -0.446854
# 1248094   144.833114
# 1249343   113.897502
# 1250949   103.981807
# 1252570   103.983454
# 1254447   103.983417
# 1254450     4.711801
# 1255556   103.963995
# 1258178    55.538013
# 1258339   103.961303
# 1258967     8.724953
# 1259110   103.962040
# 1259997     8.584442
# 1260594   103.962723
# 1260751   103.962552
# 1261597   103.960876
# 1261968   174.847651
# 1263660    80.136835
# 1264751   103.963812
# 1265422  -150.084817
# 1271487   113.862305
# 1282361   103.962040
# 1285468    -0.460516
# 1287600   144.832764
# 1295141   103.963623

# %%
data = {'airplane': [],
        'type': [],
        'curr_loc': [],
        'last_seen': [],
        'capacity': [],
        'fixed_cost': [],
        'min_cost': [],
        'idle_cost': []}

airplanes = pd.DataFrame(data)
print(airplanes)
# Out:
# Empty DataFrame
# Columns: [airplane, type, curr_loc, last_seen, capacity, fixed_cost, min_cost, idle_cost]
# Index: []

# %%
airplanes_data = dfs.registration.unique()
print(airplanes_data)
# Out:
# ['9V-SMG' '9V-SMI' '9V-SMT' '9V-SMD' '9V-SMH' '9V-SFN' '9V-SMC' '9V-SFM'
#  '9V-SMS' '9V-SFK' '9V-SML' '9V-SWQ' '9V-MGL' '9V-SMF' '9V-SFQ' '9V-SWE'
#  '9V-SFI' '9V-SMO' '9V-SFP' '9V-SFO' '9V-SMQ' '9V-SMN' '9V-SMJ' '9V-SMM'
#  '9V-SMB' '9V-SMP' '9V-SMA' '9V-SWY' '9V-SWR' '9V-SCB' '9V-SWP' '9V-SMK'
#  '9V-MGI' '9V-SMR' '9V-SWM' '9V-SWH' '9V-SWO' '9V-MGF' '9V-SWS' '9V-SKU'
#  '9V-SME' '9V-SWK' '9V-SWN']

# %%
airplanes_capacity = []
airplanes_fixedcost = []
airplanes_idlecost = []
airplanes_minutecost = []

for i in range(len(airplanes_data)):
    for j in range(len(dfs)):
        if(dfs["registration"].iloc[j]==airplanes_data[i]):
            if(dfs["typecode"].iloc[j]=="A359"):
                capacity = 350
                min_cost = 244
                fixed_cost = 946069
                idle_min_cost = 195
            elif(dfs["typecode"].iloc[j]=="B744"):
                capacity = 416
                min_cost = 321
                fixed_cost = 851244
                idle_min_cost = 257
            elif(dfs["typecode"].iloc[j]=="B77W"):
                capacity = 264
                min_cost = 194
                fixed_cost = 969244
                idle_min_cost = 155
            elif(dfs["typecode"].iloc[j]=="B738"):
                capacity = 215
                min_cost = 116
                fixed_cost = 732745
                idle_min_cost = 92
            elif(dfs["typecode"].iloc[j]=="B78X"):
                capacity = 337
                min_cost = 187
                fixed_cost = 1001250
                idle_min_cost = 150
            elif(dfs["typecode"].iloc[j]=="A388"):
                capacity = 471
                min_cost = 433
                fixed_cost = 638418
                idle_min_cost = 347
            airplanes_capacity.append(int(capacity))
            airplanes_fixedcost.append(int(fixed_cost))
            airplanes_idlecost.append(int(idle_min_cost))
            airplanes_minutecost.append(int(min_cost))
            break

print(airplanes_capacity)
# Out:
# [350, 350, 350, 350, 350, 416, 350, 416, 350, 416, 350, 264, 215, 350, 416, 264, 416, 350, 416, 416, 350, 350, 350, 350, 350, 350, 350, 264, 264, 337, 264, 350, 215, 350, 264, 264, 264, 215, 264, 471, 350, 264, 264]

# %%
no_airplane = 0
for i in airplanes_data:
    for j in range(len(dfx)):
        if(dfx["registration"].iloc[j]==i):
            airplane = {'airplane': i,
                        'type': dfx["typecode"].iloc[j],
                        'curr_loc': dfx["origin"].iloc[j],
                        'last_seen': dfx["firstseen"].iloc[j],
                        'capacity': airplanes_capacity[no_airplane],
                        'fixed_cost': airplanes_fixedcost[no_airplane],
                        'min_cost': airplanes_minutecost[no_airplane],
                        'idle_cost': airplanes_idlecost[no_airplane]}
            
            airplanes = airplanes.append(airplane, ignore_index=True)
            break
        elif((j==(len(dfx)-1)) and (dfx["registration"].iloc[j]!=i)):
            for k in range(len(dfy)):
                if((k!=0) and (dfy["registration"].iloc[-k]==i)):
                    airplane = {'airplane': i,
                                'type': dfy["typecode"].iloc[-k],
                                'curr_loc': dfy["destination"].iloc[-k],
                                'last_seen': dfy["firstseen"].iloc[-k],
                                'capacity': airplanes_capacity[no_airplane],
                                'fixed_cost': airplanes_fixedcost[no_airplane],
                                'min_cost': airplanes_minutecost[no_airplane],
                                'idle_cost': airplanes_idlecost[no_airplane]}
                    
                    airplanes = airplanes.append(airplane, ignore_index=True)
                    break
                elif((k==(len(dfy)-1)) and (dfy["registration"].iloc[-k]!=i)):
                    for l in range(len(dfs)):
                        if((l!=0) and (dfs["registration"].iloc[-l]==i)):
                            airplane = {'airplane': i,
                                        'type': dfs["typecode"].iloc[-l],
                                        'curr_loc': "WSSS",
                                        'last_seen': day_before,
                                        'capacity': airplanes_capacity[no_airplane],
                                        'fixed_cost': airplanes_fixedcost[no_airplane],
                                        'min_cost': airplanes_minutecost[no_airplane],
                                        'idle_cost': airplanes_idlecost[no_airplane]}
                            airplanes = airplanes.append(airplane, ignore_index=True)
                            break
                            
    no_airplane = no_airplane + 1
    
print(airplanes)
# Out:
#    airplane  type curr_loc                  last_seen  capacity  fixed_cost  \
# 0    9V-SMG  A359     LSZH  2020-11-19 17:47:48+00:00     350.0    946069.0
# 1    9V-SMI  A359     WSSS  2020-11-20 17:54:12+00:00     350.0    946069.0
# 2    9V-SMT  A359     WSSS  2020-11-20 11:11:12+00:00     350.0    946069.0
# 3    9V-SMD  A359     NZCH  2020-11-20 22:51:25+00:00     350.0    946069.0
# 4    9V-SMH  A359     LFPG  2020-11-21 10:03:18+00:00     350.0    946069.0
# 5    9V-SFN  B744     WSSS  2020-11-21 03:07:03+00:00     416.0    851244.0
# 6    9V-SMC  A359     WSSS  2020-11-20 02:40:15+00:00     350.0    946069.0
# 7    9V-SFM  B744     WSSS  2020-11-20 22:21:21+00:00     416.0    851244.0
# 8    9V-SMS  A359     WSSS  2020-11-20 12:00:28+00:00     350.0    946069.0
# 9    9V-SFK  B744     WSSS  2020-11-18 20:05:28+00:00     416.0    851244.0
# 10   9V-SML  A359     WSSS  2020-11-21 01:12:22+00:00     350.0    946069.0
# 11   9V-SWQ  B77W     WSSS  2020-11-18 17:03:08+00:00     264.0    969244.0
# 12   9V-MGL  B738     WSSS  2020-11-01 04:23:41+00:00     215.0    732745.0
# 13   9V-SMF  A359     LEBL  2020-11-21 09:57:44+00:00     350.0    946069.0
# 14   9V-SFQ  B744     KLAX  2020-11-20 20:56:06+00:00     416.0    851244.0
# 15   9V-SWE  B77W     WSSS  2020-11-14 23:35:45+00:00     264.0    969244.0
# 16   9V-SFI  B744     EBMB  2020-11-20 19:32:05+00:00     416.0    851244.0
# 17   9V-SMO  A359     WSSS  2020-11-20 10:45:12+00:00     350.0    946069.0
# 18   9V-SFP  B744     WSSS  2020-11-20 18:54:04+00:00     416.0    851244.0
# 19   9V-SFO  B744     WSSS  2020-11-21 02:30:04+00:00     416.0    851244.0
# 20   9V-SMQ  A359     WSSS  2020-11-20 16:06:59+00:00     350.0    946069.0
# 21   9V-SMN  A359     WSSS  2020-11-20 16:44:59+00:00     350.0    946069.0
# 22   9V-SMJ  A359     WSSS  2020-11-20 09:37:04+00:00     350.0    946069.0
# 23   9V-SMM  A359     WSSS  2020-11-20 16:08:35+00:00     350.0    946069.0
# 24   9V-SMB  A359     WSSS  2020-11-20 16:13:20+00:00     350.0    946069.0
# 25   9V-SMP  A359     EGLL  2020-11-20 20:31:38+00:00     350.0    946069.0
# 26   9V-SMA  A359     WSSS  2020-11-20 17:48:48+00:00     350.0    946069.0
# 27   9V-SWY  B77W     LTBA  2020-11-19 18:10:36+00:00     264.0    969244.0
# 28   9V-SWR  B77W     LTBW  2020-11-14 18:06:35+00:00     264.0    969244.0
# 29   9V-SCB  B78X     WSSS  2020-11-21 12:28:41+00:00     337.0   1001250.0
# 30   9V-SWP  B77W     LTBW  2020-11-12 18:10:17+00:00     264.0    969244.0
# 31   9V-SMK  A359     NZAA  2020-11-21 07:25:25+00:00     350.0    946069.0
# 32   9V-MGI  B738     WSSS  2020-11-15 04:06:48+00:00     215.0    732745.0
# 33   9V-SMR  A359     EKCH  2020-11-21 11:32:34+00:00     350.0    946069.0
# 34   9V-SWM  B77W     RJAA  2020-11-19 01:29:20+00:00     264.0    969244.0
# 35   9V-SWH  B77W     WSSS  2020-11-20 17:57:55+00:00     264.0    969244.0
# 36   9V-SWO  B77W     WSSS  2020-11-21 12:55:20+00:00     264.0    969244.0
# 37   9V-MGF  B738     WSSS  2020-11-20 00:00:00+00:00     215.0    732745.0
# 38   9V-SWS  B77W     WSSS  2020-11-20 00:00:00+00:00     264.0    969244.0
# 39   9V-SKU  A388     WSSS  2020-11-20 00:00:00+00:00     471.0    638418.0
# 40   9V-SME  A359     WSSS  2020-11-20 00:00:00+00:00     350.0    946069.0
# 41   9V-SWK  B77W     WSSS  2020-11-20 00:00:00+00:00     264.0    969244.0
# 42   9V-SWN  B77W     WSSS  2020-11-20 00:00:00+00:00     264.0    969244.0
#
#     min_cost  idle_cost
# 0      244.0      195.0
# 1      244.0      195.0
# 2      244.0      195.0
# 3      244.0      195.0
# 4      244.0      195.0
# 5      321.0      257.0
# 6      244.0      195.0
# 7      321.0      257.0
# 8      244.0      195.0
# 9      321.0      257.0
# 10     244.0      195.0
# 11     194.0      155.0
# 12     116.0       92.0
# 13     244.0      195.0
# 14     321.0      257.0
# 15     194.0      155.0
# 16     321.0      257.0
# 17     244.0      195.0
# 18     321.0      257.0
# 19     321.0      257.0
# 20     244.0      195.0
# 21     244.0      195.0
# 22     244.0      195.0
# 23     244.0      195.0
# 24     244.0      195.0
# 25     244.0      195.0
# 26     244.0      195.0
# 27     194.0      155.0
# 28     194.0      155.0
# 29     187.0      150.0
# 30     194.0      155.0
# 31     244.0      195.0
# 32     116.0       92.0
# 33     244.0      195.0
# 34     194.0      155.0
# 35     194.0      155.0
# 36     194.0      155.0
# 37     116.0       92.0
# 38     194.0      155.0
# 39     433.0      347.0
# 40     244.0      195.0
# 41     194.0      155.0
# 42     194.0      155.0

# %%
max_delay = 180 #minute
min_safe = 30 #minute
max_arrival = max_delay - min_safe

def createSchedule():
    created = False
    while(created==False):
        airplanes_temp = airplanes.copy()
        schedule = []
        wakeup = time.time() + 10
        for i in range(len(dfx)):
            flight = [i]

            found = False
            while (found == False):
                id_airplane = random.randint(0, len(airplanes)-1)
                if (pd.to_datetime(airplanes_temp["last_seen"].iloc[id_airplane]) < (pd.to_datetime(dfx["firstseen"].iloc[i])+ datetime.timedelta(minutes=max_arrival)) and airplanes_temp["curr_loc"].iloc[id_airplane]==dfx["origin"].iloc[i]):
                    found = True
                else:
                    if (time.time() > wakeup):
                        break       

            airplanes_temp["curr_loc"].iloc[id_airplane]=dfx["destination"].iloc[i]

            if (pd.to_datetime(airplanes_temp["last_seen"].iloc[id_airplane]) < (pd.to_datetime(dfx["firstseen"].iloc[i]) - datetime.timedelta(minutes=min_safe))):
                departure = pd.to_datetime(dfx["firstseen"].iloc[i])
                arrival = departure + (pd.to_datetime(dfx["lastseen"].iloc[i])-pd.to_datetime(dfx["firstseen"].iloc[i]))
                airplanes_temp["last_seen"].iloc[id_airplane]=arrival
            else:
                departure = pd.to_datetime(airplanes_temp["last_seen"].iloc[id_airplane]) + datetime.timedelta(minutes=min_safe)
                arrival = departure + (pd.to_datetime(dfx["lastseen"].iloc[i])-pd.to_datetime(dfx["firstseen"].iloc[i]))
                airplanes_temp["last_seen"].iloc[id_airplane]=arrival

            for j in range(len(airports)):
                if(airports["airport"].iloc[j]==dfx["destination"].iloc[i]):
                    load_rate = airports["load_rate"].iloc[j]
                    break     

            passenger = round(airplanes_temp["capacity"].iloc[id_airplane] * load_rate)

            flight.extend([id_airplane, departure, arrival, passenger, load_rate])
            schedule.append(flight)
        if(len(dfx)==len(schedule)):
            created = True
    
    return schedule

# %%
def createOriginalSchedule():
    schedule = []
    for i in range(len(dfx)):
        flight=[i]
        for j in range(len(airplanes)):
            if(airplanes["airplane"].iloc[j]==dfx["registration"].iloc[i]):
                break
        flight.append(j)
        flight.append(pd.to_datetime(dfx["firstseen"].iloc[i]))
        flight.append(pd.to_datetime(dfx["lastseen"].iloc[i]))
        for k in range(len(airports)):
            if(airports["airport"].iloc[k]==dfx["destination"].iloc[i]):
                break
        flight.append(round(airplanes["capacity"].iloc[j] * airports["load_rate"].iloc[k]))
        flight.append(airports["load_rate"].iloc[k])
        
        schedule.append(flight)
        
    return schedule

# %%
# normalisasi passengger & cost
# cost = fixed cost & minute cost
def countOriginalFitness(schedule):
    fitness = []
    cost = 0
    passenger = 0
    plane_count = 0
    for i in range(len(schedule)):
        if(airplanes["type"].iloc[schedule[i][1]]=="A359"):
            min_cost = 244
        elif(airplanes["type"].iloc[schedule[i][1]]=="B744"):
            min_cost = 321
        elif(airplanes["type"].iloc[schedule[i][1]]=="B77W"):
            min_cost = 194
        elif(airplanes["type"].iloc[schedule[i][1]]=="B738"):
            min_cost = 116
        elif(airplanes["type"].iloc[schedule[i][1]]=="B78X"):
            min_cost = 187
        elif(airplanes["type"].iloc[schedule[i][1]]=="A388"):
            min_cost = 433
        cost = cost + round((schedule[i][3]-schedule[i][2]).seconds/60)*min_cost
        passenger = passenger + schedule[i][4]
        
        for k in range(len(airports)):
            if(airports["airport"].iloc[k]==dfx["origin"].iloc[i]):
                origin_id = k
            if(airports["airport"].iloc[k]==dfx["destination"].iloc[i]):
                destination_id = k
        
        cost = cost + airport_dist[origin_id][destination_id]
        
    for j in range(len(airplanes)):
        plane_used = False
        idle_sec = 0
        fixed_cost = 0
        first_flight = pd.to_datetime(airplanes["last_seen"].iloc[j])
        last_flight = pd.to_datetime(dfx["lastseen"].iloc[len(dfx)-1])
        
        for k in range(len(schedule)):
            if(schedule[k][1]==j):
                if(plane_used==False):
                    plane_used = True
                    plane_count = plane_count + 1
                    lastflight_pos = k
                    idle_sec = idle_sec + (schedule[k][2] - first_flight).seconds
                else:
                    idle_sec = idle_sec + (schedule[k][2] - schedule[lastflight_pos][2]).seconds
                    lastflight_pos = k
                    
        if(plane_used==False):
            idle_sec = idle_sec + (last_flight - first_flight).seconds
            fixed_cost = 0
        else:
            idle_sec = idle_sec + (last_flight - schedule[lastflight_pos][3]).seconds
            if(airplanes["type"].iloc[j]=="A359"):
                fixed_cost = 946069
            elif(airplanes["type"].iloc[j]=="B744"):
                fixed_cost = 851244
            elif(airplanes["type"].iloc[j]=="B77W"):
                fixed_cost = 969244
            elif(airplanes["type"].iloc[j]=="B738"):
                fixed_cost = 732745
            elif(airplanes["type"].iloc[j]=="B78X"):
                fixed_cost = 1001250
            elif(airplanes["type"].iloc[j]=="A388"):
                fixed_cost = 638418
        
        if(airplanes["type"].iloc[j]=="A359"):
            idle_min_cost = 195
        elif(airplanes["type"].iloc[j]=="B744"):
            idle_min_cost = 257
        elif(airplanes["type"].iloc[j]=="B77W"):
            idle_min_cost = 155
        elif(airplanes["type"].iloc[j]=="B738"):
            idle_min_cost = 92
        elif(airplanes["type"].iloc[j]=="B78X"):
            idle_min_cost = 150
        elif(airplanes["type"].iloc[j]=="A388"):
            idle_min_cost = 347
        
        cost = cost + round(idle_sec/60)*idle_min_cost
        cost = cost + fixed_cost
#     
#     fitness_val = (((passenger-0)/(4270-0)*1000)-((cost-0)/(50898241-0)*1000))
    fitness_val = cost-passenger
    fitness.append(fitness_val)
    fitness.append(passenger)
    fitness.append(cost)
    fitness.append(plane_count)
    
    return fitness

# %%
# normalisasi passengger & cost
# cost = fixed cost & minute cost
def countAirplaneFitness(schedule, airplane_id):
    fitness = []
    cost = 0
    passenger = 0
    plane_used = False
    idle_sec = 0
    idle_min_cost = 0
    fixed_cost = 0
    id = airplane_id
    for i in range(len(schedule)):
        if(schedule[i][1]==id):
            if(airplanes["type"].iloc[id]=="A359"):
                min_cost = 244
            elif(airplanes["type"].iloc[id]=="B744"):
                min_cost = 321
            elif(airplanes["type"].iloc[id]=="B77W"):
                min_cost = 194
            elif(airplanes["type"].iloc[id]=="B738"):
                min_cost = 116
            elif(airplanes["type"].iloc[id]=="B78X"):
                min_cost = 187
            elif(airplanes["type"].iloc[id]=="A388"):
                min_cost = 433
            cost = cost + round((schedule[i][3]-schedule[i][2]).seconds/60)*min_cost
            passenger = passenger + schedule[i][4]
            
            for k in range(len(airports)):
                if(airports["airport"].iloc[k]==dfx["origin"].iloc[i]):
                    origin_id = k
                if(airports["airport"].iloc[k]==dfx["destination"].iloc[i]):
                    destination_id = k

            cost = cost + airport_dist[origin_id][destination_id]
        
    first_flight = pd.to_datetime(airplanes["last_seen"].iloc[id])
    last_flight = pd.to_datetime(dfx["lastseen"].iloc[len(dfx)-1])

    for k in range(len(schedule)):
        if(schedule[k][1]==id):
            if(plane_used==False):
                plane_used = True
                lastflight_pos = k
                idle_sec = idle_sec + (schedule[k][2] - first_flight).seconds
            else:
                idle_sec = idle_sec + (schedule[k][2] - schedule[lastflight_pos][2]).seconds
                lastflight_pos = k

    if(plane_used==False):
        idle_sec = idle_sec + (last_flight - first_flight).seconds
        fixed_cost = 0
    else:
        idle_sec = idle_sec + (last_flight - schedule[lastflight_pos][3]).seconds
        if(airplanes["type"].iloc[id]=="A359"):
            fixed_cost = 946069
        elif(airplanes["type"].iloc[id]=="B744"):
            fixed_cost = 851244
        elif(airplanes["type"].iloc[id]=="B77W"):
            fixed_cost = 969244
        elif(airplanes["type"].iloc[id]=="B738"):
            fixed_cost = 732745
        elif(airplanes["type"].iloc[id]=="B78X"):
            fixed_cost = 1001250
        elif(airplanes["type"].iloc[id]=="A388"):
            fixed_cost = 638418

    if(airplanes["type"].iloc[id]=="A359"):
        idle_min_cost = 195
    elif(airplanes["type"].iloc[id]=="B744"):
        idle_min_cost = 257
    elif(airplanes["type"].iloc[id]=="B77W"):
        idle_min_cost = 155
    elif(airplanes["type"].iloc[id]=="B738"):
        idle_min_cost = 92
    elif(airplanes["type"].iloc[id]=="B78X"):
        idle_min_cost = 150
    elif(airplanes["type"].iloc[id]=="A388"):
        idle_min_cost = 347

    cost = cost + round(idle_sec/60)*idle_min_cost
    cost = cost + fixed_cost
    
    originalFitness = countOriginalFitness(createOriginalSchedule())
    
    fitness_val = (((passenger-0)/(originalFitness[1]-0)*500)-((cost-0)/(originalFitness[2]-0)*100))
#     fitness_val = cost-passenger
    fitness.append(fitness_val)
    fitness.append(passenger)
    fitness.append(cost)
    
    return fitness

# %%
# normalisasi passengger & cost
# cost = fixed cost & minute cost
def countFitness(schedule):
    fitness = []
    cost = 0
    passenger = 0
    plane_count = 0
    for i in range(len(schedule)):
        if(airplanes["type"].iloc[schedule[i][1]]=="A359"):
            min_cost = 244
        elif(airplanes["type"].iloc[schedule[i][1]]=="B744"):
            min_cost = 321
        elif(airplanes["type"].iloc[schedule[i][1]]=="B77W"):
            min_cost = 194
        elif(airplanes["type"].iloc[schedule[i][1]]=="B738"):
            min_cost = 116
        elif(airplanes["type"].iloc[schedule[i][1]]=="B78X"):
            min_cost = 187
        elif(airplanes["type"].iloc[schedule[i][1]]=="A388"):
            min_cost = 433
        cost = cost + round((schedule[i][3]-schedule[i][2]).seconds/60)*min_cost
        passenger = passenger + schedule[i][4]
        
        for k in range(len(airports)):
            if(airports["airport"].iloc[k]==dfx["origin"].iloc[i]):
                origin_id = k
            if(airports["airport"].iloc[k]==dfx["destination"].iloc[i]):
                destination_id = k
        
        cost = cost + airport_dist[origin_id][destination_id]
        
    for j in range(len(airplanes)):
        plane_used = False
        idle_sec = 0
        fixed_cost = 0
        first_flight = pd.to_datetime(airplanes["last_seen"].iloc[j])
        last_flight = pd.to_datetime(dfx["lastseen"].iloc[len(dfx)-1])
        
        for k in range(len(schedule)):
            if(schedule[k][1]==j):
                if(plane_used==False):
                    plane_used = True
                    plane_count = plane_count + 1
                    lastflight_pos = k
                    idle_sec = idle_sec + (schedule[k][2] - first_flight).seconds
                else:
                    idle_sec = idle_sec + (schedule[k][2] - schedule[lastflight_pos][2]).seconds
                    lastflight_pos = k
                    
        if(plane_used==False):
            idle_sec = idle_sec + (last_flight - first_flight).seconds
            fixed_cost = 0
        else:
            idle_sec = idle_sec + (last_flight - schedule[lastflight_pos][3]).seconds
            if(airplanes["type"].iloc[j]=="A359"):
                fixed_cost = 946069
            elif(airplanes["type"].iloc[j]=="B744"):
                fixed_cost = 851244
            elif(airplanes["type"].iloc[j]=="B77W"):
                fixed_cost = 969244
            elif(airplanes["type"].iloc[j]=="B738"):
                fixed_cost = 732745
            elif(airplanes["type"].iloc[j]=="B78X"):
                fixed_cost = 1001250
            elif(airplanes["type"].iloc[j]=="A388"):
                fixed_cost = 638418
        
        if(airplanes["type"].iloc[j]=="A359"):
            idle_min_cost = 195
        elif(airplanes["type"].iloc[j]=="B744"):
            idle_min_cost = 257
        elif(airplanes["type"].iloc[j]=="B77W"):
            idle_min_cost = 155
        elif(airplanes["type"].iloc[j]=="B738"):
            idle_min_cost = 92
        elif(airplanes["type"].iloc[j]=="B78X"):
            idle_min_cost = 150
        elif(airplanes["type"].iloc[j]=="A388"):
            idle_min_cost = 347
        
        cost = cost + round(idle_sec/60)*idle_min_cost
        cost = cost + fixed_cost
        
    originalFitness = countOriginalFitness(createOriginalSchedule())
    
    fitness_val = (((passenger-0)/(originalFitness[1]-0)*500)-((cost-0)/(originalFitness[2]-0)*100))
#     fitness_val = cost-passenger
    fitness.append(fitness_val)
    fitness.append(passenger)
    fitness.append(cost)
    fitness.append(plane_count)
    
    return fitness

# %%
def elite(population):
    curr_elite = 0
    for i in range(len(population)):
        if(population[i][0] > population[curr_elite][0]):
            curr_elite = i
    return curr_elite

# %%
def roulleteWheel(population):
    sump = 0
    sumpart = 0
    worst = 0
    
    for k in range(len(population)):
#         print("worst", population[worst][0])
        if(population[k][0] < population[worst][0]):
            worst = k 
    
    for i in range(len(population)):
        if(population[worst][0] < 0):
            sump = sump + population[i][0] - population[worst][0]
        else:
            sump = sump + population[i][0]
#         print("sump", sump)
    
    rand = random.uniform(0, sump)
#     print("Random", rand)
    
    for j in range(len(population)):
        if(population[worst][0] < 0):
            sumpart = sumpart + population[j][0] - population[worst][0]
        else:
            sumpart = sumpart + population[j][0]
#         print("sumpart", sumpart)
        if(sumpart > rand):
            break
    
    return j

# %%
def swapPlane(flight1, flight2):
    newflight1 = []
    newflight2 = []
    result = []

#     print(flight1[1])
#     print(flight2[1])
    
    newflight1.append(flight1[0])
    newflight2.append(flight2[0])
    
    newflight1.append(flight2[1])
    newflight2.append(flight1[1])
    
#     print(newflight1[1])
#     print(newflight2[1])
    
    newflight1.append(flight2[2])
    newflight2.append(flight1[2])

    newflight1.append(flight1[2] + (flight2[3] - flight2[2]))
    newflight2.append(flight2[2] + (flight1[3] - flight1[2]))
    
    newflight1.append(round(airplanes["capacity"].iloc[flight1[1]] * flight2[5]))
    newflight2.append(round(airplanes["capacity"].iloc[flight2[1]] * flight1[5]))
    
    newflight1.append(flight1[5])
    newflight2.append(flight2[5])
    
    result = [newflight1, newflight2]
    return result

# %%
def rao3(solution, rand_solution, best_solution, worst_solution):  
    rao3_done = False
    while (rao3_done == False):
#         print(1)
        rand_flight = random.randint(0, len(solution)-1)        
        airplanelist = []
        for i in range(len(airplanes)):
            airplane = [i, airplanes["curr_loc"].iloc[i], airplanes["last_seen"].iloc[i], airplanes["capacity"].iloc[i], airplanes["fixed_cost"].iloc[i], airplanes["min_cost"].iloc[i], airplanes["idle_cost"].iloc[i], 0]
            airplanelist.append(airplane)
        for j in range(rand_flight):
            airplanelist[solution[j][1]][1] = dfx["destination"].iloc[j]
            airplanelist[solution[j][1]][2] = solution[j][3]

        available_airplanes = []
        for airplane in airplanelist:
            if (airplane[0] != solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
                available_airplanes.append(airplane)
        
#         print(2)        
        if(len(available_airplanes) >= 3):
            rao3_solution = []
            variables = ["capacity", "fixed_cost", "min_cost", "idle_cost"]
            for variable in variables:
                xsolution = airplanes[variable].iloc[solution[rand_flight][1]]
                xrandsolution = airplanes[variable].iloc[rand_solution[rand_flight][1]]
                xbests = airplanes[variable].iloc[best_solution[rand_flight][1]]
                xworst = airplanes[variable].iloc[worst_solution[rand_flight][1]]
                

                if(countFitness(solution)[0] > countFitness(rand_solution)[0]):
                    or1 = xsolution
                    or2 = xrandsolution
                else:
                    or1 = xrandsolution
                    or2 = xsolution
                    
                xsolution = xsolution + (random.random()*(xbests- abs(xworst))) + (random.random()*(abs(or1) - abs(or2)))
                rao3_solution.append(xsolution)
                
#             print(3)
            for k in range(len(rao3_solution)):
                max_val = rao3_solution[k]*2
                for airplane in available_airplanes:
                    val_diff = abs(rao3_solution[k] - airplane[k+3])                    
                    rate = ((max_val - val_diff) / (max_val - 0))*0.25
                    
                    airplane[-1] = airplane[-1] +  rate
            
#             print(4)
            new_solution = []
            available_airplanes = sorted(available_airplanes,key=lambda l:l[7], reverse=True)
            airplane1 = solution[rand_flight][1]
            airplane2 = available_airplanes[0][0]
            last_pos1 = -1
            last_pos2 = -1
            for l in range(len(solution)):
                if(l < rand_flight):
                    new_solution.append(solution[l])
                    if(solution[l][1]==airplane1):
                        last_pos1 = l
                    elif(solution[l][1]==airplane2):
                        last_pos2 = l   
                else:                                        
                    newflight = solution[l]
                    newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
                    if(solution[l][1]==airplane1):
                        newflight[1] = airplane2                        
                        if(last_pos2 > -1):
                            if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
                                newflight[2] = new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)
                                newflight[3] = new_solution[last_pos2][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
                        last_pos2 = l        
                    elif(solution[l][1]==airplane2):
                        newflight[1] = airplane1                        
                        if(last_pos1 > -1):
                            if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
                                newflight[2] = new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)
                                newflight[3] = new_solution[last_pos1][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
                        last_pos1 = l 
                    new_solution.append(newflight)                    
#             print(5)
            rao3_done = True

    return new_solution

# %%
# def crossover(besthq, xbest):
#     crossover_done = False
#     while (crossover_done == False):
#         solution = deepcopy(besthq)
#         best_solution = deepcopy(xbest)
#         rand_flight = random.randint(0, len(solution)-1)        
#         airplanelist1 = []
#         airplanelist2 = []
#         for i in range(len(airplanes)):
#             airplane = [i, airplanes["curr_loc"].iloc[i], airplanes["last_seen"].iloc[i], airplanes["capacity"].iloc[i], airplanes["fixed_cost"].iloc[i], airplanes["min_cost"].iloc[i], airplanes["idle_cost"].iloc[i], 0]
#             airplanelist1.append(airplane)
#             airplanelist2.append(airplane)
#         for j in range(rand_flight):
#             airplanelist1[solution[j][1]][1] = dfx["destination"].iloc[j]
#             airplanelist1[solution[j][1]][2] = solution[j][3]
#             airplanelist2[best_solution[j][1]][1] = dfx["destination"].iloc[j]
#             airplanelist2[best_solution[j][1]][2] = best_solution[j][3]

#         available_airplanes1 = []
#         available_airplanes2 = []
#         for airplane in airplanelist1:
#             if (airplane[0] != solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
#                 available_airplanes1.append(airplane)
#         for airplane in airplanelist2:        
#             if (airplane[0] != best_solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
#                 available_airplanes2.append(airplane)    
                
#         if(len(available_airplanes1) >= 3 and len(available_airplanes2) >= 3):
#             crossover_solution1 = []
#             crossover_solution2 = []
#             variables = ["capacity", "fixed_cost", "min_cost", "idle_cost"]
#             for variable in variables:
#                 xsolution = airplanes[variable].iloc[solution[rand_flight][1]]
#                 xbests = airplanes[variable].iloc[best_solution[rand_flight][1]]
                
#                 r = random.random()
#                 while (r==0.5):
#                     r = random.random()
#                 xsolution1 = r*xsolution + (1-r)*xbests
#                 xsolution2 = r*xbests + (1-r)*xsolution
#                 crossover_solution1.append(xsolution1)
#                 crossover_solution2.append(xsolution2)
            
#             for k in range(len(crossover_solution1)):
#                 max_val = crossover_solution1[k]*2
#                 for airplane in available_airplanes1:
#                     val_diff = abs(crossover_solution1[k] - airplane[k+3])                    
#                     rate = ((max_val - val_diff) / (max_val - 0))*0.25
                    
#                     airplane[-1] = airplane[-1] +  rate
                    
#             for m in range(len(crossover_solution2)):
#                 max_val = crossover_solution2[m]*2
#                 for airplane in available_airplanes2:
#                     val_diff = abs(crossover_solution2[m] - airplane[m+3])                    
#                     rate = ((max_val - val_diff) / (max_val - 0))*0.25
                    
#                     airplane[-1] = airplane[-1] +  rate
                    
#             new_solution1 = []
#             available_airplanes1 = sorted(available_airplanes1,key=lambda l:l[7], reverse=True)
#             airplane1 = solution[rand_flight][1]
#             airplane2 = available_airplanes1[0][0]
#             last_pos1 = -1
#             last_pos2 = -1
#             for l in range(len(solution)):
#                 if(l < rand_flight):
#                     new_solution1.append(solution[l])
#                     if(solution[l][1]==airplane1):
#                         last_pos1 = l
#                     elif(solution[l][1]==airplane2):
#                         last_pos2 = l   
#                 else:                                        
#                     newflight = solution[l]
#                     newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
#                     if(solution[l][1]==airplane1):
#                         newflight[1] = airplane2                        
#                         if(last_pos2 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution1[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution1[last_pos2][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution1[last_pos2][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos2 = l        
#                     elif(solution[l][1]==airplane2):
#                         newflight[1] = airplane1                        
#                         if(last_pos1 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution1[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution1[last_pos1][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution1[last_pos1][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos1 = l 
#                     new_solution1.append(newflight)
                    
#             new_solution2 = []
#             available_airplanes2 = sorted(available_airplanes2,key=lambda l:l[7], reverse=True)
#             airplane1 = best_solution[rand_flight][1]
#             airplane2 = available_airplanes2[0][0]
#             last_pos1 = -1
#             last_pos2 = -1
#             for l in range(len(best_solution)):
#                 if(l < rand_flight):
#                     new_solution2.append(best_solution[l])
#                     if(best_solution[l][1]==airplane1):
#                         last_pos1 = l
#                     elif(best_solution[l][1]==airplane2):
#                         last_pos2 = l   
#                 else:                                        
#                     newflight = best_solution[l]
#                     newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
#                     if(best_solution[l][1]==airplane1):
#                         newflight[1] = airplane2                        
#                         if(last_pos2 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution2[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution2[last_pos2][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution2[last_pos2][3] + (best_solution[l][3]-best_solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos2 = l        
#                     elif(best_solution[l][1]==airplane2):
#                         newflight[1] = airplane1                        
#                         if(last_pos1 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution2[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution2[last_pos1][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution2[last_pos1][3] + (best_solution[l][3]-best_solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos1 = l 
#                     new_solution2.append(newflight)
            
#             crossover_done = True

#     return new_solution1, new_solution2

# %%
# biar crossover ama randomwalk lebih sering, 
# data last seen pesawat dicek dipenerbangan terakhirnya kalo ada kalo g ada pake last seen di data pesawat
def crossOver(solution, crossover_range):
    doneCrossover = False
    cross_range = round(crossover_range * len(solution))
#     print(cross_range)
    try_time = 0
    while(doneCrossover==False):
        solutionCopy = solution[:]
#         solutionCopy2 = solution[:]
        while True:
            if(try_time > 3 and cross_range >= 3):
                cross_range = cross_range - 1
                try_time = 1
            condition = []
            range1 = random.randint(0, len(solutionCopy)-1-cross_range)
#             range1 = random.randint(0, len(solutionCopy)-1)
            if(cross_range >= 3):
                range2 = range1 + cross_range
            else:
                range2 = range1 + 2
#             range2 = random.randint(0, len(solutionCopy)-1)
            if(range1 < range2 and range1+1!=range2):
                for o in range(range1, range2+1):
                    if(dfx["origin"].iloc[o]!="WSSS"):
                        condition.append(False)

                    else:
                        condition.append(True)
            else:
                condition.append(False)
                print(condition)
            if False not in condition:
                break
                try_time = try_time + 1
            else:
                try_time = try_time + 1
            
        while True:
            cut1 = random.randint(range1, range2)
            cut2 = random.randint(range1, range2)
            if(cut1 < cut2 and cut1+1!=cut2):
                break

        crossover_pos = 0
        exc = []
        constructed_position = [solutionCopy[cut1], solutionCopy[cut2]]
        for i in range(range1, range2+1):
            if(i!=cut1 and i!=cut2):
                constructed_position.append(solution[i])
                    
        index = 0
        for j in range(range1, range2+1):
            condition = []
            last_pos = constructed_position[index][0]

            for p in range(len(constructed_position)):
                if(constructed_position[p][0]==j):
                    index_j = p
            for k in range(len(solution)):
                if(solution[k][1]==constructed_position[index][1] and solution[k][0] < range1):
                    last_pos = solution[k][0]
                elif(solutionCopy[k][0]==constructed_position[index][0]):
                    break
            if(last_pos==constructed_position[index][0]):
                plane_lastseen_time = pd.to_datetime(airplanes["last_seen"].iloc[constructed_position[index][1]])
                plane_lastseen_place = dfx["origin"].iloc[last_pos]
            else:
                plane_lastseen_time = solution[last_pos][3]
                plane_lastseen_place = dfx["destination"].iloc[last_pos]

            if(plane_lastseen_time < (pd.to_datetime(dfx["firstseen"].iloc[j]) + datetime.timedelta(minutes=max_arrival)) and plane_lastseen_place==dfx["origin"].iloc[j]):
                condition.append(True)

                newflight = []
                newflight.append(j)
                newflight.append(constructed_position[index][1])

                if(plane_lastseen_time > (pd.to_datetime(dfx["firstseen"].iloc[j]) - datetime.timedelta(minutes=min_safe))):
                    departure = plane_lastseen_time + datetime.timedelta(minutes=min_safe)
                else:
                    departure = pd.to_datetime(dfx["firstseen"].iloc[j])

                newflight.append(departure)
                arrival = departure + (constructed_position[index_j][3] - constructed_position[index_j][2])
                newflight.append(arrival)
                newflight.append(round(airplanes["capacity"].iloc[constructed_position[index][1]] * constructed_position[index_j][5]))
                newflight.append(constructed_position[index_j][5])


                ext = []
                if(constructed_position[index][0]!=constructed_position[index_j][0]):
                    for l in range(range2, len(solutionCopy)-1):
                        if(solutionCopy[l][0]!=constructed_position[index][0] and solutionCopy[l][0] not in exc):
                            if(constructed_position[index_j][1]==solutionCopy[l][1]):
                                ext.append(solutionCopy[l][0])
                                exc.append(solutionCopy[l][0])

                solutionCopy[j] = newflight

                for m in (ext):
                    new_flight = []
                    new_flight.append(solutionCopy[m][0])
                    new_flight.append(newflight[1])
                    if(pd.to_datetime(dfx["firstseen"].iloc[m]) > newflight[3] + datetime.timedelta(minutes=min_safe)):
                        new_flight.append(pd.to_datetime(dfx["firstseen"].iloc[m]))
                        new_flight.append(pd.to_datetime(dfx["lastseen"].iloc[m]))
                    else:
                        new_flight.append(newflight[3] + datetime.timedelta(minutes=min_safe))
                        new_flight.append(newflight[3] + (solutionCopy[m][3]-solutionCopy[m][2]) + datetime.timedelta(minutes=min_safe))
                    new_flight.append(round(airplanes["capacity"].iloc[newflight[1]] * solutionCopy[m][5]))
                    new_flight.append(solutionCopy[m][5])


                    solutionCopy[m] = new_flight
                    newflight = solutionCopy[m]

                index = index+1

            else:
                condition.append(False)
                index = index+1
                
        solutionCopy1 = solutionCopy[:]
        solutionCopy = solution[:]
        exc = []
        constructed_position = []
        for i in range(range1, range2+1):
            if(i!=cut1 and i!=cut2):
                constructed_position.append(solution[i])
        constructed_position.append(solutionCopy[cut1])
        constructed_position.append(solutionCopy[cut2])
                    
        index = 0
        for j in range(range1, range2+1):
            condition = []
            last_pos = constructed_position[index][0]

            for p in range(len(constructed_position)):
                if(constructed_position[p][0]==j):
                    index_j = p
            for k in range(len(solution)):
                if(solution[k][1]==constructed_position[index][1] and solution[k][0] < range1):
                    last_pos = solution[k][0]
                elif(solutionCopy[k][0]==constructed_position[index][0]):
                    break
            if(last_pos==constructed_position[index][0]):
                plane_lastseen_time = pd.to_datetime(airplanes["last_seen"].iloc[constructed_position[index][1]])
                plane_lastseen_place = dfx["origin"].iloc[last_pos]
            else:
                plane_lastseen_time = solution[last_pos][3]
                plane_lastseen_place = dfx["destination"].iloc[last_pos]

            if(plane_lastseen_time < (pd.to_datetime(dfx["firstseen"].iloc[j]) + datetime.timedelta(minutes=max_arrival)) and plane_lastseen_place==dfx["origin"].iloc[j]):
                condition.append(True)

                newflight = []
                newflight.append(j)
                newflight.append(constructed_position[index][1])

                if(plane_lastseen_time > (pd.to_datetime(dfx["firstseen"].iloc[j]) - datetime.timedelta(minutes=min_safe))):
                    departure = plane_lastseen_time + datetime.timedelta(minutes=min_safe)
                else:
                    departure = pd.to_datetime(dfx["firstseen"].iloc[j])

                newflight.append(departure)
                arrival = departure + (constructed_position[index_j][3] - constructed_position[index_j][2])
                newflight.append(arrival)
                newflight.append(round(airplanes["capacity"].iloc[constructed_position[index][1]] * constructed_position[index_j][5]))
                newflight.append(constructed_position[index_j][5])


                ext = []
                if(constructed_position[index][0]!=constructed_position[index_j][0]):
                    for l in range(range2, len(solutionCopy)-1):
                        if(solutionCopy[l][0]!=constructed_position[index][0] and solutionCopy[l][0] not in exc):
                            if(constructed_position[index_j][1]==solutionCopy[l][1]):
                                ext.append(solutionCopy[l][0])
                                exc.append(solutionCopy[l][0])

                solutionCopy[j] = newflight

                for m in (ext):
                    new_flight = []
                    new_flight.append(solutionCopy[m][0])
                    new_flight.append(newflight[1])
                    if(pd.to_datetime(dfx["firstseen"].iloc[m]) > newflight[3] + datetime.timedelta(minutes=min_safe)):
                        new_flight.append(pd.to_datetime(dfx["firstseen"].iloc[m]))
                        new_flight.append(pd.to_datetime(dfx["lastseen"].iloc[m]))
                    else:
                        new_flight.append(newflight[3] + datetime.timedelta(minutes=min_safe))
                        new_flight.append(newflight[3] + (solutionCopy[m][3]-solutionCopy[m][2]) + datetime.timedelta(minutes=min_safe))
                    new_flight.append(round(airplanes["capacity"].iloc[newflight[1]] * solutionCopy[m][5]))
                    new_flight.append(solutionCopy[m][5])


                    solutionCopy[m] = new_flight
                    newflight = solutionCopy[m]

                index = index+1

            else:
                condition.append(False)
                index = index+1
                
        solutionCopy2 = solutionCopy[:]
        if False not in condition:
            doneCrossover = True
            
    return solutionCopy1, solutionCopy2

# %%
# def mutation(xbest, var_a, var_b):  
#     mutation_done = False
#     solution = deepcopy(xbest)
#     if(random.random() >= var_b):
#         mutation_done = True
#         new_solution = solution
#     while (mutation_done == False):
#         solution = deepcopy(xbest)
#         rand_flight = random.randint(0, len(solution)-1)        
#         airplanelist = []
#         for i in range(len(airplanes)):
#             airplane = [i, airplanes["curr_loc"].iloc[i], airplanes["last_seen"].iloc[i], airplanes["capacity"].iloc[i], airplanes["fixed_cost"].iloc[i], airplanes["min_cost"].iloc[i], airplanes["idle_cost"].iloc[i], 0]
#             airplanelist.append(airplane)
#         for j in range(rand_flight):
#             airplanelist[solution[j][1]][1] = dfx["destination"].iloc[j]
#             airplanelist[solution[j][1]][2] = solution[j][3]

#         available_airplanes = []
#         for airplane in airplanelist:
#             if (airplane[0] != solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
#                 available_airplanes.append(airplane)
                
#         if(len(available_airplanes) >= 3):
#             mutation_solution = []
#             variables = ["capacity", "fixed_cost", "min_cost", "idle_cost"]
#             index = 3
#             for variable in variables:
#                 airplanelist = sorted(airplanelist,key=lambda l:l[index], reverse=True)
#                 xsolution = airplanes[variable].iloc[solution[rand_flight][1]]               
#                 uppervar =  airplanelist[0][index]
#                 lowervar =  airplanelist[-1][index]
#                 xsolution = xsolution + (2*random.random()-1) * var_a*abs(uppervar - lowervar)
#                 mutation_solution.append(xsolution)
#                 index = index + 1
            
#             for k in range(len(mutation_solution)):
#                 max_val = mutation_solution[k]*2
#                 for airplane in available_airplanes:
#                     val_diff = abs(mutation_solution[k] - airplane[k+3])                    
#                     rate = ((max_val - val_diff) / (max_val - 0))*0.25
                    
#                     airplane[-1] = airplane[-1] +  rate
            
#             new_solution = []
#             available_airplanes = sorted(available_airplanes,key=lambda l:l[7], reverse=True)
#             airplane1 = solution[rand_flight][1]
#             airplane2 = available_airplanes[0][0]
#             last_pos1 = -1
#             last_pos2 = -1
#             for l in range(len(solution)):
#                 if(l < rand_flight):
#                     new_solution.append(solution[l])
#                     if(solution[l][1]==airplane1):
#                         last_pos1 = l
#                     elif(solution[l][1]==airplane2):
#                         last_pos2 = l   
#                 else:                                        
#                     newflight = solution[l]
#                     newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
#                     if(solution[l][1]==airplane1):
#                         newflight[1] = airplane2                        
#                         if(last_pos2 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution[last_pos2][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos2 = l        
#                     elif(solution[l][1]==airplane2):
#                         newflight[1] = airplane1                        
#                         if(last_pos1 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution[last_pos1][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos1 = l 
#                     new_solution.append(newflight)                    
#             mutation_done = True

#     return new_solution

# %%
def mutation(solution, solutions, mutation_range):
    doneMutation = False
    mut_range = round(mutation_range * len(solution))
    try_time = 0
    while(doneMutation==False):        
        mut_range = round(mutation_range * len(solution))
        solutionCopy = solution[:]
        while True:
            if(try_time > 3 and mut_range >= 3):
                mut_range = mut_range - 1
                try_time = 1
            condition = []
            range1 = random.randint(0, len(solutionCopy)-1-mut_range)
#             range1 = random.randint(0, len(solutionCopy)-1)
            if(mut_range >= 3):
                range2 = range1 + mut_range
            else:
                range2 = range1 + 2
#             range2 = random.randint(0, len(solutionCopy)-1)
            if(range1 < range2 and range1+1!=range2):
                for o in range(range1, range2+1):
                    if(dfx["origin"].iloc[o]!="WSSS"):
                        condition.append(False)
#                         print("False")
                    else:
                        condition.append(True)
#                         print("True")
            else:
                condition.append(False)
            if False not in condition:
                break
                try_time = try_time + 1
            else:
                try_time = try_time + 1
                
        while True:
            empty_position = []
            constructed_position = []
            changeable_pos = 0
            for a in range(range1, range2+1):
                if(random.randint(0, 1) == 1):
                    constructed_position.append(solutionCopy[a])
                    empty_position.append(solutionCopy[a][0])
                    changeable_pos = changeable_pos + 1
            if(changeable_pos > 1):
                break
            
        
        condition = []
        real_exc = []
        for b in range(len(constructed_position)):
            index = constructed_position[b][0]
#             print("B", index)
            last_pos = constructed_position[b][0]
            found_position = False
            for k in range(len(solutionCopy)):
                if(solution[k][1]==constructed_position[b][1] and solution[k][0] < constructed_position[b][0]):
                    last_pos = solution[k][0]
                elif(solutionCopy[k][0]==constructed_position[b][0]):
                    break
            if(last_pos==constructed_position[b][0]):
                plane_lastseen_time = pd.to_datetime(airplanes["last_seen"].iloc[constructed_position[b][1]])
                plane_lastseen_place = dfx["origin"].iloc[last_pos]
            else:
                plane_lastseen_time = solutionCopy[last_pos][3]
                plane_lastseen_place = dfx["destination"].iloc[last_pos]
            
            for c in range(len(empty_position)):
                exc = real_exc[:]
                best_exc = []
                index_c = empty_position[c]
                solutionCopyCopy = solutionCopy[:]
                if(plane_lastseen_time < (pd.to_datetime(dfx["firstseen"].iloc[index_c]) + datetime.timedelta(minutes=max_arrival)) and plane_lastseen_place==dfx["origin"].iloc[index_c]):
                    
                    newflight = []
                    newflight.append(index_c)
                    newflight.append(constructed_position[b][1])

                    if(plane_lastseen_time > (pd.to_datetime(dfx["firstseen"].iloc[index_c]) - datetime.timedelta(minutes=min_safe))):
                        departure = plane_lastseen_time + datetime.timedelta(minutes=min_safe)
                    else:
                        departure = pd.to_datetime(dfx["firstseen"].iloc[index_c])

                    newflight.append(departure)
                    arrival = departure + (constructed_position[c][3] - constructed_position[c][2])
                    newflight.append(arrival)
                    newflight.append(round(airplanes["capacity"].iloc[constructed_position[b][1]] * constructed_position[c][5]))
                    newflight.append(constructed_position[c][5])


                    ext = []
                    if(constructed_position[b][0]!=index_c):
                        for l in range(range2, len(solutionCopy)-1):
                            if(solutionCopy[l][0]!=constructed_position[b][0] and solutionCopy[l][0] not in exc):
                                if(solutionCopy[index_c][1]==solutionCopy[l][1]):
#                                     print("index_c", index_c)
#                                     print("solutionCopy[index_c][1]", solutionCopy[index_c][1])
                                    ext.append(solutionCopy[l][0])
                                    exc.append(solutionCopy[l][0])

                    solutionCopyCopy[index_c] = newflight
#                     print(ext)

                    for m in (ext):
                        new_flight = []
                        new_flight.append(solutionCopyCopy[m][0])
                        new_flight.append(newflight[1])
                        if(pd.to_datetime(dfx["firstseen"].iloc[m]) > newflight[3] + datetime.timedelta(minutes=min_safe)):
                            new_flight.append(pd.to_datetime(dfx["firstseen"].iloc[m]))
                            new_flight.append(pd.to_datetime(dfx["lastseen"].iloc[m]))
                        else:
                            new_flight.append(newflight[3] + datetime.timedelta(minutes=min_safe))
                            new_flight.append(newflight[3] + (solutionCopyCopy[m][3]-solutionCopyCopy[m][2]) + datetime.timedelta(minutes=min_safe))
                        new_flight.append(round(airplanes["capacity"].iloc[newflight[1]] * solutionCopyCopy[m][5]))
                        new_flight.append(solutionCopyCopy[m][5])


                        solutionCopyCopy[m] = new_flight
                        newflight = solutionCopyCopy[m]
#                         print(new_flight)
                        
                    if(found_position == False):
                        best_position = solutionCopyCopy[:]
                        best_c = c
#                         print("Best position", index_c)
                        temp_exc = exc
                    elif(found_position == True and countFitness(solutionCopyCopy)[0] > countFitness(best_position)[0]):
                        best_position = solutionCopyCopy[:]
                        best_c = c
#                         print("Best position", index_c)
                        temp_exc = exc
                        
                    found_position = True
                    
            if(found_position == True):
                condition.append(True)
                solutionCopy = best_position[:]
                empty_position.pop(best_c)
#                 print("Fitness", countFitness(solutionCopy)[0])
                real_exc.extend(temp_exc)
            else:
                condition.append(False)
                
        if False not in condition:
            done_swap = True
            while (done_swap==False):
                while True:
                    selected_solution = random.randint(0, len(solutions)-1)
                    if(solution != solutions[selected_solution][0]):
                        break
                for o in range(range1, range2+1):
                    if(random.randint(0, 1)==0):
                        found = False
                        for p in range(len(solutionCopy)):
                            if (solutionCopy[p][1]==solutions[selected_solution][0][o][1] and solutionCopy[p][0] < solutionCopy[o][0]):
                                ant_fpos = solutionCopy[p][0]
                                found = True
                            elif (solutionCopy[p][0]==solutionCopy[o][0] and found==True):
                                break
                            elif (solutionCopy[p][1]==solutions[selected_solution][0][o][1] and solutionCopy[p][0] > solutionCopy[o][0]):
                                ant_fpos = solutionCopy[p][0]
                                found = True
                                break

                        if(found==True):
                            last_pos1 = solutionCopy[o][0]
                            last_pos2 = solutionCopy[ant_fpos][0]

                            for a in range(len(solutionCopy)):
                                if(solutionCopy[a][1]==solutionCopy[o][1] and solutionCopy[a][0] < solutionCopy[o][0]):
                                    last_pos1 = solutionCopy[a][0]
                                elif(solutionCopy[a][0]==solutionCopy[o][0]):
                                    break

                            if(last_pos1==solutionCopy[o][0]):
                                plane_lastseen_time1 = pd.to_datetime(airplanes["last_seen"].iloc[solutionCopy[o][1]])
                                plane_lastseen_place1 = dfx["origin"].iloc[last_pos1]
                            else:
                                plane_lastseen_time1 = solutionCopy[last_pos1][3]
                                plane_lastseen_place1 = dfx["destination"].iloc[last_pos1]

                            for b in range(len(solutionCopy)):
                                if(solutionCopy[b][1]==solutionCopy[ant_fpos][1] and solutionCopy[b][0] < solutionCopy[ant_fpos][0]):
                                    last_pos2 = solutionCopy[b][0]
                                elif(solutionCopy[b][0]==solutionCopy[ant_fpos][0]):
                                    break

                            if(last_pos2==solutionCopy[ant_fpos][0]):
                                plane_lastseen_time2 = pd.to_datetime(airplanes["last_seen"].iloc[solutionCopy[ant_fpos][1]])
                                plane_lastseen_place2 = dfx["origin"].iloc[last_pos2]
                            else:
                                plane_lastseen_time2 = solutionCopy[last_pos2][3]
                                plane_lastseen_place2 = dfx["destination"].iloc[last_pos2]

                            if(plane_lastseen_time1 < pd.to_datetime(dfx["firstseen"].iloc[ant_fpos]) + datetime.timedelta(minutes=max_arrival) and plane_lastseen_place1==plane_lastseen_place2):
                                if(plane_lastseen_time2 < pd.to_datetime(dfx["firstseen"].iloc[o]) + datetime.timedelta(minutes=max_arrival) and plane_lastseen_place2==plane_lastseen_place1):
                                    done_swap = True
                                    flight1 = solutionCopy[o]
                                    flight2 = solutionCopy[ant_fpos]

                                    result = swapPlane(flight1, flight2)

                                    solutionCopy[o] = result[0]
                                    solutionCopy[ant_fpos] = result[1]

                                    newflight1 = result[0]
                                    newflight2 = result[1]

                                    ext1 = []
                                    ext2 = []
                                    for k in range(range2, len(solutionCopy)-1):
                                        if(solutionCopy[k][0]!=flight1[0] and solutionCopy[k][0]!=flight2[0]):
                                            if(flight1[1]==solutionCopy[k][1]):
                                                ext1.append(solutionCopy[k][0])
                                            elif(flight2[1]==solutionCopy[k][1]):
                                                ext2.append(solutionCopy[k][0])

                                    for l in (ext1):
                                        newflight = []
                                        newflight.append(solutionCopy[l][0])
                                        newflight.append(newflight1[1])
                                        if(pd.to_datetime(dfx["firstseen"].iloc[l]) > newflight1[3] + datetime.timedelta(minutes=min_safe)):
                                            newflight.append(pd.to_datetime(dfx["firstseen"].iloc[l]))
                                            newflight.append(pd.to_datetime(dfx["lastseen"].iloc[l]))
                                        else:
                                            newflight.append(newflight1[3] + datetime.timedelta(minutes=min_safe))
                                            newflight.append(newflight1[3] + (solutionCopy[l][3]-solutionCopy[l][2]) + datetime.timedelta(minutes=min_safe))
                                        newflight.append(round(airplanes["capacity"].iloc[newflight1[1]] * solutionCopy[l][5]))
                                        newflight.append(solutionCopy[l][5])

                                        newflight1 = newflight
                                        solutionCopy[l] = newflight

                                    for m in (ext2):
                                        newflight = []
                                        newflight.append(solutionCopy[m][0])
                                        newflight.append(newflight2[1])
                                        if(pd.to_datetime(dfx["firstseen"].iloc[m]) > newflight2[3] + datetime.timedelta(minutes=min_safe)):
                                            newflight.append(pd.to_datetime(dfx["firstseen"].iloc[m]))
                                            newflight.append(pd.to_datetime(dfx["lastseen"].iloc[m]))
                                        else:
                                            newflight.append(newflight2[3] + datetime.timedelta(minutes=min_safe))
                                            newflight.append(newflight2[3] + (solutionCopy[m][3]-solutionCopy[m][2]) + (solutionCopy[m][3]-solutionCopy[m][2]) + datetime.timedelta(minutes=min_safe))
                                        newflight.append(round(airplanes["capacity"].iloc[newflight2[1]] * solutionCopy[m][5]))
                                        newflight.append(solutionCopy[m][5])

                                        newflight2 = newflight
                                        solutionCopy[m] = newflight    
            
            doneMutation = True
#             print("Range 1", range1)
#             print("Range 2", range2)
            
    return solutionCopy

# %%
def randomwalk(solution, rand_solution):  
    randomwalk_done = False
    while (randomwalk_done == False):
        rand_flight = random.randint(0, len(solution)-1)        
        airplanelist = []
        for i in range(len(airplanes)):
            airplane = [i, airplanes["curr_loc"].iloc[i], airplanes["last_seen"].iloc[i], airplanes["capacity"].iloc[i], airplanes["fixed_cost"].iloc[i], airplanes["min_cost"].iloc[i], airplanes["idle_cost"].iloc[i], 0]
            airplanelist.append(airplane)
        for j in range(rand_flight):
            airplanelist[solution[j][1]][1] = dfx["destination"].iloc[j]
            airplanelist[solution[j][1]][2] = solution[j][3]

        available_airplanes = []
        for airplane in airplanelist:
            if (airplane[0] != solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
                available_airplanes.append(airplane)
                
        if(len(available_airplanes) >= 3):
            randomwalk_solution = []
            variables = ["capacity", "fixed_cost", "min_cost", "idle_cost"]
            selected_var = random.randint(0,3)
            variable = variables[selected_var]
            xsolution = airplanes[variable].iloc[solution[rand_flight][1]]
            xrandsolution = airplanes[variable].iloc[rand_solution[rand_flight][1]]
                
            xsolution = xsolution + (random.random()*(xrandsolution - xsolution))
            randomwalk_solution.append(xsolution)          

            max_val = randomwalk_solution[0]*2
            for airplane in available_airplanes:
                val_diff = abs(randomwalk_solution[0] - airplane[selected_var+3])                    
                rate = ((max_val - val_diff) / (max_val - 0))
                    
                airplane[-1] = airplane[-1] +  rate
            
            new_solution = []
            available_airplanes = sorted(available_airplanes,key=lambda l:l[7], reverse=True)
            airplane1 = solution[rand_flight][1]
            airplane2 = available_airplanes[0][0]
            last_pos1 = -1
            last_pos2 = -1
            for l in range(len(solution)):
                if(l < rand_flight):
                    new_solution.append(solution[l])
                    if(solution[l][1]==airplane1):
                        last_pos1 = l
                    elif(solution[l][1]==airplane2):
                        last_pos2 = l   
                else:                                        
                    newflight = solution[l]
                    newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
                    if(solution[l][1]==airplane1):
                        newflight[1] = airplane2                        
                        if(last_pos2 > -1):
                            if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
                                newflight[2] = new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)
                                newflight[3] = new_solution[last_pos2][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
                        last_pos2 = l        
                    elif(solution[l][1]==airplane2):
                        newflight[1] = airplane1                        
                        if(last_pos1 > -1):
                            if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
                                newflight[2] = new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)
                                newflight[3] = new_solution[last_pos1][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
                        last_pos1 = l 
                    new_solution.append(newflight)                    
            randomwalk_done = True

    return new_solution

# %%
print(dfx)
# Out:
#         callsign registration typecode origin destination  \
# 1208410   SIA322       9V-SMQ     A359   WSSS        EGLL
# 1208521   SIA324       9V-SMM     A359   WSSS        EHAM
# 1208877    SIA26       9V-SMB     A359   WSSS        EDDF
# 1211170   SIA352       9V-SMN     A359   WSSS        EKCH
# 1215881   SIA478       9V-SMA     A359   WSSS        FABB
# 1216201   SIA231       9V-SMI     A359   WSSS        YSSY
# 1220352  SIA7296       9V-SFP     B744   WSSS        YSSY
# 1223142  SIA7951       9V-SFI     B744   EBMB        VABB
# 1227439   SIA319       9V-SMP     A359   EGLL        WSSS
# 1229204  SIA7321       9V-SFQ     B744   KLAX        EHAM
# 1235197  SIA7394       9V-SFM     B744   WSSS        OMSJ
# 1237066   SIA298       9V-SMD     A359   NZCH        WSSS
# 1244788   SIA308       9V-SML     A359   WSSS        EGLL
# 1248094  SIA7294       9V-SFO     B744   WSSS        YMML
# 1249343  SIA7980       9V-SFN     B744   WSSS        VHHH
# 1250949  SIA7295       9V-SFP     B744   YSSY        WSSS
# 1252570   SIA222       9V-SMI     A359   YSSY        WSSS
# 1254447  SIA7951       9V-SFI     B744   VABB        WSSS
# 1254450  SIA7394       9V-SFM     B744   OMSJ        EHAM
# 1255556   SIA286       9V-SMK     A359   NZAA        WSSS
# 1258178  SIA7321       9V-SFQ     B744   EHAM        OMSJ
# 1258339   SIA323       9V-SMM     A359   EHAM        WSSS
# 1258967   SIA377       9V-SMF     A359   LEBL        LIMC
# 1259110   SIA335       9V-SMH     A359   LFPG        WSSS
# 1259997    SIA25       9V-SMB     A359   EDDF        EDDF
# 1260594    SIA25       9V-SMB     A359   EDDF        WSSS
# 1260751   SIA317       9V-SMQ     A359   EGLL        WSSS
# 1261597   SIA351       9V-SMR     A359   EKCH        WSSS
# 1261968  SIA7294       9V-SFO     B744   YMML        NZAA
# 1263660  SIA8028       9V-SCB     B78X   WSSS        VOMM
# 1264751   SIA447       9V-SWO     B77W   WSSS        WSSS
# 1265422  SIA7980       9V-SFN     B744   VHHH        PANC
# 1271487  SIA7870       9V-SFI     B744   WSSS        VHHH
# 1282361  SIA8029       9V-SCB     B78X   VOMM        WSSS
# 1285468  SIA7394       9V-SFM     B744   EHAM        EGLL
# 1287600  SIA7293       9V-SFO     B744   NZAA        YMML
# 1295141  SIA7869       9V-SFI     B744   VHHH        WSSS
#
#                          firstseen                   lastseen  \
# 1208410  2020-11-20 16:06:59+00:00  2020-11-21 05:40:59+00:00
# 1208521  2020-11-20 16:08:35+00:00  2020-11-21 05:29:37+00:00
# 1208877  2020-11-20 16:13:20+00:00  2020-11-21 05:09:18+00:00
# 1211170  2020-11-20 16:44:59+00:00  2020-11-21 05:14:59+00:00
# 1215881  2020-11-20 17:48:48+00:00  2020-11-21 03:40:12+00:00
# 1216201  2020-11-20 17:54:12+00:00  2020-11-21 00:57:39+00:00
# 1220352  2020-11-20 18:54:04+00:00  2020-11-21 01:49:29+00:00
# 1223142  2020-11-20 19:32:05+00:00  2020-11-21 04:04:48+00:00
# 1227439  2020-11-20 20:31:38+00:00  2020-11-21 08:46:45+00:00
# 1229204  2020-11-20 20:56:06+00:00  2020-11-21 06:11:53+00:00
# 1235197  2020-11-20 22:21:21+00:00  2020-11-21 05:10:47+00:00
# 1237066  2020-11-20 22:51:25+00:00  2020-11-21 09:05:51+00:00
# 1244788  2020-11-21 01:12:22+00:00  2020-11-21 15:01:21+00:00
# 1248094  2020-11-21 02:30:04+00:00  2020-11-21 08:59:52+00:00
# 1249343  2020-11-21 03:07:03+00:00  2020-11-21 06:16:27+00:00
# 1250949  2020-11-21 04:01:25+00:00  2020-11-21 11:46:29+00:00
# 1252570  2020-11-21 05:09:13+00:00  2020-11-21 12:51:55+00:00
# 1254447  2020-11-21 06:32:16+00:00  2020-11-21 11:06:39+00:00
# 1254450  2020-11-21 06:32:24+00:00  2020-11-21 14:17:22+00:00
# 1255556  2020-11-21 07:25:25+00:00  2020-11-21 17:45:52+00:00
# 1258178  2020-11-21 09:24:06+00:00  2020-11-21 16:09:35+00:00
# 1258339  2020-11-21 09:31:00+00:00  2020-11-21 21:03:58+00:00
# 1258967  2020-11-21 09:57:44+00:00  2020-11-21 11:08:48+00:00
# 1259110  2020-11-21 10:03:18+00:00  2020-11-21 22:01:29+00:00
# 1259997  2020-11-21 10:38:05+00:00  2020-11-21 10:50:28+00:00
# 1260594  2020-11-21 11:01:31+00:00  2020-11-21 22:38:09+00:00
# 1260751  2020-11-21 11:06:23+00:00  2020-11-21 22:54:41+00:00
# 1261597  2020-11-21 11:32:34+00:00  2020-11-21 22:18:44+00:00
# 1261968  2020-11-21 11:43:39+00:00  2020-11-21 14:38:28+00:00
# 1263660  2020-11-21 12:28:41+00:00  2020-11-21 15:55:19+00:00
# 1264751  2020-11-21 12:55:20+00:00  2020-11-21 21:22:54+00:00
# 1265422  2020-11-21 13:10:08+00:00  2020-11-21 22:01:52+00:00
# 1271487  2020-11-21 14:53:31+00:00  2020-11-21 17:54:56+00:00
# 1282361  2020-11-21 17:28:30+00:00  2020-11-21 20:59:48+00:00
# 1285468  2020-11-21 18:14:33+00:00  2020-11-21 18:55:57+00:00
# 1287600  2020-11-21 18:46:11+00:00  2020-11-21 22:14:24+00:00
# 1295141  2020-11-21 20:38:56+00:00  2020-11-21 23:54:22+00:00
#
#                                day  latitude_1  longitude_1  latitude_2  \
# 1208410  2020-11-21 00:00:00+00:00    1.376782   104.004680   51.477676
# 1208521  2020-11-21 00:00:00+00:00    1.373151   104.003543   52.366985
# 1208877  2020-11-21 00:00:00+00:00    1.369567   104.002407   50.030225
# 1211170  2020-11-21 00:00:00+00:00    1.371429   104.002691   55.628155
# 1215881  2020-11-21 00:00:00+00:00    1.369939   104.001980  -26.219757
# 1216201  2020-11-21 00:00:00+00:00    1.373151   104.003496  -33.919962
# 1220352  2020-11-21 00:00:00+00:00    1.398988   104.013488  -33.919310
# 1223142  2020-11-21 00:00:00+00:00   50.909295     4.491577   19.088652
# 1227439  2020-11-21 00:00:00+00:00   51.477651    -0.449219    1.315706
# 1229204  2020-11-21 00:00:00+00:00   33.933975  -118.416474   52.359629
# 1235197  2020-11-21 00:00:00+00:00    1.397172   104.013488   25.331726
# 1237066  2020-11-21 00:00:00+00:00  -43.491119   172.529616    1.325715
# 1244788  2020-11-21 00:00:00+00:00    1.370265   104.002501   51.477604
# 1248094  2020-11-21 00:00:00+00:00    1.397265   104.012919  -37.643463
# 1249343  2020-11-21 00:00:00+00:00    1.380600   104.005958   22.310765
# 1250949  2020-11-21 00:00:00+00:00  -33.950363   151.177032    1.321153
# 1252570  2020-11-21 00:00:00+00:00  -33.952595   151.177597    1.325272
# 1254447  2020-11-21 00:00:00+00:00   19.088792    72.872864    1.325109
# 1254450  2020-11-21 00:00:00+00:00   25.329849    55.519714   52.360933
# 1255556  2020-11-21 00:00:00+00:00  -37.021040   174.752058    1.317078
# 1258178  2020-11-21 00:00:00+00:00   52.298401     4.778061   25.319297
# 1258339  2020-11-21 00:00:00+00:00   52.297948     4.760141    1.310632
# 1258967  2020-11-21 00:00:00+00:00   41.282822     2.230347   45.623062
# 1259110  2020-11-21 00:00:00+00:00   49.022881     2.555152    1.312454
# 1259997  2020-11-21 00:00:00+00:00   50.046030     8.570728   50.046449
# 1260594  2020-11-21 00:00:00+00:00   50.044842     8.585671    1.314030
# 1260751  2020-11-21 00:00:00+00:00   51.477676    -0.444946    1.313690
# 1261597  2020-11-21 00:00:00+00:00   55.597092    12.610474    1.309708
# 1261968  2020-11-21 00:00:00+00:00  -37.690063   144.841588  -36.995063
# 1263660  2020-11-21 00:00:00+00:00    1.385239   104.007987   12.978104
# 1264751  2020-11-21 00:00:00+00:00    1.382182   104.006905    1.316683
# 1265422  2020-11-21 00:00:00+00:00   22.301082   113.913015   61.167664
# 1271487  2020-11-21 00:00:00+00:00    1.387583   104.008752   22.284760
# 1282361  2020-11-21 00:00:00+00:00   13.002133    80.202364    1.312363
# 1285468  2020-11-21 00:00:00+00:00   52.293339     4.748056   51.477596
# 1287600  2020-11-21 00:00:00+00:00  -37.021729   174.750873  -37.641441
# 1295141  2020-11-21 00:00:00+00:00   22.300690   113.911893    1.316218
#
#          longitude_2
# 1208410    -0.446357
# 1208521     4.712350
# 1208877     8.541035
# 1211170    12.671700
# 1215881    28.231166
# 1216201   151.169186
# 1220352   151.169014
# 1223142    72.863475
# 1227439   103.979440
# 1229204     4.711722
# 1235197    55.516403
# 1237066   103.983702
# 1244788    -0.446854
# 1248094   144.833114
# 1249343   113.897502
# 1250949   103.981807
# 1252570   103.983454
# 1254447   103.983417
# 1254450     4.711801
# 1255556   103.963995
# 1258178    55.538013
# 1258339   103.961303
# 1258967     8.724953
# 1259110   103.962040
# 1259997     8.584442
# 1260594   103.962723
# 1260751   103.962552
# 1261597   103.960876
# 1261968   174.847651
# 1263660    80.136835
# 1264751   103.963812
# 1265422  -150.084817
# 1271487   113.862305
# 1282361   103.962040
# 1285468    -0.460516
# 1287600   144.832764
# 1295141   103.963623

# %%
test = createSchedule()
# Out:
# c:\users\user\opencv\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
print(test)
# Out:
# [[0, 22, Timestamp('2020-11-20 16:06:59+0000', tz='UTC'), Timestamp('2020-11-21 05:40:59+0000', tz='UTC'), 47, 0.133], [1, 1, Timestamp('2020-11-20 18:24:12+0000', tz='UTC'), Timestamp('2020-11-21 07:45:14+0000', tz='UTC'), 47, 0.133], [2, 6, Timestamp('2020-11-20 16:13:20+0000', tz='UTC'), Timestamp('2020-11-21 05:09:18+0000', tz='UTC'), 47, 0.133], [3, 18, Timestamp('2020-11-20 19:24:04+0000', tz='UTC'), Timestamp('2020-11-21 07:54:04+0000', tz='UTC'), 55, 0.133], [4, 8, Timestamp('2020-11-20 17:48:48+0000', tz='UTC'), Timestamp('2020-11-21 03:40:12+0000', tz='UTC'), 49, 0.14], [5, 42, Timestamp('2020-11-20 17:54:12+0000', tz='UTC'), Timestamp('2020-11-21 00:57:39+0000', tz='UTC'), 45, 0.171], [6, 20, Timestamp('2020-11-20 18:54:04+0000', tz='UTC'), Timestamp('2020-11-21 01:49:29+0000', tz='UTC'), 60, 0.171], [7, 16, Timestamp('2020-11-20 20:02:05+0000', tz='UTC'), Timestamp('2020-11-21 04:34:48+0000', tz='UTC'), 53, 0.128], [8, 25, Timestamp('2020-11-20 21:01:38+0000', tz='UTC'), Timestamp('2020-11-21 09:16:45+0000', tz='UTC'), 60, 0.171], [9, 14, Timestamp('2020-11-20 21:26:06+0000', tz='UTC'), Timestamp('2020-11-21 06:41:53+0000', tz='UTC'), 55, 0.133], [10, 11, Timestamp('2020-11-20 22:21:21+0000', tz='UTC'), Timestamp('2020-11-21 05:10:47+0000', tz='UTC'), 37, 0.14], [11, 3, Timestamp('2020-11-20 23:21:25+0000', tz='UTC'), Timestamp('2020-11-21 09:35:51+0000', tz='UTC'), 60, 0.171], [12, 35, Timestamp('2020-11-21 01:12:22+0000', tz='UTC'), Timestamp('2020-11-21 15:01:21+0000', tz='UTC'), 35, 0.133], [13, 32, Timestamp('2020-11-21 02:30:04+0000', tz='UTC'), Timestamp('2020-11-21 08:59:52+0000', tz='UTC'), 37, 0.171], [14, 23, Timestamp('2020-11-21 03:07:03+0000', tz='UTC'), Timestamp('2020-11-21 06:16:27+0000', tz='UTC'), 45, 0.128], [15, 42, Timestamp('2020-11-21 04:01:25+0000', tz='UTC'), Timestamp('2020-11-21 11:46:29+0000', tz='UTC'), 45, 0.171], [16, 20, Timestamp('2020-11-21 05:09:13+0000', tz='UTC'), Timestamp('2020-11-21 12:51:55+0000', tz='UTC'), 60, 0.171], [17, 16, Timestamp('2020-11-21 06:32:16+0000', tz='UTC'), Timestamp('2020-11-21 11:06:39+0000', tz='UTC'), 71, 0.171], [18, 11, Timestamp('2020-11-21 06:32:24+0000', tz='UTC'), Timestamp('2020-11-21 14:17:22+0000', tz='UTC'), 35, 0.133], [19, 31, Timestamp('2020-11-21 07:55:25+0000', tz='UTC'), Timestamp('2020-11-21 18:15:52+0000', tz='UTC'), 60, 0.171], [20, 1, Timestamp('2020-11-21 09:24:06+0000', tz='UTC'), Timestamp('2020-11-21 16:09:35+0000', tz='UTC'), 49, 0.14], [21, 14, Timestamp('2020-11-21 09:31:00+0000', tz='UTC'), Timestamp('2020-11-21 21:03:58+0000', tz='UTC'), 71, 0.171], [22, 13, Timestamp('2020-11-21 10:27:44+0000', tz='UTC'), Timestamp('2020-11-21 11:38:48+0000', tz='UTC'), 47, 0.133], [23, 4, Timestamp('2020-11-21 10:33:18+0000', tz='UTC'), Timestamp('2020-11-21 22:31:29+0000', tz='UTC'), 60, 0.171], [24, 6, Timestamp('2020-11-21 10:38:05+0000', tz='UTC'), Timestamp('2020-11-21 10:50:28+0000', tz='UTC'), 47, 0.133], [25, 6, Timestamp('2020-11-21 11:20:28+0000', tz='UTC'), Timestamp('2020-11-21 22:57:06+0000', tz='UTC'), 60, 0.171], [26, 22, Timestamp('2020-11-21 11:06:23+0000', tz='UTC'), Timestamp('2020-11-21 22:54:41+0000', tz='UTC'), 60, 0.171], [27, 18, Timestamp('2020-11-21 11:32:34+0000', tz='UTC'), Timestamp('2020-11-21 22:18:44+0000', tz='UTC'), 71, 0.171], [28, 32, Timestamp('2020-11-21 11:43:39+0000', tz='UTC'), Timestamp('2020-11-21 14:38:28+0000', tz='UTC'), 37, 0.171], [29, 17, Timestamp('2020-11-21 12:28:41+0000', tz='UTC'), Timestamp('2020-11-21 15:55:19+0000', tz='UTC'), 45, 0.128], [30, 2, Timestamp('2020-11-21 12:55:20+0000', tz='UTC'), Timestamp('2020-11-21 21:22:54+0000', tz='UTC'), 60, 0.171], [31, 23, Timestamp('2020-11-21 13:10:08+0000', tz='UTC'), Timestamp('2020-11-21 22:01:52+0000', tz='UTC'), 40, 0.113], [32, 7, Timestamp('2020-11-21 14:53:31+0000', tz='UTC'), Timestamp('2020-11-21 17:54:56+0000', tz='UTC'), 53, 0.128], [33, 17, Timestamp('2020-11-21 17:28:30+0000', tz='UTC'), Timestamp('2020-11-21 20:59:48+0000', ...

# %%
def era():
    print("Starting...")
    p = 40
    s = 0.5
    a = 0.075
    b = 0.075
    iteration = 100
    y_plot_list = []
    x_plot_list = []
    xbest = []
    xworst = []
    besthq = []
    f1 = 0
    f2 = 0
    f3 = 0
    
    print("Creating Solution...")
       
    with open('solution/solution_35-1', 'rb') as fp:
        initial_solutions1 = pickle.load(fp)
    with open('solution/solution_35-2', 'rb') as fp:
        initial_solutions2 = pickle.load(fp)
    initial_solutions =  initial_solutions1 + initial_solutions2
    
#     solutions = deepcopy(initial_solutions)
    solutions = []
    
    for i in range(len(initial_solutions)):
        fitness = countFitness(initial_solutions[i])[0]
        sol_fit = [initial_solutions[i], fitness]
        solutions.append(sol_fit)
        
    
    for i in range(iteration):
        print("Iterasi ke-", i)
        for solution in solutions:
            solution[1] = countFitness(solution[0])[0]
            
        solutions = sorted(solutions,key=lambda l:l[1], reverse=True)              
        
        if(i==0):
            f2 = countFitness(solutions[0][0])[0]
            f3 = countFitness(solutions[0][0])[0]
            xbest = deepcopy(solutions[0])
            xworst = deepcopy(solutions[-1])
        else:
            f3 = f2
            f2 = f1
            if(solutions[0][1] > xbest[1]):
                xbest = deepcopy(solutions[0])
            if(solutions[-1][1] > xworst[1]):
                xworst = deepcopy(solutions[-1])
        
        if ((round(s*p)) < 2):
            hq = solutions[:2]
            lq = solutions[2:]
        else:
            hq = solutions[:(round(s*p))]
            lq = solutions[(round(s*p)):]       
        
        print("Rao3 High-Quality solution...")
        for hq_indv in hq:
            
            random_hq = random.randint(0, len(hq)-1)
            while hq_indv==hq[random_hq]:
                random_hq = random.randint(0, len(hq)-1)
            
            randomwalk_indv = rao3(hq_indv[0], hq[random_hq][0], xbest[0], xworst[0])
            randomwalk_indvfit = countFitness(randomwalk_indv)[0]
            if(countFitness(randomwalk_indv)[0] > hq_indv[1]):
                hq_indv[0] = randomwalk_indv
                hq_indv[1] = randomwalk_indvfit
        
        hq = sorted(hq,key=lambda l:l[1], reverse=True)
        
#         print(hq)
        
        besthq = hq[0]
        
        if(random.random() > 0.5):
            print("Solution Crossover...")
#             o1, o2 = crossover(besthq[0], xbest[0])
            o1, o2 = crossOver(besthq[0], a)
            o1fit = countFitness(o1)[0]
            o2fit = countFitness(o2)[0]
            if(o1fit > countFitness(besthq[0])[0]):
#                 print("o1",countFitness(o1)[0])
                offsol1 = [o1, o1fit]
                hq[0] =  offsol1
                
            if(o2fit > countFitness(besthq[0])[0]):
#                 print("o2",countFitness(o2)[0])
                offsol2 = [o2, o2fit]
                hq[0] =  offsol2
#                 xbest = deepcopy(offsol2)
        else:
            print("Solution Mutation...")
#             o = mutation(xbest[0], a, b)
            o = mutation(xbest[0], hq, b)
            ofit = countFitness(o)[0]
            if(ofit > xbest[1]):
#                 print("o",countFitness(o)[0])
                offsol = [o, ofit]
                xbest = deepcopy(offsol)
        
        print("Random Walk Low-Quality Solution...")
        for lq_indv in lq:
            
            random_hq = random.randint(0, len(hq)-1)               
            lq_indv[0] = randomwalk(lq_indv[0], hq[random_hq][0])
            lq_indv[1] = countFitness(lq_indv[0])[0]
        
        solutions = hq+lq
        solutions = sorted(solutions,key=lambda l:l[1], reverse=True)
        
        if(solutions[0][1] > xbest[1]):
            xbest = deepcopy(solutions[0])
       
        f1 = countFitness(xbest[0])[0]
        diff1 = abs(f1-f2)/f1
        diff2 = abs(f2-f3)/f2       
        
        if(diff1 > 0 and diff2 > 0):
            s = s * (1-((diff1 + diff2)/2))
            a = a * 0.97
            b = b * 0.97
        elif(diff1 == 0 and diff2 == 0):
            s = s * 0.97
            a = a * 1.03
            b = b * 1.03
        
        print("s:", s)
        print("a:", a)
        print("b:", b)
        print("Elite Solution:", countFitness(xbest[0]))
        print("High-Quality Solution")
        for j in range(len(hq)):
            print("Solution: ", hq[j][1])
        
#         if(i==0):
#             values = [countFitness(xbest[0])[0]]
#             y_plot_list.append(values)
#         else:
#             y_plot_list[0].append(countFitness(xbest[0])[0])
        
        for j in range(10):
            fit = countFitness(solutions[j][0])[0]
            if(i==0):
                values = [fit]
                y_plot_list.append(values)
            else:
                if(fit > y_plot_list[j][i-1]):
                    y_plot_list[j].append(fit)
                else:
                    y_plot_list[j].append(y_plot_list[j][i-1])    
        x_plot_list.append(i)
        
    print("Final Elite Solutions")
    for k in range(10):
        print("Solution: ", countFitness(solutions[k][0]))
    
    print("Final Elite Solution")
    print("Solution: ", countFitness(xbest[0]))       
            
            
    return xbest[0], x_plot_list, y_plot_list

# %%
start_time = time.time()
result, x_plot_list, y_plot_list = era()
end_time = time.time()
# Out:
# Starting...
# Creating Solution...
# Iterasi ke- 0
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.485
# a: 0.07725
# b: 0.07725
# Elite Solution: [381.8956813798452, 2030, 31451027.501371205, 20]
# High-Quality Solution
# Solution:  381.8956813798452
# Solution:  373.5869654708758
# Solution:  370.60810723563316
# Solution:  369.4985798116781
# Solution:  366.8544297984523
# Solution:  366.63210199583943
# Solution:  363.8910377200755
# Solution:  362.5442973398246
# Solution:  360.9031010564498
# Solution:  360.7458310484442
# Solution:  358.92066287800657
# Solution:  358.7820429653965
# Solution:  358.1437506106604
# Solution:  358.0396776202791
# Solution:  356.5072244016446
# Solution:  356.387850811434
# Solution:  356.3502204162058
# Solution:  355.6203641867647
# Solution:  355.2402585311981
# Solution:  354.8696084880397
# Iterasi ke- 1
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.485
# a: 0.07725
# b: 0.07725
# Elite Solution: [383.4051731688163, 2038, 31573556.501371205, 20]
# High-Quality Solution
# Solution:  383.4051731688163
# Solution:  373.5869654708758
# Solution:  370.1429477757888
# Solution:  369.4985798116781
# Solution:  367.9899914623786
# Solution:  367.3775193968531
# Solution:  367.28784071176915
# Solution:  365.91413358513273
# Solution:  363.54914287865324
# Solution:  362.5442973398246
# Solution:  360.7458310484442
# Solution:  359.8694545314187
# Solution:  359.03302604859823
# Solution:  358.7820429653965
# Solution:  357.5518342591936
# Solution:  356.5072244016446
# Solution:  356.3502204162058
# Solution:  355.6203641867647
# Solution:  355.2402585311981
# Iterasi ke- 2
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4808985534680976
# a: 0.0749325
# b: 0.0749325
# Elite Solution: [388.4456890022257, 2063, 31854356.501371205, 20]
# High-Quality Solution
# Solution:  388.4456890022257
# Solution:  373.5533919064983
# Solution:  372.5167353721299
# Solution:  372.49663282860246
# Solution:  370.1429477757888
# Solution:  369.8447370559081
# Solution:  368.3265603883446
# Solution:  367.28784071176915
# Solution:  365.91413358513273
# Solution:  363.7575989136494
# Solution:  362.0016564835975
# Solution:  360.72401086408735
# Solution:  360.2091299420951
# Solution:  359.8694545314187
# Solution:  359.73113749600805
# Solution:  359.3179393846883
# Solution:  355.80085531313017
# Solution:  355.6203641867647
# Solution:  355.43730466920726
# Iterasi ke- 3
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4808985534680976
# a: 0.0749325
# b: 0.0749325
# Elite Solution: [388.4456890022257, 2063, 31854356.501371205, 20]
# High-Quality Solution
# Solution:  388.4456890022257
# Solution:  375.60494182230303
# Solution:  373.5533919064983
# Solution:  372.49663282860246
# Solution:  371.0167564792416
# Solution:  370.1429477757888
# Solution:  368.58226765599716
# Solution:  368.32594283595716
# Solution:  365.65838197373847
# Solution:  365.20982847534174
# Solution:  363.7575989136494
# Solution:  362.05561157394385
# Solution:  362.0016564835975
# Solution:  361.05907262097423
# Solution:  360.2091299420951
# Solution:  359.72171614891613
# Solution:  357.4814459547648
# Solution:  357.24605083263725
# Solution:  355.43730466920726
# Iterasi ke- 4
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4664715968640547
# a: 0.077180475
# b: 0.077180475
# Elite Solution: [388.4456890022257, 2063, 31854356.501371205, 20]
# High-Quality Solution
# Solution:  387.2736695788923
# Solution:  375.60494182230303
# Solution:  374.56164967539155
# Solution:  373.3518680207267
# Solution:  371.0167564792416
# Solution:  370.7565236477219
# Solution:  369.9289835838125
# Solution:  368.94800579576815
# Solution:  368.58226765599716
# Solution:  368.32594283595716
# Solution:  366.6360926198291
# Solution:  365.65838197373847
# Solution:  362.7090234555184
# Solution:  362.3317553673514
# Solution:  362.09156867873156
# Solution:  362.05561157394385
# Solution:  361.96720571137257
# Solution:  361.11299859804717
# Solution:  360.7844221736659
# Iterasi ke- 5
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4664715968640547
# a: 0.077180475
# b: 0.077180475
# Elite Solution: [390.07497501283285, 2073, 32088851.501371205, 20]
# High-Quality Solution
# Solution:  390.07497501283285
# Solution:  380.74597964184716
# Solution:  375.60494182230303
# Solution:  375.55951184964744
# Solution:  374.80855345376744
# Solution:  373.35215937877615
# Solution:  371.0167564792416
# Solution:  369.9289835838125
# Solution:  367.84481021081524
# Solution:  367.6190828724681
# Solution:  365.92923265634005
# Solution:  365.4205727704971
# Solution:  365.180667036132
# Solution:  364.43654233564286
# Solution:  362.7793772091447
# Solution:  362.7090234555184
# Solution:  362.681955380497
# Solution:  362.278006439876
# Solution:  361.79719913931956
# Iterasi ke- 6
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.46274716435015384
# a: 0.07486506074999999
# b: 0.07486506074999999
# Elite Solution: [394.7294970014571, 2089, 31817467.501371205, 20]
# High-Quality Solution
# Solution:  394.7294970014571
# Solution:  381.44023174369283
# Solution:  380.74597964184716
# Solution:  379.3151948199914
# Solution:  375.55951184964744
# Solution:  373.35215937877615
# Solution:  372.1601338407579
# Solution:  371.0167564792416
# Solution:  368.5259549316952
# Solution:  368.20608870144713
# Solution:  368.0314503769813
# Solution:  367.2388061957469
# Solution:  366.5567519868108
# Solution:  366.1802445407401
# Solution:  364.43654233564286
# Solution:  362.681955380497
# Solution:  362.5178099492638
# Solution:  361.78045959561626
# Solution:  359.25322218501833
# Iterasi ke- 7
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.46001852025568624
# a: 0.07261910892749998
# b: 0.07261910892749998
# Elite Solution: [394.73011455384454, 2089, 31817272.501371205, 20]
# High-Quality Solution
# Solution:  394.7294970014571
# Solution:  383.2873706640108
# Solution:  382.3295071816307
# Solution:  379.3151948199914
# Solution:  375.2384194378112
# Solution:  374.4640968538044
# Solution:  374.39164312328023
# Solution:  372.8374244279418
# Solution:  372.1494802703404
# Solution:  371.76396346425554
# Solution:  371.4903394094187
# Solution:  369.68428486217215
# Solution:  368.43742441670224
# Solution:  367.2388061957469
# Solution:  366.76148426354797
# Solution:  366.4026394066723
# Solution:  366.1339171701502
# Solution:  363.7280833553031
# Solution:  360.22713887583143
# Iterasi ke- 8
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.45946501185625843
# a: 0.07044053565967498
# b: 0.07044053565967498
# Elite Solution: [395.6816882105453, 2098, 32190867.501371205, 20]
# High-Quality Solution
# Solution:  395.6816882105453
# Solution:  383.2873706640108
# Solution:  382.3295071816307
# Solution:  379.3151948199914
# Solution:  375.2384194378112
# Solution:  374.4640968538044
# Solution:  374.39164312328023
# Solution:  374.25387423322434
# Solution:  373.1806398813926
# Solution:  372.8374244279418
# Solution:  371.76396346425554
# Solution:  371.4903394094187
# Solution:  369.99334060266676
# Solution:  369.68428486217215
# Solution:  368.8306129808575
# Solution:  368.28040460323416
# Solution:  367.3369495213227
# Solution:  366.98961444934514
# Iterasi ke- 9
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4579373664998592
# a: 0.06832731958988472
# b: 0.06832731958988472
# Elite Solution: [397.3684270355225, 2106, 32257428.501371205, 20]
# High-Quality Solution
# Solution:  395.6816882105453
# Solution:  383.6332141094525
# Solution:  382.6379263614788
# Solution:  380.2667575285143
# Solution:  379.3151948199914
# Solution:  379.2551125994946
# Solution:  378.60381478334216
# Solution:  375.13824438048437
# Solution:  373.9894086499061
# Solution:  373.82359310846215
# Solution:  373.1806398813926
# Solution:  372.9371952727863
# Solution:  372.5504718709916
# Solution:  371.48848675225634
# Solution:  371.18453609820347
# Solution:  370.5474892121535
# Solution:  369.68428486217215
# Solution:  367.3369495213227
# Iterasi ke- 10
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4579373664998592
# a: 0.06832731958988472
# b: 0.06832731958988472
# Elite Solution: [397.3684270355225, 2106, 32257428.501371205, 20]
# High-Quality Solution
# Solution:  396.85370763387874
# Solution:  383.6332141094525
# Solution:  382.6379263614788
# Solution:  382.24503033720055
# Solution:  381.15603296645213
# Solution:  379.2551125994946
# Solution:  378.1431753966579
# Solution:  375.72161719026786
# Solution:  375.2583432055304
# Solution:  375.13824438048437
# Solution:  374.465630520252
# Solution:  372.5957932980938
# Solution:  372.5504718709916
# Solution:  370.5474892121535
# Solution:  369.9618655744626
# Solution:  369.68428486217215
# Solution:  368.87999614525097
# Solution:  366.21346856040486
# Iterasi ke- 11
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4579373664998592
# a: 0.06832731958988472
# b: 0.06832731958988472
# Elite Solution: [397.9624390217715, 2098, 31470691.501371205, 20]
# High-Quality Solution
# Solution:  397.9624390217715
# Solution:  384.62600282673634
# Solution:  384.2160661011188
# Solution:  382.24503033720055
# Solution:  381.5579043908558
# Solution:  379.4272767043116
# Solution:  378.42380617973686
# Solution:  378.391415621739
# Solution:  375.7302859686393
# Solution:  375.72161719026786
# Solution:  375.2583432055304
# Solution:  372.5504718709916
# Solution:  371.93620675574994
# Solution:  371.46293360096774
# Solution:  370.6687255379517
# Solution:  368.8219591674101
# Solution:  368.7581293005436
# Solution:  368.51226543883865
# Iterasi ke- 12
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4579373664998592
# a: 0.06832731958988472
# b: 0.06832731958988472
# Elite Solution: [397.9624390217715, 2098, 31470691.501371205, 20]
# High-Quality Solution
# Solution:  397.9624390217715
# Solution:  391.41409633096964
# Solution:  384.2451385673591
# Solution:  382.52268935312134
# Solution:  382.4931280501922
# Solution:  381.07335811486644
# Solution:  379.5204945690646
# Solution:  379.4272767043116
# Solution:  379.38764249548365
# Solution:  377.7717033910409
# Solution:  376.89363661360136
# Solution:  375.7302859686393
# Solution:  371.5580009758895
# Solution:  370.1399961987175
# Solution:  368.8219591674101
# Solution:  368.2807307975722
# Solution:  366.1351067825921
# Solution:  365.39907761859246
# Iterasi ke- 13
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4579373664998592
# a: 0.06832731958988472
# b: 0.06832731958988472
# Elite Solution: [399.00694841379016, 2102, 31440459.501371205, 20]
# High-Quality Solution
# Solution:  399.00694841379016
# Solution:  391.41409633096964
# Solution:  384.2451385673591
# Solution:  384.22448322428636
# Solution:  382.52268935312134
# Solution:  382.4931280501922
# Solution:  381.07335811486644
# Solution:  380.4687702975055
# Solution:  379.38764249548365
# Solution:  379.33402629380566
# Solution:  376.89363661360136
# Solution:  374.44202042652546
# Solution:  374.13549708569565
# Solution:  372.6128216371194
# Solution:  371.5580009758895
# Solution:  370.34185376793636
# Solution:  367.5604844972647
# Solution:  364.93492726252384
# Iterasi ke- 14
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4557905039709192
# a: 0.06627750000218818
# b: 0.06627750000218818
# Elite Solution: [401.7219683977467, 2102, 30583157.501371205, 19]
# High-Quality Solution
# Solution:  401.7219683977467
# Solution:  389.51705399911316
# Solution:  386.3836401448038
# Solution:  384.22448322428636
# Solution:  383.7929733153254
# Solution:  380.5406778744299
# Solution:  380.15077284458243
# Solution:  377.826853272461
# Solution:  376.89844402141756
# Solution:  375.2346424392127
# Solution:  374.44202042652546
# Solution:  374.13549708569565
# Solution:  373.9542286194521
# Solution:  372.6128216371194
# Solution:  370.64922499097395
# Solution:  370.34185376793636
# Solution:  369.0851755374876
# Solution:  365.6629512904336
# Iterasi ke- 15
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4557905039709192
# a: 0.06627750000218818
# b: 0.06627750000218818
# Elite Solution: [401.7219683977467, 2102, 30583157.501371205, 19]
# High-Quality Solution
# Solution:  401.7219683977467
# Solution:  386.8994742810914
# Solution:  386.3836401448038
# Solution:  383.7929733153254
# Solution:  381.02572740764924
# Solution:  380.5406778744299
# Solution:  380.47854059174915
# Solution:  380.150155292195
# Solution:  378.58232858121306
# Solution:  376.89844402141756
# Solution:  374.44202042652546
# Solution:  373.8585768022208
# Solution:  371.5403277572388
# Solution:  370.15736309439467
# Solution:  368.1959000995497
# Solution:  367.74364909465976
# Solution:  367.36926263214826
# Solution:  365.75475613106164
# Iterasi ke- 16
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4421167888517916
# a: 0.06826582500225382
# b: 0.06826582500225382
# Elite Solution: [401.7219683977467, 2102, 30583157.501371205, 19]
# High-Quality Solution
# Solution:  401.46974762045403
# Solution:  389.2642905206422
# Solution:  386.59388635471413
# Solution:  385.04850887303735
# Solution:  381.02572740764924
# Solution:  379.7600976984219
# Solution:  378.58232858121306
# Solution:  378.495404253458
# Solution:  378.44981448001715
# Solution:  375.82278177213925
# Solution:  374.4582858063305
# Solution:  373.8590676771954
# Solution:  373.4632540357346
# Solution:  371.3041423220642
# Solution:  371.12788337652523
# Solution:  370.6687255379517
# Solution:  367.74364909465976
# Solution:  367.36926263214826
# Iterasi ke- 17
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4288532851862379
# a: 0.07031379975232144
# b: 0.07031379975232144
# Elite Solution: [401.7219683977467, 2102, 30583157.501371205, 19]
# High-Quality Solution
# Solution:  401.46974762045403
# Solution:  393.9468275311847
# Solution:  390.3725310335603
# Solution:  382.2904706671202
# Solution:  380.1789444870561
# Solution:  380.06748420510564
# Solution:  379.7600976984219
# Solution:  378.1355373262847
# Solution:  377.6096415244096
# Solution:  377.0260481910395
# Solution:  376.45206187876477
# Solution:  376.2963278476839
# Solution:  376.10663561232724
# Solution:  376.07391225392917
# Solution:  374.71475029024674
# Solution:  371.12788337652523
# Solution:  370.6687255379517
# Solution:  368.84795971968424
# Iterasi ke- 18
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4159876866306507
# a: 0.07242321374489108
# b: 0.07242321374489108
# Elite Solution: [401.7219683977467, 2102, 30583157.501371205, 19]
# High-Quality Solution
# Solution:  401.30448369672786
# Solution:  397.200297905084
# Solution:  390.3725310335603
# Solution:  386.08553708078244
# Solution:  384.3802952868062
# Solution:  383.7404168883883
# Solution:  380.6083627646866
# Solution:  380.06748420510564
# Solution:  379.7600976984219
# Solution:  377.6096415244096
# Solution:  377.0260481910395
# Solution:  376.55876861074114
# Solution:  376.31371576331696
# Solution:  376.29714175006126
# Solution:  376.10663561232724
# Solution:  371.5915431563998
# Solution:  370.6687255379517
# Iterasi ke- 19
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4035080560317312
# a: 0.07459591015723781
# b: 0.07459591015723781
# Elite Solution: [401.7219683977467, 2102, 30583157.501371205, 19]
# High-Quality Solution
# Solution:  401.3052975991052
# Solution:  396.31102246714613
# Solution:  387.15744651170615
# Solution:  386.8198621347992
# Solution:  385.6379500952195
# Solution:  384.42323576281404
# Solution:  380.6088536396613
# Solution:  379.93108169160297
# Solution:  379.88512026472733
# Solution:  379.7600976984219
# Solution:  376.55876861074114
# Solution:  376.4397085404802
# Solution:  376.29714175006126
# Solution:  376.10663561232724
# Solution:  375.84008993677
# Solution:  374.26515745944573
# Solution:  372.18258166257465
# Iterasi ke- 20
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3914028143507792
# a: 0.07683378746195495
# b: 0.07683378746195495
# Elite Solution: [401.7219683977467, 2102, 30583157.501371205, 19]
# High-Quality Solution
# Solution:  401.3052975991052
# Solution:  397.200297905084
# Solution:  388.03065809846083
# Solution:  387.15744651170615
# Solution:  386.8198621347992
# Solution:  385.6379500952195
# Solution:  384.42323576281404
# Solution:  381.4981290775991
# Solution:  380.2010934484197
# Solution:  379.93108169160297
# Solution:  379.3371123162378
# Solution:  376.50399244098327
# Solution:  376.19509042630017
# Solution:  376.19176313251717
# Solution:  375.2645000066319
# Solution:  373.65243235116964
# Iterasi ke- 21
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.3914028143507792
# a: 0.07683378746195495
# b: 0.07683378746195495
# Elite Solution: [402.47650312006135, 2098, 30045318.501371205, 19]
# High-Quality Solution
# Solution:  402.47650312006135
# Solution:  397.2091874925281
# Solution:  388.03065809846083
# Solution:  386.0572143284022
# Solution:  386.0222818699335
# Solution:  385.21250716457956
# Solution:  385.18204929358524
# Solution:  381.4981290775991
# Solution:  380.81541728141326
# Solution:  378.03354848477187
# Solution:  377.87918083689146
# Solution:  376.19509042630017
# Solution:  376.19176313251717
# Solution:  373.8413501015085
# Solution:  373.65243235116964
# Solution:  373.3656732694071
# Iterasi ke- 22
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3914028143507792
# a: 0.07683378746195495
# b: 0.07683378746195495
# Elite Solution: [402.47650312006135, 2098, 30045318.501371205, 19]
# High-Quality Solution
# Solution:  402.47650312006135
# Solution:  397.2091874925281
# Solution:  390.462676127889
# Solution:  387.3262741074202
# Solution:  387.29138023644197
# Solution:  386.0572143284022
# Solution:  385.7342966065828
# Solution:  384.3026855067418
# Solution:  383.37364748294146
# Solution:  382.33054361929123
# Solution:  379.18075899326436
# Solution:  375.75706267896396
# Solution:  374.2135827625162
# Solution:  372.56738302676314
# Solution:  371.6462712245668
# Solution:  369.34005281583626
# Iterasi ke- 23
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3914028143507792
# a: 0.07683378746195495
# b: 0.07683378746195495
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  402.7228178484677
# Solution:  396.0371680691946
# Solution:  395.559429256772
# Solution:  392.3678191881615
# Solution:  390.462676127889
# Solution:  388.4469255543725
# Solution:  387.9207326249022
# Solution:  387.29138023644197
# Solution:  386.6805526867475
# Solution:  386.0572143284022
# Solution:  383.50256304262473
# Solution:  383.1548447781206
# Solution:  380.9255552317717
# Solution:  375.14785516607606
# Solution:  373.56653239089474
# Solution:  371.6462712245668
# Iterasi ke- 24
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.3914028143507792
# a: 0.07683378746195495
# b: 0.07683378746195495
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  402.7228178484677
# Solution:  400.28932344291377
# Solution:  397.04542583808785
# Solution:  396.8629213973169
# Solution:  392.3678191881615
# Solution:  390.9646359604217
# Solution:  390.529840784295
# Solution:  387.6163763176423
# Solution:  386.73909348614313
# Solution:  386.1084458410786
# Solution:  383.7931722612785
# Solution:  383.50256304262473
# Solution:  382.0546341790973
# Solution:  373.56653239089474
# Solution:  373.53625275797265
# Solution:  373.07711795105155
# Iterasi ke- 25
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.37966072992025585
# a: 0.0791388010858136
# b: 0.0791388010858136
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  402.32434540212074
# Solution:  397.04542583808785
# Solution:  396.8629213973169
# Solution:  393.89943778324346
# Solution:  392.9979601634582
# Solution:  390.9646359604217
# Solution:  390.7205694639596
# Solution:  388.0617504984634
# Solution:  386.95360009381164
# Solution:  386.73909348614313
# Solution:  386.1084458410786
# Solution:  383.7931722612785
# Solution:  383.50256304262473
# Solution:  381.77857473105746
# Solution:  375.6313013868597
# Solution:  372.82812313890616
# Iterasi ke- 26
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.36827090802264817
# a: 0.08151296511838801
# b: 0.08151296511838801
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  402.32434540212074
# Solution:  397.04542583808785
# Solution:  394.96538819048567
# Solution:  393.89943778324346
# Solution:  391.82675464250207
# Solution:  391.05603371376526
# Solution:  390.7205694639596
# Solution:  388.1898760571746
# Solution:  388.0617504984634
# Solution:  384.6904729921568
# Solution:  384.60436862845813
# Solution:  381.835166437801
# Solution:  381.77857473105746
# Solution:  379.8197878098527
# Solution:  375.6313013868597
# Iterasi ke- 27
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.35722278078196873
# a: 0.08395835407193966
# b: 0.08395835407193966
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  400.9804048715318
# Solution:  397.04542583808785
# Solution:  396.13740761381916
# Solution:  393.74642413630824
# Solution:  391.82675464250207
# Solution:  391.05603371376526
# Solution:  390.5617925657135
# Solution:  385.69497248522475
# Solution:  384.6904729921568
# Solution:  382.0414974392555
# Solution:  381.2225432357799
# Solution:  379.8197878098527
# Solution:  377.2058733978823
# Solution:  374.2617630890489
# Solution:  373.64175287429754
# Iterasi ke- 28
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3465060973585097
# a: 0.08647710469409785
# b: 0.08647710469409785
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  396.13740761381916
# Solution:  394.1787381547072
# Solution:  392.32483468048684
# Solution:  392.20402243188835
# Solution:  391.82675464250207
# Solution:  390.5617925657135
# Solution:  388.69709644811314
# Solution:  386.82731106545305
# Solution:  384.4805411785959
# Solution:  383.08586432583195
# Solution:  382.0915416366728
# Solution:  381.2225432357799
# Solution:  378.6498142267361
# Solution:  377.81459003579556
# Iterasi ke- 29
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.33611091443775437
# a: 0.08907141783492079
# b: 0.08907141783492079
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  397.0640468401519
# Solution:  393.9267500110649
# Solution:  393.7043548529995
# Solution:  393.2851248984276
# Solution:  391.9256698238962
# Solution:  390.57414621607313
# Solution:  388.69709644811314
# Solution:  387.0944101115276
# Solution:  386.82731106545305
# Solution:  384.4805411785959
# Solution:  383.7679329486616
# Solution:  382.1965888878941
# Solution:  379.4886498924749
# Solution:  378.6498142267361
# Iterasi ke- 30
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.32602758700462176
# a: 0.0917435603699684
# b: 0.0917435603699684
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  398.25795352445596
# Solution:  394.04226714380786
# Solution:  393.9267500110649
# Solution:  393.70373730061203
# Solution:  393.2851248984276
# Solution:  392.34493405707894
# Solution:  387.2534631041186
# Solution:  387.20526925338646
# Solution:  383.7679329486616
# Solution:  383.1019635842756
# Solution:  382.77101740922774
# Solution:  382.39410430995
# Solution:  379.7473245851698
# Iterasi ke- 31
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3162467593944831
# a: 0.09449586718106746
# b: 0.09449586718106746
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  398.37845541339306
# Solution:  394.04226714380786
# Solution:  393.40702080987774
# Solution:  393.186275903953
# Solution:  392.34493405707894
# Solution:  388.5054761400601
# Solution:  388.36055689431754
# Solution:  387.5925252779343
# Solution:  387.20526925338646
# Solution:  383.29142548981207
# Solution:  382.87194158285365
# Solution:  382.39410430995
# Solution:  381.21524459845796
# Iterasi ke- 32
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3067593566126486
# a: 0.0973307431964995
# b: 0.0973307431964995
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  398.37845541339306
# Solution:  394.04226714380786
# Solution:  393.40702080987774
# Solution:  389.80041352519953
# Solution:  389.62840114114465
# Solution:  388.5054761400601
# Solution:  388.36055689431754
# Solution:  386.0006422141844
# Solution:  384.7731193612663
# Solution:  383.29142548981207
# Solution:  381.68516942620687
# Solution:  381.33019313021515
# Solution:  378.73688911336757
# Iterasi ke- 33
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.2975565759142691
# a: 0.10025066549239448
# b: 0.10025066549239448
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  395.89624289986295
# Solution:  394.04145324143053
# Solution:  390.6980433385123
# Solution:  390.3440033001368
# Solution:  386.9863934302145
# Solution:  386.06163679089224
# Solution:  384.8249525916535
# Solution:  383.7720444805183
# Solution:  383.31143823050076
# Solution:  383.2704062546053
# Solution:  381.68516942620687
# Solution:  379.0832286190632
# Iterasi ke- 34
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.28862987863684103
# a: 0.10325818545716631
# b: 0.10325818545716631
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  393.34256646583935
# Solution:  394.04145324143053
# Solution:  392.40313715628105
# Solution:  392.07073763676004
# Solution:  390.6980433385123
# Solution:  387.45354027806815
# Solution:  386.5397055422075
# Solution:  385.3132747242973
# Solution:  385.1793729544007
# Solution:  384.4128188494402
# Solution:  383.4985364404025
# Solution:  379.7900885825523
# Iterasi ke- 35
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.2799709822777358
# a: 0.1063559310208813
# b: 0.1063559310208813
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  394.04096236645586
# Solution:  393.34256646583935
# Solution:  392.40313715628105
# Solution:  390.9807873239079
# Solution:  388.5723540394294
# Solution:  387.6537127588578
# Solution:  386.5397055422075
# Solution:  385.3132747242973
# Solution:  385.1985936691261
# Solution:  385.18018685677805
# Solution:  381.6245865377963
# Solution:  381.47779822924264
# Iterasi ke- 36
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.2715718528094037
# a: 0.10954660895150774
# b: 0.10954660895150774
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  394.7918720964202
# Solution:  394.04096236645586
# Solution:  391.2311177329476
# Solution:  388.61267227969756
# Solution:  387.8580868930649
# Solution:  387.6537127588578
# Solution:  387.27019977301984
# Solution:  385.1985936691261
# Solution:  385.18018685677805
# Solution:  382.3826820440023
# Solution:  381.6245865377963
# Iterasi ke- 37
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.2634246972251216
# a: 0.11283300722005297
# b: 0.11283300722005297
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  394.7758537375702
# Solution:  391.450170320231
# Solution:  390.37394464195177
# Solution:  389.72020197167376
# Solution:  388.31405937897296
# Solution:  387.6732429701393
# Solution:  387.27019977301984
# Solution:  386.2663236018852
# Solution:  385.89978336437275
# Solution:  383.9546646505243
# Solution:  383.4157950765278
# Iterasi ke- 38
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.25552195630836794
# a: 0.11621799743665456
# b: 0.11621799743665456
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  396.1222446196389
# Solution:  395.8293526115912
# Solution:  392.635511022113
# Solution:  390.5506864223257
# Solution:  389.72020197167376
# Solution:  389.0640794855983
# Solution:  385.89978336437275
# Solution:  383.9546646505243
# Solution:  383.4157950765278
# Solution:  382.2501774635541
# Solution:  382.11147461971194
# Iterasi ke- 39
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.2478562976191169
# a: 0.1197045373597542
# b: 0.1197045373597542
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  396.1222446196389
# Solution:  395.8293526115912
# Solution:  393.1395247615912
# Solution:  393.1050598543113
# Solution:  390.5506864223257
# Solution:  386.3400276942416
# Solution:  384.58700059748395
# Solution:  383.2859602159074
# Solution:  382.30581217156424
# Solution:  381.1083648402776
# Iterasi ke- 40
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.24042060869054338
# a: 0.12329567348054683
# b: 0.12329567348054683
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  397.09038855833523
# Solution:  395.0017791587652
# Solution:  394.8201361376957
# Solution:  394.25806210988526
# Solution:  393.64941918123696
# Solution:  385.45075225630376
# Solution:  384.58700059748395
# Solution:  383.7417876004099
# Solution:  383.6397146524847
# Solution:  383.47818685597844
# Iterasi ke- 41
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.23320799042982707
# a: 0.12699454368496324
# b: 0.12699454368496324
# Elite Solution: [402.7228178484677, 2098, 29967541.501371205, 19]
# High-Quality Solution
# Solution:  397.09038855833523
# Solution:  395.0017791587652
# Solution:  394.83615449654576
# Solution:  394.3171887923151
# Solution:  392.94305009272256
# Solution:  387.1799357758737
# Solution:  387.1646311393565
# Solution:  383.47818685597844
# Solution:  382.38741113489357
# Solution:  382.30581217156424
# Iterasi ke- 42
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.23320799042982707
# a: 0.12699454368496324
# b: 0.12699454368496324
# Elite Solution: [407.0345196596424, 2122, 30403577.501371205, 19]
# High-Quality Solution
# Solution:  396.00817391987925
# Solution:  394.3171887923151
# Solution:  392.5714254965909
# Solution:  391.64534855731506
# Solution:  389.6363058117041
# Solution:  388.9078476614056
# Solution:  387.41588685783455
# Solution:  387.1646311393565
# Solution:  382.30581217156424
# Iterasi ke- 43
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.23320799042982707
# a: 0.12699454368496324
# b: 0.12699454368496324
# Elite Solution: [407.0345196596424, 2122, 30403577.501371205, 19]
# High-Quality Solution
# Solution:  396.02197542400506
# Solution:  392.3877919072824
# Solution:  391.2954413429436
# Solution:  390.7560731193772
# Solution:  389.3871267396908
# Solution:  389.0067628295053
# Solution:  388.9078476614056
# Solution:  387.41588685783455
# Solution:  387.1646311393565
# Iterasi ke- 44
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.22621175071693225
# a: 0.13080437999551214
# b: 0.13080437999551214
# Elite Solution: [407.0345196596424, 2122, 30403577.501371205, 19]
# High-Quality Solution
# Solution:  404.4370825200103
# Solution:  394.2701033822396
# Solution:  392.3877919072824
# Solution:  389.99656919005895
# Solution:  389.1464563531306
# Solution:  387.76810131403545
# Solution:  387.1646311393565
# Solution:  385.1277458602954
# Solution:  385.0243894803436
# Iterasi ke- 45
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.21942539819542428
# a: 0.1347285113953775
# b: 0.1347285113953775
# Elite Solution: [407.0345196596424, 2122, 30403577.501371205, 19]
# High-Quality Solution
# Solution:  404.592879903092
# Solution:  394.2701033822396
# Solution:  391.8401913581522
# Solution:  390.068794018193
# Solution:  389.69985873441476
# Solution:  389.3578432573172
# Solution:  387.76810131403545
# Solution:  385.77852227406413
# Solution:  385.18652417984003
# Iterasi ke- 46
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.21284263624956154
# a: 0.13877036673723883
# b: 0.13877036673723883
# Elite Solution: [407.0345196596424, 2122, 30403577.501371205, 19]
# High-Quality Solution
# Solution:  404.592879903092
# Solution:  394.0342378141795
# Solution:  393.96930844978476
# Solution:  391.8401913581522
# Solution:  391.8306686957191
# Solution:  388.4854282775968
# Solution:  387.7672874116581
# Solution:  387.16524869174395
# Solution:  385.77852227406413
# Iterasi ke- 47
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.2064573571620747
# a: 0.142933477739356
# b: 0.142933477739356
# Elite Solution: [407.0345196596424, 2122, 30403577.501371205, 19]
# High-Quality Solution
# Solution:  399.7030249691609
# Solution:  393.96930844978476
# Solution:  392.1351605836367
# Solution:  391.8306686957191
# Solution:  391.8228408681237
# Solution:  387.8809115735377
# Solution:  387.2997464164528
# Solution:  387.29109695841544
# Solution:  387.16524869174395
# Iterasi ke- 48
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.20026363644721246
# a: 0.14722148207153668
# b: 0.14722148207153668
# Elite Solution: [407.0345196596424, 2122, 30403577.501371205, 19]
# High-Quality Solution
# Solution:  399.7030249691609
# Solution:  395.45196103288856
# Solution:  393.96930844978476
# Solution:  393.67835576139174
# Solution:  392.50931327720104
# Solution:  391.8228408681237
# Solution:  391.6451142041014
# Solution:  387.8809115735377
# Iterasi ke- 49
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.19425572735379606
# a: 0.15163812653368278
# b: 0.15163812653368278
# Elite Solution: [407.0345196596424, 2122, 30403577.501371205, 19]
# High-Quality Solution
# Solution:  395.45196103288856
# Solution:  393.7995385480699
# Solution:  393.67835576139174
# Solution:  392.824467094398
# Solution:  392.50931327720104
# Solution:  391.6451142041014
# Solution:  389.3538105801213
# Solution:  388.66710989945113
# Iterasi ke- 50
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.18842805553318218
# a: 0.15618727032969326
# b: 0.15618727032969326
# Elite Solution: [407.0345196596424, 2122, 30403577.501371205, 19]
# High-Quality Solution
# Solution:  396.9708603459716
# Solution:  395.45196103288856
# Solution:  394.93928776359496
# Solution:  391.80294418868664
# Solution:  390.4730947807679
# Solution:  390.3970048375239
# Solution:  389.3538105801213
# Solution:  386.62556145752114
# Iterasi ke- 51
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.1827752138671867
# a: 0.16087288843958406
# b: 0.16087288843958406
# Elite Solution: [407.0345196596424, 2122, 30403577.501371205, 19]
# High-Quality Solution
# Solution:  403.23814328334896
# Solution:  399.5799685053644
# Solution:  396.6248254370388
# Solution:  396.5639877597251
# Solution:  394.93928776359496
# Solution:  389.90541098185554
# Solution:  389.326116315012
# Solution:  389.0564313301526
# Iterasi ke- 52
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.1772919574511711
# a: 0.16569907509277157
# b: 0.16569907509277157
# Elite Solution: [407.0345196596424, 2122, 30403577.501371205, 19]
# High-Quality Solution
# Solution:  403.23814328334896
# Solution:  401.5770871485807
# Solution:  399.5799685053644
# Solution:  396.6248254370388
# Solution:  394.87515242356585
# Solution:  394.0500123256571
# Solution:  390.67775364702055
# Iterasi ke- 53
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.17197319872763597
# a: 0.17067004734555472
# b: 0.17067004734555472
# Elite Solution: [407.0345196596424, 2122, 30403577.501371205, 19]
# High-Quality Solution
# Solution:  401.94831185440387
# Solution:  401.5770871485807
# Solution:  399.5211444080007
# Solution:  396.2809337068013
# Solution:  394.015717277646
# Solution:  390.67837119940805
# Solution:  390.5810247995888
# Iterasi ke- 54
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.17197319872763597
# a: 0.17067004734555472
# b: 0.17067004734555472
# Elite Solution: [408.4567065242951, 2135, 30928155.501371205, 19]
# High-Quality Solution
# Solution:  408.4567065242951
# Solution:  402.3767521399342
# Solution:  399.5211444080007
# Solution:  398.83107871580955
# Solution:  394.015717277646
# Solution:  392.3277540105857
# Solution:  391.5676466373459
# Iterasi ke- 55
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.17197319872763597
# a: 0.17067004734555472
# b: 0.17067004734555472
# Elite Solution: [408.4567065242951, 2135, 30928155.501371205, 19]
# High-Quality Solution
# Solution:  408.4567065242951
# Solution:  402.3767521399342
# Solution:  398.83107871580955
# Solution:  398.0018017239728
# Solution:  397.3864195503157
# Solution:  393.17934147084014
# Solution:  391.8445539609462
# Iterasi ke- 56
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.16681400276580688
# a: 0.17579014876592136
# b: 0.17579014876592136
# Elite Solution: [408.4567065242951, 2135, 30928155.501371205, 19]
# High-Quality Solution
# Solution:  406.5530884927696
# Solution:  401.42798553651863
# Solution:  398.31494743198505
# Solution:  398.0018017239728
# Solution:  395.0145030417768
# Solution:  391.8445539609462
# Solution:  391.2870141280563
# Iterasi ke- 57
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.16681400276580688
# a: 0.17579014876592136
# b: 0.17579014876592136
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  410.3461628908209
# Solution:  406.5530884927696
# Solution:  401.42798553651863
# Solution:  400.6187638896071
# Solution:  394.0657364383612
# Solution:  392.0259738757603
# Solution:  389.4912685328966
# Iterasi ke- 58
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.16681400276580688
# a: 0.17579014876592136
# b: 0.17579014876592136
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  408.5215207304269
# Solution:  403.8028078509569
# Solution:  401.42798553651863
# Solution:  400.6187638896071
# Solution:  394.06655034073856
# Solution:  392.3366896613349
# Solution:  390.7222162636789
# Iterasi ke- 59
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.16180958268283266
# a: 0.181063853228899
# b: 0.181063853228899
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  409.58653660626373
# Solution:  404.0297936245121
# Solution:  399.4467444662736
# Solution:  394.3741968149574
# Solution:  394.2982306610298
# Solution:  393.5019413438889
# Solution:  392.1179891814914
# Iterasi ke- 60
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.15695529520234766
# a: 0.186495768825766
# b: 0.186495768825766
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  409.58653660626373
# Solution:  404.0297936245121
# Solution:  399.9057514405433
# Solution:  397.55253970846417
# Solution:  397.40768293832264
# Solution:  394.2982306610298
# Iterasi ke- 61
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.15224663634627722
# a: 0.19209064189053898
# b: 0.19209064189053898
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  406.9881865195067
# Solution:  406.2518602545008
# Solution:  404.0297936245121
# Solution:  397.40768293832264
# Solution:  396.38805644924884
# Solution:  394.9294927181354
# Iterasi ke- 62
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.1476792372558889
# a: 0.19785336114725516
# b: 0.19785336114725516
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  406.9881865195067
# Solution:  406.2518602545008
# Solution:  402.71237185505674
# Solution:  397.56934347392087
# Solution:  396.530511527179
# Solution:  393.43678223394045
# Iterasi ke- 63
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.14324886013821225
# a: 0.20378896198167282
# b: 0.20378896198167282
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  409.13014783104586
# Solution:  406.2518602545008
# Solution:  400.10326369566394
# Solution:  397.56934347392087
# Solution:  396.5535659465581
# Solution:  394.74496749379125
# Iterasi ke- 64
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.1389513943340659
# a: 0.209902630841123
# b: 0.209902630841123
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  410.0194232689837
# Solution:  403.8572420049947
# Solution:  399.61391114715525
# Solution:  398.4775781983827
# Solution:  396.64535323294604
# Solution:  392.9767281593184
# Iterasi ke- 65
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.1347828525040439
# a: 0.21619970976635672
# b: 0.21619970976635672
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  410.0194232689837
# Solution:  404.9395611323746
# Solution:  402.96139172384585
# Solution:  399.61391114715525
# Solution:  398.4775781983827
# Solution:  398.09692177490905
# Iterasi ke- 66
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.13073936692892257
# a: 0.22268570105934743
# b: 0.22268570105934743
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  409.2061036077677
# Solution:  404.3973199075589
# Solution:  402.96139172384585
# Solution:  399.3678299088573
# Solution:  396.8172366424054
# Iterasi ke- 67
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.1268171859210549
# a: 0.22936627209112787
# b: 0.22936627209112787
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  409.7328084255213
# Solution:  404.3973199075589
# Solution:  403.2623447109333
# Solution:  400.26530887116047
# Solution:  396.8172366424054
# Iterasi ke- 68
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.12301267034342325
# a: 0.2362472602538617
# b: 0.2362472602538617
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  409.7328084255213
# Solution:  407.9774398016762
# Solution:  406.9565021947326
# Solution:  398.85609779697313
# Solution:  396.8874896250736
# Iterasi ke- 69
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.11932229023312055
# a: 0.24333467806147754
# b: 0.24333467806147754
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  408.0211498429669
# Solution:  407.9774398016762
# Solution:  404.83875385651663
# Solution:  398.07123476917343
# Solution:  396.4384553367747
# Iterasi ke- 70
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.11574262152612692
# a: 0.25063471840332185
# b: 0.25063471840332185
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  408.0211498429669
# Solution:  406.1228557085535
# Solution:  401.2733987924818
# Solution:  398.3034200795525
# Solution:  398.2262585635789
# Iterasi ke- 71
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.11227034288034311
# a: 0.2581537599554215
# b: 0.2581537599554215
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  406.37936019409585
# Solution:  404.9229586233481
# Solution:  401.15078139075075
# Solution:  398.2262585635789
# Solution:  395.3931527702014
# Iterasi ke- 72
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.10890223259393282
# a: 0.2658983727540842
# b: 0.2658983727540842
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  406.7442901810937
# Solution:  404.9229586233481
# Solution:  403.77949287977617
# Solution:  393.90770695014515
# Iterasi ke- 73
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.10563516561611483
# a: 0.2738753239367067
# b: 0.2738753239367067
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  407.2722663806354
# Solution:  406.7442901810937
# Solution:  406.388601039169
# Solution:  397.46183407987826
# Iterasi ke- 74
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.10246611064763138
# a: 0.2820915836548079
# b: 0.2820915836548079
# Elite Solution: [412.3040026128789, 2148, 30686974.501371205, 19]
# High-Quality Solution
# Solution:  405.1863290246649
# Solution:  406.7442901810937
# Solution:  406.388601039169
# Solution:  398.1873478633759
# Iterasi ke- 75
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.10246611064763138
# a: 0.2820915836548079
# b: 0.2820915836548079
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  405.1863290246649
# Solution:  404.0490940769454
# Solution:  403.8986079232345
# Solution:  398.1873478633759
# Iterasi ke- 76
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.10246611064763138
# a: 0.2820915836548079
# b: 0.2820915836548079
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  403.47577455394577
# Solution:  403.46649630320996
# Solution:  403.1090843285292
# Solution:  396.35917054005915
# Iterasi ke- 77
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.09939212732820243
# a: 0.2905543311644522
# b: 0.2905543311644522
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  403.1090843285292
# Solution:  402.7474410494218
# Solution:  401.8318227580037
# Solution:  394.9229362922698
# Iterasi ke- 78
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.09641036350835636
# a: 0.2992709610993857
# b: 0.2992709610993857
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  406.60390540911044
# Solution:  402.7474410494218
# Solution:  401.8318227580037
# Solution:  398.9477696263177
# Iterasi ke- 79
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.09351805260310567
# a: 0.3082490899323673
# b: 0.3082490899323673
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  406.60390540911044
# Solution:  404.0050586977748
# Solution:  402.7474410494218
# Solution:  397.77656410536156
# Iterasi ke- 80
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.09071251102501249
# a: 0.3174965626303384
# b: 0.3174965626303384
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  406.69569269549845
# Solution:  405.17707812110825
# Solution:  403.49950325835664
# Solution:  401.9145554908249
# Iterasi ke- 81
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.0879911356942621
# a: 0.32702145950924855
# b: 0.32702145950924855
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  406.69569269549845
# Solution:  405.17707812110825
# Solution:  403.91325270190816
# Solution:  399.78396607304893
# Iterasi ke- 82
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.08535140162343424
# a: 0.336832103294526
# b: 0.336832103294526
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  406.12143231387
# Solution:  404.42637453407303
# Solution:  403.91325270190816
# Solution:  396.54097105143654
# Iterasi ke- 83
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.08279085957473122
# a: 0.3469370663933618
# b: 0.3469370663933618
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  402.66928568672967
# Solution:  402.1703390703529
# Solution:  395.80977693456566
# Iterasi ke- 84
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.08030713378748927
# a: 0.35734517838516267
# b: 0.35734517838516267
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  402.668794811755
# Solution:  402.1703390703529
# Solution:  395.80977693456566
# Iterasi ke- 85
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.0778979197738646
# a: 0.3680655337367176
# b: 0.3680655337367176
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  402.1703390703529
# Solution:  396.9331804350169
# Solution:  395.88065294703375
# Iterasi ke- 86
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.07556098218064865
# a: 0.37910749974881913
# b: 0.37910749974881913
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  411.0395852689072
# Solution:  395.88065294703375
# Solution:  392.8603055619126
# Iterasi ke- 87
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.07329415271522918
# a: 0.3904807247412837
# b: 0.3904807247412837
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  411.0395852689072
# Solution:  394.9806341092509
# Solution:  393.4403936821497
# Iterasi ke- 88
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.07109532813377231
# a: 0.4021951464835222
# b: 0.4021951464835222
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  412.69750526795576
# Solution:  402.83228151379444
# Solution:  400.7191830797924
# Iterasi ke- 89
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.06896246828975915
# a: 0.4142610008780279
# b: 0.4142610008780279
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  412.69750526795576
# Solution:  402.83228151379444
# Solution:  400.7191830797924
# Iterasi ke- 90
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.06689359424106638
# a: 0.42668883090436877
# b: 0.42668883090436877
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  411.53318898655976
# Solution:  402.83228151379444
# Solution:  398.90555782427236
# Iterasi ke- 91
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.06488678641383439
# a: 0.4394894958314998
# b: 0.4394894958314998
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  411.53318898655976
# Solution:  399.65556123311586
# Solution:  397.36993421124896
# Iterasi ke- 92
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.06294018282141935
# a: 0.45267418070644483
# b: 0.45267418070644483
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  403.9785439733291
# Solution:  397.14302329555005
# Solution:  396.19791478791547
# Iterasi ke- 93
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.061051977336776767
# a: 0.4662544061276382
# b: 0.4662544061276382
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  397.32583060687324
# Solution:  396.90948974047706
# Solution:  394.2219475480257
# Iterasi ke- 94
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.059220418016673465
# a: 0.48024203831146733
# b: 0.48024203831146733
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  397.32583060687324
# Solution:  396.90948974047706
# Iterasi ke- 95
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.05744380547617326
# a: 0.4946492994608114
# b: 0.4946492994608114
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  406.3982780249746
# Solution:  396.90948974047706
# Iterasi ke- 96
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.05572049131188806
# a: 0.5094887784446357
# b: 0.5094887784446357
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  406.3982780249746
# Solution:  395.91753592558473
# Iterasi ke- 97
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.05404887657253142
# a: 0.5247734417979748
# b: 0.5247734417979748
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  402.85434209310233
# Solution:  395.09326069315176
# Iterasi ke- 98
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.052427410275355475
# a: 0.5405166450519141
# b: 0.5405166450519141
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  396.4227133577557
# Solution:  395.09326069315176
# Iterasi ke- 99
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.05085458796709481
# a: 0.5567321444034715
# b: 0.5567321444034715
# Elite Solution: [413.0983713331383, 2148, 30436142.501371205, 19]
# High-Quality Solution
# Solution:  397.6308056151119
# Solution:  396.2392124942446
# Final Elite Solutions
# Solution:  [396.74504145198614, 2088, 31106137.501371205, 20]
# Solution:  [396.6672940529784, 2089, 31205583.501371205, 19]
# Solution:  [396.6587295112809, 2084, 30833806.501371205, 19]
# Solution:  [396.2392124942446, 2092, 31565444.501371205, 20]
# Solution:  [393.09074703952155, 2074, 31211479.501371205, 19]
# Solution:  [392.60390529974984, 2076, 31514998.501371205, 20]
# Solution:  [391.6069287320867, 2065, 31005947.501371205, 20]
# Solution:  [390.9751593943578, 2068, 31430125.501371205, 20]
# Solution:  [389.927525372475, 2091, 33483543.501371205, 22]
# Solution:  [388.6289929314804, 2087, 33593986.501371205, 22]
# Final Elite Solution
# Solution:  [413.0983713331383, 2148, 30436142.501371205, 19]

# %%
print(result)
# Out:
# [[0, 2, Timestamp('2020-11-20 16:06:59+0000', tz='UTC'), Timestamp('2020-11-21 05:40:59+0000', tz='UTC'), 47, 0.133], [1, 1, Timestamp('2020-11-20 18:24:12+0000', tz='UTC'), Timestamp('2020-11-21 07:45:14+0000', tz='UTC'), 47, 0.133], [2, 39, Timestamp('2020-11-20 16:13:20+0000', tz='UTC'), Timestamp('2020-11-21 05:09:18+0000', tz='UTC'), 63, 0.133], [3, 18, Timestamp('2020-11-20 19:24:04+0000', tz='UTC'), Timestamp('2020-11-21 07:54:04+0000', tz='UTC'), 55, 0.133], [4, 11, Timestamp('2020-11-21 06:48:48+0000', tz='UTC'), Timestamp('2020-11-21 19:18:48+0000', tz='UTC'), 35, 0.133], [5, 12, Timestamp('2020-11-20 17:54:12+0000', tz='UTC'), Timestamp('2020-11-21 00:57:39+0000', tz='UTC'), 60, 0.171], [6, 9, Timestamp('2020-11-21 02:19:29+0000', tz='UTC'), Timestamp('2020-11-21 09:14:54+0000', tz='UTC'), 71, 0.171], [7, 16, Timestamp('2020-11-20 20:02:05+0000', tz='UTC'), Timestamp('2020-11-21 04:34:48+0000', tz='UTC'), 53, 0.128], [8, 25, Timestamp('2020-11-20 21:01:38+0000', tz='UTC'), Timestamp('2020-11-21 09:16:45+0000', tz='UTC'), 60, 0.171], [9, 14, Timestamp('2020-11-20 21:26:06+0000', tz='UTC'), Timestamp('2020-11-21 06:41:53+0000', tz='UTC'), 55, 0.133], [10, 15, Timestamp('2020-11-20 22:21:21+0000', tz='UTC'), Timestamp('2020-11-21 05:10:47+0000', tz='UTC'), 49, 0.14], [11, 3, Timestamp('2020-11-20 23:21:25+0000', tz='UTC'), Timestamp('2020-11-21 09:35:51+0000', tz='UTC'), 60, 0.171], [12, 6, Timestamp('2020-11-21 01:12:22+0000', tz='UTC'), Timestamp('2020-11-21 15:01:21+0000', tz='UTC'), 47, 0.133], [13, 7, Timestamp('2020-11-21 02:30:04+0000', tz='UTC'), Timestamp('2020-11-21 08:59:52+0000', tz='UTC'), 71, 0.171], [14, 5, Timestamp('2020-11-21 03:07:03+0000', tz='UTC'), Timestamp('2020-11-21 06:16:27+0000', tz='UTC'), 53, 0.128], [15, 9, Timestamp('2020-11-21 09:44:54+0000', tz='UTC'), Timestamp('2020-11-21 17:29:58+0000', tz='UTC'), 71, 0.171], [16, 12, Timestamp('2020-11-21 05:09:13+0000', tz='UTC'), Timestamp('2020-11-21 12:51:55+0000', tz='UTC'), 37, 0.171], [17, 16, Timestamp('2020-11-21 06:32:16+0000', tz='UTC'), Timestamp('2020-11-21 11:06:39+0000', tz='UTC'), 71, 0.171], [18, 15, Timestamp('2020-11-21 06:32:24+0000', tz='UTC'), Timestamp('2020-11-21 14:17:22+0000', tz='UTC'), 47, 0.133], [19, 31, Timestamp('2020-11-21 07:55:25+0000', tz='UTC'), Timestamp('2020-11-21 18:15:52+0000', tz='UTC'), 60, 0.171], [20, 14, Timestamp('2020-11-21 09:24:06+0000', tz='UTC'), Timestamp('2020-11-21 16:09:35+0000', tz='UTC'), 58, 0.14], [21, 1, Timestamp('2020-11-21 09:31:00+0000', tz='UTC'), Timestamp('2020-11-21 21:03:58+0000', tz='UTC'), 60, 0.171], [22, 13, Timestamp('2020-11-21 10:27:44+0000', tz='UTC'), Timestamp('2020-11-21 11:38:48+0000', tz='UTC'), 47, 0.133], [23, 4, Timestamp('2020-11-21 10:33:18+0000', tz='UTC'), Timestamp('2020-11-21 22:31:29+0000', tz='UTC'), 60, 0.171], [24, 39, Timestamp('2020-11-21 10:38:05+0000', tz='UTC'), Timestamp('2020-11-21 10:50:28+0000', tz='UTC'), 63, 0.133], [25, 39, Timestamp('2020-11-21 11:20:28+0000', tz='UTC'), Timestamp('2020-11-21 22:57:06+0000', tz='UTC'), 81, 0.171], [26, 2, Timestamp('2020-11-21 11:06:23+0000', tz='UTC'), Timestamp('2020-11-21 22:54:41+0000', tz='UTC'), 60, 0.171], [27, 18, Timestamp('2020-11-21 11:32:34+0000', tz='UTC'), Timestamp('2020-11-21 22:18:44+0000', tz='UTC'), 71, 0.171], [28, 7, Timestamp('2020-11-21 11:43:39+0000', tz='UTC'), Timestamp('2020-11-21 14:38:28+0000', tz='UTC'), 71, 0.171], [29, 8, Timestamp('2020-11-21 12:28:41+0000', tz='UTC'), Timestamp('2020-11-21 15:55:19+0000', tz='UTC'), 45, 0.128], [30, 16, Timestamp('2020-11-21 13:21:55+0000', tz='UTC'), Timestamp('2020-11-21 21:22:54+0000', tz='UTC'), 71, 0.171], [31, 5, Timestamp('2020-11-21 13:10:08+0000', tz='UTC'), Timestamp('2020-11-21 22:01:52+0000', tz='UTC'), 47, 0.113], [32, 9, Timestamp('2020-11-21 17:59:58+0000', tz='UTC'), Timestamp('2020-11-21 21:01:23+0000', tz='UTC'), 53, 0.128], [33, 8, Timestamp('2020-11-21 17:28:30+0000', tz='UTC'), Timestamp('2020-11-21 20:59:48+0000', tz=' ...

# %%
def printResult(result):
    fitness = countFitness(result)
    originalschedule = createOriginalSchedule()
    original_fitness = countFitness(originalschedule)
    print("------------------------------------------------------------------------------------------------------------------")
    print("Airplane \tPassenger \tCost \t\tRouting")
    print("------------------------------------------------------------------------------------------------------------------")
    for i in range(len(airplanes)):
        flight_list = []
        airplanefitness = countAirplaneFitness(result, i)
        print(airplanes["airplane"].iloc[i], end="\t\t")
        print(airplanefitness[1], end="\t\t")
        print(airplanefitness[2], end="\t\t")
        
        for j in range(len(result)):
            if(result[j][1]==i):
                flight_list.append(result[j])
                
        for k in range(len(flight_list)):
            print("Flight-", flight_list[k][0], end=", ")     
            
        print("\n")
    
    print("------------------------------------------------------------------------------------------------------------------")
    print('Result\t\t%d\t\t%d\t\t%d' % (fitness[1], fitness[2], fitness[3]))
    print("------------------------------------------------------------------------------------------------------------------")
    print('Original\t%d\t\t%d\t\t%d' % (original_fitness[1], original_fitness[2], original_fitness[3]))
    print("------------------------------------------------------------------------------------------------------------------")
    print('Difference\t%d\t\t%d\t\t\t%d' % (fitness[1] - original_fitness[1], original_fitness[2] - fitness[2], original_fitness[3] - fitness[3]))
    print("------------------------------------------------------------------------------------------------------------------")

# %%
printResult(result)
# Out:
# ------------------------------------------------------------------------------------------------------------------
# Airplane 	Passenger 	Cost 		Routing
# ------------------------------------------------------------------------------------------------------------------
# 9V-SMG		0		71565
#
# 9V-SMI		107		1547524.5308433375		Flight- 1, Flight- 21,
#
# 9V-SMT		107		1630751.5210252982		Flight- 0, Flight- 26,
#
# 9V-SMD		60		1277652.8373252342		Flight- 11,
#
# 9V-SMH		60		1154031.7855521704		Flight- 23,
#
# 9V-SFN		100		1277438.1108331797		Flight- 14, Flight- 31,
#
# 9V-SMC		47		1526814.760512649		Flight- 12,
#
# 9V-SFM		213		1451224.5581899695		Flight- 13, Flight- 28, Flight- 35,
#
# 9V-SMS		105		1152003.6005723756		Flight- 29, Flight- 33,
#
# 9V-SFK		195		1589151.7182803224		Flight- 6, Flight- 15, Flight- 32,
#
# 9V-SML		0		265590
#
# 9V-SWQ		35		1294066.954912411		Flight- 4,
#
# 9V-MGL		97		1045736.6735580678		Flight- 5, Flight- 16,
#
# 9V-SMF		47		1113477.7633108336		Flight- 22,
#
# 9V-SFQ		113		1485608.8965848708		Flight- 9, Flight- 20,
#
# 9V-SWE		143		1600979.6342113835		Flight- 10, Flight- 18, Flight- 34,
#
# 9V-SFI		195		1582868.2159677343		Flight- 7, Flight- 17, Flight- 30,
#
# 9V-SMO		0		153855
#
# 9V-SFP		197		1781547.250175292		Flight- 3, Flight- 27, Flight- 36,
#
# 9V-SFO		0		329988
#
# 9V-SMQ		0		91065
#
# 9V-SMN		0		83655
#
# 9V-SMJ		0		167115
#
# 9V-SMM		0		90870
#
# 9V-SMB		0		89895
#
# 9V-SMP		60		1313363.760512649		Flight- 8,
#
# 9V-SMA		0		71370
#
# 9V-SWY		0		53320
#
# 9V-SWR		0		53940
#
# 9V-SCB		0		102900
#
# 9V-SWP		0		53320
#
# 9V-SMK		60		1177527.7363326042		Flight- 19,
#
# 9V-MGI		0		109296
#
# 9V-SMR		0		144690
#
# 9V-SWM		0		208475
#
# 9V-SWH		0		55180
#
# 9V-SWO		0		102145
#
# 9V-MGF		0		131928
#
# 9V-SWS		0		222270
#
# 9V-SKU		207		2057770.1926708242		Flight- 2, Flight- 24, Flight- 25,
#
# 9V-SME		0		279630
#
# 9V-SWK		0		222270
#
# 9V-SWN		0		222270
#
# ------------------------------------------------------------------------------------------------------------------
# Result		2148		30436142		19
# ------------------------------------------------------------------------------------------------------------------
# Original	2108		31576268		21
# ------------------------------------------------------------------------------------------------------------------
# Difference	40		1140126			2
# ------------------------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np
    
for i in range(len(y_plot_list)):
    plt.plot(x_plot_list, y_plot_list[i])

plt.show()

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 6512.374591827393 seconds ---

# %%
import pickle

with open('dera_output-1-40', 'wb') as fp:
    pickle.dump(result, fp)
with open('dera_xplot-1-40', 'wb') as fp:
    pickle.dump(x_plot_list, fp)
with open('dera_yplot-1-40', 'wb') as fp:
    pickle.dump(y_plot_list, fp)

# %%
with open('dera_output-1-40', 'rb') as fp:
    read_result = pickle.load(fp)
    
print(read_result)
# Out:
# [[0, 2, Timestamp('2020-11-20 16:06:59+0000', tz='UTC'), Timestamp('2020-11-21 05:40:59+0000', tz='UTC'), 47, 0.133], [1, 1, Timestamp('2020-11-20 18:24:12+0000', tz='UTC'), Timestamp('2020-11-21 07:45:14+0000', tz='UTC'), 47, 0.133], [2, 39, Timestamp('2020-11-20 16:13:20+0000', tz='UTC'), Timestamp('2020-11-21 05:09:18+0000', tz='UTC'), 63, 0.133], [3, 18, Timestamp('2020-11-20 19:24:04+0000', tz='UTC'), Timestamp('2020-11-21 07:54:04+0000', tz='UTC'), 55, 0.133], [4, 11, Timestamp('2020-11-21 06:48:48+0000', tz='UTC'), Timestamp('2020-11-21 19:18:48+0000', tz='UTC'), 35, 0.133], [5, 12, Timestamp('2020-11-20 17:54:12+0000', tz='UTC'), Timestamp('2020-11-21 00:57:39+0000', tz='UTC'), 60, 0.171], [6, 9, Timestamp('2020-11-21 02:19:29+0000', tz='UTC'), Timestamp('2020-11-21 09:14:54+0000', tz='UTC'), 71, 0.171], [7, 16, Timestamp('2020-11-20 20:02:05+0000', tz='UTC'), Timestamp('2020-11-21 04:34:48+0000', tz='UTC'), 53, 0.128], [8, 25, Timestamp('2020-11-20 21:01:38+0000', tz='UTC'), Timestamp('2020-11-21 09:16:45+0000', tz='UTC'), 60, 0.171], [9, 14, Timestamp('2020-11-20 21:26:06+0000', tz='UTC'), Timestamp('2020-11-21 06:41:53+0000', tz='UTC'), 55, 0.133], [10, 15, Timestamp('2020-11-20 22:21:21+0000', tz='UTC'), Timestamp('2020-11-21 05:10:47+0000', tz='UTC'), 49, 0.14], [11, 3, Timestamp('2020-11-20 23:21:25+0000', tz='UTC'), Timestamp('2020-11-21 09:35:51+0000', tz='UTC'), 60, 0.171], [12, 6, Timestamp('2020-11-21 01:12:22+0000', tz='UTC'), Timestamp('2020-11-21 15:01:21+0000', tz='UTC'), 47, 0.133], [13, 7, Timestamp('2020-11-21 02:30:04+0000', tz='UTC'), Timestamp('2020-11-21 08:59:52+0000', tz='UTC'), 71, 0.171], [14, 5, Timestamp('2020-11-21 03:07:03+0000', tz='UTC'), Timestamp('2020-11-21 06:16:27+0000', tz='UTC'), 53, 0.128], [15, 9, Timestamp('2020-11-21 09:44:54+0000', tz='UTC'), Timestamp('2020-11-21 17:29:58+0000', tz='UTC'), 71, 0.171], [16, 12, Timestamp('2020-11-21 05:09:13+0000', tz='UTC'), Timestamp('2020-11-21 12:51:55+0000', tz='UTC'), 37, 0.171], [17, 16, Timestamp('2020-11-21 06:32:16+0000', tz='UTC'), Timestamp('2020-11-21 11:06:39+0000', tz='UTC'), 71, 0.171], [18, 15, Timestamp('2020-11-21 06:32:24+0000', tz='UTC'), Timestamp('2020-11-21 14:17:22+0000', tz='UTC'), 47, 0.133], [19, 31, Timestamp('2020-11-21 07:55:25+0000', tz='UTC'), Timestamp('2020-11-21 18:15:52+0000', tz='UTC'), 60, 0.171], [20, 14, Timestamp('2020-11-21 09:24:06+0000', tz='UTC'), Timestamp('2020-11-21 16:09:35+0000', tz='UTC'), 58, 0.14], [21, 1, Timestamp('2020-11-21 09:31:00+0000', tz='UTC'), Timestamp('2020-11-21 21:03:58+0000', tz='UTC'), 60, 0.171], [22, 13, Timestamp('2020-11-21 10:27:44+0000', tz='UTC'), Timestamp('2020-11-21 11:38:48+0000', tz='UTC'), 47, 0.133], [23, 4, Timestamp('2020-11-21 10:33:18+0000', tz='UTC'), Timestamp('2020-11-21 22:31:29+0000', tz='UTC'), 60, 0.171], [24, 39, Timestamp('2020-11-21 10:38:05+0000', tz='UTC'), Timestamp('2020-11-21 10:50:28+0000', tz='UTC'), 63, 0.133], [25, 39, Timestamp('2020-11-21 11:20:28+0000', tz='UTC'), Timestamp('2020-11-21 22:57:06+0000', tz='UTC'), 81, 0.171], [26, 2, Timestamp('2020-11-21 11:06:23+0000', tz='UTC'), Timestamp('2020-11-21 22:54:41+0000', tz='UTC'), 60, 0.171], [27, 18, Timestamp('2020-11-21 11:32:34+0000', tz='UTC'), Timestamp('2020-11-21 22:18:44+0000', tz='UTC'), 71, 0.171], [28, 7, Timestamp('2020-11-21 11:43:39+0000', tz='UTC'), Timestamp('2020-11-21 14:38:28+0000', tz='UTC'), 71, 0.171], [29, 8, Timestamp('2020-11-21 12:28:41+0000', tz='UTC'), Timestamp('2020-11-21 15:55:19+0000', tz='UTC'), 45, 0.128], [30, 16, Timestamp('2020-11-21 13:21:55+0000', tz='UTC'), Timestamp('2020-11-21 21:22:54+0000', tz='UTC'), 71, 0.171], [31, 5, Timestamp('2020-11-21 13:10:08+0000', tz='UTC'), Timestamp('2020-11-21 22:01:52+0000', tz='UTC'), 47, 0.113], [32, 9, Timestamp('2020-11-21 17:59:58+0000', tz='UTC'), Timestamp('2020-11-21 21:01:23+0000', tz='UTC'), 53, 0.128], [33, 8, Timestamp('2020-11-21 17:28:30+0000', tz='UTC'), Timestamp('2020-11-21 20:59:48+0000', tz=' ...

# %%
with open('dera_yplot-1-40', 'rb') as fp:
    read_yplot = pickle.load(fp)
    
print(read_yplot)
# Out:
# [[381.8956813798452, 383.4051731688163, 388.4456890022257, 388.4456890022257, 388.4456890022257, 390.07497501283285, 394.7294970014571, 394.7294970014571, 395.6816882105453, 395.6816882105453, 396.85370763387874, 397.9624390217715, 397.9624390217715, 399.00694841379016, 401.7219683977467, 401.7219683977467, 401.7219683977467, 401.7219683977467, 401.7219683977467, 401.7219683977467, 401.7219683977467, 402.47650312006135, 402.47650312006135, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 402.7228178484677, 404.4370825200103, 404.592879903092, 404.592879903092, 404.592879903092, 404.592879903092, 404.592879903092, 404.592879903092, 404.592879903092, 404.592879903092, 404.592879903092, 408.4567065242951, 408.4567065242951, 408.4567065242951, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 410.3461628908209, 411.0395852689072, 411.0395852689072, 412.69750526795576, 412.69750526795576, 412.69750526795576, 412.69750526795576, 412.69750526795576, 412.69750526795576, 412.69750526795576, 412.69750526795576, 412.69750526795576, 412.69750526795576, 412.69750526795576, 412.69750526795576], [373.5869654708758, 373.5869654708758, 373.5869654708758, 375.60494182230303, 375.60494182230303, 380.74597964184716, 381.44023174369283, 383.2873706640108, 383.2873706640108, 383.6332141094525, 383.6332141094525, 384.62600282673634, 391.41409633096964, 391.41409633096964, 391.41409633096964, 391.41409633096964, 391.41409633096964, 393.9468275311847, 396.31102246714613, 396.31102246714613, 397.200297905084, 397.2091874925281, 397.2091874925281, 397.2091874925281, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 400.28932344291377, 401.5770871485807, 401.5770871485807, 402.3767521399342, 402.3767521399342, 402.3767521399342, 403.8028078509569, 403.8028078509569, 404.0297936245121, 404.0297936245121, 406.2518602545008, 406.2518602545008, 406.2518602545008, 406.2518602545008, 406.2518602545008, 406.2518602545008, 406.2518602545008, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762, 407.9774398016762], [369.4360878122997, 370.1429477757888, 372.5167353721299, 373.5533919064983, 374.56164967539155, 375.5104404723456, 376.22406558729807, 382.32950718 ...

# %%
with open('dera_output-1-40', 'rb') as fp:
    read_result = pickle.load(fp)
    print(countFitness(read_result))
    
# print(read_result)
# Out:
# [413.0983713331383, 2148, 30436142.501371205, 19]
