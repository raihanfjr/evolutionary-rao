# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
import random
import operator
import pickle
from copy import deepcopy

# %%
df = pd.read_csv('flightlist-november.csv') 

print(df)
# Out:
#         callsign number  icao24 registration typecode origin destination  \
# 0        TUP6928    NaN  424450          NaN      NaN    NaN        UUWW
# 1         CSN399  CZ399  781795          NaN      NaN   YMML        KJFK
# 2         ETH714    NaN  040101       ET-ASG     B788   KEWR        ESSA
# 3          ZSALT    NaN  008142       ZS-ALT     B190    NaN        YPPH
# 4         IRM112  W5112  7335a1       EP-MMA     A343   WMKK        LTBW
# ...          ...    ...     ...          ...      ...    ...         ...
# 1825010   NKS236  NK236  ac97e1       N910NK      NaN    NaN        KFLL
# 1825011    AM333    NaN  7c6a57       VH-VAH     BE20   YMAV        YMEN
# 1825012   N404AM    NaN  a4bb89       N404AM     B407    NaN        1IL4
# 1825013   N383AK    NaN  a46679       N383AK      NaN   PAMR        PAMR
# 1825014   EJA426  1I426  a51358       N426QS     GLF4   KALN        KSUS
#
#                          firstseen                   lastseen  \
# 0        2020-10-31 01:29:44+00:00  2020-11-01 08:20:32+00:00
# 1        2020-10-31 01:36:33+00:00  2020-11-01 08:09:29+00:00
# 2        2020-10-31 02:07:17+00:00  2020-11-01 04:37:41+00:00
# 3        2020-10-31 03:33:19+00:00  2020-11-01 10:21:26+00:00
# 4        2020-10-31 03:58:50+00:00  2020-11-01 06:27:20+00:00
# ...                            ...                        ...
# 1825010  2020-11-30 23:36:31+00:00  2020-11-30 23:48:56+00:00
# 1825011  2020-11-30 23:36:47+00:00  2020-11-30 23:48:04+00:00
# 1825012  2020-11-30 23:37:40+00:00  2020-11-30 23:48:30+00:00
# 1825013  2020-11-30 23:37:41+00:00  2020-11-30 23:49:10+00:00
# 1825014  2020-11-30 23:38:09+00:00  2020-11-30 23:49:10+00:00
#
#                                day  latitude_1  longitude_1  altitude_1  \
# 0        2020-11-01 00:00:00+00:00   55.096390    83.177975      3962.4
# 1        2020-11-01 00:00:00+00:00  -37.679306   144.839776         0.0
# 2        2020-11-01 00:00:00+00:00   40.699677   -74.159973         0.0
# 3        2020-11-01 00:00:00+00:00    3.441971    99.149051      3962.4
# 4        2020-11-01 00:00:00+00:00    2.687073   101.735540       304.8
# ...                            ...         ...          ...         ...
# 1825010  2020-11-30 00:00:00+00:00   25.533949   -79.421669      3352.8
# 1825011  2020-11-30 00:00:00+00:00  -38.082275   144.500603       609.6
# 1825012  2020-11-30 00:00:00+00:00   38.586452   -90.448425         0.0
# 1825013  2020-11-30 00:00:00+00:00   61.202957  -149.835761       304.8
# 1825014  2020-11-30 00:00:00+00:00   38.893603   -90.052002       304.8
#
#          latitude_2  longitude_2  altitude_2
# 0         55.478723    37.030020      944.88
# 1         40.654999   -73.747314      -22.86
# 2         59.676710    17.968992      190.50
# 3        -31.957169   115.960199       91.44
# 4         41.183395    28.729309      533.40
# ...             ...          ...         ...
# 1825010   26.065292   -80.063125      396.24
# 1825011  -37.743298   144.901786      236.22
# 1825012   38.379501   -90.119973      518.16
# 1825013   61.213074  -149.846257      281.94
# 1825014   38.662844   -90.628601      137.16
#
# [1825015 rows x 16 columns]

# %%
dfs = df

# %%
dfs = dfs.drop(['number', 'icao24', 'altitude_1', 'altitude_2'], axis=1)

# %%
dfs = dfs.dropna(subset=['registration', 'typecode', 'origin', 'destination', 'latitude_2', 'longitude_2'])

# %%
dfs = dfs[dfs["callsign"].str[:3]=="SIA"]

# %%
dfs.head()
# Out:
#     callsign registration typecode origin destination  \
# 34    SIA377       9V-SMG     A359   LIMC        WSSS
# 161    SIA26       9V-SMI     A359   WSSS        EDDF
# 167   SIA324       9V-SMT     A359   WSSS        EHAM
# 171   SIA283       9V-SMD     A359   WSSS        NZAA
# 267   SIA346       9V-SMH     A359   WSSS        LSZH
#
#                      firstseen                   lastseen  \
# 34   2020-10-31 12:31:55+00:00  2020-11-01 00:48:28+00:00
# 161  2020-10-31 16:12:38+00:00  2020-11-01 04:36:47+00:00
# 167  2020-10-31 16:16:27+00:00  2020-11-01 04:55:17+00:00
# 171  2020-10-31 16:18:49+00:00  2020-11-01 01:19:01+00:00
# 267  2020-10-31 17:42:04+00:00  2020-11-01 06:16:57+00:00
#
#                            day  latitude_1  longitude_1  latitude_2  \
# 34   2020-11-01 00:00:00+00:00   45.623749     8.735337    1.308929
# 161  2020-11-01 00:00:00+00:00    1.395721   103.997048   50.040572
# 167  2020-11-01 00:00:00+00:00    1.389542   103.994720   52.357628
# 171  2020-11-01 00:00:00+00:00    1.394240   103.996298  -36.991241
# 267  2020-11-01 00:00:00+00:00    1.392471   103.996251   47.478653
#
#      longitude_2
# 34    103.960644
# 161     8.549163
# 167     4.711487
# 171   174.861496
# 267     8.540771

# %%
dfs.registration.unique()
# dfs.origin.unique()
# Out:
# array(['9V-SMG', '9V-SMI', '9V-SMT', '9V-SMD', '9V-SMH', '9V-SFN',
#        '9V-SMC', '9V-SFM', '9V-SMS', '9V-SFK', '9V-SML', '9V-SWQ',
#        '9V-MGL', '9V-SMF', '9V-SFQ', '9V-SWE', '9V-SFI', '9V-SMO',
#        '9V-SFP', '9V-SFO', '9V-SMQ', '9V-SMN', '9V-SMJ', '9V-SMM',
#        '9V-SMB', '9V-SMP', '9V-SMA', '9V-SWY', '9V-SWR', '9V-SCB',
#        '9V-SWP', '9V-SMK', '9V-MGI', '9V-SMR', '9V-SWM', '9V-SWH',
#        '9V-SWO', '9V-MGF', '9V-SWS', '9V-SKU', '9V-SME', '9V-SWK',
#        '9V-SWN'], dtype=object)

# %%
data = {'airport': [],
        'latitude': [],
        'longitude': []}

airports = pd.DataFrame(data)
print(airports)
# Out:
# Empty DataFrame
# Columns: [airport, latitude, longitude]
# Index: []

# %%
airports_data = dfs.origin.unique()
airports_another_data = dfs.destination.unique()

for i in airports_another_data:
    found = False
    for j in airports_data:
        if i == j:
            found = True
    if found == False:
        airports_data = np.append(airports_data, i)

# %%
print(airports_data)
# Out:
# ['LIMC' 'WSSS' 'OMSJ' 'EGLL' 'YSSY' 'YMML' 'NZAA' 'KORD' 'WBSB' 'VOMM'
#  'KDFW' 'EHAM' 'VHHH' 'EDDF' 'FAOR' 'YBBN' 'PANC' 'EBMB' 'WMKK' 'KLAX'
#  'LSZH' 'NZCH' 'VOBL' 'ZUCK' 'VABB' 'LFPG' 'EKCH' 'VIDP' 'FARA' 'EBBR'
#  'YPPH' 'LEBL' 'WSAC' 'VGZR' 'YSCB' 'RJAK' 'FAGM' 'LTBW' 'YTWB' 'YRED'
#  'TS53' 'YPWH' 'RJAA' 'LTBA' 'FABB' 'VGTJ' '6AK5' 'WIDD']

# %%
for i in airports_data:
    if (np.isnan(dfs[dfs["origin"]==i]["latitude_1"].median())):
        latitude = dfs[dfs["destination"]==i]["latitude_2"].median()
        longitude = dfs[dfs["destination"]==i]["longitude_2"].median()
        
    elif (np.isnan(dfs[dfs["destination"]==i]["latitude_2"].median())):
        latitude = dfs[dfs["origin"]==i]["latitude_1"].median()
        longitude = dfs[dfs["origin"]==i]["longitude_1"].median()
        
    else:
        latitude = (dfs[dfs["origin"]==i]["latitude_1"].median() + dfs[dfs["destination"]==i]["latitude_2"].median())/2
        longitude = (dfs[dfs["origin"]==i]["longitude_1"].median() + dfs[dfs["destination"]==i]["longitude_2"].median())/2
        
    airport = {'airport': i, 'latitude': latitude, 'longitude': longitude}
    airports = airports.append(airport, ignore_index=True)

print(airports)
# Out:
#    airport   latitude   longitude
# 0     LIMC  45.622997    8.729880
# 1     WSSS   1.349354  103.991831
# 2     OMSJ  25.333187   55.513881
# 3     EGLL  51.464928   -0.451351
# 4     YSSY -33.937398  151.173686
# 5     YMML -37.659397  144.836085
# 6     NZAA -37.007307  174.802684
# 7     KORD  41.967407  -87.905482
# 8     WBSB   4.943314  114.927863
# 9     VOMM  12.988395   80.164536
# 10    KDFW  32.904827  -97.050797
# 11    EHAM  52.329506    4.733640
# 12    VHHH  22.306459  113.907723
# 13    EDDF  50.045047    8.569396
# 14    FAOR -26.110302   28.248013
# 15    YBBN -27.383320  153.122108
# 16    PANC  61.179126 -150.017751
# 17    EBMB  50.909637    4.492666
# 18    WMKK   2.714566  101.717297
# 19    KLAX  33.936884 -118.397799
# 20    LSZH  47.467043    8.551562
# 21    NZCH -43.486825  172.534596
# 22    VOBL  13.189594   77.703107
# 23    ZUCK  29.778076  106.693145
# 24    VABB  19.088734   72.868544
# 25    LFPG  48.996591    2.563600
# 26    EKCH  55.612789   12.641687
# 27    VIDP  28.559853   77.113512
# 28    FARA -26.040070   28.290002
# 29    EBBR  50.899951    4.490988
# 30    YPPH -31.945056  115.963682
# 31    LEBL  41.243946    2.255799
# 32    WSAC   1.355883  104.011877
# 33    VGZR  23.810166   90.425202
# 34    YSCB -35.311934  149.194422
# 35    RJAK  35.937350  140.290852
# 36    FAGM -26.213150   28.215637
# 37    LTBW  41.195649   28.718870
# 38    YTWB -27.684998  151.934181
# 39    YRED -27.252937  153.181211
# 40    TS53  32.915543  -97.089313
# 41    YPWH -27.861511  151.637239
# 42    RJAA  35.736291  140.589996
# 43    LTBA  40.966736   28.866821
# 44    FABB -26.219757   28.231166
# 45    VGTJ  23.776183   90.456244
# 46    6AK5  61.167709 -150.083738
# 47    WIDD   1.111854  104.047252

# %%
e_asia = ["VOMM", "VHHH", "VOBL", "ZUCK", "VABB", "VIDP", "VGZR", "RJAK", "RJAA", "VGTJ"]
americas = ["KORD", "KDFW", "PANC", "KLAX", "TS53", "6AK5"]
europe = ["LIMC", "EGLL", "EHAM", "EDDF", "EBMB", "LSZH", "LFPG", "EKCH", "FARA", "EBBR", "LEBL"]
sw_pasific = ["WSSS", "YSSY", "YMML", "NZAA", "WBSB", "YBBN", "WMKK", "NZCH", "YPPH", "WSAC", "YSCB", "YTWB", "YRED", "YPWH", "WIDD"]
w_asia_africa = ["OMSJ", "FAOR", "FAGM", "LTBW", "LTBA", "FABB"]

# %%
region = []
load_rate = []
for i in range(len(airports)):
    for j in range(len(e_asia)):
        if(airports["airport"].iloc[i]==e_asia[j]):
            region.append("East Asia")
            load_rate.append(0.128)
            break
    for k in range(len(americas)):
        if(airports["airport"].iloc[i]==americas[k]):
            region.append("Americas")
            load_rate.append(0.113)
            break
    for l in range(len(europe)):
        if(airports["airport"].iloc[i]==europe[l]):
            region.append("Europe")
            load_rate.append(0.133)
            break
    for m in range(len(sw_pasific)):
        if(airports["airport"].iloc[i]==sw_pasific[m]):
            region.append("South West Pacific")
            load_rate.append(0.171)
            break
    for n in range(len(w_asia_africa)):
        if(airports["airport"].iloc[i]==w_asia_africa[n]):
            region.append("West Asia and Africa")
            load_rate.append(0.140)
            break
            
print(region)
# Out:
# ['Europe', 'South West Pacific', 'West Asia and Africa', 'Europe', 'South West Pacific', 'South West Pacific', 'South West Pacific', 'Americas', 'South West Pacific', 'East Asia', 'Americas', 'Europe', 'East Asia', 'Europe', 'West Asia and Africa', 'South West Pacific', 'Americas', 'Europe', 'South West Pacific', 'Americas', 'Europe', 'South West Pacific', 'East Asia', 'East Asia', 'East Asia', 'Europe', 'Europe', 'East Asia', 'Europe', 'Europe', 'South West Pacific', 'Europe', 'South West Pacific', 'East Asia', 'South West Pacific', 'East Asia', 'West Asia and Africa', 'West Asia and Africa', 'South West Pacific', 'South West Pacific', 'Americas', 'South West Pacific', 'East Asia', 'West Asia and Africa', 'West Asia and Africa', 'East Asia', 'Americas', 'South West Pacific']

# %%
airports['region'] = region
airports['load_rate'] = load_rate
print(airports)
# Out:
#    airport   latitude   longitude                region  load_rate
# 0     LIMC  45.622997    8.729880                Europe      0.133
# 1     WSSS   1.349354  103.991831    South West Pacific      0.171
# 2     OMSJ  25.333187   55.513881  West Asia and Africa      0.140
# 3     EGLL  51.464928   -0.451351                Europe      0.133
# 4     YSSY -33.937398  151.173686    South West Pacific      0.171
# 5     YMML -37.659397  144.836085    South West Pacific      0.171
# 6     NZAA -37.007307  174.802684    South West Pacific      0.171
# 7     KORD  41.967407  -87.905482              Americas      0.113
# 8     WBSB   4.943314  114.927863    South West Pacific      0.171
# 9     VOMM  12.988395   80.164536             East Asia      0.128
# 10    KDFW  32.904827  -97.050797              Americas      0.113
# 11    EHAM  52.329506    4.733640                Europe      0.133
# 12    VHHH  22.306459  113.907723             East Asia      0.128
# 13    EDDF  50.045047    8.569396                Europe      0.133
# 14    FAOR -26.110302   28.248013  West Asia and Africa      0.140
# 15    YBBN -27.383320  153.122108    South West Pacific      0.171
# 16    PANC  61.179126 -150.017751              Americas      0.113
# 17    EBMB  50.909637    4.492666                Europe      0.133
# 18    WMKK   2.714566  101.717297    South West Pacific      0.171
# 19    KLAX  33.936884 -118.397799              Americas      0.113
# 20    LSZH  47.467043    8.551562                Europe      0.133
# 21    NZCH -43.486825  172.534596    South West Pacific      0.171
# 22    VOBL  13.189594   77.703107             East Asia      0.128
# 23    ZUCK  29.778076  106.693145             East Asia      0.128
# 24    VABB  19.088734   72.868544             East Asia      0.128
# 25    LFPG  48.996591    2.563600                Europe      0.133
# 26    EKCH  55.612789   12.641687                Europe      0.133
# 27    VIDP  28.559853   77.113512             East Asia      0.128
# 28    FARA -26.040070   28.290002                Europe      0.133
# 29    EBBR  50.899951    4.490988                Europe      0.133
# 30    YPPH -31.945056  115.963682    South West Pacific      0.171
# 31    LEBL  41.243946    2.255799                Europe      0.133
# 32    WSAC   1.355883  104.011877    South West Pacific      0.171
# 33    VGZR  23.810166   90.425202             East Asia      0.128
# 34    YSCB -35.311934  149.194422    South West Pacific      0.171
# 35    RJAK  35.937350  140.290852             East Asia      0.128
# 36    FAGM -26.213150   28.215637  West Asia and Africa      0.140
# 37    LTBW  41.195649   28.718870  West Asia and Africa      0.140
# 38    YTWB -27.684998  151.934181    South West Pacific      0.171
# 39    YRED -27.252937  153.181211    South West Pacific      0.171
# 40    TS53  32.915543  -97.089313              Americas      0.113
# 41    YPWH -27.861511  151.637239    South West Pacific      0.171
# 42    RJAA  35.736291  140.589996             East Asia      0.128
# 43    LTBA  40.966736   28.866821  West Asia and Africa      0.140
# 44    FABB -26.219757   28.231166  West Asia and Africa      0.140
# 45    VGTJ  23.776183   90.456244             East Asia      0.128
# 46    6AK5  61.167709 -150.083738              Americas      0.113
# 47    WIDD   1.111854  104.047252    South West Pacific      0.171

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(lat1, lon1, lat2, lon2):

      R = 6378.1 #earth radius in km

      dLat = radians(lat2 - lat1)
      dLon = radians(lon2 - lon1)
      lat1 = radians(lat1)
      lat2 = radians(lat2)

      a = sin(dLat/2)**2 + cos(lat1)*cos(lat2)*sin(dLon/2)**2
      c = 2*asin(sqrt(a))

      return R * c

# %%
airport_dist = []

# print(len(airports))
# print(airports["latitude"].iloc[1])
for i in range(len(airports)):
    row = []
    for j in range(len(airports)):
        dist = haversine(airports["latitude"].iloc[i], airports["longitude"].iloc[i], airports["latitude"].iloc[j], airports["longitude"].iloc[j])
        row.append(dist)
    airport_dist.append(row)
    
print(airport_dist)
# Out:
# [[0.0, 10320.430258215578, 4717.841781312695, 937.1660268519785, 16609.560128529316, 16328.954466590929, 18532.59680591183, 7269.067818856925, 10868.089507810684, 7548.95074633125, 8547.656137571441, 801.3169185796232, 9367.722728633229, 492.40317589072635, 8226.20896899483, 16305.37145127493, 7994.969157835845, 666.7552359065804, 10035.00646673157, 9707.300556374426, 205.7303869886589, 18733.26757149964, 7342.358008596109, 8269.138067898637, 6515.603799301376, 597.7053144643955, 1145.392331724757, 6165.855188281992, 8219.648382286154, 665.8771017492281, 13763.71195323607, 714.7633108335267, 10321.464585191243, 7525.8491042544, 16538.803322184736, 9739.086961262197, 8236.528918768698, 1684.8073009086406, 16240.840339895418, 16299.853550010886, 8549.282279244859, 16231.958278267468, 9772.276447147076, 1706.5289191728648, 8237.618885773374, 7530.724450895547, 7997.137643355394, 10343.682712043537], [10320.430258215578, 0.0, 5841.7632385838115, 10894.76051264912, 6299.836779033911, 6038.438896550015, 8418.73633260409, 15068.744588255582, 1279.5010057485506, 2928.8002861878294, 15629.793631547207, 10527.265421668828, 2568.044722254665, 10290.596335412143, 8664.6708760633, 6150.109163748203, 10735.388681880311, 10566.321673598291, 295.1642203208813, 14118.598208005285, 10316.7968215347, 8412.83732523417, 3182.78032127795, 3177.546517831396, 3925.97264061222, 10735.785552170339, 9979.602726518628, 4162.711379891772, 8659.473513963996, 10566.592870740193, 3915.4931135500406, 10897.657772001752, 2.346255818210745, 2896.810574720782, 6218.429548740631, 5368.625060503927, 8669.39451207522, 8690.481931602231, 6056.067552693563, 6149.820325551374, 15626.779809616955, 6037.478416658099, 5376.563159517929, 8674.304631877993, 8667.954912411142, 2891.9234600277327, 10732.28529348282, 27.14817244047462], [4717.841781312695, 5841.7632385838115, 0.0, 5506.8618381394035, 12048.0465062446, 11649.800806282066, 14208.311769009377, 11653.51701532367, 6715.45708634375, 2925.7975035142226, 12931.98577783635, 5180.021024368576, 5909.281941024525, 4852.729801807736, 6432.468071091534, 11982.514029612448, 10135.328939956715, 5156.62005286444, 5546.606912613255, 13408.178593563865, 4777.860433835961, 14062.502015456803, 2688.7369433071267, 5034.7179282817, 1916.72379593414, 5247.629826986142, 4825.292960299169, 2170.1861289891613, 6423.595415009144, 5156.478901784671, 9046.378059979404, 5173.872130678893, 5843.287759886152, 3528.5121745318047, 11926.469286105654, 7956.359633934239, 6444.0353642012615, 3035.1468561185375, 11883.945104798386, 11983.058602550253, 12932.598121808254, 11863.338303540371, 7989.047891226768, 3012.486651697701, 6443.917975772616, 3532.2906358651935, 10135.1174669785, 5860.8374465065635], [937.1660268519785, 10894.76051264912, 5506.8618381394035, 0.0, 17038.360971755203, 16925.68607274427, 18384.972264798915, 6352.641899767896, 11294.007238315664, 8243.215397150638, 7636.805148062444, 368.84994843109445, 9641.050469242773, 654.1805012689989, 9081.354186250748, 16561.734354164048, 7209.1891097368825, 350.37749834459356, 10619.936469989312, 8770.375175195673, 787.9736159669434, 19005.39943512223, 8055.302858017427, 8544.453182630268, 7220.381364726168, 348.63996871279, 979.3847603022281, 6739.414795785145, 9075.17333846972, 350.48964845255233, 14523.847910406084, 1156.4275864777765, 10895.54267726216, 8027.9995280294925, 17029.349580281367, 9581.330257766034, 9091.289961308832, 2493.8459120463403, 16526.18991716695, 16552.579821679705, 7638.30620788436, 16526.313289986098, 9612.535110199567, 2519.1781225173677, 9092.459574789265, 8032.929097669114, 7211.614576108594, 10919.484974283207], [16609.560128529316, 6299.836779033911, 12048.0465062446, 17038.360971755203, 0.0, 706.1771528962224, 2163.4923737566182, 14878.267636807592, 5765.535532732732, 9138.29299935174, 13822.743285185885, 16677.203955988603, 7401.315329951462, 16513.708884399803, 11038.639144083883, 753.0182097296351, 11842.042921354594, 16754.7976630837, 6588.55598012932, ...

# %%
dfs['day'].value_counts()
# Out:
# 2020-11-28 00:00:00+00:00    40
# 2020-11-15 00:00:00+00:00    38
# 2020-11-25 00:00:00+00:00    38
# 2020-11-22 00:00:00+00:00    37
# 2020-11-29 00:00:00+00:00    37
# 2020-11-18 00:00:00+00:00    37
# 2020-11-21 00:00:00+00:00    37
# 2020-11-16 00:00:00+00:00    37
# 2020-11-23 00:00:00+00:00    36
# 2020-11-20 00:00:00+00:00    36
# 2020-11-04 00:00:00+00:00    35
# 2020-11-09 00:00:00+00:00    35
# 2020-11-14 00:00:00+00:00    35
# 2020-11-01 00:00:00+00:00    34
# 2020-11-30 00:00:00+00:00    34
# 2020-11-11 00:00:00+00:00    34
# 2020-11-19 00:00:00+00:00    34
# 2020-11-13 00:00:00+00:00    34
# 2020-11-27 00:00:00+00:00    33
# 2020-11-02 00:00:00+00:00    33
# 2020-11-07 00:00:00+00:00    33
# 2020-11-08 00:00:00+00:00    33
# 2020-11-26 00:00:00+00:00    33
# 2020-11-06 00:00:00+00:00    32
# 2020-11-05 00:00:00+00:00    32
# 2020-11-12 00:00:00+00:00    32
# 2020-11-17 00:00:00+00:00    30
# 2020-11-10 00:00:00+00:00    28
# 2020-11-03 00:00:00+00:00    27
# 2020-11-24 00:00:00+00:00    26
# Name: day, dtype: int64

# %%
# dfs[dfs["day"].isin({day, day_after})]

# %%
day = "2020-11-21 00:00:00+00:00"
# day_after = "2020-11-30 00:00:00+00:00"
day_after = "2020-11-30 00:00:00+00:00"
day_before = "2020-11-20 00:00:00+00:00"
# dfx = dfs[dfs["day"]==day]
# dfx = dfs[dfs["day"].isin({day, day_after})]
# dfx = dfs[dfs["day"].isin({day, day_after})]
dfx = dfs[(dfs["day"] >= day) & (dfs["day"] <= day_after)]
dfy = dfs[dfs["day"]<day]
dfx = dfx[:70]

# %%
print(dfx)
# Out:
#         callsign registration typecode origin destination  \
# 1208410   SIA322       9V-SMQ     A359   WSSS        EGLL
# 1208521   SIA324       9V-SMM     A359   WSSS        EHAM
# 1208877    SIA26       9V-SMB     A359   WSSS        EDDF
# 1211170   SIA352       9V-SMN     A359   WSSS        EKCH
# 1215881   SIA478       9V-SMA     A359   WSSS        FABB
# ...          ...          ...      ...    ...         ...
# 1322349  SIA7198       9V-SFQ     B744   VHHH        PANC
# 1322991    SIA25       9V-SMD     A359   EDDF        WSSS
# 1323385   SIA285       9V-SMP     A359   WSSS        NZAA
# 1323492   SIA288       9V-SMQ     A359   YSSY        YBBN
# 1324267  SIA7286       9V-SFI     B744   YSSY        YMML
#
#                          firstseen                   lastseen  \
# 1208410  2020-11-20 16:06:59+00:00  2020-11-21 05:40:59+00:00
# 1208521  2020-11-20 16:08:35+00:00  2020-11-21 05:29:37+00:00
# 1208877  2020-11-20 16:13:20+00:00  2020-11-21 05:09:18+00:00
# 1211170  2020-11-20 16:44:59+00:00  2020-11-21 05:14:59+00:00
# 1215881  2020-11-20 17:48:48+00:00  2020-11-21 03:40:12+00:00
# ...                            ...                        ...
# 1322349  2020-11-22 10:10:26+00:00  2020-11-22 18:45:05+00:00
# 1322991  2020-11-22 10:37:06+00:00  2020-11-22 22:10:36+00:00
# 1323385  2020-11-22 10:53:43+00:00  2020-11-22 19:54:17+00:00
# 1323492  2020-11-22 10:58:09+00:00  2020-11-22 12:01:17+00:00
# 1324267  2020-11-22 11:23:11+00:00  2020-11-22 12:28:19+00:00
#
#                                day  latitude_1  longitude_1  latitude_2  \
# 1208410  2020-11-21 00:00:00+00:00    1.376782   104.004680   51.477676
# 1208521  2020-11-21 00:00:00+00:00    1.373151   104.003543   52.366985
# 1208877  2020-11-21 00:00:00+00:00    1.369567   104.002407   50.030225
# 1211170  2020-11-21 00:00:00+00:00    1.371429   104.002691   55.628155
# 1215881  2020-11-21 00:00:00+00:00    1.369939   104.001980  -26.219757
# ...                            ...         ...          ...         ...
# 1322349  2020-11-22 00:00:00+00:00   22.302887   113.918635   61.169734
# 1322991  2020-11-22 00:00:00+00:00   50.043807     8.568389    1.319046
# 1323385  2020-11-22 00:00:00+00:00    1.387070   103.993603  -36.992615
# 1323492  2020-11-22 00:00:00+00:00  -33.940445   151.174393  -27.395370
# 1324267  2020-11-22 00:00:00+00:00  -33.943052   151.175137  -37.688370
#
#          longitude_2
# 1208410    -0.446357
# 1208521     4.712350
# 1208877     8.541035
# 1211170    12.671700
# 1215881    28.231166
# ...              ...
# 1322349  -150.026143
# 1322991   103.980847
# 1323385   174.856178
# 1323492   153.122466
# 1324267   144.841529
#
# [70 rows x 12 columns]

# %%
data = {'airplane': [],
        'type': [],
        'curr_loc': [],
        'last_seen': [],
        'capacity': [],
        'fixed_cost': [],
        'min_cost': [],
        'idle_cost': []}

airplanes = pd.DataFrame(data)
print(airplanes)
# Out:
# Empty DataFrame
# Columns: [airplane, type, curr_loc, last_seen, capacity, fixed_cost, min_cost, idle_cost]
# Index: []

# %%
airplanes_data = dfs.registration.unique()
print(airplanes_data)
# Out:
# ['9V-SMG' '9V-SMI' '9V-SMT' '9V-SMD' '9V-SMH' '9V-SFN' '9V-SMC' '9V-SFM'
#  '9V-SMS' '9V-SFK' '9V-SML' '9V-SWQ' '9V-MGL' '9V-SMF' '9V-SFQ' '9V-SWE'
#  '9V-SFI' '9V-SMO' '9V-SFP' '9V-SFO' '9V-SMQ' '9V-SMN' '9V-SMJ' '9V-SMM'
#  '9V-SMB' '9V-SMP' '9V-SMA' '9V-SWY' '9V-SWR' '9V-SCB' '9V-SWP' '9V-SMK'
#  '9V-MGI' '9V-SMR' '9V-SWM' '9V-SWH' '9V-SWO' '9V-MGF' '9V-SWS' '9V-SKU'
#  '9V-SME' '9V-SWK' '9V-SWN']

# %%
airplanes_capacity = []
airplanes_fixedcost = []
airplanes_idlecost = []
airplanes_minutecost = []

for i in range(len(airplanes_data)):
    for j in range(len(dfs)):
        if(dfs["registration"].iloc[j]==airplanes_data[i]):
            if(dfs["typecode"].iloc[j]=="A359"):
                capacity = 350
                min_cost = 244
                fixed_cost = 946069
                idle_min_cost = 195
            elif(dfs["typecode"].iloc[j]=="B744"):
                capacity = 416
                min_cost = 321
                fixed_cost = 851244
                idle_min_cost = 257
            elif(dfs["typecode"].iloc[j]=="B77W"):
                capacity = 264
                min_cost = 194
                fixed_cost = 969244
                idle_min_cost = 155
            elif(dfs["typecode"].iloc[j]=="B738"):
                capacity = 215
                min_cost = 116
                fixed_cost = 732745
                idle_min_cost = 92
            elif(dfs["typecode"].iloc[j]=="B78X"):
                capacity = 337
                min_cost = 187
                fixed_cost = 1001250
                idle_min_cost = 150
            elif(dfs["typecode"].iloc[j]=="A388"):
                capacity = 471
                min_cost = 433
                fixed_cost = 638418
                idle_min_cost = 347
            airplanes_capacity.append(int(capacity))
            airplanes_fixedcost.append(int(fixed_cost))
            airplanes_idlecost.append(int(idle_min_cost))
            airplanes_minutecost.append(int(min_cost))
            break

print(airplanes_capacity)
# Out:
# [350, 350, 350, 350, 350, 416, 350, 416, 350, 416, 350, 264, 215, 350, 416, 264, 416, 350, 416, 416, 350, 350, 350, 350, 350, 350, 350, 264, 264, 337, 264, 350, 215, 350, 264, 264, 264, 215, 264, 471, 350, 264, 264]

# %%
no_airplane = 0
for i in airplanes_data:
    for j in range(len(dfx)):
        if(dfx["registration"].iloc[j]==i):
            airplane = {'airplane': i,
                        'type': dfx["typecode"].iloc[j],
                        'curr_loc': dfx["origin"].iloc[j],
                        'last_seen': dfx["firstseen"].iloc[j],
                        'capacity': airplanes_capacity[no_airplane],
                        'fixed_cost': airplanes_fixedcost[no_airplane],
                        'min_cost': airplanes_minutecost[no_airplane],
                        'idle_cost': airplanes_idlecost[no_airplane]}
            
            airplanes = airplanes.append(airplane, ignore_index=True)
            break
        elif((j==(len(dfx)-1)) and (dfx["registration"].iloc[j]!=i)):
            for k in range(len(dfy)):
                if((k!=0) and (dfy["registration"].iloc[-k]==i)):
                    airplane = {'airplane': i,
                                'type': dfy["typecode"].iloc[-k],
                                'curr_loc': dfy["destination"].iloc[-k],
                                'last_seen': dfy["firstseen"].iloc[-k],
                                'capacity': airplanes_capacity[no_airplane],
                                'fixed_cost': airplanes_fixedcost[no_airplane],
                                'min_cost': airplanes_minutecost[no_airplane],
                                'idle_cost': airplanes_idlecost[no_airplane]}
                    
                    airplanes = airplanes.append(airplane, ignore_index=True)
                    break
                elif((k==(len(dfy)-1)) and (dfy["registration"].iloc[-k]!=i)):
                    for l in range(len(dfs)):
                        if((l!=0) and (dfs["registration"].iloc[-l]==i)):
                            airplane = {'airplane': i,
                                        'type': dfs["typecode"].iloc[-l],
                                        'curr_loc': "WSSS",
                                        'last_seen': day_before,
                                        'capacity': airplanes_capacity[no_airplane],
                                        'fixed_cost': airplanes_fixedcost[no_airplane],
                                        'min_cost': airplanes_minutecost[no_airplane],
                                        'idle_cost': airplanes_idlecost[no_airplane]}
                            airplanes = airplanes.append(airplane, ignore_index=True)
                            break
                            
    no_airplane = no_airplane + 1
    
print(airplanes)
# Out:
#    airplane  type curr_loc                  last_seen  capacity  fixed_cost  \
# 0    9V-SMG  A359     LSZH  2020-11-21 13:12:36+00:00     350.0    946069.0
# 1    9V-SMI  A359     WSSS  2020-11-20 17:54:12+00:00     350.0    946069.0
# 2    9V-SMT  A359     WSSS  2020-11-22 02:15:05+00:00     350.0    946069.0
# 3    9V-SMD  A359     NZCH  2020-11-20 22:51:25+00:00     350.0    946069.0
# 4    9V-SMH  A359     LFPG  2020-11-21 10:03:18+00:00     350.0    946069.0
# 5    9V-SFN  B744     WSSS  2020-11-21 03:07:03+00:00     416.0    851244.0
# 6    9V-SMC  A359     WSSS  2020-11-20 02:40:15+00:00     350.0    946069.0
# 7    9V-SFM  B744     WSSS  2020-11-20 22:21:21+00:00     416.0    851244.0
# 8    9V-SMS  A359     WSSS  2020-11-21 16:05:15+00:00     350.0    946069.0
# 9    9V-SFK  B744     WSSS  2020-11-22 06:01:20+00:00     416.0    851244.0
# 10   9V-SML  A359     WSSS  2020-11-21 01:12:22+00:00     350.0    946069.0
# 11   9V-SWQ  B77W     WSSS  2020-11-18 17:03:08+00:00     264.0    969244.0
# 12   9V-MGL  B738     WSSS  2020-11-01 04:23:41+00:00     215.0    732745.0
# 13   9V-SMF  A359     LEBL  2020-11-21 09:57:44+00:00     350.0    946069.0
# 14   9V-SFQ  B744     KLAX  2020-11-20 20:56:06+00:00     416.0    851244.0
# 15   9V-SWE  B77W     WSSS  2020-11-14 23:35:45+00:00     264.0    969244.0
# 16   9V-SFI  B744     EBMB  2020-11-20 19:32:05+00:00     416.0    851244.0
# 17   9V-SMO  A359     WSSS  2020-11-21 16:11:06+00:00     350.0    946069.0
# 18   9V-SFP  B744     WSSS  2020-11-20 18:54:04+00:00     416.0    851244.0
# 19   9V-SFO  B744     WSSS  2020-11-21 02:30:04+00:00     416.0    851244.0
# 20   9V-SMQ  A359     WSSS  2020-11-20 16:06:59+00:00     350.0    946069.0
# 21   9V-SMN  A359     WSSS  2020-11-20 16:44:59+00:00     350.0    946069.0
# 22   9V-SMJ  A359     WSSS  2020-11-21 16:26:10+00:00     350.0    946069.0
# 23   9V-SMM  A359     WSSS  2020-11-20 16:08:35+00:00     350.0    946069.0
# 24   9V-SMB  A359     WSSS  2020-11-20 16:13:20+00:00     350.0    946069.0
# 25   9V-SMP  A359     EGLL  2020-11-20 20:31:38+00:00     350.0    946069.0
# 26   9V-SMA  A359     WSSS  2020-11-20 17:48:48+00:00     350.0    946069.0
# 27   9V-SWY  B77W     LTBA  2020-11-19 18:10:36+00:00     264.0    969244.0
# 28   9V-SWR  B77W     WSSS  2020-11-21 17:54:28+00:00     264.0    969244.0
# 29   9V-SCB  B78X     WSSS  2020-11-21 12:28:41+00:00     337.0   1001250.0
# 30   9V-SWP  B77W     LTBW  2020-11-12 18:10:17+00:00     264.0    969244.0
# 31   9V-SMK  A359     NZAA  2020-11-21 07:25:25+00:00     350.0    946069.0
# 32   9V-MGI  B738     WSSS  2020-11-15 04:06:48+00:00     215.0    732745.0
# 33   9V-SMR  A359     EKCH  2020-11-21 11:32:34+00:00     350.0    946069.0
# 34   9V-SWM  B77W     RJAA  2020-11-19 01:29:20+00:00     264.0    969244.0
# 35   9V-SWH  B77W     WSSS  2020-11-20 17:57:55+00:00     264.0    969244.0
# 36   9V-SWO  B77W     WSSS  2020-11-21 12:55:20+00:00     264.0    969244.0
# 37   9V-MGF  B738     WSSS  2020-11-22 00:59:12+00:00     215.0    732745.0
# 38   9V-SWS  B77W     WSSS  2020-11-20 00:00:00+00:00     264.0    969244.0
# 39   9V-SKU  A388     WSSS  2020-11-20 00:00:00+00:00     471.0    638418.0
# 40   9V-SME  A359     WSSS  2020-11-20 00:00:00+00:00     350.0    946069.0
# 41   9V-SWK  B77W     WSSS  2020-11-20 00:00:00+00:00     264.0    969244.0
# 42   9V-SWN  B77W     WSSS  2020-11-20 00:00:00+00:00     264.0    969244.0
#
#     min_cost  idle_cost
# 0      244.0      195.0
# 1      244.0      195.0
# 2      244.0      195.0
# 3      244.0      195.0
# 4      244.0      195.0
# 5      321.0      257.0
# 6      244.0      195.0
# 7      321.0      257.0
# 8      244.0      195.0
# 9      321.0      257.0
# 10     244.0      195.0
# 11     194.0      155.0
# 12     116.0       92.0
# 13     244.0      195.0
# 14     321.0      257.0
# 15     194.0      155.0
# 16     321.0      257.0
# 17     244.0      195.0
# 18     321.0      257.0
# 19     321.0      257.0
# 20     244.0      195.0
# 21     244.0      195.0
# 22     244.0      195.0
# 23     244.0      195.0
# 24     244.0      195.0
# 25     244.0      195.0
# 26     244.0      195.0
# 27     194.0      155.0
# 28     194.0      155.0
# 29     187.0      150.0
# 30     194.0      155.0
# 31     244.0      195.0
# 32     116.0       92.0
# 33     244.0      195.0
# 34     194.0      155.0
# 35     194.0      155.0
# 36     194.0      155.0
# 37     116.0       92.0
# 38     194.0      155.0
# 39     433.0      347.0
# 40     244.0      195.0
# 41     194.0      155.0
# 42     194.0      155.0

# %%
max_delay = 180 #minute
min_safe = 30 #minute
max_arrival = max_delay - min_safe

def createSchedule():
    created = False
    while(created==False):
        airplanes_temp = airplanes.copy()
        schedule = []
        wakeup = time.time() + 10
        for i in range(len(dfx)):
            flight = [i]

            found = False
            while (found == False):
                id_airplane = random.randint(0, len(airplanes)-1)
                if (pd.to_datetime(airplanes_temp["last_seen"].iloc[id_airplane]) < (pd.to_datetime(dfx["firstseen"].iloc[i])+ datetime.timedelta(minutes=max_arrival)) and airplanes_temp["curr_loc"].iloc[id_airplane]==dfx["origin"].iloc[i]):
                    found = True
                else:
                    if (time.time() > wakeup):
                        break       

            airplanes_temp["curr_loc"].iloc[id_airplane]=dfx["destination"].iloc[i]

            if (pd.to_datetime(airplanes_temp["last_seen"].iloc[id_airplane]) < (pd.to_datetime(dfx["firstseen"].iloc[i]) - datetime.timedelta(minutes=min_safe))):
                departure = pd.to_datetime(dfx["firstseen"].iloc[i])
                arrival = departure + (pd.to_datetime(dfx["lastseen"].iloc[i])-pd.to_datetime(dfx["firstseen"].iloc[i]))
                airplanes_temp["last_seen"].iloc[id_airplane]=arrival
            else:
                departure = pd.to_datetime(airplanes_temp["last_seen"].iloc[id_airplane]) + datetime.timedelta(minutes=min_safe)
                arrival = departure + (pd.to_datetime(dfx["lastseen"].iloc[i])-pd.to_datetime(dfx["firstseen"].iloc[i]))
                airplanes_temp["last_seen"].iloc[id_airplane]=arrival

            for j in range(len(airports)):
                if(airports["airport"].iloc[j]==dfx["destination"].iloc[i]):
                    load_rate = airports["load_rate"].iloc[j]
                    break     

            passenger = round(airplanes_temp["capacity"].iloc[id_airplane] * load_rate)

            flight.extend([id_airplane, departure, arrival, passenger, load_rate])
            schedule.append(flight)
        if(len(dfx)==len(schedule)):
            created = True
    
    return schedule

# %%
def createOriginalSchedule():
    schedule = []
    for i in range(len(dfx)):
        flight=[i]
        for j in range(len(airplanes)):
            if(airplanes["airplane"].iloc[j]==dfx["registration"].iloc[i]):
                break
        flight.append(j)
        flight.append(pd.to_datetime(dfx["firstseen"].iloc[i]))
        flight.append(pd.to_datetime(dfx["lastseen"].iloc[i]))
        for k in range(len(airports)):
            if(airports["airport"].iloc[k]==dfx["destination"].iloc[i]):
                break
        flight.append(round(airplanes["capacity"].iloc[j] * airports["load_rate"].iloc[k]))
        flight.append(airports["load_rate"].iloc[k])
        
        schedule.append(flight)
        
    return schedule

# %%
# normalisasi passengger & cost
# cost = fixed cost & minute cost
def countOriginalFitness(schedule):
    fitness = []
    cost = 0
    passenger = 0
    plane_count = 0
    for i in range(len(schedule)):
        if(airplanes["type"].iloc[schedule[i][1]]=="A359"):
            min_cost = 244
        elif(airplanes["type"].iloc[schedule[i][1]]=="B744"):
            min_cost = 321
        elif(airplanes["type"].iloc[schedule[i][1]]=="B77W"):
            min_cost = 194
        elif(airplanes["type"].iloc[schedule[i][1]]=="B738"):
            min_cost = 116
        elif(airplanes["type"].iloc[schedule[i][1]]=="B78X"):
            min_cost = 187
        elif(airplanes["type"].iloc[schedule[i][1]]=="A388"):
            min_cost = 433
        cost = cost + round((schedule[i][3]-schedule[i][2]).seconds/60)*min_cost
        passenger = passenger + schedule[i][4]
        
        for k in range(len(airports)):
            if(airports["airport"].iloc[k]==dfx["origin"].iloc[i]):
                origin_id = k
            if(airports["airport"].iloc[k]==dfx["destination"].iloc[i]):
                destination_id = k
        
        cost = cost + airport_dist[origin_id][destination_id]
        
    for j in range(len(airplanes)):
        plane_used = False
        idle_sec = 0
        fixed_cost = 0
        first_flight = pd.to_datetime(airplanes["last_seen"].iloc[j])
        last_flight = pd.to_datetime(dfx["lastseen"].iloc[len(dfx)-1])
        
        for k in range(len(schedule)):
            if(schedule[k][1]==j):
                if(plane_used==False):
                    plane_used = True
                    plane_count = plane_count + 1
                    lastflight_pos = k
                    idle_sec = idle_sec + (schedule[k][2] - first_flight).seconds
                else:
                    idle_sec = idle_sec + (schedule[k][2] - schedule[lastflight_pos][2]).seconds
                    lastflight_pos = k
                    
        if(plane_used==False):
            idle_sec = idle_sec + (last_flight - first_flight).seconds
            fixed_cost = 0
        else:
            idle_sec = idle_sec + (last_flight - schedule[lastflight_pos][3]).seconds
            if(airplanes["type"].iloc[j]=="A359"):
                fixed_cost = 946069
            elif(airplanes["type"].iloc[j]=="B744"):
                fixed_cost = 851244
            elif(airplanes["type"].iloc[j]=="B77W"):
                fixed_cost = 969244
            elif(airplanes["type"].iloc[j]=="B738"):
                fixed_cost = 732745
            elif(airplanes["type"].iloc[j]=="B78X"):
                fixed_cost = 1001250
            elif(airplanes["type"].iloc[j]=="A388"):
                fixed_cost = 638418
        
        if(airplanes["type"].iloc[j]=="A359"):
            idle_min_cost = 195
        elif(airplanes["type"].iloc[j]=="B744"):
            idle_min_cost = 257
        elif(airplanes["type"].iloc[j]=="B77W"):
            idle_min_cost = 155
        elif(airplanes["type"].iloc[j]=="B738"):
            idle_min_cost = 92
        elif(airplanes["type"].iloc[j]=="B78X"):
            idle_min_cost = 150
        elif(airplanes["type"].iloc[j]=="A388"):
            idle_min_cost = 347
        
        cost = cost + round(idle_sec/60)*idle_min_cost
        cost = cost + fixed_cost
#     
#     fitness_val = (((passenger-0)/(4270-0)*1000)-((cost-0)/(50898241-0)*1000))
    fitness_val = cost-passenger
    fitness.append(fitness_val)
    fitness.append(passenger)
    fitness.append(cost)
    fitness.append(plane_count)
    
    return fitness

# %%
# normalisasi passengger & cost
# cost = fixed cost & minute cost
def countAirplaneFitness(schedule, airplane_id):
    fitness = []
    cost = 0
    passenger = 0
    plane_used = False
    idle_sec = 0
    idle_min_cost = 0
    fixed_cost = 0
    id = airplane_id
    for i in range(len(schedule)):
        if(schedule[i][1]==id):
            if(airplanes["type"].iloc[id]=="A359"):
                min_cost = 244
            elif(airplanes["type"].iloc[id]=="B744"):
                min_cost = 321
            elif(airplanes["type"].iloc[id]=="B77W"):
                min_cost = 194
            elif(airplanes["type"].iloc[id]=="B738"):
                min_cost = 116
            elif(airplanes["type"].iloc[id]=="B78X"):
                min_cost = 187
            elif(airplanes["type"].iloc[id]=="A388"):
                min_cost = 433
            cost = cost + round((schedule[i][3]-schedule[i][2]).seconds/60)*min_cost
            passenger = passenger + schedule[i][4]
            
            for k in range(len(airports)):
                if(airports["airport"].iloc[k]==dfx["origin"].iloc[i]):
                    origin_id = k
                if(airports["airport"].iloc[k]==dfx["destination"].iloc[i]):
                    destination_id = k

            cost = cost + airport_dist[origin_id][destination_id]
        
    first_flight = pd.to_datetime(airplanes["last_seen"].iloc[id])
    last_flight = pd.to_datetime(dfx["lastseen"].iloc[len(dfx)-1])

    for k in range(len(schedule)):
        if(schedule[k][1]==id):
            if(plane_used==False):
                plane_used = True
                lastflight_pos = k
                idle_sec = idle_sec + (schedule[k][2] - first_flight).seconds
            else:
                idle_sec = idle_sec + (schedule[k][2] - schedule[lastflight_pos][2]).seconds
                lastflight_pos = k

    if(plane_used==False):
        idle_sec = idle_sec + (last_flight - first_flight).seconds
        fixed_cost = 0
    else:
        idle_sec = idle_sec + (last_flight - schedule[lastflight_pos][3]).seconds
        if(airplanes["type"].iloc[id]=="A359"):
            fixed_cost = 946069
        elif(airplanes["type"].iloc[id]=="B744"):
            fixed_cost = 851244
        elif(airplanes["type"].iloc[id]=="B77W"):
            fixed_cost = 969244
        elif(airplanes["type"].iloc[id]=="B738"):
            fixed_cost = 732745
        elif(airplanes["type"].iloc[id]=="B78X"):
            fixed_cost = 1001250
        elif(airplanes["type"].iloc[id]=="A388"):
            fixed_cost = 638418

    if(airplanes["type"].iloc[id]=="A359"):
        idle_min_cost = 195
    elif(airplanes["type"].iloc[id]=="B744"):
        idle_min_cost = 257
    elif(airplanes["type"].iloc[id]=="B77W"):
        idle_min_cost = 155
    elif(airplanes["type"].iloc[id]=="B738"):
        idle_min_cost = 92
    elif(airplanes["type"].iloc[id]=="B78X"):
        idle_min_cost = 150
    elif(airplanes["type"].iloc[id]=="A388"):
        idle_min_cost = 347

    cost = cost + round(idle_sec/60)*idle_min_cost
    cost = cost + fixed_cost
    
    originalFitness = countOriginalFitness(createOriginalSchedule())
    
    fitness_val = (((passenger-0)/(originalFitness[1]-0)*1000)-((cost-0)/(originalFitness[2]-0)*200))
#     fitness_val = cost-passenger
    fitness.append(fitness_val)
    fitness.append(passenger)
    fitness.append(cost)
    
    return fitness

# %%
# normalisasi passengger & cost
# cost = fixed cost & minute cost
def countFitness(schedule):
    fitness = []
    cost = 0
    passenger = 0
    plane_count = 0
    for i in range(len(schedule)):
        if(airplanes["type"].iloc[schedule[i][1]]=="A359"):
            min_cost = 244
        elif(airplanes["type"].iloc[schedule[i][1]]=="B744"):
            min_cost = 321
        elif(airplanes["type"].iloc[schedule[i][1]]=="B77W"):
            min_cost = 194
        elif(airplanes["type"].iloc[schedule[i][1]]=="B738"):
            min_cost = 116
        elif(airplanes["type"].iloc[schedule[i][1]]=="B78X"):
            min_cost = 187
        elif(airplanes["type"].iloc[schedule[i][1]]=="A388"):
            min_cost = 433
        cost = cost + round((schedule[i][3]-schedule[i][2]).seconds/60)*min_cost
        passenger = passenger + schedule[i][4]
        
        for k in range(len(airports)):
            if(airports["airport"].iloc[k]==dfx["origin"].iloc[i]):
                origin_id = k
            if(airports["airport"].iloc[k]==dfx["destination"].iloc[i]):
                destination_id = k
        
        cost = cost + airport_dist[origin_id][destination_id]
        
    for j in range(len(airplanes)):
        plane_used = False
        idle_sec = 0
        fixed_cost = 0
        first_flight = pd.to_datetime(airplanes["last_seen"].iloc[j])
        last_flight = pd.to_datetime(dfx["lastseen"].iloc[len(dfx)-1])
        
        for k in range(len(schedule)):
            if(schedule[k][1]==j):
                if(plane_used==False):
                    plane_used = True
                    plane_count = plane_count + 1
                    lastflight_pos = k
                    idle_sec = idle_sec + (schedule[k][2] - first_flight).seconds
                else:
                    idle_sec = idle_sec + (schedule[k][2] - schedule[lastflight_pos][2]).seconds
                    lastflight_pos = k
                    
        if(plane_used==False):
            idle_sec = idle_sec + (last_flight - first_flight).seconds
            fixed_cost = 0
        else:
            idle_sec = idle_sec + (last_flight - schedule[lastflight_pos][3]).seconds
            if(airplanes["type"].iloc[j]=="A359"):
                fixed_cost = 946069
            elif(airplanes["type"].iloc[j]=="B744"):
                fixed_cost = 851244
            elif(airplanes["type"].iloc[j]=="B77W"):
                fixed_cost = 969244
            elif(airplanes["type"].iloc[j]=="B738"):
                fixed_cost = 732745
            elif(airplanes["type"].iloc[j]=="B78X"):
                fixed_cost = 1001250
            elif(airplanes["type"].iloc[j]=="A388"):
                fixed_cost = 638418
        
        if(airplanes["type"].iloc[j]=="A359"):
            idle_min_cost = 195
        elif(airplanes["type"].iloc[j]=="B744"):
            idle_min_cost = 257
        elif(airplanes["type"].iloc[j]=="B77W"):
            idle_min_cost = 155
        elif(airplanes["type"].iloc[j]=="B738"):
            idle_min_cost = 92
        elif(airplanes["type"].iloc[j]=="B78X"):
            idle_min_cost = 150
        elif(airplanes["type"].iloc[j]=="A388"):
            idle_min_cost = 347
        
        cost = cost + round(idle_sec/60)*idle_min_cost
        cost = cost + fixed_cost
        
    originalFitness = countOriginalFitness(createOriginalSchedule())
    
    fitness_val = (((passenger-0)/(originalFitness[1]-0)*1000)-((cost-0)/(originalFitness[2]-0)*200))
#     fitness_val = cost-passenger
    fitness.append(fitness_val)
    fitness.append(passenger)
    fitness.append(cost)
    fitness.append(plane_count)
    
    return fitness

# %%
def elite(population):
    curr_elite = 0
    for i in range(len(population)):
        if(population[i][0] > population[curr_elite][0]):
            curr_elite = i
    return curr_elite

# %%
def roulleteWheel(population):
    sump = 0
    sumpart = 0
    worst = 0
    
    for k in range(len(population)):
#         print("worst", population[worst][0])
        if(population[k][0] < population[worst][0]):
            worst = k 
    
    for i in range(len(population)):
        if(population[worst][0] < 0):
            sump = sump + population[i][0] - population[worst][0]
        else:
            sump = sump + population[i][0]
#         print("sump", sump)
    
    rand = random.uniform(0, sump)
#     print("Random", rand)
    
    for j in range(len(population)):
        if(population[worst][0] < 0):
            sumpart = sumpart + population[j][0] - population[worst][0]
        else:
            sumpart = sumpart + population[j][0]
#         print("sumpart", sumpart)
        if(sumpart > rand):
            break
    
    return j

# %%
def swapPlane(flight1, flight2):
    newflight1 = []
    newflight2 = []
    result = []

#     print(flight1[1])
#     print(flight2[1])
    
    newflight1.append(flight1[0])
    newflight2.append(flight2[0])
    
    newflight1.append(flight2[1])
    newflight2.append(flight1[1])
    
#     print(newflight1[1])
#     print(newflight2[1])
    
    newflight1.append(flight2[2])
    newflight2.append(flight1[2])

    newflight1.append(flight1[2] + (flight2[3] - flight2[2]))
    newflight2.append(flight2[2] + (flight1[3] - flight1[2]))
    
    newflight1.append(round(airplanes["capacity"].iloc[flight1[1]] * flight2[5]))
    newflight2.append(round(airplanes["capacity"].iloc[flight2[1]] * flight1[5]))
    
    newflight1.append(flight1[5])
    newflight2.append(flight2[5])
    
    result = [newflight1, newflight2]
    return result

# %%
def rao3(solution, rand_solution, best_solution, worst_solution):  
    rao3_done = False
    while (rao3_done == False):
#         print(1)
        rand_flight = random.randint(0, len(solution)-1)        
        airplanelist = []
        for i in range(len(airplanes)):
            airplane = [i, airplanes["curr_loc"].iloc[i], airplanes["last_seen"].iloc[i], airplanes["capacity"].iloc[i], airplanes["fixed_cost"].iloc[i], airplanes["min_cost"].iloc[i], airplanes["idle_cost"].iloc[i], 0]
            airplanelist.append(airplane)
        for j in range(rand_flight):
            airplanelist[solution[j][1]][1] = dfx["destination"].iloc[j]
            airplanelist[solution[j][1]][2] = solution[j][3]

        available_airplanes = []
        for airplane in airplanelist:
            if (airplane[0] != solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
                available_airplanes.append(airplane)
        
#         print(2)        
        if(len(available_airplanes) >= 3):
            rao3_solution = []
            variables = ["capacity", "fixed_cost", "min_cost", "idle_cost"]
            for variable in variables:
                xsolution = airplanes[variable].iloc[solution[rand_flight][1]]
                xrandsolution = airplanes[variable].iloc[rand_solution[rand_flight][1]]
                xbests = airplanes[variable].iloc[best_solution[rand_flight][1]]
                xworst = airplanes[variable].iloc[worst_solution[rand_flight][1]]
                

                if(countFitness(solution)[0] > countFitness(rand_solution)[0]):
                    or1 = xsolution
                    or2 = xrandsolution
                else:
                    or1 = xrandsolution
                    or2 = xsolution
                    
                xsolution = xsolution + (random.random()*(xbests- abs(xworst))) + (random.random()*(abs(or1) - abs(or2)))
                rao3_solution.append(xsolution)
                
#             print(3)
            for k in range(len(rao3_solution)):
                max_val = rao3_solution[k]*2
                for airplane in available_airplanes:
                    val_diff = abs(rao3_solution[k] - airplane[k+3])                    
                    rate = ((max_val - val_diff) / (max_val - 0))*0.25
                    
                    airplane[-1] = airplane[-1] +  rate
            
#             print(4)
            new_solution = []
            available_airplanes = sorted(available_airplanes,key=lambda l:l[7], reverse=True)
            airplane1 = solution[rand_flight][1]
            airplane2 = available_airplanes[0][0]
            last_pos1 = -1
            last_pos2 = -1
            for l in range(len(solution)):
                if(l < rand_flight):
                    new_solution.append(solution[l])
                    if(solution[l][1]==airplane1):
                        last_pos1 = l
                    elif(solution[l][1]==airplane2):
                        last_pos2 = l   
                else:                                        
                    newflight = solution[l]
                    newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
                    if(solution[l][1]==airplane1):
                        newflight[1] = airplane2                        
                        if(last_pos2 > -1):
                            if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
                                newflight[2] = new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)
                                newflight[3] = new_solution[last_pos2][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
                        last_pos2 = l        
                    elif(solution[l][1]==airplane2):
                        newflight[1] = airplane1                        
                        if(last_pos1 > -1):
                            if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
                                newflight[2] = new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)
                                newflight[3] = new_solution[last_pos1][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
                        last_pos1 = l 
                    new_solution.append(newflight)                    
#             print(5)
            rao3_done = True

    return new_solution

# %%
# def crossover(besthq, xbest):
#     crossover_done = False
#     while (crossover_done == False):
#         solution = deepcopy(besthq)
#         best_solution = deepcopy(xbest)
#         rand_flight = random.randint(0, len(solution)-1)        
#         airplanelist1 = []
#         airplanelist2 = []
#         for i in range(len(airplanes)):
#             airplane = [i, airplanes["curr_loc"].iloc[i], airplanes["last_seen"].iloc[i], airplanes["capacity"].iloc[i], airplanes["fixed_cost"].iloc[i], airplanes["min_cost"].iloc[i], airplanes["idle_cost"].iloc[i], 0]
#             airplanelist1.append(airplane)
#             airplanelist2.append(airplane)
#         for j in range(rand_flight):
#             airplanelist1[solution[j][1]][1] = dfx["destination"].iloc[j]
#             airplanelist1[solution[j][1]][2] = solution[j][3]
#             airplanelist2[best_solution[j][1]][1] = dfx["destination"].iloc[j]
#             airplanelist2[best_solution[j][1]][2] = best_solution[j][3]

#         available_airplanes1 = []
#         available_airplanes2 = []
#         for airplane in airplanelist1:
#             if (airplane[0] != solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
#                 available_airplanes1.append(airplane)
#         for airplane in airplanelist2:        
#             if (airplane[0] != best_solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
#                 available_airplanes2.append(airplane)    
                
#         if(len(available_airplanes1) >= 3 and len(available_airplanes2) >= 3):
#             crossover_solution1 = []
#             crossover_solution2 = []
#             variables = ["capacity", "fixed_cost", "min_cost", "idle_cost"]
#             for variable in variables:
#                 xsolution = airplanes[variable].iloc[solution[rand_flight][1]]
#                 xbests = airplanes[variable].iloc[best_solution[rand_flight][1]]
                
#                 r = random.random()
#                 while (r==0.5):
#                     r = random.random()
#                 xsolution1 = r*xsolution + (1-r)*xbests
#                 xsolution2 = r*xbests + (1-r)*xsolution
#                 crossover_solution1.append(xsolution1)
#                 crossover_solution2.append(xsolution2)
            
#             for k in range(len(crossover_solution1)):
#                 max_val = crossover_solution1[k]*2
#                 for airplane in available_airplanes1:
#                     val_diff = abs(crossover_solution1[k] - airplane[k+3])                    
#                     rate = ((max_val - val_diff) / (max_val - 0))*0.25
                    
#                     airplane[-1] = airplane[-1] +  rate
                    
#             for m in range(len(crossover_solution2)):
#                 max_val = crossover_solution2[m]*2
#                 for airplane in available_airplanes2:
#                     val_diff = abs(crossover_solution2[m] - airplane[m+3])                    
#                     rate = ((max_val - val_diff) / (max_val - 0))*0.25
                    
#                     airplane[-1] = airplane[-1] +  rate
                    
#             new_solution1 = []
#             available_airplanes1 = sorted(available_airplanes1,key=lambda l:l[7], reverse=True)
#             airplane1 = solution[rand_flight][1]
#             airplane2 = available_airplanes1[0][0]
#             last_pos1 = -1
#             last_pos2 = -1
#             for l in range(len(solution)):
#                 if(l < rand_flight):
#                     new_solution1.append(solution[l])
#                     if(solution[l][1]==airplane1):
#                         last_pos1 = l
#                     elif(solution[l][1]==airplane2):
#                         last_pos2 = l   
#                 else:                                        
#                     newflight = solution[l]
#                     newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
#                     if(solution[l][1]==airplane1):
#                         newflight[1] = airplane2                        
#                         if(last_pos2 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution1[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution1[last_pos2][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution1[last_pos2][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos2 = l        
#                     elif(solution[l][1]==airplane2):
#                         newflight[1] = airplane1                        
#                         if(last_pos1 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution1[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution1[last_pos1][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution1[last_pos1][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos1 = l 
#                     new_solution1.append(newflight)
                    
#             new_solution2 = []
#             available_airplanes2 = sorted(available_airplanes2,key=lambda l:l[7], reverse=True)
#             airplane1 = best_solution[rand_flight][1]
#             airplane2 = available_airplanes2[0][0]
#             last_pos1 = -1
#             last_pos2 = -1
#             for l in range(len(best_solution)):
#                 if(l < rand_flight):
#                     new_solution2.append(best_solution[l])
#                     if(best_solution[l][1]==airplane1):
#                         last_pos1 = l
#                     elif(best_solution[l][1]==airplane2):
#                         last_pos2 = l   
#                 else:                                        
#                     newflight = best_solution[l]
#                     newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
#                     if(best_solution[l][1]==airplane1):
#                         newflight[1] = airplane2                        
#                         if(last_pos2 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution2[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution2[last_pos2][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution2[last_pos2][3] + (best_solution[l][3]-best_solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos2 = l        
#                     elif(best_solution[l][1]==airplane2):
#                         newflight[1] = airplane1                        
#                         if(last_pos1 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution2[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution2[last_pos1][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution2[last_pos1][3] + (best_solution[l][3]-best_solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos1 = l 
#                     new_solution2.append(newflight)
            
#             crossover_done = True

#     return new_solution1, new_solution2

# %%
# biar crossover ama randomwalk lebih sering, 
# data last seen pesawat dicek dipenerbangan terakhirnya kalo ada kalo g ada pake last seen di data pesawat
def crossOver(solution, crossover_range):
    doneCrossover = False
    cross_range = round(crossover_range * len(solution))
#     print(cross_range)
    try_time = 0
    while(doneCrossover==False):
        solutionCopy = solution[:]
#         solutionCopy2 = solution[:]
        while True:
            if(try_time > 3 and cross_range >= 3):
                cross_range = cross_range - 1
                try_time = 1
            condition = []
            range1 = random.randint(0, len(solutionCopy)-1-cross_range)
#             range1 = random.randint(0, len(solutionCopy)-1)
            if(cross_range >= 3):
                range2 = range1 + cross_range
            else:
                range2 = range1 + 2
#             range2 = random.randint(0, len(solutionCopy)-1)
            if(range1 < range2 and range1+1!=range2):
                for o in range(range1, range2+1):
                    if(dfx["origin"].iloc[o]!="WSSS"):
                        condition.append(False)

                    else:
                        condition.append(True)
            else:
                condition.append(False)
                print(condition)
            if False not in condition:
                break
                try_time = try_time + 1
            else:
                try_time = try_time + 1
            
        while True:
            cut1 = random.randint(range1, range2)
            cut2 = random.randint(range1, range2)
            if(cut1 < cut2 and cut1+1!=cut2):
                break

        crossover_pos = 0
        exc = []
        constructed_position = [solutionCopy[cut1], solutionCopy[cut2]]
        for i in range(range1, range2+1):
            if(i!=cut1 and i!=cut2):
                constructed_position.append(solution[i])
                    
        index = 0
        for j in range(range1, range2+1):
            condition = []
            last_pos = constructed_position[index][0]

            for p in range(len(constructed_position)):
                if(constructed_position[p][0]==j):
                    index_j = p
            for k in range(len(solution)):
                if(solution[k][1]==constructed_position[index][1] and solution[k][0] < range1):
                    last_pos = solution[k][0]
                elif(solutionCopy[k][0]==constructed_position[index][0]):
                    break
            if(last_pos==constructed_position[index][0]):
                plane_lastseen_time = pd.to_datetime(airplanes["last_seen"].iloc[constructed_position[index][1]])
                plane_lastseen_place = dfx["origin"].iloc[last_pos]
            else:
                plane_lastseen_time = solution[last_pos][3]
                plane_lastseen_place = dfx["destination"].iloc[last_pos]

            if(plane_lastseen_time < (pd.to_datetime(dfx["firstseen"].iloc[j]) + datetime.timedelta(minutes=max_arrival)) and plane_lastseen_place==dfx["origin"].iloc[j]):
                condition.append(True)

                newflight = []
                newflight.append(j)
                newflight.append(constructed_position[index][1])

                if(plane_lastseen_time > (pd.to_datetime(dfx["firstseen"].iloc[j]) - datetime.timedelta(minutes=min_safe))):
                    departure = plane_lastseen_time + datetime.timedelta(minutes=min_safe)
                else:
                    departure = pd.to_datetime(dfx["firstseen"].iloc[j])

                newflight.append(departure)
                arrival = departure + (constructed_position[index_j][3] - constructed_position[index_j][2])
                newflight.append(arrival)
                newflight.append(round(airplanes["capacity"].iloc[constructed_position[index][1]] * constructed_position[index_j][5]))
                newflight.append(constructed_position[index_j][5])


                ext = []
                if(constructed_position[index][0]!=constructed_position[index_j][0]):
                    for l in range(range2, len(solutionCopy)-1):
                        if(solutionCopy[l][0]!=constructed_position[index][0] and solutionCopy[l][0] not in exc):
                            if(constructed_position[index_j][1]==solutionCopy[l][1]):
                                ext.append(solutionCopy[l][0])
                                exc.append(solutionCopy[l][0])

                solutionCopy[j] = newflight

                for m in (ext):
                    new_flight = []
                    new_flight.append(solutionCopy[m][0])
                    new_flight.append(newflight[1])
                    if(pd.to_datetime(dfx["firstseen"].iloc[m]) > newflight[3] + datetime.timedelta(minutes=min_safe)):
                        new_flight.append(pd.to_datetime(dfx["firstseen"].iloc[m]))
                        new_flight.append(pd.to_datetime(dfx["lastseen"].iloc[m]))
                    else:
                        new_flight.append(newflight[3] + datetime.timedelta(minutes=min_safe))
                        new_flight.append(newflight[3] + (solutionCopy[m][3]-solutionCopy[m][2]) + datetime.timedelta(minutes=min_safe))
                    new_flight.append(round(airplanes["capacity"].iloc[newflight[1]] * solutionCopy[m][5]))
                    new_flight.append(solutionCopy[m][5])


                    solutionCopy[m] = new_flight
                    newflight = solutionCopy[m]

                index = index+1

            else:
                condition.append(False)
                index = index+1
                
        solutionCopy1 = solutionCopy[:]
        solutionCopy = solution[:]
        exc = []
        constructed_position = []
        for i in range(range1, range2+1):
            if(i!=cut1 and i!=cut2):
                constructed_position.append(solution[i])
        constructed_position.append(solutionCopy[cut1])
        constructed_position.append(solutionCopy[cut2])
                    
        index = 0
        for j in range(range1, range2+1):
            condition = []
            last_pos = constructed_position[index][0]

            for p in range(len(constructed_position)):
                if(constructed_position[p][0]==j):
                    index_j = p
            for k in range(len(solution)):
                if(solution[k][1]==constructed_position[index][1] and solution[k][0] < range1):
                    last_pos = solution[k][0]
                elif(solutionCopy[k][0]==constructed_position[index][0]):
                    break
            if(last_pos==constructed_position[index][0]):
                plane_lastseen_time = pd.to_datetime(airplanes["last_seen"].iloc[constructed_position[index][1]])
                plane_lastseen_place = dfx["origin"].iloc[last_pos]
            else:
                plane_lastseen_time = solution[last_pos][3]
                plane_lastseen_place = dfx["destination"].iloc[last_pos]

            if(plane_lastseen_time < (pd.to_datetime(dfx["firstseen"].iloc[j]) + datetime.timedelta(minutes=max_arrival)) and plane_lastseen_place==dfx["origin"].iloc[j]):
                condition.append(True)

                newflight = []
                newflight.append(j)
                newflight.append(constructed_position[index][1])

                if(plane_lastseen_time > (pd.to_datetime(dfx["firstseen"].iloc[j]) - datetime.timedelta(minutes=min_safe))):
                    departure = plane_lastseen_time + datetime.timedelta(minutes=min_safe)
                else:
                    departure = pd.to_datetime(dfx["firstseen"].iloc[j])

                newflight.append(departure)
                arrival = departure + (constructed_position[index_j][3] - constructed_position[index_j][2])
                newflight.append(arrival)
                newflight.append(round(airplanes["capacity"].iloc[constructed_position[index][1]] * constructed_position[index_j][5]))
                newflight.append(constructed_position[index_j][5])


                ext = []
                if(constructed_position[index][0]!=constructed_position[index_j][0]):
                    for l in range(range2, len(solutionCopy)-1):
                        if(solutionCopy[l][0]!=constructed_position[index][0] and solutionCopy[l][0] not in exc):
                            if(constructed_position[index_j][1]==solutionCopy[l][1]):
                                ext.append(solutionCopy[l][0])
                                exc.append(solutionCopy[l][0])

                solutionCopy[j] = newflight

                for m in (ext):
                    new_flight = []
                    new_flight.append(solutionCopy[m][0])
                    new_flight.append(newflight[1])
                    if(pd.to_datetime(dfx["firstseen"].iloc[m]) > newflight[3] + datetime.timedelta(minutes=min_safe)):
                        new_flight.append(pd.to_datetime(dfx["firstseen"].iloc[m]))
                        new_flight.append(pd.to_datetime(dfx["lastseen"].iloc[m]))
                    else:
                        new_flight.append(newflight[3] + datetime.timedelta(minutes=min_safe))
                        new_flight.append(newflight[3] + (solutionCopy[m][3]-solutionCopy[m][2]) + datetime.timedelta(minutes=min_safe))
                    new_flight.append(round(airplanes["capacity"].iloc[newflight[1]] * solutionCopy[m][5]))
                    new_flight.append(solutionCopy[m][5])


                    solutionCopy[m] = new_flight
                    newflight = solutionCopy[m]

                index = index+1

            else:
                condition.append(False)
                index = index+1
                
        solutionCopy2 = solutionCopy[:]
        if False not in condition:
            doneCrossover = True
            
    return solutionCopy1, solutionCopy2

# %%
# def mutation(xbest, var_a, var_b):  
#     mutation_done = False
#     solution = deepcopy(xbest)
#     if(random.random() >= var_b):
#         mutation_done = True
#         new_solution = solution
#     while (mutation_done == False):
#         solution = deepcopy(xbest)
#         rand_flight = random.randint(0, len(solution)-1)        
#         airplanelist = []
#         for i in range(len(airplanes)):
#             airplane = [i, airplanes["curr_loc"].iloc[i], airplanes["last_seen"].iloc[i], airplanes["capacity"].iloc[i], airplanes["fixed_cost"].iloc[i], airplanes["min_cost"].iloc[i], airplanes["idle_cost"].iloc[i], 0]
#             airplanelist.append(airplane)
#         for j in range(rand_flight):
#             airplanelist[solution[j][1]][1] = dfx["destination"].iloc[j]
#             airplanelist[solution[j][1]][2] = solution[j][3]

#         available_airplanes = []
#         for airplane in airplanelist:
#             if (airplane[0] != solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
#                 available_airplanes.append(airplane)
                
#         if(len(available_airplanes) >= 3):
#             mutation_solution = []
#             variables = ["capacity", "fixed_cost", "min_cost", "idle_cost"]
#             index = 3
#             for variable in variables:
#                 airplanelist = sorted(airplanelist,key=lambda l:l[index], reverse=True)
#                 xsolution = airplanes[variable].iloc[solution[rand_flight][1]]               
#                 uppervar =  airplanelist[0][index]
#                 lowervar =  airplanelist[-1][index]
#                 xsolution = xsolution + (2*random.random()-1) * var_a*abs(uppervar - lowervar)
#                 mutation_solution.append(xsolution)
#                 index = index + 1
            
#             for k in range(len(mutation_solution)):
#                 max_val = mutation_solution[k]*2
#                 for airplane in available_airplanes:
#                     val_diff = abs(mutation_solution[k] - airplane[k+3])                    
#                     rate = ((max_val - val_diff) / (max_val - 0))*0.25
                    
#                     airplane[-1] = airplane[-1] +  rate
            
#             new_solution = []
#             available_airplanes = sorted(available_airplanes,key=lambda l:l[7], reverse=True)
#             airplane1 = solution[rand_flight][1]
#             airplane2 = available_airplanes[0][0]
#             last_pos1 = -1
#             last_pos2 = -1
#             for l in range(len(solution)):
#                 if(l < rand_flight):
#                     new_solution.append(solution[l])
#                     if(solution[l][1]==airplane1):
#                         last_pos1 = l
#                     elif(solution[l][1]==airplane2):
#                         last_pos2 = l   
#                 else:                                        
#                     newflight = solution[l]
#                     newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
#                     if(solution[l][1]==airplane1):
#                         newflight[1] = airplane2                        
#                         if(last_pos2 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution[last_pos2][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos2 = l        
#                     elif(solution[l][1]==airplane2):
#                         newflight[1] = airplane1                        
#                         if(last_pos1 > -1):
#                             if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
#                                 newflight[2] = new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)
#                                 newflight[3] = new_solution[last_pos1][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
#                         last_pos1 = l 
#                     new_solution.append(newflight)                    
#             mutation_done = True

#     return new_solution

# %%
def mutation(solution, solutions, mutation_range):
    doneMutation = False
    mut_range = round(mutation_range * len(solution))
    try_time = 0
    while(doneMutation==False):        
        mut_range = round(mutation_range * len(solution))
        solutionCopy = solution[:]
        while True:
            if(try_time > 3 and mut_range >= 3):
                mut_range = mut_range - 1
                try_time = 1
            condition = []
            range1 = random.randint(0, len(solutionCopy)-1-mut_range)
#             range1 = random.randint(0, len(solutionCopy)-1)
            if(mut_range >= 3):
                range2 = range1 + mut_range
            else:
                range2 = range1 + 2
#             range2 = random.randint(0, len(solutionCopy)-1)
            if(range1 < range2 and range1+1!=range2):
                for o in range(range1, range2+1):
                    if(dfx["origin"].iloc[o]!="WSSS"):
                        condition.append(False)
#                         print("False")
                    else:
                        condition.append(True)
#                         print("True")
            else:
                condition.append(False)
            if False not in condition:
                break
                try_time = try_time + 1
            else:
                try_time = try_time + 1
                
        while True:
            empty_position = []
            constructed_position = []
            changeable_pos = 0
            for a in range(range1, range2+1):
                if(random.randint(0, 1) == 1):
                    constructed_position.append(solutionCopy[a])
                    empty_position.append(solutionCopy[a][0])
                    changeable_pos = changeable_pos + 1
            if(changeable_pos > 1):
                break
            
        
        condition = []
        real_exc = []
        for b in range(len(constructed_position)):
            index = constructed_position[b][0]
#             print("B", index)
            last_pos = constructed_position[b][0]
            found_position = False
            for k in range(len(solutionCopy)):
                if(solution[k][1]==constructed_position[b][1] and solution[k][0] < constructed_position[b][0]):
                    last_pos = solution[k][0]
                elif(solutionCopy[k][0]==constructed_position[b][0]):
                    break
            if(last_pos==constructed_position[b][0]):
                plane_lastseen_time = pd.to_datetime(airplanes["last_seen"].iloc[constructed_position[b][1]])
                plane_lastseen_place = dfx["origin"].iloc[last_pos]
            else:
                plane_lastseen_time = solutionCopy[last_pos][3]
                plane_lastseen_place = dfx["destination"].iloc[last_pos]
            
            for c in range(len(empty_position)):
                exc = real_exc[:]
                best_exc = []
                index_c = empty_position[c]
                solutionCopyCopy = solutionCopy[:]
                if(plane_lastseen_time < (pd.to_datetime(dfx["firstseen"].iloc[index_c]) + datetime.timedelta(minutes=max_arrival)) and plane_lastseen_place==dfx["origin"].iloc[index_c]):
                    
                    newflight = []
                    newflight.append(index_c)
                    newflight.append(constructed_position[b][1])

                    if(plane_lastseen_time > (pd.to_datetime(dfx["firstseen"].iloc[index_c]) - datetime.timedelta(minutes=min_safe))):
                        departure = plane_lastseen_time + datetime.timedelta(minutes=min_safe)
                    else:
                        departure = pd.to_datetime(dfx["firstseen"].iloc[index_c])

                    newflight.append(departure)
                    arrival = departure + (constructed_position[c][3] - constructed_position[c][2])
                    newflight.append(arrival)
                    newflight.append(round(airplanes["capacity"].iloc[constructed_position[b][1]] * constructed_position[c][5]))
                    newflight.append(constructed_position[c][5])


                    ext = []
                    if(constructed_position[b][0]!=index_c):
                        for l in range(range2, len(solutionCopy)-1):
                            if(solutionCopy[l][0]!=constructed_position[b][0] and solutionCopy[l][0] not in exc):
                                if(solutionCopy[index_c][1]==solutionCopy[l][1]):
#                                     print("index_c", index_c)
#                                     print("solutionCopy[index_c][1]", solutionCopy[index_c][1])
                                    ext.append(solutionCopy[l][0])
                                    exc.append(solutionCopy[l][0])

                    solutionCopyCopy[index_c] = newflight
#                     print(ext)

                    for m in (ext):
                        new_flight = []
                        new_flight.append(solutionCopyCopy[m][0])
                        new_flight.append(newflight[1])
                        if(pd.to_datetime(dfx["firstseen"].iloc[m]) > newflight[3] + datetime.timedelta(minutes=min_safe)):
                            new_flight.append(pd.to_datetime(dfx["firstseen"].iloc[m]))
                            new_flight.append(pd.to_datetime(dfx["lastseen"].iloc[m]))
                        else:
                            new_flight.append(newflight[3] + datetime.timedelta(minutes=min_safe))
                            new_flight.append(newflight[3] + (solutionCopyCopy[m][3]-solutionCopyCopy[m][2]) + datetime.timedelta(minutes=min_safe))
                        new_flight.append(round(airplanes["capacity"].iloc[newflight[1]] * solutionCopyCopy[m][5]))
                        new_flight.append(solutionCopyCopy[m][5])


                        solutionCopyCopy[m] = new_flight
                        newflight = solutionCopyCopy[m]
#                         print(new_flight)
                        
                    if(found_position == False):
                        best_position = solutionCopyCopy[:]
                        best_c = c
#                         print("Best position", index_c)
                        temp_exc = exc
                    elif(found_position == True and countFitness(solutionCopyCopy)[0] > countFitness(best_position)[0]):
                        best_position = solutionCopyCopy[:]
                        best_c = c
#                         print("Best position", index_c)
                        temp_exc = exc
                        
                    found_position = True
                    
            if(found_position == True):
                condition.append(True)
                solutionCopy = best_position[:]
                empty_position.pop(best_c)
#                 print("Fitness", countFitness(solutionCopy)[0])
                real_exc.extend(temp_exc)
            else:
                condition.append(False)
                
        if False not in condition:
            done_swap = True
            while (done_swap==False):
                while True:
                    selected_solution = random.randint(0, len(solutions)-1)
                    if(solution != solutions[selected_solution][0]):
                        break
                for o in range(range1, range2+1):
                    if(random.randint(0, 1)==0):
                        found = False
                        for p in range(len(solutionCopy)):
                            if (solutionCopy[p][1]==solutions[selected_solution][0][o][1] and solutionCopy[p][0] < solutionCopy[o][0]):
                                ant_fpos = solutionCopy[p][0]
                                found = True
                            elif (solutionCopy[p][0]==solutionCopy[o][0] and found==True):
                                break
                            elif (solutionCopy[p][1]==solutions[selected_solution][0][o][1] and solutionCopy[p][0] > solutionCopy[o][0]):
                                ant_fpos = solutionCopy[p][0]
                                found = True
                                break

                        if(found==True):
                            last_pos1 = solutionCopy[o][0]
                            last_pos2 = solutionCopy[ant_fpos][0]

                            for a in range(len(solutionCopy)):
                                if(solutionCopy[a][1]==solutionCopy[o][1] and solutionCopy[a][0] < solutionCopy[o][0]):
                                    last_pos1 = solutionCopy[a][0]
                                elif(solutionCopy[a][0]==solutionCopy[o][0]):
                                    break

                            if(last_pos1==solutionCopy[o][0]):
                                plane_lastseen_time1 = pd.to_datetime(airplanes["last_seen"].iloc[solutionCopy[o][1]])
                                plane_lastseen_place1 = dfx["origin"].iloc[last_pos1]
                            else:
                                plane_lastseen_time1 = solutionCopy[last_pos1][3]
                                plane_lastseen_place1 = dfx["destination"].iloc[last_pos1]

                            for b in range(len(solutionCopy)):
                                if(solutionCopy[b][1]==solutionCopy[ant_fpos][1] and solutionCopy[b][0] < solutionCopy[ant_fpos][0]):
                                    last_pos2 = solutionCopy[b][0]
                                elif(solutionCopy[b][0]==solutionCopy[ant_fpos][0]):
                                    break

                            if(last_pos2==solutionCopy[ant_fpos][0]):
                                plane_lastseen_time2 = pd.to_datetime(airplanes["last_seen"].iloc[solutionCopy[ant_fpos][1]])
                                plane_lastseen_place2 = dfx["origin"].iloc[last_pos2]
                            else:
                                plane_lastseen_time2 = solutionCopy[last_pos2][3]
                                plane_lastseen_place2 = dfx["destination"].iloc[last_pos2]

                            if(plane_lastseen_time1 < pd.to_datetime(dfx["firstseen"].iloc[ant_fpos]) + datetime.timedelta(minutes=max_arrival) and plane_lastseen_place1==plane_lastseen_place2):
                                if(plane_lastseen_time2 < pd.to_datetime(dfx["firstseen"].iloc[o]) + datetime.timedelta(minutes=max_arrival) and plane_lastseen_place2==plane_lastseen_place1):
                                    done_swap = True
                                    flight1 = solutionCopy[o]
                                    flight2 = solutionCopy[ant_fpos]

                                    result = swapPlane(flight1, flight2)

                                    solutionCopy[o] = result[0]
                                    solutionCopy[ant_fpos] = result[1]

                                    newflight1 = result[0]
                                    newflight2 = result[1]

                                    ext1 = []
                                    ext2 = []
                                    for k in range(range2, len(solutionCopy)-1):
                                        if(solutionCopy[k][0]!=flight1[0] and solutionCopy[k][0]!=flight2[0]):
                                            if(flight1[1]==solutionCopy[k][1]):
                                                ext1.append(solutionCopy[k][0])
                                            elif(flight2[1]==solutionCopy[k][1]):
                                                ext2.append(solutionCopy[k][0])

                                    for l in (ext1):
                                        newflight = []
                                        newflight.append(solutionCopy[l][0])
                                        newflight.append(newflight1[1])
                                        if(pd.to_datetime(dfx["firstseen"].iloc[l]) > newflight1[3] + datetime.timedelta(minutes=min_safe)):
                                            newflight.append(pd.to_datetime(dfx["firstseen"].iloc[l]))
                                            newflight.append(pd.to_datetime(dfx["lastseen"].iloc[l]))
                                        else:
                                            newflight.append(newflight1[3] + datetime.timedelta(minutes=min_safe))
                                            newflight.append(newflight1[3] + (solutionCopy[l][3]-solutionCopy[l][2]) + datetime.timedelta(minutes=min_safe))
                                        newflight.append(round(airplanes["capacity"].iloc[newflight1[1]] * solutionCopy[l][5]))
                                        newflight.append(solutionCopy[l][5])

                                        newflight1 = newflight
                                        solutionCopy[l] = newflight

                                    for m in (ext2):
                                        newflight = []
                                        newflight.append(solutionCopy[m][0])
                                        newflight.append(newflight2[1])
                                        if(pd.to_datetime(dfx["firstseen"].iloc[m]) > newflight2[3] + datetime.timedelta(minutes=min_safe)):
                                            newflight.append(pd.to_datetime(dfx["firstseen"].iloc[m]))
                                            newflight.append(pd.to_datetime(dfx["lastseen"].iloc[m]))
                                        else:
                                            newflight.append(newflight2[3] + datetime.timedelta(minutes=min_safe))
                                            newflight.append(newflight2[3] + (solutionCopy[m][3]-solutionCopy[m][2]) + (solutionCopy[m][3]-solutionCopy[m][2]) + datetime.timedelta(minutes=min_safe))
                                        newflight.append(round(airplanes["capacity"].iloc[newflight2[1]] * solutionCopy[m][5]))
                                        newflight.append(solutionCopy[m][5])

                                        newflight2 = newflight
                                        solutionCopy[m] = newflight    
            
            doneMutation = True
#             print("Range 1", range1)
#             print("Range 2", range2)
            
    return solutionCopy

# %%
def randomwalk(solution, rand_solution):  
    randomwalk_done = False
    while (randomwalk_done == False):
        rand_flight = random.randint(0, len(solution)-1)        
        airplanelist = []
        for i in range(len(airplanes)):
            airplane = [i, airplanes["curr_loc"].iloc[i], airplanes["last_seen"].iloc[i], airplanes["capacity"].iloc[i], airplanes["fixed_cost"].iloc[i], airplanes["min_cost"].iloc[i], airplanes["idle_cost"].iloc[i], 0]
            airplanelist.append(airplane)
        for j in range(rand_flight):
            airplanelist[solution[j][1]][1] = dfx["destination"].iloc[j]
            airplanelist[solution[j][1]][2] = solution[j][3]

        available_airplanes = []
        for airplane in airplanelist:
            if (airplane[0] != solution[rand_flight][1] and airplane[1] == dfx["origin"].iloc[rand_flight] and pd.to_datetime(airplane[2]) < (pd.to_datetime(dfx["firstseen"].iloc[rand_flight]) + datetime.timedelta(minutes=min_safe))):
                available_airplanes.append(airplane)
                
        if(len(available_airplanes) >= 3):
            randomwalk_solution = []
            variables = ["capacity", "fixed_cost", "min_cost", "idle_cost"]
            selected_var = random.randint(0,3)
            variable = variables[selected_var]
            xsolution = airplanes[variable].iloc[solution[rand_flight][1]]
            xrandsolution = airplanes[variable].iloc[rand_solution[rand_flight][1]]
                
            xsolution = xsolution + (random.random()*(xrandsolution - xsolution))
            randomwalk_solution.append(xsolution)          

            max_val = randomwalk_solution[0]*2
            for airplane in available_airplanes:
                val_diff = abs(randomwalk_solution[0] - airplane[selected_var+3])                    
                rate = ((max_val - val_diff) / (max_val - 0))
                    
                airplane[-1] = airplane[-1] +  rate
            
            new_solution = []
            available_airplanes = sorted(available_airplanes,key=lambda l:l[7], reverse=True)
            airplane1 = solution[rand_flight][1]
            airplane2 = available_airplanes[0][0]
            last_pos1 = -1
            last_pos2 = -1
            for l in range(len(solution)):
                if(l < rand_flight):
                    new_solution.append(solution[l])
                    if(solution[l][1]==airplane1):
                        last_pos1 = l
                    elif(solution[l][1]==airplane2):
                        last_pos2 = l   
                else:                                        
                    newflight = solution[l]
                    newflight[4] = round(airplanes["capacity"].iloc[newflight[1]] * newflight[5])
                    if(solution[l][1]==airplane1):
                        newflight[1] = airplane2                        
                        if(last_pos2 > -1):
                            if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)):
                                newflight[2] = new_solution[last_pos2][3] + datetime.timedelta(minutes=min_safe)
                                newflight[3] = new_solution[last_pos2][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
                        last_pos2 = l        
                    elif(solution[l][1]==airplane2):
                        newflight[1] = airplane1                        
                        if(last_pos1 > -1):
                            if(pd.to_datetime(dfx["firstseen"].iloc[l]) < new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)):
                                newflight[2] = new_solution[last_pos1][3] + datetime.timedelta(minutes=min_safe)
                                newflight[3] = new_solution[last_pos1][3] + (solution[l][3]-solution[l][2]) + datetime.timedelta(minutes=min_safe)
                        last_pos1 = l 
                    new_solution.append(newflight)                    
            randomwalk_done = True

    return new_solution

# %%
print(dfx)
# Out:
#         callsign registration typecode origin destination  \
# 1208410   SIA322       9V-SMQ     A359   WSSS        EGLL
# 1208521   SIA324       9V-SMM     A359   WSSS        EHAM
# 1208877    SIA26       9V-SMB     A359   WSSS        EDDF
# 1211170   SIA352       9V-SMN     A359   WSSS        EKCH
# 1215881   SIA478       9V-SMA     A359   WSSS        FABB
# ...          ...          ...      ...    ...         ...
# 1322349  SIA7198       9V-SFQ     B744   VHHH        PANC
# 1322991    SIA25       9V-SMD     A359   EDDF        WSSS
# 1323385   SIA285       9V-SMP     A359   WSSS        NZAA
# 1323492   SIA288       9V-SMQ     A359   YSSY        YBBN
# 1324267  SIA7286       9V-SFI     B744   YSSY        YMML
#
#                          firstseen                   lastseen  \
# 1208410  2020-11-20 16:06:59+00:00  2020-11-21 05:40:59+00:00
# 1208521  2020-11-20 16:08:35+00:00  2020-11-21 05:29:37+00:00
# 1208877  2020-11-20 16:13:20+00:00  2020-11-21 05:09:18+00:00
# 1211170  2020-11-20 16:44:59+00:00  2020-11-21 05:14:59+00:00
# 1215881  2020-11-20 17:48:48+00:00  2020-11-21 03:40:12+00:00
# ...                            ...                        ...
# 1322349  2020-11-22 10:10:26+00:00  2020-11-22 18:45:05+00:00
# 1322991  2020-11-22 10:37:06+00:00  2020-11-22 22:10:36+00:00
# 1323385  2020-11-22 10:53:43+00:00  2020-11-22 19:54:17+00:00
# 1323492  2020-11-22 10:58:09+00:00  2020-11-22 12:01:17+00:00
# 1324267  2020-11-22 11:23:11+00:00  2020-11-22 12:28:19+00:00
#
#                                day  latitude_1  longitude_1  latitude_2  \
# 1208410  2020-11-21 00:00:00+00:00    1.376782   104.004680   51.477676
# 1208521  2020-11-21 00:00:00+00:00    1.373151   104.003543   52.366985
# 1208877  2020-11-21 00:00:00+00:00    1.369567   104.002407   50.030225
# 1211170  2020-11-21 00:00:00+00:00    1.371429   104.002691   55.628155
# 1215881  2020-11-21 00:00:00+00:00    1.369939   104.001980  -26.219757
# ...                            ...         ...          ...         ...
# 1322349  2020-11-22 00:00:00+00:00   22.302887   113.918635   61.169734
# 1322991  2020-11-22 00:00:00+00:00   50.043807     8.568389    1.319046
# 1323385  2020-11-22 00:00:00+00:00    1.387070   103.993603  -36.992615
# 1323492  2020-11-22 00:00:00+00:00  -33.940445   151.174393  -27.395370
# 1324267  2020-11-22 00:00:00+00:00  -33.943052   151.175137  -37.688370
#
#          longitude_2
# 1208410    -0.446357
# 1208521     4.712350
# 1208877     8.541035
# 1211170    12.671700
# 1215881    28.231166
# ...              ...
# 1322349  -150.026143
# 1322991   103.980847
# 1323385   174.856178
# 1323492   153.122466
# 1324267   144.841529
#
# [70 rows x 12 columns]

# %%
test = createSchedule()
# Out:
# c:\users\user\opencv\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
print(test)
# Out:
# [[0, 35, Timestamp('2020-11-20 18:27:55+0000', tz='UTC'), Timestamp('2020-11-21 08:01:55+0000', tz='UTC'), 35, 0.133], [1, 6, Timestamp('2020-11-20 16:08:35+0000', tz='UTC'), Timestamp('2020-11-21 05:29:37+0000', tz='UTC'), 47, 0.133], [2, 42, Timestamp('2020-11-20 16:13:20+0000', tz='UTC'), Timestamp('2020-11-21 05:09:18+0000', tz='UTC'), 35, 0.133], [3, 40, Timestamp('2020-11-20 16:44:59+0000', tz='UTC'), Timestamp('2020-11-21 05:14:59+0000', tz='UTC'), 47, 0.133], [4, 21, Timestamp('2020-11-20 17:48:48+0000', tz='UTC'), Timestamp('2020-11-21 03:40:12+0000', tz='UTC'), 49, 0.14], [5, 15, Timestamp('2020-11-20 17:54:12+0000', tz='UTC'), Timestamp('2020-11-21 00:57:39+0000', tz='UTC'), 45, 0.171], [6, 23, Timestamp('2020-11-20 18:54:04+0000', tz='UTC'), Timestamp('2020-11-21 01:49:29+0000', tz='UTC'), 60, 0.171], [7, 16, Timestamp('2020-11-20 20:02:05+0000', tz='UTC'), Timestamp('2020-11-21 04:34:48+0000', tz='UTC'), 53, 0.128], [8, 25, Timestamp('2020-11-20 21:01:38+0000', tz='UTC'), Timestamp('2020-11-21 09:16:45+0000', tz='UTC'), 60, 0.171], [9, 14, Timestamp('2020-11-20 21:26:06+0000', tz='UTC'), Timestamp('2020-11-21 06:41:53+0000', tz='UTC'), 55, 0.133], [10, 11, Timestamp('2020-11-20 22:21:21+0000', tz='UTC'), Timestamp('2020-11-21 05:10:47+0000', tz='UTC'), 37, 0.14], [11, 3, Timestamp('2020-11-20 23:21:25+0000', tz='UTC'), Timestamp('2020-11-21 09:35:51+0000', tz='UTC'), 60, 0.171], [12, 19, Timestamp('2020-11-21 03:00:04+0000', tz='UTC'), Timestamp('2020-11-21 16:49:03+0000', tz='UTC'), 55, 0.133], [13, 12, Timestamp('2020-11-21 02:30:04+0000', tz='UTC'), Timestamp('2020-11-21 08:59:52+0000', tz='UTC'), 37, 0.171], [14, 10, Timestamp('2020-11-21 03:07:03+0000', tz='UTC'), Timestamp('2020-11-21 06:16:27+0000', tz='UTC'), 45, 0.128], [15, 23, Timestamp('2020-11-21 04:01:25+0000', tz='UTC'), Timestamp('2020-11-21 11:46:29+0000', tz='UTC'), 60, 0.171], [16, 15, Timestamp('2020-11-21 05:09:13+0000', tz='UTC'), Timestamp('2020-11-21 12:51:55+0000', tz='UTC'), 45, 0.171], [17, 16, Timestamp('2020-11-21 06:32:16+0000', tz='UTC'), Timestamp('2020-11-21 11:06:39+0000', tz='UTC'), 71, 0.171], [18, 11, Timestamp('2020-11-21 06:32:24+0000', tz='UTC'), Timestamp('2020-11-21 14:17:22+0000', tz='UTC'), 35, 0.133], [19, 31, Timestamp('2020-11-21 07:55:25+0000', tz='UTC'), Timestamp('2020-11-21 18:15:52+0000', tz='UTC'), 60, 0.171], [20, 14, Timestamp('2020-11-21 09:24:06+0000', tz='UTC'), Timestamp('2020-11-21 16:09:35+0000', tz='UTC'), 58, 0.14], [21, 6, Timestamp('2020-11-21 09:31:00+0000', tz='UTC'), Timestamp('2020-11-21 21:03:58+0000', tz='UTC'), 60, 0.171], [22, 13, Timestamp('2020-11-21 10:27:44+0000', tz='UTC'), Timestamp('2020-11-21 11:38:48+0000', tz='UTC'), 47, 0.133], [23, 4, Timestamp('2020-11-21 10:33:18+0000', tz='UTC'), Timestamp('2020-11-21 22:31:29+0000', tz='UTC'), 60, 0.171], [24, 42, Timestamp('2020-11-21 10:38:05+0000', tz='UTC'), Timestamp('2020-11-21 10:50:28+0000', tz='UTC'), 35, 0.133], [25, 42, Timestamp('2020-11-21 11:20:28+0000', tz='UTC'), Timestamp('2020-11-21 22:57:06+0000', tz='UTC'), 45, 0.171], [26, 35, Timestamp('2020-11-21 11:06:23+0000', tz='UTC'), Timestamp('2020-11-21 22:54:41+0000', tz='UTC'), 45, 0.171], [27, 40, Timestamp('2020-11-21 11:32:34+0000', tz='UTC'), Timestamp('2020-11-21 22:18:44+0000', tz='UTC'), 60, 0.171], [28, 12, Timestamp('2020-11-21 11:43:39+0000', tz='UTC'), Timestamp('2020-11-21 14:38:28+0000', tz='UTC'), 37, 0.171], [29, 18, Timestamp('2020-11-21 12:28:41+0000', tz='UTC'), Timestamp('2020-11-21 15:55:19+0000', tz='UTC'), 53, 0.128], [30, 13, Timestamp('2020-11-21 12:50:57+0000', tz='UTC'), Timestamp('2020-11-22 00:58:16+0000', tz='UTC'), 60, 0.171], [31, 39, Timestamp('2020-11-21 12:55:20+0000', tz='UTC'), Timestamp('2020-11-21 21:22:54+0000', tz='UTC'), 81, 0.171], [32, 10, Timestamp('2020-11-21 13:10:08+0000', tz='UTC'), Timestamp('2020-11-21 22:01:52+0000', tz='UTC'), 40, 0.113], [33, 0, Timestamp('2020-11-21 13:42:36+0000', tz='UTC'), Timestamp('2020-11-22 01:30:22+0 ...

# %%
def era():
    print("Starting...")
    p = 40
    s = 0.5
    a = 0.075
    b = 0.075
    iteration = 100
    y_plot_list = []
    x_plot_list = []
    xbest = []
    xworst = []
    besthq = []
    f1 = 0
    f2 = 0
    f3 = 0
    
    print("Creating Solution...")
       
    with open('solution/solution_70-1', 'rb') as fp:
        initial_solutions1 = pickle.load(fp)
    with open('solution/solution_70-2', 'rb') as fp:
        initial_solutions2 = pickle.load(fp)
    initial_solutions =  initial_solutions1 + initial_solutions2
    
#     solutions = deepcopy(initial_solutions)
    solutions = []
    
    for i in range(len(initial_solutions)):
        fitness = countFitness(initial_solutions[i])[0]
        sol_fit = [initial_solutions[i], fitness]
        solutions.append(sol_fit)
        
    
    for i in range(iteration):
        print("Iterasi ke-", i)
        for solution in solutions:
            solution[1] = countFitness(solution[0])[0]
            
        solutions = sorted(solutions,key=lambda l:l[1], reverse=True)              
        
        if(i==0):
            f2 = countFitness(solutions[0][0])[0]
            f3 = countFitness(solutions[0][0])[0]
            xbest = deepcopy(solutions[0])
            xworst = deepcopy(solutions[-1])
        else:
            f3 = f2
            f2 = f1
            if(solutions[0][1] > xbest[1]):
                xbest = deepcopy(solutions[0])
            if(solutions[-1][1] > xworst[1]):
                xworst = deepcopy(solutions[-1])
        
        if ((round(s*p)) < 2):
            hq = solutions[:2]
            lq = solutions[2:]
        else:
            hq = solutions[:(round(s*p))]
            lq = solutions[(round(s*p)):]       
        
        print("Rao3 High-Quality solution...")
        for hq_indv in hq:
            
            random_hq = random.randint(0, len(hq)-1)
            while hq_indv==hq[random_hq]:
                random_hq = random.randint(0, len(hq)-1)
            
            randomwalk_indv = rao3(hq_indv[0], hq[random_hq][0], xbest[0], xworst[0])
            randomwalk_indvfit = countFitness(randomwalk_indv)[0]
            if(countFitness(randomwalk_indv)[0] > hq_indv[1]):
                hq_indv[0] = randomwalk_indv
                hq_indv[1] = randomwalk_indvfit
        
        hq = sorted(hq,key=lambda l:l[1], reverse=True)
        
#         print(hq)
        
        besthq = hq[0]
        
        if(random.random() > 0.5):
            print("Solution Crossover...")
#             o1, o2 = crossover(besthq[0], xbest[0])
            o1, o2 = crossOver(besthq[0], a)
            o1fit = countFitness(o1)[0]
            o2fit = countFitness(o2)[0]
            if(o1fit > countFitness(besthq[0])[0]):
#                 print("o1",countFitness(o1)[0])
                offsol1 = [o1, o1fit]
                hq[0] =  offsol1
                
            if(o2fit > countFitness(besthq[0])[0]):
#                 print("o2",countFitness(o2)[0])
                offsol2 = [o2, o2fit]
                hq[0] =  offsol2
#                 xbest = deepcopy(offsol2)
        else:
            print("Solution Mutation...")
#             o = mutation(xbest[0], a, b)
            o = mutation(xbest[0], hq, b)
            ofit = countFitness(o)[0]
            if(ofit > xbest[1]):
#                 print("o",countFitness(o)[0])
                offsol = [o, ofit]
                xbest = deepcopy(offsol)
        
        print("Random Walk Low-Quality Solution...")
        for lq_indv in lq:
            
            random_hq = random.randint(0, len(hq)-1)               
            lq_indv[0] = randomwalk(lq_indv[0], hq[random_hq][0])
            lq_indv[1] = countFitness(lq_indv[0])[0]
        
        solutions = hq+lq
        solutions = sorted(solutions,key=lambda l:l[1], reverse=True)
        
        if(solutions[0][1] > xbest[1]):
            xbest = deepcopy(solutions[0])
       
        f1 = countFitness(xbest[0])[0]
        diff1 = abs(f1-f2)/f1
        diff2 = abs(f2-f3)/f2       
        
        if(diff1 > 0 and diff2 > 0):
            s = s * (1-((diff1 + diff2)/2))
            a = a * 0.97
            b = b * 0.97
        elif(diff1 == 0 and diff2 == 0):
            s = s * 0.97
            a = a * 1.03
            b = b * 1.03
        
        print("s:", s)
        print("a:", a)
        print("b:", b)
        print("Elite Solution:", countFitness(xbest[0]))
        print("High-Quality Solution")
        for j in range(len(hq)):
            print("Solution: ", hq[j][1])
        
#         if(i==0):
#             values = [countFitness(xbest[0])[0]]
#             y_plot_list.append(values)
#         else:
#             y_plot_list[0].append(countFitness(xbest[0])[0])
        
        for j in range(10):
            fit = countFitness(solutions[j][0])[0]
            if(i==0):
                values = [fit]
                y_plot_list.append(values)
            else:
                if(fit > y_plot_list[j][i-1]):
                    y_plot_list[j].append(fit)
                else:
                    y_plot_list[j].append(y_plot_list[j][i-1])    
        x_plot_list.append(i)
        
    print("Final Elite Solutions")
    for k in range(25):
        print("Solution: ", countFitness(solutions[k][0]))
    
    print("Final Elite Solution")
    print("Solution: ", countFitness(xbest[0]))       
            
            
    return xbest[0], x_plot_list, y_plot_list

# %%
start_time = time.time()
result, x_plot_list, y_plot_list = era()
end_time = time.time()
# Out:
# Starting...
# Creating Solution...
# Iterasi ke- 0
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.485
# a: 0.07725
# b: 0.07725
# Elite Solution: [767.7423505225764, 3831, 48862187.76003823, 29]
# High-Quality Solution
# Solution:  767.7423505225764
# Solution:  749.2552377497924
# Solution:  742.2134372952218
# Solution:  742.0840852304575
# Solution:  738.8211067432852
# Solution:  737.7579413135751
# Solution:  732.158169843295
# Solution:  728.6010157937116
# Solution:  726.0106361674681
# Solution:  724.8228650680743
# Solution:  721.9004763606902
# Solution:  720.3168218952447
# Solution:  719.4538606635862
# Solution:  717.3070176640593
# Solution:  717.2658357810801
# Solution:  716.4926837072228
# Solution:  715.5121853551551
# Solution:  714.6041193932058
# Solution:  714.3884963517655
# Solution:  714.1183413491877
# Iterasi ke- 1
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.485
# a: 0.07725
# b: 0.07725
# Elite Solution: [769.9511173997921, 3848, 49364456.76003823, 30]
# High-Quality Solution
# Solution:  769.9511173997921
# Solution:  749.2552377497924
# Solution:  744.1933619603543
# Solution:  743.1502620290568
# Solution:  741.3604668245448
# Solution:  737.7579413135751
# Solution:  734.5116568281832
# Solution:  732.0226576418765
# Solution:  728.6010157937116
# Solution:  728.4382194589124
# Solution:  722.5484216181321
# Solution:  720.3356339403032
# Solution:  719.9625329894953
# Solution:  717.4201695744234
# Solution:  717.3070176640593
# Solution:  716.383973949976
# Solution:  715.5121853551551
# Solution:  714.6041193932058
# Solution:  714.2239853954812
# Iterasi ke- 2
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.485
# a: 0.07725
# b: 0.07725
# Elite Solution: [769.9511173997921, 3848, 49364456.76003823, 30]
# High-Quality Solution
# Solution:  769.9511173997921
# Solution:  745.2274118524874
# Solution:  744.1933619603543
# Solution:  743.1502620290568
# Solution:  742.2972915583798
# Solution:  740.0881544356857
# Solution:  737.7411968813672
# Solution:  737.5580704632256
# Solution:  735.7892832021912
# Solution:  728.4382194589124
# Solution:  722.5484216181321
# Solution:  721.0863654921309
# Solution:  720.5094873789546
# Solution:  719.9625329894953
# Solution:  716.558789138884
# Solution:  714.6041193932058
# Solution:  714.2239853954812
# Solution:  713.8792100230713
# Solution:  713.5575392598635
# Iterasi ke- 3
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.47045
# a: 0.0795675
# b: 0.0795675
# Elite Solution: [769.9511173997921, 3848, 49364456.76003823, 30]
# High-Quality Solution
# Solution:  769.205012679793
# Solution:  745.2027768140872
# Solution:  743.5751717017006
# Solution:  743.149183337495
# Solution:  740.0881544356857
# Solution:  739.3868836655904
# Solution:  737.7411968813672
# Solution:  737.5580704632256
# Solution:  735.7892832021912
# Solution:  728.4382194589124
# Solution:  724.7443966083431
# Solution:  724.2097082558577
# Solution:  722.5938429284353
# Solution:  721.2943035394424
# Solution:  721.0863654921309
# Solution:  720.7718850298378
# Solution:  720.4826806846746
# Solution:  714.603040701644
# Solution:  713.9801986813821
# Iterasi ke- 4
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.47045
# a: 0.0795675
# b: 0.0795675
# Elite Solution: [774.751480733794, 3859, 48886269.76003823, 29]
# High-Quality Solution
# Solution:  774.751480733794
# Solution:  752.7348710708261
# Solution:  743.5751717017006
# Solution:  743.2407252167285
# Solution:  739.3868836655904
# Solution:  738.794040348559
# Solution:  738.7374748811644
# Solution:  736.3738638807971
# Solution:  734.2598292000977
# Solution:  733.668312687772
# Solution:  732.1725065695633
# Solution:  724.7443966083431
# Solution:  724.6428196487118
# Solution:  724.2097082558577
# Solution:  721.2943035394424
# Solution:  721.2483889526277
# Solution:  720.7718850298378
# Solution:  714.3518566685062
# Solution:  713.7272829734624
# Iterasi ke- 5
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.47045
# a: 0.0795675
# b: 0.0795675
# Elite Solution: [774.751480733794, 3859, 48886269.76003823, 29]
# High-Quality Solution
# Solution:  774.751480733794
# Solution:  761.2767827994796
# Solution:  747.0836611770529
# Solution:  743.4872590741969
# Solution:  740.5643909294984
# Solution:  739.0629081505995
# Solution:  738.7941417061347
# Solution:  738.794040348559
# Solution:  736.3738638807971
# Solution:  734.2598292000977
# Solution:  733.384676879398
# Solution:  729.2826675907171
# Solution:  727.0875355591958
# Solution:  726.932227793918
# Solution:  724.6428196487118
# Solution:  724.3066547150632
# Solution:  721.2483889526277
# Solution:  714.072801628012
# Solution:  712.0777871326395
# Iterasi ke- 6
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4563365
# a: 0.081954525
# b: 0.081954525
# Elite Solution: [774.751480733794, 3859, 48886269.76003823, 29]
# High-Quality Solution
# Solution:  770.9424406119047
# Solution:  761.3451978674075
# Solution:  747.0836611770529
# Solution:  745.5862537629317
# Solution:  743.4872590741969
# Solution:  743.201159325335
# Solution:  740.9834437136655
# Solution:  738.7941417061347
# Solution:  737.6154543930891
# Solution:  734.2598292000977
# Solution:  732.948230877046
# Solution:  732.9164127269739
# Solution:  730.1428926319334
# Solution:  727.1317661104733
# Solution:  724.3066547150632
# Solution:  720.3115642187927
# Solution:  718.8029420345465
# Solution:  714.072801628012
# Solution:  709.5781167561339
# Iterasi ke- 7
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4563365
# a: 0.081954525
# b: 0.081954525
# Elite Solution: [777.431661059845, 3873, 49094721.76003823, 29]
# High-Quality Solution
# Solution:  770.9424406119047
# Solution:  763.8139614665344
# Solution:  761.3451978674075
# Solution:  746.6646083928858
# Solution:  744.5018375840003
# Solution:  743.201159325335
# Solution:  739.8480596676449
# Solution:  738.3916953737887
# Solution:  733.6838377097131
# Solution:  733.2593742558463
# Solution:  732.893161150745
# Solution:  731.5009107440853
# Solution:  727.615574706401
# Solution:  727.2148337552194
# Solution:  724.3058362525942
# Solution:  722.4295156570761
# Solution:  722.4020064478468
# Solution:  716.1702224033247
# Iterasi ke- 8
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.45533791643264016
# a: 0.07949588925
# b: 0.07949588925
# Elite Solution: [778.1545998295096, 3875, 49043481.76003823, 29]
# High-Quality Solution
# Solution:  768.7363793285409
# Solution:  763.8139614665344
# Solution:  760.8594243378207
# Solution:  745.811706283348
# Solution:  745.5175816165041
# Solution:  744.3397380973399
# Solution:  738.3916953737887
# Solution:  734.4556021241558
# Solution:  732.893161150745
# Solution:  731.4276406707519
# Solution:  731.3322691187541
# Solution:  731.2650882518534
# Solution:  729.4760207457516
# Solution:  727.2148337552194
# Solution:  726.6395093093527
# Solution:  726.5998306738971
# Solution:  725.5697763460523
# Solution:  722.0939743153019
# Iterasi ke- 9
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.45533791643264016
# a: 0.07949588925
# b: 0.07949588925
# Elite Solution: [778.1545998295096, 3875, 49043481.76003823, 29]
# High-Quality Solution
# Solution:  769.9149652840108
# Solution:  763.0445467260859
# Solution:  761.7979489552453
# Solution:  745.5831173754382
# Solution:  744.9239413412249
# Solution:  744.3397380973399
# Solution:  738.3916953737887
# Solution:  737.0135822767909
# Solution:  734.4556021241558
# Solution:  731.5072858282111
# Solution:  730.8341701248295
# Solution:  729.9370577629913
# Solution:  729.4760207457516
# Solution:  729.0315267881225
# Solution:  727.9436364968744
# Solution:  726.302777060601
# Solution:  722.8979216170782
# Solution:  721.1508061828043
# Iterasi ke- 10
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4416777789396609
# a: 0.0818807659275
# b: 0.0818807659275
# Elite Solution: [778.1545998295096, 3875, 49043481.76003823, 29]
# High-Quality Solution
# Solution:  769.9149652840108
# Solution:  761.7985995279771
# Solution:  755.9239853157172
# Solution:  745.5831173754382
# Solution:  744.9239413412249
# Solution:  744.4829171400753
# Solution:  738.348904477008
# Solution:  737.421722228037
# Solution:  737.0250676158444
# Solution:  734.4556021241558
# Solution:  733.2766788139149
# Solution:  731.9730119593328
# Solution:  731.5075088107591
# Solution:  730.4742461607718
# Solution:  730.2101127435923
# Solution:  727.4548245859602
# Solution:  722.8979216170782
# Solution:  721.591311078148
# Iterasi ke- 11
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4416777789396609
# a: 0.0818807659275
# b: 0.0818807659275
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  766.5227363539732
# Solution:  762.8513423670558
# Solution:  748.0984983406526
# Solution:  746.8758265383952
# Solution:  746.5144052050829
# Solution:  745.5191010186262
# Solution:  741.1159799108974
# Solution:  739.2775909144239
# Solution:  737.421722228037
# Solution:  736.3182348744695
# Solution:  735.3056951254584
# Solution:  733.2766788139149
# Solution:  731.9730119593328
# Solution:  730.4853259953735
# Solution:  730.4742461607718
# Solution:  729.1322625229545
# Solution:  725.2945557464346
# Solution:  723.6169849672177
# Iterasi ke- 12
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.4416777789396609
# a: 0.0818807659275
# b: 0.0818807659275
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  765.5376936876011
# Solution:  762.8513423670558
# Solution:  750.3311274454728
# Solution:  747.5578976896918
# Solution:  746.5144052050829
# Solution:  745.4240420608558
# Solution:  743.1579304456701
# Solution:  741.3211909130002
# Solution:  739.2802855447067
# Solution:  737.8174579082413
# Solution:  735.3056951254584
# Solution:  733.0737784525065
# Solution:  732.4524535296077
# Solution:  730.3731073954831
# Solution:  729.1476669243511
# Solution:  727.8636491530252
# Solution:  725.3323572202906
# Solution:  725.2945557464346
# Iterasi ke- 13
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.4284274455714711
# a: 0.084337188905325
# b: 0.084337188905325
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  766.0905965647878
# Solution:  758.0273766751317
# Solution:  750.3311274454728
# Solution:  749.9329298652167
# Solution:  748.3358251270587
# Solution:  746.3432224713628
# Solution:  743.1579304456701
# Solution:  742.611287180871
# Solution:  741.3211909130002
# Solution:  739.2802855447067
# Solution:  738.2600239144327
# Solution:  737.8174579082413
# Solution:  733.0737784525065
# Solution:  729.1476669243511
# Solution:  727.6001382388469
# Solution:  725.3323572202906
# Solution:  724.9489071887971
# Solution:  722.6227632995141
# Iterasi ke- 14
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.41557462220432695
# a: 0.08686730457248476
# b: 0.08686730457248476
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  766.0905965647878
# Solution:  758.0273766751317
# Solution:  749.9329298652167
# Solution:  748.3358251270587
# Solution:  747.2950432265145
# Solution:  746.3588236251964
# Solution:  742.611287180871
# Solution:  741.2562637543637
# Solution:  740.3349345560364
# Solution:  738.2600239144327
# Solution:  736.2938418594856
# Solution:  734.7086189359704
# Solution:  729.9521390401503
# Solution:  728.6361449344752
# Solution:  727.6001382388469
# Solution:  724.6490611082877
# Solution:  723.8013492549838
# Iterasi ke- 15
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.40310738353819714
# a: 0.08947332370965931
# b: 0.08947332370965931
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  759.4880924637758
# Solution:  758.0273766751317
# Solution:  748.9704461770427
# Solution:  747.8039939343282
# Solution:  746.3588236251964
# Solution:  745.4240420608558
# Solution:  742.611287180871
# Solution:  740.3353207024321
# Solution:  737.2593381217927
# Solution:  736.6142426340466
# Solution:  736.5974384995094
# Solution:  736.2938418594856
# Solution:  729.9521390401503
# Solution:  728.6361449344752
# Solution:  724.6490611082877
# Solution:  723.8013492549838
# Solution:  721.9409467527221
# Iterasi ke- 16
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.3910141620320512
# a: 0.09215752342094909
# b: 0.09215752342094909
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  759.4891711553377
# Solution:  758.5060513022383
# Solution:  749.7365901124789
# Solution:  747.8039939343282
# Solution:  745.6930204607929
# Solution:  743.0898864690545
# Solution:  741.954414386651
# Solution:  740.3353207024321
# Solution:  736.5974384995094
# Solution:  736.2944924322175
# Solution:  733.0335200688114
# Solution:  731.2815864634017
# Solution:  728.5565750630747
# Solution:  728.3754670010192
# Solution:  727.901904986464
# Solution:  724.6490611082877
# Iterasi ke- 17
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.37928373717108965
# a: 0.09492224912357757
# b: 0.09492224912357757
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  759.4891711553377
# Solution:  758.5060513022383
# Solution:  749.7365901124789
# Solution:  747.8039939343282
# Solution:  745.5211433422869
# Solution:  743.0898864690545
# Solution:  740.6855528084903
# Solution:  740.3353207024321
# Solution:  736.2944924322175
# Solution:  733.128089365803
# Solution:  733.0328694960796
# Solution:  731.5187183369904
# Solution:  729.749801162226
# Solution:  729.5998247312978
# Solution:  728.5573935255437
# Solution:  728.3754670010192
# Iterasi ke- 18
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.36790522505595696
# a: 0.0977699165972849
# b: 0.0977699165972849
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  759.4880924637758
# Solution:  758.5052328397693
# Solution:  749.4791477779268
# Solution:  748.8004159513757
# Solution:  747.8039939343282
# Solution:  740.6863712709594
# Solution:  737.9461830613023
# Solution:  736.5600784656765
# Solution:  736.3506656634886
# Solution:  736.2936739697484
# Solution:  733.3231439797237
# Solution:  733.128089365803
# Solution:  732.5091376193332
# Solution:  730.1309465898885
# Solution:  729.7649112385783
# Iterasi ke- 19
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.35686806830427825
# a: 0.10070301409520345
# b: 0.10070301409520345
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  759.4880924637758
# Solution:  757.4185749099288
# Solution:  749.4791477779268
# Solution:  747.7057526202032
# Solution:  746.6364131511349
# Solution:  740.6863712709594
# Solution:  739.7473769851875
# Solution:  739.7131990962507
# Solution:  738.749635870681
# Solution:  734.1896877012815
# Solution:  733.3231439797237
# Solution:  733.1276066828084
# Solution:  732.5091376193332
# Solution:  732.2106167047265
# Solution:  730.0233592833928
# Iterasi ke- 20
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3461620262551499
# a: 0.10372410451805955
# b: 0.10372410451805955
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  767.5918977627042
# Solution:  754.9098736408558
# Solution:  750.0589885634547
# Solution:  747.7057526202032
# Solution:  746.6364131511349
# Solution:  746.1827369887164
# Solution:  744.0885935732836
# Solution:  742.593143755627
# Solution:  739.9373318954747
# Solution:  734.286845492226
# Solution:  733.3231439797237
# Solution:  732.2106167047265
# Solution:  730.0233592833928
# Solution:  729.6252314387559
# Iterasi ke- 21
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.3357771654674954
# a: 0.10683582765360133
# b: 0.10683582765360133
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  767.5918977627042
# Solution:  757.8666553538842
# Solution:  755.9007654884581
# Solution:  750.0589885634547
# Solution:  749.229969086228
# Solution:  745.0096534607911
# Solution:  744.0988556748789
# Solution:  743.3693641201618
# Solution:  742.593143755627
# Solution:  740.9530759279785
# Solution:  735.5931358882759
# Solution:  734.286845492226
# Solution:  732.2081291560744
# Solution:  730.0233592833928
# Iterasi ke- 22
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.32570385050347056
# a: 0.11004090248320937
# b: 0.11004090248320937
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  763.2982466419294
# Solution:  761.6756954757734
# Solution:  755.9007654884581
# Solution:  749.229969086228
# Solution:  749.1806692586713
# Solution:  745.9993085805064
# Solution:  745.0096534607911
# Solution:  743.3693641201618
# Solution:  743.1613803683122
# Solution:  741.2637265060489
# Solution:  735.5931358882759
# Solution:  732.2081291560744
# Solution:  731.7474854109664
# Iterasi ke- 23
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.31593273498836644
# a: 0.11334212955770566
# b: 0.11334212955770566
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  763.3019276244186
# Solution:  761.6756954757734
# Solution:  749.6510898004332
# Solution:  749.1806692586713
# Solution:  746.1827369887164
# Solution:  746.0083116676662
# Solution:  744.7389414407231
# Solution:  741.7687895620177
# Solution:  741.2637265060489
# Solution:  737.7658802356102
# Solution:  732.8851122016821
# Solution:  730.1800702389501
# Solution:  729.974168372707
# Iterasi ke- 24
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.30645475293871544
# a: 0.11674239344443683
# b: 0.11674239344443683
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  763.5594285089203
# Solution:  762.5177590446631
# Solution:  749.0550351163953
# Solution:  748.4195118070252
# Solution:  746.3601625458509
# Solution:  746.0083116676662
# Solution:  745.8726881917532
# Solution:  745.4286266030622
# Solution:  741.2712015322768
# Solution:  737.7500356416576
# Solution:  736.9662372122937
# Solution:  730.9144001158285
# Solution:  730.1811489305119
# Iterasi ke- 25
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.29726111035055397
# a: 0.12024466524776994
# b: 0.12024466524776994
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  764.82910854955
# Solution:  762.5177590446631
# Solution:  749.4073946433622
# Solution:  749.0550351163953
# Solution:  748.6485542815487
# Solution:  748.6338202232149
# Solution:  745.8726881917532
# Solution:  744.9171727628669
# Solution:  742.0516518194916
# Solution:  741.945335537651
# Solution:  741.2712015322768
# Solution:  732.0483193238915
# Iterasi ke- 26
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.2883432770400373
# a: 0.12385200520520305
# b: 0.12385200520520305
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  770.4520782371387
# Solution:  756.7989156582967
# Solution:  752.0244122283143
# Solution:  750.6258282870465
# Solution:  749.4073946433622
# Solution:  748.9988395879335
# Solution:  748.6485542815487
# Solution:  744.9171727628669
# Solution:  743.5760442525527
# Solution:  742.0516518194916
# Solution:  736.8691410161626
# Solution:  735.6947622739073
# Iterasi ke- 27
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.2796929787288362
# a: 0.12756756536135916
# b: 0.12756756536135916
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  770.7060142452647
# Solution:  755.6417183373479
# Solution:  754.7872595685013
# Solution:  750.6258282870465
# Solution:  749.4374259201121
# Solution:  748.9988395879335
# Solution:  747.065776405605
# Solution:  746.9682731825903
# Solution:  746.5225260359302
# Solution:  743.6609282041895
# Solution:  739.4364867413244
# Solution:  735.6947622739073
# Iterasi ke- 28
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.2713021893669711
# a: 0.13139459232219994
# b: 0.13139459232219994
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  771.4488157875483
# Solution:  757.4417683484832
# Solution:  756.1265419260812
# Solution:  749.8594843534929
# Solution:  749.4374259201121
# Solution:  747.4597201271872
# Solution:  747.065776405605
# Solution:  746.9682731825903
# Solution:  744.9424840861057
# Solution:  742.9714092505619
# Solution:  739.4364867413244
# Iterasi ke- 29
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.26316312368596195
# a: 0.13533643009186594
# b: 0.13533643009186594
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  771.4488157875483
# Solution:  757.636574278391
# Solution:  757.4417683484832
# Solution:  749.8594843534929
# Solution:  747.4597201271872
# Solution:  747.1253298874055
# Solution:  747.0546746967296
# Solution:  744.9424840861057
# Solution:  743.1620942168829
# Solution:  742.5210286643418
# Solution:  741.3345220876002
# Iterasi ke- 30
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.25526822997538307
# a: 0.1393965229946219
# b: 0.1393965229946219
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  763.3228635275178
# Solution:  757.636574278391
# Solution:  757.225022697698
# Solution:  752.3166626726934
# Solution:  749.6646899686651
# Solution:  749.3701902775883
# Solution:  746.6272702439685
# Solution:  746.2928666723518
# Solution:  743.3959255347029
# Solution:  743.3691879945316
# Solution:  743.1620942168829
# Iterasi ke- 31
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.24761018307612156
# a: 0.14357841868446056
# b: 0.14357841868446056
# Elite Solution: [778.169420296065, 3875, 49039950.76003823, 29]
# High-Quality Solution
# Solution:  769.6109731093186
# Solution:  763.3086633649336
# Solution:  753.7118910182463
# Solution:  752.7237893543822
# Solution:  752.3166626726934
# Solution:  751.6599502617802
# Solution:  749.6646899686651
# Solution:  746.9848216553306
# Solution:  742.6020592293211
# Solution:  741.5884535284306
# Iterasi ke- 32
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.24761018307612156
# a: 0.14357841868446056
# b: 0.14357841868446056
# Elite Solution: [778.250813240682, 3875, 49020558.76003823, 29]
# High-Quality Solution
# Solution:  770.8558797082442
# Solution:  763.3086633649336
# Solution:  755.6492363826604
# Solution:  753.6922668647696
# Solution:  753.0792858503534
# Solution:  751.7963136155587
# Solution:  751.6599502617802
# Solution:  751.4541093137524
# Solution:  750.843275924135
# Solution:  749.5987918300932
# Iterasi ke- 33
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.24761018307612156
# a: 0.14357841868446056
# b: 0.14357841868446056
# Elite Solution: [778.250813240682, 3875, 49020558.76003823, 29]
# High-Quality Solution
# Solution:  773.485763208151
# Solution:  758.7091994067384
# Solution:  755.6492363826604
# Solution:  753.6922668647696
# Solution:  753.3056948664905
# Solution:  753.0792858503534
# Solution:  752.8691399472679
# Solution:  750.843275924135
# Solution:  750.195903490013
# Solution:  748.7941073887694
# Iterasi ke- 34
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.2401818775838379
# a: 0.14788577124499439
# b: 0.14788577124499439
# Elite Solution: [778.250813240682, 3875, 49020558.76003823, 29]
# High-Quality Solution
# Solution:  773.485763208151
# Solution:  758.7091994067384
# Solution:  757.5518795198963
# Solution:  753.2574168615718
# Solution:  752.8691399472679
# Solution:  752.3534495660185
# Solution:  751.9063943489755
# Solution:  750.8421972325732
# Solution:  750.2246676643863
# Solution:  747.2731121009406
# Iterasi ke- 35
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.23297642125632276
# a: 0.1523223443823442
# b: 0.1523223443823442
# Elite Solution: [778.250813240682, 3875, 49020558.76003823, 29]
# High-Quality Solution
# Solution:  772.7231897630367
# Solution:  761.5024954961241
# Solution:  761.1676956075117
# Solution:  757.588811900039
# Solution:  756.6970326699471
# Solution:  753.9914793729794
# Solution:  752.3534495660185
# Solution:  751.9063943489755
# Solution:  750.6358916486331
# Solution:  749.6636112771033
# Iterasi ke- 36
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.22598712861863307
# a: 0.15689201471381453
# b: 0.15689201471381453
# Elite Solution: [778.250813240682, 3875, 49020558.76003823, 29]
# High-Quality Solution
# Solution:  774.2943690800835
# Solution:  761.5168836466061
# Solution:  761.4307227391803
# Solution:  761.1676956075117
# Solution:  757.588811900039
# Solution:  753.9914793729794
# Solution:  751.6610012007992
# Solution:  751.3918542767495
# Solution:  748.9134274179997
# Iterasi ke- 37
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.21920751476007408
# a: 0.16159877515522897
# b: 0.16159877515522897
# Elite Solution: [778.250813240682, 3875, 49020558.76003823, 29]
# High-Quality Solution
# Solution:  774.2943690800835
# Solution:  761.5168836466061
# Solution:  761.4307227391803
# Solution:  758.8830899968472
# Solution:  757.7199495271518
# Solution:  757.588811900039
# Solution:  750.8748876163096
# Solution:  749.0186742379572
# Solution:  748.576840867524
# Iterasi ke- 38
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.21263128931727185
# a: 0.16644673840988583
# b: 0.16644673840988583
# Elite Solution: [778.250813240682, 3875, 49020558.76003823, 29]
# High-Quality Solution
# Solution:  768.8301122745747
# Solution:  761.5168836466061
# Solution:  760.2521367837105
# Solution:  759.8199147306822
# Solution:  757.7199495271518
# Solution:  757.588811900039
# Solution:  753.1594932269741
# Solution:  750.8809222057132
# Solution:  748.596874310421
# Iterasi ke- 39
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.21263128931727185
# a: 0.16644673840988583
# b: 0.16644673840988583
# Elite Solution: [778.6604864438893, 3883, 49406958.76003823, 29]
# High-Quality Solution
# Solution:  767.4198513906229
# Solution:  760.7567394645172
# Solution:  759.9540737386901
# Solution:  758.4696515490946
# Solution:  757.588811900039
# Solution:  753.1594932269741
# Solution:  751.5016135563125
# Solution:  751.2392981164074
# Solution:  750.1191141813352
# Iterasi ke- 40
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.21263128931727185
# a: 0.16644673840988583
# b: 0.16644673840988583
# Elite Solution: [778.6604864438893, 3883, 49406958.76003823, 29]
# High-Quality Solution
# Solution:  776.6896419387301
# Solution:  760.8432354641775
# Solution:  760.7567394645172
# Solution:  757.588811900039
# Solution:  757.5321762425277
# Solution:  756.942333478768
# Solution:  755.8008219859842
# Solution:  753.1594932269741
# Solution:  749.5305230419518
# Iterasi ke- 41
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.20625235063775368
# a: 0.1714401405621824
# b: 0.1714401405621824
# Elite Solution: [778.6604864438893, 3883, 49406958.76003823, 29]
# High-Quality Solution
# Solution:  778.0504160645198
# Solution:  763.9281801111056
# Solution:  760.8432354641775
# Solution:  759.0136669165888
# Solution:  756.942333478768
# Solution:  756.7376467198192
# Solution:  756.354408749527
# Solution:  756.1867430414788
# Solution:  750.2769145805651
# Iterasi ke- 42
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.20006478011862106
# a: 0.17658334477904788
# b: 0.17658334477904788
# Elite Solution: [778.6604864438893, 3883, 49406958.76003823, 29]
# High-Quality Solution
# Solution:  778.0504160645198
# Solution:  764.7307279969289
# Solution:  763.9281801111056
# Solution:  762.8397185189691
# Solution:  759.0136669165888
# Solution:  756.7376467198192
# Solution:  756.1867430414788
# Solution:  750.2769145805651
# Iterasi ke- 43
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.20006478011862106
# a: 0.17658334477904788
# b: 0.17658334477904788
# Elite Solution: [781.0970073476243, 3877, 48463449.76003823, 29]
# High-Quality Solution
# Solution:  781.0970073476243
# Solution:  764.7307279969289
# Solution:  763.1600899128262
# Solution:  760.6159884160568
# Solution:  760.3322719191362
# Solution:  759.3500380438115
# Solution:  757.5187284331681
# Solution:  753.8697446284447
# Iterasi ke- 44
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.20006478011862106
# a: 0.17658334477904788
# b: 0.17658334477904788
# Elite Solution: [781.0970073476243, 3877, 48463449.76003823, 29]
# High-Quality Solution
# Solution:  781.0970073476243
# Solution:  766.0718729790291
# Solution:  760.6979483585892
# Solution:  760.590455220427
# Solution:  759.3500380438115
# Solution:  758.5127109637256
# Solution:  757.5187284331681
# Solution:  753.8697446284447
# Iterasi ke- 45
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.20006478011862106
# a: 0.17658334477904788
# b: 0.17658334477904788
# Elite Solution: [783.9857347442014, 3889, 48501213.76003823, 29]
# High-Quality Solution
# Solution:  783.9857347442014
# Solution:  766.0718729790291
# Solution:  760.6979483585892
# Solution:  760.590455220427
# Solution:  760.2181641896495
# Solution:  760.1471851239894
# Solution:  759.0029660497819
# Solution:  753.4671913139348
# Iterasi ke- 46
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.20006478011862106
# a: 0.17658334477904788
# b: 0.17658334477904788
# Elite Solution: [783.9857347442014, 3889, 48501213.76003823, 29]
# High-Quality Solution
# Solution:  783.9857347442014
# Solution:  765.3005791316322
# Solution:  762.502769800314
# Solution:  761.5423261310415
# Solution:  760.6979483585892
# Solution:  760.1471851239894
# Solution:  753.1750850982643
# Solution:  751.7505631863775
# Iterasi ke- 47
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.19406283671506241
# a: 0.18188084512241934
# b: 0.18188084512241934
# Elite Solution: [783.9857347442014, 3889, 48501213.76003823, 29]
# High-Quality Solution
# Solution:  773.0606914183097
# Solution:  772.2162952815872
# Solution:  763.5824634566519
# Solution:  762.5038484918758
# Solution:  760.6979483585892
# Solution:  756.368765055952
# Solution:  756.3534355599197
# Solution:  754.945468897741
# Iterasi ke- 48
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.18824095161361054
# a: 0.18733727047609192
# b: 0.18733727047609192
# Elite Solution: [783.9857347442014, 3889, 48501213.76003823, 29]
# High-Quality Solution
# Solution:  775.1376480628132
# Solution:  773.4001644141573
# Solution:  771.8607923893426
# Solution:  768.1450937174685
# Solution:  762.5038484918758
# Solution:  756.7300931512103
# Solution:  756.3534355599197
# Solution:  755.8177185656059
# Iterasi ke- 49
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.18259372306520222
# a: 0.19295738859037467
# b: 0.19295738859037467
# Elite Solution: [783.9857347442014, 3889, 48501213.76003823, 29]
# High-Quality Solution
# Solution:  775.1376480628132
# Solution:  774.2440301757756
# Solution:  771.8607923893426
# Solution:  768.1450937174685
# Solution:  762.7325311029791
# Solution:  761.4845227940225
# Solution:  756.3534355599197
# Solution:  755.8869185180554
# Iterasi ke- 50
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.18259372306520222
# a: 0.19295738859037467
# b: 0.19295738859037467
# Elite Solution: [787.5633220743229, 3904, 48556357.76003823, 29]
# High-Quality Solution
# Solution:  779.846933265437
# Solution:  770.9239676555076
# Solution:  768.1442752549995
# Solution:  768.0541175145349
# Solution:  762.7325311029791
# Solution:  761.4845227940225
# Solution:  756.3534355599197
# Iterasi ke- 51
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.18259372306520222
# a: 0.19295738859037467
# b: 0.19295738859037467
# Elite Solution: [787.5633220743229, 3904, 48556357.76003823, 29]
# High-Quality Solution
# Solution:  779.846933265437
# Solution:  769.9072054267405
# Solution:  769.3347484275997
# Solution:  768.0541175145349
# Solution:  762.5954575270043
# Solution:  758.6187480178277
# Solution:  757.6020348450083
# Iterasi ke- 52
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.17711591137324614
# a: 0.19874611024808592
# b: 0.19874611024808592
# Elite Solution: [787.5633220743229, 3904, 48556357.76003823, 29]
# High-Quality Solution
# Solution:  769.9827467267744
# Solution:  769.9072054267405
# Solution:  768.0541175145349
# Solution:  762.5954575270043
# Solution:  758.7403022915369
# Solution:  758.6187480178277
# Solution:  756.4119246757791
# Iterasi ke- 53
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.17711591137324614
# a: 0.19874611024808592
# b: 0.19874611024808592
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  769.9827467267744
# Solution:  768.0470871317877
# Solution:  765.4754358278346
# Solution:  760.8026526874938
# Solution:  760.0789248889289
# Solution:  756.9018898877157
# Solution:  755.46434886681
# Iterasi ke- 54
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.17711591137324614
# a: 0.19874611024808592
# b: 0.19874611024808592
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  771.0973792840837
# Solution:  766.8080165937158
# Solution:  765.4754358278346
# Solution:  760.8026526874938
# Solution:  760.0789248889289
# Solution:  759.2553037433524
# Solution:  758.4326082538676
# Iterasi ke- 55
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.17180243403204876
# a: 0.2047084935555285
# b: 0.2047084935555285
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  771.3893101564511
# Solution:  769.1374725838476
# Solution:  765.1544371522223
# Solution:  763.2065173034441
# Solution:  760.2453581827046
# Solution:  759.4324755840387
# Solution:  758.6584702645207
# Iterasi ke- 56
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.1666483610110873
# a: 0.21084974836219436
# b: 0.21084974836219436
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  771.3893101564511
# Solution:  769.1374725838476
# Solution:  765.1552556146913
# Solution:  765.1397675221073
# Solution:  763.7031561324361
# Solution:  759.4324755840387
# Solution:  758.4855690186175
# Iterasi ke- 57
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.16164891018075467
# a: 0.2171752408130602
# b: 0.2171752408130602
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  779.1355096278047
# Solution:  771.742103733382
# Solution:  768.5855686505975
# Solution:  765.1552556146913
# Solution:  763.7031561324361
# Solution:  757.9660678575204
# Solution:  753.6475256136316
# Iterasi ke- 58
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.156799442875332
# a: 0.223690498037452
# b: 0.223690498037452
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  780.2243417297426
# Solution:  771.742103733382
# Solution:  768.2209709027063
# Solution:  763.1237675496837
# Solution:  760.6552734621928
# Solution:  756.5975885337123
# Iterasi ke- 59
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.15209545958907206
# a: 0.23040121297857558
# b: 0.23040121297857558
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  780.2243417297426
# Solution:  770.8982815194947
# Solution:  767.1343939785997
# Solution:  762.9264803194455
# Solution:  761.8330409551936
# Solution:  761.7662936096106
# Iterasi ke- 60
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.14753259580139988
# a: 0.23731324936793285
# b: 0.23731324936793285
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  781.2592769230517
# Solution:  766.7838824439867
# Solution:  766.7563860908106
# Solution:  762.4186083031934
# Solution:  761.8330409551936
# Solution:  761.7662936096106
# Iterasi ke- 61
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.14310661792735788
# a: 0.24443264684897084
# b: 0.24443264684897084
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  781.5833125104242
# Solution:  766.0739982537724
# Solution:  763.9422243519493
# Solution:  763.6931792848003
# Solution:  761.8319622636318
# Solution:  761.7654751471414
# Iterasi ke- 62
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.13881341938953715
# a: 0.25176562625444
# b: 0.25176562625444
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  781.5833125104242
# Solution:  767.0474062142181
# Solution:  766.5373069841363
# Solution:  763.9422243519493
# Solution:  758.3829110520231
# Solution:  757.55821588791
# Iterasi ke- 63
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.13464901680785102
# a: 0.2593185950420732
# b: 0.2593185950420732
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  779.5518244454166
# Solution:  770.8636503282672
# Solution:  767.0474062142181
# Solution:  762.533465763958
# Solution:  762.0155696308775
# Solution:  760.8197886157205
# Iterasi ke- 64
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.1306095463036155
# a: 0.26709815289333544
# b: 0.26709815289333544
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  782.0759105992363
# Solution:  771.3158991107314
# Solution:  770.8636503282672
# Solution:  768.8110304006925
# Solution:  762.0155696308775
# Iterasi ke- 65
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.12669125991450703
# a: 0.2751110974801355
# b: 0.2751110974801355
# Elite Solution: [788.1139962152477, 3904, 48425158.76003823, 29]
# High-Quality Solution
# Solution:  782.0767290617054
# Solution:  773.0399000611068
# Solution:  768.8110304006925
# Solution:  767.6535763077896
# Solution:  761.6503559348523
# Iterasi ke- 66
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.12669125991450703
# a: 0.2751110974801355
# b: 0.2751110974801355
# Elite Solution: [788.6132709131145, 3904, 48306205.76003823, 29]
# High-Quality Solution
# Solution:  782.0767290617054
# Solution:  773.0399000611068
# Solution:  764.6871239873021
# Solution:  762.5175859638969
# Solution:  761.6503559348523
# Iterasi ke- 67
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.12669125991450703
# a: 0.2751110974801355
# b: 0.2751110974801355
# Elite Solution: [788.6132709131145, 3904, 48306205.76003823, 29]
# High-Quality Solution
# Solution:  782.1680233035765
# Solution:  773.0399000611068
# Solution:  764.6871239873021
# Solution:  757.6936202719727
# Solution:  757.6672494672764
# Iterasi ke- 68
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.12289052211707181
# a: 0.28336443040453957
# b: 0.28336443040453957
# Elite Solution: [788.6132709131145, 3904, 48306205.76003823, 29]
# High-Quality Solution
# Solution:  782.1680233035765
# Solution:  767.4533078823358
# Solution:  761.5969304813259
# Solution:  761.578083071565
# Solution:  758.4709106692593
# Iterasi ke- 69
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.12289052211707181
# a: 0.28336443040453957
# b: 0.28336443040453957
# Elite Solution: [792.8434764493193, 3918, 48145361.76003823, 28]
# High-Quality Solution
# Solution:  792.8434764493193
# Solution:  777.9773968848709
# Solution:  761.5969304813259
# Solution:  761.578083071565
# Solution:  758.4709106692593
# Iterasi ke- 70
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.12289052211707181
# a: 0.28336443040453957
# b: 0.28336443040453957
# Elite Solution: [792.8434764493193, 3918, 48145361.76003823, 28]
# High-Quality Solution
# Solution:  768.7202062500857
# Solution:  777.9773968848709
# Solution:  761.17170596256
# Solution:  759.5718948375808
# Solution:  758.7514668533346
# Iterasi ke- 71
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.12289052211707181
# a: 0.28336443040453957
# b: 0.28336443040453957
# Elite Solution: [794.0278420089938, 3918, 47863184.76003823, 28]
# High-Quality Solution
# Solution:  771.376139365158
# Solution:  768.7202062500857
# Solution:  766.303942659852
# Solution:  758.3135750538935
# Solution:  751.9722577572204
# Iterasi ke- 72
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.12289052211707181
# a: 0.28336443040453957
# b: 0.28336443040453957
# Elite Solution: [794.0278420089938, 3918, 47863184.76003823, 28]
# High-Quality Solution
# Solution:  771.376139365158
# Solution:  766.303942659852
# Solution:  765.93389542042
# Solution:  760.9949226893999
# Solution:  760.1150295769237
# Iterasi ke- 73
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.11920380645355966
# a: 0.2918653633166758
# b: 0.2918653633166758
# Elite Solution: [794.0278420089938, 3918, 47863184.76003823, 28]
# High-Quality Solution
# Solution:  767.1124813758897
# Solution:  766.8135091043414
# Solution:  764.9330922635577
# Solution:  762.5784080598637
# Solution:  760.1150295769237
# Iterasi ke- 74
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.11920380645355966
# a: 0.2918653633166758
# b: 0.2918653633166758
# Elite Solution: [796.3957626374438, 3942, 48751039.76003823, 28]
# High-Quality Solution
# Solution:  768.8211623877414
# Solution:  766.8135091043414
# Solution:  766.1108597565585
# Solution:  762.5784080598637
# Solution:  756.7685374270446
# Iterasi ke- 75
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.11920380645355966
# a: 0.2918653633166758
# b: 0.2918653633166758
# Elite Solution: [796.3957626374438, 3942, 48751039.76003823, 28]
# High-Quality Solution
# Solution:  768.8211623877414
# Solution:  766.1108597565585
# Solution:  764.3710336760156
# Solution:  761.031333511842
# Solution:  756.8606272633253
# Iterasi ke- 76
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.11920380645355966
# a: 0.2918653633166758
# b: 0.2918653633166758
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  767.3846405040204
# Solution:  766.4386601126947
# Solution:  764.3710336760156
# Solution:  763.3175636671731
# Solution:  756.9694360733887
# Iterasi ke- 77
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.11920380645355966
# a: 0.2918653633166758
# b: 0.2918653633166758
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  773.7016454320334
# Solution:  766.4386601126947
# Solution:  764.2097592173337
# Solution:  759.8042890171215
# Solution:  755.5965999051698
# Iterasi ke- 78
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.11562769225995287
# a: 0.30062132421617604
# b: 0.30062132421617604
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  773.7016454320334
# Solution:  765.7956953656865
# Solution:  764.276873139798
# Solution:  762.61219870289
# Solution:  760.8496180018687
# Iterasi ke- 79
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.11215886149215427
# a: 0.30963996394266136
# b: 0.30963996394266136
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  776.3700763098826
# Solution:  771.0350885758326
# Solution:  765.0394996266449
# Solution:  764.5596463142385
# Solution:  763.7286234831445
# Iterasi ke- 80
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.10879409564738965
# a: 0.3189291628609412
# b: 0.3189291628609412
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  790.2479755094919
# Solution:  778.1452968033593
# Solution:  765.0394996266449
# Solution:  764.3681428854485
# Iterasi ke- 81
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.10553027277796796
# a: 0.3284970377467694
# b: 0.3284970377467694
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  792.9655572602996
# Solution:  778.5742495209424
# Solution:  771.5678454140125
# Solution:  766.888193278659
# Iterasi ke- 82
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.10236436459462891
# a: 0.3383519488791725
# b: 0.3383519488791725
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  795.9338700591422
# Solution:  778.5742495209424
# Solution:  773.5816235750937
# Solution:  771.5678454140125
# Iterasi ke- 83
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.09929343365679004
# a: 0.3485025073455477
# b: 0.3485025073455477
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  795.9338700591422
# Solution:  778.2108857626199
# Solution:  773.5822741478255
# Solution:  771.5171007409298
# Iterasi ke- 84
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.09631463064708634
# a: 0.35895758256591415
# b: 0.35895758256591415
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  794.0471881506185
# Solution:  774.7687306219688
# Solution:  773.5822741478255
# Solution:  771.5171007409298
# Iterasi ke- 85
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.09342519172767375
# a: 0.3697263100428916
# b: 0.3697263100428916
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  790.7127342764107
# Solution:  775.8056511114207
# Solution:  773.5822741478255
# Solution:  771.5171007409298
# Iterasi ke- 86
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.09062243597584353
# a: 0.3808180993441783
# b: 0.3808180993441783
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  791.3826297531597
# Solution:  775.8056511114207
# Solution:  773.5822741478255
# Solution:  766.9186398710501
# Iterasi ke- 87
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.08790376289656822
# a: 0.3922426423245037
# b: 0.3922426423245037
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  791.3826297531597
# Solution:  775.8048326489517
# Solution:  773.9224368554338
# Solution:  773.7589613073036
# Iterasi ke- 88
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.08526665000967117
# a: 0.4040099215942388
# b: 0.4040099215942388
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  791.3834482156287
# Solution:  777.8814615384154
# Solution:  775.8048326489517
# Solution:  775.3608460819962
# Iterasi ke- 89
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.08270865050938103
# a: 0.416130219242066
# b: 0.416130219242066
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  794.2833530829215
# Solution:  777.8814615384154
# Solution:  775.8048326489517
# Iterasi ke- 90
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.0802273909940996
# a: 0.428614125819328
# b: 0.428614125819328
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  794.2833530829215
# Solution:  779.5874825974466
# Solution:  775.8048326489517
# Iterasi ke- 91
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.0778205692642766
# a: 0.44147254959390786
# b: 0.44147254959390786
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  789.3896065907933
# Solution:  779.5874825974466
# Solution:  775.38987217713
# Iterasi ke- 92
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.0754859521863483
# a: 0.4547167260817251
# b: 0.4547167260817251
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  789.3896065907933
# Solution:  779.9127479771444
# Solution:  774.4139340612228
# Iterasi ke- 93
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.07322137362075785
# a: 0.46835822786417686
# b: 0.46835822786417686
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  787.5054457560043
# Solution:  779.9127479771444
# Solution:  776.5167040700155
# Iterasi ke- 94
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.07102473241213511
# a: 0.4824089747001022
# b: 0.4824089747001022
# Elite Solution: [797.4654719925802, 3948, 48859183.76003823, 28]
# High-Quality Solution
# Solution:  788.0124993097871
# Solution:  779.5639361675269
# Solution:  774.5079106588341
# Iterasi ke- 95
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.07102473241213511
# a: 0.4824089747001022
# b: 0.4824089747001022
# Elite Solution: [797.4686828838051, 3948, 48858418.76003823, 28]
# High-Quality Solution
# Solution:  788.0124993097871
# Solution:  779.5639361675269
# Solution:  774.5079106588341
# Iterasi ke- 96
# Rao3 High-Quality solution...
# Solution Mutation...
# Random Walk Low-Quality Solution...
# s: 0.07102473241213511
# a: 0.4824089747001022
# b: 0.4824089747001022
# Elite Solution: [797.4686828838051, 3948, 48858418.76003823, 28]
# High-Quality Solution
# Solution:  788.0116808473181
# Solution:  779.5631177050578
# Solution:  772.4588095965513
# Iterasi ke- 97
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.06889399043977106
# a: 0.4968812439411053
# b: 0.4968812439411053
# Elite Solution: [797.4686828838051, 3948, 48858418.76003823, 28]
# High-Quality Solution
# Solution:  791.4233556061722
# Solution:  777.4643868611486
# Solution:  763.3238498797241
# Iterasi ke- 98
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.06682717072657793
# a: 0.5117876812593385
# b: 0.5117876812593385
# Elite Solution: [797.4686828838051, 3948, 48858418.76003823, 28]
# High-Quality Solution
# Solution:  791.4241740686413
# Solution:  777.4643868611486
# Solution:  760.9058222420051
# Iterasi ke- 99
# Rao3 High-Quality solution...
# Solution Crossover...
# Random Walk Low-Quality Solution...
# s: 0.06482235560478058
# a: 0.5271413116971186
# b: 0.5271413116971186
# Elite Solution: [797.4686828838051, 3948, 48858418.76003823, 28]
# High-Quality Solution
# Solution:  794.324078935934
# Solution:  774.1125144267015
# Solution:  764.3659874898965
# Final Elite Solutions
# Solution:  [794.324078935934, 3936, 48881617.76003823, 29]
# Solution:  [772.0321886538317, 3870, 50199652.76003823, 30]
# Solution:  [764.3659874898965, 3813, 48577599.76003823, 28]
# Solution:  [762.2866914055053, 3806, 48649490.76003823, 27]
# Solution:  [759.39288088281, 3809, 49520447.76003823, 30]
# Solution:  [758.365202617664, 3809, 49765293.76003823, 30]
# Solution:  [757.4101369282002, 3794, 49085329.76003823, 29]
# Solution:  [756.8234413146866, 3756, 46926085.76003823, 28]
# Solution:  [754.4848421002006, 3762, 47846264.76003823, 28]
# Solution:  [753.0134228650256, 3762, 48196832.76003823, 29]
# Solution:  [752.9608660822954, 3779, 49237865.76003823, 29]
# Solution:  [752.9236312891674, 3759, 48036723.76003823, 29]
# Solution:  [749.1094415196402, 3723, 46767436.76003823, 27]
# Solution:  [742.5748375788103, 3779, 51712353.76003823, 32]
# Solution:  [741.340018013142, 3719, 48376511.76003823, 28]
# Solution:  [741.3148968239666, 3758, 50742022.76003823, 31]
# Solution:  [740.1212433460896, 3725, 49029890.76003823, 30]
# Solution:  [739.8104785015255, 3699, 47530913.76003823, 29]
# Solution:  [736.1242652532968, 3676, 47017644.76003823, 27]
# Solution:  [736.1160224380667, 3723, 49863139.76003823, 30]
# Solution:  [732.5768235192837, 3684, 48346833.76003823, 29]
# Solution:  [730.9605153351358, 3690, 49094925.76003823, 30]
# Solution:  [729.999706082768, 3694, 49565842.76003823, 31]
# Solution:  [728.6286184418113, 3655, 47532980.76003823, 29]
# Solution:  [728.0234919922867, 3659, 47919155.76003823, 28]
# Final Elite Solution
# Solution:  [797.4686828838051, 3948, 48858418.76003823, 28]

# %%
print(result)
# Out:
# [[0, 11, Timestamp('2020-11-20 16:06:59+0000', tz='UTC'), Timestamp('2020-11-21 05:40:59+0000', tz='UTC'), 35, 0.133], [1, 15, Timestamp('2020-11-20 16:08:35+0000', tz='UTC'), Timestamp('2020-11-21 05:29:37+0000', tz='UTC'), 35, 0.133], [2, 6, Timestamp('2020-11-20 16:13:20+0000', tz='UTC'), Timestamp('2020-11-21 05:09:18+0000', tz='UTC'), 47, 0.133], [3, 41, Timestamp('2020-11-20 16:44:59+0000', tz='UTC'), Timestamp('2020-11-21 05:14:59+0000', tz='UTC'), 35, 0.133], [4, 12, Timestamp('2020-11-21 07:39:50+0000', tz='UTC'), Timestamp('2020-11-21 21:00:52+0000', tz='UTC'), 29, 0.133], [5, 1, Timestamp('2020-11-20 17:54:12+0000', tz='UTC'), Timestamp('2020-11-21 00:57:39+0000', tz='UTC'), 81, 0.171], [6, 39, Timestamp('2020-11-20 18:54:04+0000', tz='UTC'), Timestamp('2020-11-21 08:15:06+0000', tz='UTC'), 63, 0.133], [7, 16, Timestamp('2020-11-20 20:02:05+0000', tz='UTC'), Timestamp('2020-11-21 04:34:48+0000', tz='UTC'), 53, 0.128], [8, 25, Timestamp('2020-11-20 21:01:38+0000', tz='UTC'), Timestamp('2020-11-21 09:16:45+0000', tz='UTC'), 60, 0.171], [9, 14, Timestamp('2020-11-20 21:26:06+0000', tz='UTC'), Timestamp('2020-11-21 06:41:53+0000', tz='UTC'), 55, 0.133], [10, 21, Timestamp('2020-11-20 22:21:21+0000', tz='UTC'), Timestamp('2020-11-21 05:10:47+0000', tz='UTC'), 49, 0.14], [11, 3, Timestamp('2020-11-20 23:21:25+0000', tz='UTC'), Timestamp('2020-11-21 09:35:51+0000', tz='UTC'), 60, 0.171], [12, 20, Timestamp('2020-11-21 01:42:22+0000', tz='UTC'), Timestamp('2020-11-21 15:31:21+0000', tz='UTC'), 47, 0.133], [13, 18, Timestamp('2020-11-21 03:37:03+0000', tz='UTC'), Timestamp('2020-11-21 10:06:51+0000', tz='UTC'), 71, 0.171], [14, 7, Timestamp('2020-11-21 03:07:03+0000', tz='UTC'), Timestamp('2020-11-21 06:16:27+0000', tz='UTC'), 53, 0.128], [15, 39, Timestamp('2020-11-21 09:44:54+0000', tz='UTC'), Timestamp('2020-11-21 17:29:58+0000', tz='UTC'), 60, 0.171], [16, 1, Timestamp('2020-11-21 05:09:13+0000', tz='UTC'), Timestamp('2020-11-21 12:51:55+0000', tz='UTC'), 81, 0.171], [17, 16, Timestamp('2020-11-21 06:32:16+0000', tz='UTC'), Timestamp('2020-11-21 11:06:39+0000', tz='UTC'), 71, 0.171], [18, 21, Timestamp('2020-11-21 06:32:24+0000', tz='UTC'), Timestamp('2020-11-21 14:17:22+0000', tz='UTC'), 47, 0.133], [19, 31, Timestamp('2020-11-21 07:55:25+0000', tz='UTC'), Timestamp('2020-11-21 18:15:52+0000', tz='UTC'), 60, 0.171], [20, 15, Timestamp('2020-11-21 09:24:06+0000', tz='UTC'), Timestamp('2020-11-21 16:09:35+0000', tz='UTC'), 37, 0.14], [21, 14, Timestamp('2020-11-21 09:31:00+0000', tz='UTC'), Timestamp('2020-11-21 21:03:58+0000', tz='UTC'), 71, 0.171], [22, 13, Timestamp('2020-11-21 10:27:44+0000', tz='UTC'), Timestamp('2020-11-21 11:38:48+0000', tz='UTC'), 47, 0.133], [23, 4, Timestamp('2020-11-21 10:33:18+0000', tz='UTC'), Timestamp('2020-11-21 22:31:29+0000', tz='UTC'), 60, 0.171], [24, 6, Timestamp('2020-11-21 10:38:05+0000', tz='UTC'), Timestamp('2020-11-21 10:50:28+0000', tz='UTC'), 47, 0.133], [25, 6, Timestamp('2020-11-21 11:20:28+0000', tz='UTC'), Timestamp('2020-11-21 22:57:06+0000', tz='UTC'), 60, 0.171], [26, 11, Timestamp('2020-11-21 11:06:23+0000', tz='UTC'), Timestamp('2020-11-21 22:54:41+0000', tz='UTC'), 45, 0.171], [27, 33, Timestamp('2020-11-21 12:02:34+0000', tz='UTC'), Timestamp('2020-11-21 22:48:44+0000', tz='UTC'), 60, 0.171], [28, 18, Timestamp('2020-11-21 11:43:39+0000', tz='UTC'), Timestamp('2020-11-21 14:38:28+0000', tz='UTC'), 71, 0.171], [29, 16, Timestamp('2020-11-21 12:28:41+0000', tz='UTC'), Timestamp('2020-11-21 15:55:19+0000', tz='UTC'), 53, 0.128], [30, 13, Timestamp('2020-11-21 12:50:57+0000', tz='UTC'), Timestamp('2020-11-22 00:58:16+0000', tz='UTC'), 60, 0.171], [31, 19, Timestamp('2020-11-21 12:55:20+0000', tz='UTC'), Timestamp('2020-11-21 21:22:54+0000', tz='UTC'), 71, 0.171], [32, 7, Timestamp('2020-11-21 13:10:08+0000', tz='UTC'), Timestamp('2020-11-21 22:01:52+0000', tz='UTC'), 47, 0.113], [33, 0, Timestamp('2020-11-21 13:42:36+0000', tz='UTC'), Timestamp('2020-11-22 01:30:22+0000' ...

# %%
def printResult(result):
    fitness = countFitness(result)
    originalschedule = createOriginalSchedule()
    original_fitness = countFitness(originalschedule)
    print("------------------------------------------------------------------------------------------------------------------")
    print("Airplane \tPassenger \tCost \t\tRouting")
    print("------------------------------------------------------------------------------------------------------------------")
    for i in range(len(airplanes)):
        flight_list = []
        airplanefitness = countAirplaneFitness(result, i)
        print(airplanes["airplane"].iloc[i], end="\t\t")
        print(airplanefitness[1], end="\t\t")
        print(airplanefitness[2], end="\t\t")
        
        for j in range(len(result)):
            if(result[j][1]==i):
                flight_list.append(result[j])
                
        for k in range(len(flight_list)):
            print("Flight-", flight_list[k][0], end=", ")     
            
        print("\n")
    
    print("------------------------------------------------------------------------------------------------------------------")
    print('Result\t\t%d\t\t%d\t\t%d' % (fitness[1], fitness[2], fitness[3]))
    print("------------------------------------------------------------------------------------------------------------------")
    print('Original\t%d\t\t%d\t\t%d' % (original_fitness[1], original_fitness[2], original_fitness[3]))
    print("------------------------------------------------------------------------------------------------------------------")
    print('Difference\t%d\t\t%d\t\t\t%d' % (fitness[1] - original_fitness[1], original_fitness[2] - fitness[2], original_fitness[3] - fitness[3]))
    print("------------------------------------------------------------------------------------------------------------------")

# %%
printResult(result)
# Out:
# ------------------------------------------------------------------------------------------------------------------
# Airplane 	Passenger 	Cost 		Routing
# ------------------------------------------------------------------------------------------------------------------
# 9V-SMG		145		1763273.9076547145		Flight- 33, Flight- 58, Flight- 65,
#
# 9V-SMI		531		2140657.4358901377		Flight- 5, Flight- 16, Flight- 34, Flight- 45, Flight- 51, Flight- 57, Flight- 59,
#
# 9V-SMT		165		1480060.8257771134		Flight- 55, Flight- 62, Flight- 67,
#
# 9V-SMD		167		1796917.368168572		Flight- 11, Flight- 36, Flight- 64,
#
# 9V-SMH		60		1301061.7855521704		Flight- 23,
#
# 9V-SFN		126		2053783.1926708242		Flight- 35, Flight- 66,
#
# 9V-SMC		154		1869335.1926708242		Flight- 2, Flight- 24, Flight- 25,
#
# 9V-SFM		202		2199174.1727986056		Flight- 14, Flight- 32, Flight- 49, Flight- 61,
#
# 9V-SMS		47		1234070.7968215346		Flight- 40,
#
# 9V-SFK		0		99459
#
# 9V-SML		0		131820
#
# 9V-SWQ		80		1803536.5210252982		Flight- 0, Flight- 26,
#
# 9V-MGL		29		937736.9549124112		Flight- 4,
#
# 9V-SMF		107		1320101.1935690492		Flight- 22, Flight- 30,
#
# 9V-SFQ		292		2429529.7597962418		Flight- 9, Flight- 21, Flight- 47, Flight- 56, Flight- 63,
#
# 9V-SWE		152		2139459.8101972705		Flight- 1, Flight- 20, Flight- 42, Flight- 52,
#
# 9V-SFI		248		1831670.81654011		Flight- 7, Flight- 17, Flight- 29, Flight- 39,
#
# 9V-SMO		49		1226521.4819316021		Flight- 41,
#
# 9V-SFP		284		1786239.9970865196		Flight- 13, Flight- 28, Flight- 44, Flight- 50,
#
# 9V-SFO		213		2127681.01393193		Flight- 31, Flight- 54, Flight- 69,
#
# 9V-SMQ		156		2092267.3855893724		Flight- 12, Flight- 48, Flight- 60,
#
# 9V-SMN		203		1738330.3947240326		Flight- 10, Flight- 18, Flight- 43, Flight- 46,
#
# 9V-SMJ		0		234390
#
# 9V-SMM		0		237900
#
# 9V-SMB		120		1293173.8549887636		Flight- 53, Flight- 68,
#
# 9V-SMP		60		1179593.760512649		Flight- 8,
#
# 9V-SMA		0		218400
#
# 9V-SWY		0		170190
#
# 9V-SWR		0		172670
#
# 9V-SCB		0		216000
#
# 9V-SWP		0		170190
#
# 9V-SMK		60		1324557.7363326042		Flight- 19,
#
# 9V-MGI		0		46184
#
# 9V-SMR		60		1279422.6027265186		Flight- 27,
#
# 9V-SWM		0		102145
#
# 9V-SWH		0		172050
#
# 9V-SWO		45		1218166.7363326042		Flight- 37,
#
# 9V-MGF		0		63388
#
# 9V-SWS		35		1351137.7855521704		Flight- 38,
#
# 9V-SKU		123		2296756.6735580675		Flight- 6, Flight- 15,
#
# 9V-SME		0		145860
#
# 9V-SWK		35		1347613.6027265186		Flight- 3,
#
# 9V-SWN		0		115940
#
# ------------------------------------------------------------------------------------------------------------------
# Result		3948		48858418		28
# ------------------------------------------------------------------------------------------------------------------
# Original	3938		47650321		29
# ------------------------------------------------------------------------------------------------------------------
# Difference	10		-1208097			1
# ------------------------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np
    
for i in range(len(y_plot_list)):
    plt.plot(x_plot_list, y_plot_list[i])

plt.show()

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 12650.187151432037 seconds ---

# %%
import pickle

with open('dera_output-2-40', 'wb') as fp:
    pickle.dump(result, fp)
with open('dera_xplot-2-40', 'wb') as fp:
    pickle.dump(x_plot_list, fp)
with open('dera_yplot-2-40', 'wb') as fp:
    pickle.dump(y_plot_list, fp)

# %%
with open('dera_output-2-40', 'rb') as fp:
    read_result = pickle.load(fp)
    
print(read_result)
# Out:
# [[0, 11, Timestamp('2020-11-20 16:06:59+0000', tz='UTC'), Timestamp('2020-11-21 05:40:59+0000', tz='UTC'), 35, 0.133], [1, 15, Timestamp('2020-11-20 16:08:35+0000', tz='UTC'), Timestamp('2020-11-21 05:29:37+0000', tz='UTC'), 35, 0.133], [2, 6, Timestamp('2020-11-20 16:13:20+0000', tz='UTC'), Timestamp('2020-11-21 05:09:18+0000', tz='UTC'), 47, 0.133], [3, 41, Timestamp('2020-11-20 16:44:59+0000', tz='UTC'), Timestamp('2020-11-21 05:14:59+0000', tz='UTC'), 35, 0.133], [4, 12, Timestamp('2020-11-21 07:39:50+0000', tz='UTC'), Timestamp('2020-11-21 21:00:52+0000', tz='UTC'), 29, 0.133], [5, 1, Timestamp('2020-11-20 17:54:12+0000', tz='UTC'), Timestamp('2020-11-21 00:57:39+0000', tz='UTC'), 81, 0.171], [6, 39, Timestamp('2020-11-20 18:54:04+0000', tz='UTC'), Timestamp('2020-11-21 08:15:06+0000', tz='UTC'), 63, 0.133], [7, 16, Timestamp('2020-11-20 20:02:05+0000', tz='UTC'), Timestamp('2020-11-21 04:34:48+0000', tz='UTC'), 53, 0.128], [8, 25, Timestamp('2020-11-20 21:01:38+0000', tz='UTC'), Timestamp('2020-11-21 09:16:45+0000', tz='UTC'), 60, 0.171], [9, 14, Timestamp('2020-11-20 21:26:06+0000', tz='UTC'), Timestamp('2020-11-21 06:41:53+0000', tz='UTC'), 55, 0.133], [10, 21, Timestamp('2020-11-20 22:21:21+0000', tz='UTC'), Timestamp('2020-11-21 05:10:47+0000', tz='UTC'), 49, 0.14], [11, 3, Timestamp('2020-11-20 23:21:25+0000', tz='UTC'), Timestamp('2020-11-21 09:35:51+0000', tz='UTC'), 60, 0.171], [12, 20, Timestamp('2020-11-21 01:42:22+0000', tz='UTC'), Timestamp('2020-11-21 15:31:21+0000', tz='UTC'), 47, 0.133], [13, 18, Timestamp('2020-11-21 03:37:03+0000', tz='UTC'), Timestamp('2020-11-21 10:06:51+0000', tz='UTC'), 71, 0.171], [14, 7, Timestamp('2020-11-21 03:07:03+0000', tz='UTC'), Timestamp('2020-11-21 06:16:27+0000', tz='UTC'), 53, 0.128], [15, 39, Timestamp('2020-11-21 09:44:54+0000', tz='UTC'), Timestamp('2020-11-21 17:29:58+0000', tz='UTC'), 60, 0.171], [16, 1, Timestamp('2020-11-21 05:09:13+0000', tz='UTC'), Timestamp('2020-11-21 12:51:55+0000', tz='UTC'), 81, 0.171], [17, 16, Timestamp('2020-11-21 06:32:16+0000', tz='UTC'), Timestamp('2020-11-21 11:06:39+0000', tz='UTC'), 71, 0.171], [18, 21, Timestamp('2020-11-21 06:32:24+0000', tz='UTC'), Timestamp('2020-11-21 14:17:22+0000', tz='UTC'), 47, 0.133], [19, 31, Timestamp('2020-11-21 07:55:25+0000', tz='UTC'), Timestamp('2020-11-21 18:15:52+0000', tz='UTC'), 60, 0.171], [20, 15, Timestamp('2020-11-21 09:24:06+0000', tz='UTC'), Timestamp('2020-11-21 16:09:35+0000', tz='UTC'), 37, 0.14], [21, 14, Timestamp('2020-11-21 09:31:00+0000', tz='UTC'), Timestamp('2020-11-21 21:03:58+0000', tz='UTC'), 71, 0.171], [22, 13, Timestamp('2020-11-21 10:27:44+0000', tz='UTC'), Timestamp('2020-11-21 11:38:48+0000', tz='UTC'), 47, 0.133], [23, 4, Timestamp('2020-11-21 10:33:18+0000', tz='UTC'), Timestamp('2020-11-21 22:31:29+0000', tz='UTC'), 60, 0.171], [24, 6, Timestamp('2020-11-21 10:38:05+0000', tz='UTC'), Timestamp('2020-11-21 10:50:28+0000', tz='UTC'), 47, 0.133], [25, 6, Timestamp('2020-11-21 11:20:28+0000', tz='UTC'), Timestamp('2020-11-21 22:57:06+0000', tz='UTC'), 60, 0.171], [26, 11, Timestamp('2020-11-21 11:06:23+0000', tz='UTC'), Timestamp('2020-11-21 22:54:41+0000', tz='UTC'), 45, 0.171], [27, 33, Timestamp('2020-11-21 12:02:34+0000', tz='UTC'), Timestamp('2020-11-21 22:48:44+0000', tz='UTC'), 60, 0.171], [28, 18, Timestamp('2020-11-21 11:43:39+0000', tz='UTC'), Timestamp('2020-11-21 14:38:28+0000', tz='UTC'), 71, 0.171], [29, 16, Timestamp('2020-11-21 12:28:41+0000', tz='UTC'), Timestamp('2020-11-21 15:55:19+0000', tz='UTC'), 53, 0.128], [30, 13, Timestamp('2020-11-21 12:50:57+0000', tz='UTC'), Timestamp('2020-11-22 00:58:16+0000', tz='UTC'), 60, 0.171], [31, 19, Timestamp('2020-11-21 12:55:20+0000', tz='UTC'), Timestamp('2020-11-21 21:22:54+0000', tz='UTC'), 71, 0.171], [32, 7, Timestamp('2020-11-21 13:10:08+0000', tz='UTC'), Timestamp('2020-11-21 22:01:52+0000', tz='UTC'), 47, 0.113], [33, 0, Timestamp('2020-11-21 13:42:36+0000', tz='UTC'), Timestamp('2020-11-22 01:30:22+0000' ...

# %%
with open('dera_yplot-2-40', 'rb') as fp:
    read_yplot = pickle.load(fp)
    
print(read_yplot)
# Out:
# [[767.7423505225764, 769.9511173997921, 769.9511173997921, 769.9511173997921, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 774.751480733794, 776.6896419387301, 778.0504160645198, 778.0504160645198, 781.0970073476243, 781.0970073476243, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 783.9857347442014, 792.8434764493193, 792.8434764493193, 792.8434764493193, 792.8434764493193, 792.8434764493193, 792.8434764493193, 792.8434764493193, 792.8434764493193, 792.8434764493193, 792.8434764493193, 792.8434764493193, 792.8434764493193, 792.9655572602996, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422, 795.9338700591422], [749.2552377497924, 749.2552377497924, 749.2552377497924, 749.2552377497924, 752.7348710708261, 761.2767827994796, 761.3451978674075, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.8139614665344, 763.9281801111056, 764.7307279969289, 764.7307279969289, 766.0718729790291, 766.0718729790291, 766.0718729790291, 772.2162952815872, 773.4001644141573, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 774.2440301757756, 777.9773968848709, 777.9773968848709, 777.9773968848709, 777.9773968848709, 777.9773968848709, 777.9773968848709, 777.9773968848709, 777.9773968848709, 777.9773968848709, 777.9773968848709, 777.9773968848709, 778.1452968033593, 778.5742495209424, 778.5742495209424, 778.5742495209424, 778.5742495209424, 778.5742495209424, 778.5742495209424, 778.5742495209424, 778.5742495209424, 778.5742495209424, 779.5874825974466, 779.5874825974466, 779.9127479771444, 779.9127479771444, 779.9127479771444, 779.9127479771444, 779.9127479771444, 779.9127479771444, 779.9127479771444, 779.9127479771444], [742.2134372952218, 744.1933619603543, 744.1933619603543, 744.1933619603543, 744.1933619603543, 747.0836611770529, 747.0836611770529, 760.8373258511556, 760.8594243378207, 761.7979489552453, 761.7979489552453, 761.7979489552453, 76 ...

# %%
with open('dera_output-2-40', 'rb') as fp:
    read_result = pickle.load(fp)
    print(countFitness(read_result))
    
# print(read_result)
# Out:
# [797.4686828838051, 3948, 48858418.76003823, 28]
